# %%
from google.colab import drive 
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("drive/MyDrive/Cognizant_final_hackathon/topic_7")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-7532cab38c86> in <module>()
#       1 import os
# ----> 2 os.chdir("drive/MyDrive/Cogni_AI/Hackathon_2")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/Cogni_AI/Hackathon_2'

# %%
import pandas as pd
import numpy as np
import nltk
import re

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
def get_simple_pos(tag):
  if tag.startswith('J'):
    return wordnet.ADJ
  elif tag.startswith('V'):
    return wordnet.VERB
  elif tag.startswith('N'):
    return wordnet.NOUN
  elif tag.startswith('R'):
    return wordnet.ADV
  else:
    return wordnet.NOUN

# %%
def to_nltk_format(words):
  final_doc = []
  for index,row in words.iterrows():
    output_list = []
    output_words = []
    words =row['tweet']
    words = words.split()
    for w in words:
      if w.isalpha():
        if w not in stops and len(w)>2:
          output_words.append(w)
    output_list = [output_words] + [row['class']]
    final_doc.append(output_list)
  return final_doc

# %%
def to_prediction_format(words):
  final_doc = []
  for index,row in words.iterrows():
    output_list = []
    output_words = []
    words =row['tweet']
    words = words.split()
    for w in words:
      if w.isalpha():
        if w not in stops and len(w)>2:
          output_words.append(w)
    output_list = output_words
    final_doc.append(output_list)
  return final_doc

# %%
def reg_fun(df_):
  # to list
  tweets = df_.tweet.values
  #to lower
  tweets = [i.lower() for i in tweets]
  # removing handles with @
  tweets_no_handle = [  re.sub("&*@\w+",'',sent) for sent in tweets]
  # removing hashtag
  tweets_clean = [re.sub("#\w+",'',tweet) for tweet in tweets_no_handle]
  # remove urls: 
  tweets_clean = [re.sub("http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|''[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+",'',tweet) for tweet in tweets_clean]
  # remove rt
  #tweets_clean = [re.sub("[(rt :)]",' ',tweet) for tweet in tweets_clean]
  #remove &;
  tweets_clean = [re.sub(":*;*&;*",'',tweet) for tweet in tweets_clean]
  #remove &;
  tweets_clean = [re.sub("[...\"\;\']",'',tweet) for tweet in tweets_clean]
  # to dataframe
  temp = pd.DataFrame(data = tweets_clean, columns=['tweet'])
  df_2 = df_.copy()
  df_2['tweet'] = temp['tweet'] 
  return df_2

# %%
stops = set(stopwords.words('english'))
punctuations =list(string.punctuation)
extra = ['&;',  ':',  'a', "a", 'i', 'rt' , '&;:',"'" , 'if', 'but', 'rt', 'just', 'you','to' , '&;&;', '":'  ,  '.' , '&;&;&;' , ',' , '-'  , 'n', '"' , '...'  , '!' , '2' , '?', '..' , "'" , '&;&;&;&;&;' , '"i' , '|' , '3' , '1' ,'@', '4', "'"]
#stops = stops.append(extra)
stops.update(punctuations)
stops.update(extra) 
#stops.append()
stops.remove('not')
stops

# %%
def rm_train_stopwords(df_):
  dataframe = pd.DataFrame(columns = ['tweet','class'])
  for index,row in df_.iterrows():
    clean_sentence=[]
    tokens = word_tokenize(row['tweet'])      
    for w in tokens:
        w = w.lower()
        if w.isalpha() and len(w)>2:
          if w not in stops:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1])) 
            clean_sentence.append(clean_word)     
    dataframe = dataframe.append({'class':row['class'], 'tweet': ' '.join(clean_sentence)}, ignore_index = True)
  return dataframe

# %%
def rm_test_stopwords(df_):
  dataframe = pd.DataFrame(columns = ['tweet'])
  for index,row in df_.iterrows():
    clean_sentence=[]
    tokens = word_tokenize(row['tweet'])      
    for w in tokens:
      w = w.lower()
      if w.isalpha() and len(w)>2:
        if w not in stops:
          pos = pos_tag([w])
          clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1])) 
          clean_sentence.append(clean_word)     
    dataframe = dataframe.append({'tweet': ' '.join(clean_sentence)}, ignore_index = True)
  return dataframe

# %%
def get_feature_dict(words):
  current_features = {}
  words_set = set(words)
  for w in features:
    current_features[w] = w in words_set
  return current_features

# %%
data = pd.read_csv("hate_speech_train.csv")
test_data = pd.read_csv("personal_twitter_data.csv")
raw_test = pd.read_excel("hate_speech_test.xlsx")

# %%
data.head()
# Out:
#    count  hate_speech  ...  class                                              tweet
# 0      3            1  ...      1  RT @HENNERGIZED: &#128557;&#128557;&#128557;&#...
# 1      3            0  ...      1  We are back bitches! @vnpacheco21 @xoxoclaire_...
# 2      3            0  ...      1  RT @SuperrrrMcNasty: Lmfao , this bitch was gi...
# 3      3            0  ...      1  @bradley_eckman don't say shit like that lil n...
# 4      3            1  ...      1                             Young jezzy dat nigguh
#
# [5 rows x 6 columns]

# %%
test_data.head()
# Out:
#                                                tweet  class
# 0  RT @RedTvvitter: "Does my Mewtwo make your pus...      1
# 1  @kieffer_jason and who said I didn't like myse...      1
# 2                      Get this bitch off my TV bruh      1
# 3                    Lmfao bitch got her shit rocked      1
# 4  Verizon customer service is trash as fuck. I'v...      1

# %%
raw_test.head()
# Out:
#    class                                              tweet
# 0    NaN  RT @RedTvvitter: "Does my Mewtwo make your pus...
# 1    NaN  @kieffer_jason and who said I didn't like myse...
# 2    NaN                      Get this bitch off my TV bruh
# 3    NaN                    Lmfao bitch got her shit rocked
# 4    NaN  Verizon customer service is trash as fuck. I'v...

# %%
print("data: {}".format(data.shape))
print("labelled: {}".format(test_data.shape))
print("test: {}".format(raw_test.shape))
# Out:
# data: (19826, 6)
# labelled: (4957, 2)
# test: (4957, 2)

# %%
print('train:{}'.format(data.isnull().sum()))
# Out:
# train:count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
print('git:{}'.format(test_data.isnull().sum()))
# Out:
# git:tweet    0
# class    0
# dtype: int64

# %%
print('test:{}'.format(raw_test.isnull().sum()))
# Out:
# test:class    4957
# tweet       0
# dtype: int64

# %%
test = raw_test.drop('class', axis=1)
#test = raw_test

# %%
test.head()
# Out:
#                                                tweet
# 0  RT @RedTvvitter: "Does my Mewtwo make your pus...
# 1  @kieffer_jason and who said I didn't like myse...
# 2                      Get this bitch off my TV bruh
# 3                    Lmfao bitch got her shit rocked
# 4  Verizon customer service is trash as fuck. I'v...

# %%
df = pd.DataFrame(data = data[['tweet','class']], columns = ['tweet','class'])

# %%
df.head()
# Out:
#                                                tweet  class
# 0  RT @HENNERGIZED: &#128557;&#128557;&#128557;&#...      1
# 1  We are back bitches! @vnpacheco21 @xoxoclaire_...      1
# 2  RT @SuperrrrMcNasty: Lmfao , this bitch was gi...      1
# 3  @bradley_eckman don't say shit like that lil n...      1
# 4                             Young jezzy dat nigguh      1

# %%
df.tweet.values
# Out:
# array(['RT @HENNERGIZED: &#128557;&#128557;&#128557;&#8220;@StopBeingSober: Yall say "Why you dating lil girls" like mature hoes just on a rampage outside.&#8221;',
#        'We are back bitches! @vnpacheco21 @xoxoclaire_ @treyhunter_ @Medgmon @delaney_jade @sean_steezy @alexistiefa',
#        'RT @SuperrrrMcNasty: Lmfao , this bitch was giving head in the back of a classroom she better go tf ahead !',
#        ...,
#        'RT @FunnyOGtweets: When rednecks fool around with the aux cord http://t.co/Tyzuro7qR5',
#        "@PaulMoon8 @yurista4life @justinmiculka01 you fuckin Yankees I'll be there in 2 months I'll meet you pussy",
#        "RT @liyyy_: yall females really be cool with cuffin hoe ass niggas &#128514; nope. couldn't be me."],
#       dtype=object)

# %%
df_2 = reg_fun(df)
df_t = reg_fun(test_data)
df_test = reg_fun(test)
df_2.head()
# Out:
#                                                tweet  class
# 0  rt : : yall say why you dating lil girls like ...      1
# 1                        we are back bitches!             1
# 2  rt : lmfao , this bitch was giving head in the...      1
# 3   dont say shit like that lil nig  or ill give ...      1
# 4                             young jezzy dat nigguh      1

# %%
df_t.head()
# Out:
#                                                tweet  class
# 0          rt : does my mewtwo make your pussy wet?       1
# 1   and who said i didnt like myself where the fu...      1
# 2                      get this bitch off my tv bruh      1
# 3                    lmfao bitch got her shit rocked      1
# 4  verizon customer service is trash as fuck ive ...      1

# %%
df_test.head()
# Out:
#                                                tweet
# 0          rt : does my mewtwo make your pussy wet?
# 1   and who said i didnt like myself where the fu...
# 2                      get this bitch off my tv bruh
# 3                    lmfao bitch got her shit rocked
# 4  verizon customer service is trash as fuck ive ...

# %%
#dataframe = rm_train_stopwords(df_2)
#dataframe_t = rm_train_stopwords(df_t)
#dataframe_test = rm_test_stopwords(df_test)

dataframe = df_2
dataframe_t = df_t
dataframe_test = df_test

# %%
dataframe.head(10)
# Out:
#                                                tweet  class
# 0  rt : : yall say why you dating lil girls like ...      1
# 1                        we are back bitches!             1
# 2  rt : lmfao , this bitch was giving head in the...      1
# 3   dont say shit like that lil nig  or ill give ...      1
# 4                             young jezzy dat nigguh      1
# 5  same shit rt : but your bm tho?  : if my ex wa...      1
# 6                   rt : so cute! :) rt : shy bunny       2
# 7  this bitch always got shit to say about what o...      1
# 8  rt : i just wanna pimp these hoe$ amp ride rarris      1
# 9             i heard them same pussy niggas hatin !      1

# %%
dataframe_t.head()
# Out:
#                                                tweet  class
# 0          rt : does my mewtwo make your pussy wet?       1
# 1   and who said i didnt like myself where the fu...      1
# 2                      get this bitch off my tv bruh      1
# 3                    lmfao bitch got her shit rocked      1
# 4  verizon customer service is trash as fuck ive ...      1

# %%
dataframe_test.head()
# Out:
#                                                tweet
# 0          rt : does my mewtwo make your pussy wet?
# 1   and who said i didnt like myself where the fu...
# 2                      get this bitch off my tv bruh
# 3                    lmfao bitch got her shit rocked
# 4  verizon customer service is trash as fuck ive ...

# %%
def basic_clean(text):
  """
  Function to clean up the data. All the words that
  are not designated as a stop word is then lemmatized after
  encoding and basic regex parsing are performed.
  """
  words = text.split()
  return [word for word in words ]

# %%
#words = basic_clean(str(dataframe['tweet'].tolist()))

# %%
#(pd.Series(nltk.ngrams(words, 3)).value_counts())[:10]
# Out:
# ('hoe, aint, loyal',)      28
# (bitch, as, nigga)         28
# (bitch, look, like)        23
# (stupid, as, bitch)        17
# (as, bitch, aint)          17
# (park, slope, top)         16
# (slope, top, rat)          16
# (top, rat, spa',)          16
# ('best, asian, massage)    16
# (bitch, thing, like',)     15
# dtype: int64

# %%
#(pd.Series(nltk.ngrams(words, 2)).value_counts())[:100]
# Out:
# (look, like)     194
# (bitch, get)     176
# (bad, bitch)     152
# (like, bitch)    144
# (bitch, as)      134
#                 ...
# (talk, bout)      31
# (bitch, try)      31
# (fuck, nigga)     30
# (side, bitch)     30
# (bitch, gon)      30
# Length: 100, dtype: int64

# %%
#flag = (look, like) in 'hey look like'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-f3c4cce1ba38> in <module>()
# ----> 1 flag = (look, like) in 'hey look like'
#
# NameError: name 'look' is not defined

# %%
documents = to_nltk_format(dataframe)
documents_t = to_nltk_format(dataframe_t)
documents_test = to_prediction_format(dataframe_test)

# %%
documents
# Out:
# [[['yall',
#    'say',
#    'dating',
#    'lil',
#    'girls',
#    'like',
#    'mature',
#    'hoes',
#    'rampage',
#    'outside'],
#   1],
#  [['back'], 1],
#  [['lmfao', 'bitch', 'giving', 'head', 'back', 'classroom', 'better', 'ahead'],
#   1],
#  [['dont', 'say', 'shit', 'like', 'lil', 'nig', 'ill', 'give', 'stamp'], 1],
#  [['young', 'jezzy', 'dat', 'nigguh'], 1],
#  [['shit', 'wanna', 'fuck', 'may', 'god', 'aint', 'hoe'], 1],
#  [['shy', 'bunny'], 2],
#  [['bitch', 'always', 'got', 'shit', 'say', 'people', 'like'], 1],
#  [['wanna', 'pimp', 'amp', 'ride', 'rarris'], 1],
#  [['heard', 'pussy', 'niggas', 'hatin'], 1],
#  [['inmate', 'sums', 'return', 'means'], 2],
#  [['want', 'ian', 'trippin', 'hoes'], 1],
#  [['yall',
#    'men',
#    'need',
#    'watch',
#    'cream',
#    'pies',
#    'bitches',
#    'yeast',
#    'infections',
#    'amp',
#    'day',
#    'monistat',
#    'treatment',
#    'know',
#    'difference'],
#   1],
#  [['gradeschool',
#    'dance',
#    'tried',
#    'worm',
#    'impress',
#    'bitch',
#    'slammed',
#    'dick',
#    'unforgiving',
#    'ceramic'],
#   1],
#  [['perhaps',
#    'not',
#    'diehard',
#    'yankee',
#    'theres',
#    'point',
#    'watching',
#    'debacle',
#    'else',
#    'lol'],
#   2],
#  [['homie', 'reallly', 'love', 'fat', 'bitches', 'like', 'love'], 1],
#  [['orr', 'thts', 'lor', 'bae', 'tho', 'wyd', 'fucking'], 1],
#  [['time', 'bounce', 'bronx'], 2],
#  [['bitches',
#    'rather',
#    'petty',
#    'hoes',
#    'instead',
#    'posting',
#    'bail',
#    'really',
#    'fck',
#    'uppsa'],
#   1],
#  [['pissed', 'lad', 'past', 'would', 'lick', 'dirty', 'soles', 'slept'], 2],
#  [['jealous', 'bitches', 'smh'], 1],
#  [['pussy'], 1],
#  [['fuck', 'outta', 'faggot', 'wouldnt', 'even', 'fair'], 0],
#  [['wish', 'got', 'hoes', 'like', 'james', 'bond'], 1],
#  [['pick',
#    'president',
#    'uncle',
#    'tom',
#    'association',
#    'would',
#    'pick',
#    'larry',
#    'elder'],
#   2],
#  [['bitches', 'dont', 'want', 'boyfriend', 'want', 'pimp'], 1],
#  [['fuk', 'dat', 'bitch', 'lol', 'voice'], 1],
#  [['someone',
#    'tell',
#    'dreads',
#    'part',
#    'uniform',
#    'pull',
#    'hair',
#    'trash',
#    'cut',
#    'doodoo',
#    'braids'],
#   2],
#  [['appropriately', 'guy', 'wears', 'yellow', 'rick', 'james', 'face'], 2],
#  [['good', 'riddance', 'bitches'], 1],
#  [['pirates', 'made', 'playoffs', 'yankees', 'outhell', 'frozen'], 2],
#  [['swear',
#    'needa',
#    'back',
#    'old',
#    'bitches',
#    'think',
#    'game',
#    'apparently',
#    'lets',
#    'real'],
#   1],
#  [['naw', 'bryan', 'said', 'trash', 'hotel', 'staying', 'somewhere', 'else'],
#   2],
#  [['fuck', 'yaw', 'sayin', 'bitch', 'hood', 'love'], 1],
#  [['fucking', 'gook'], 0],
#  [['night', 'cap', 'nonsense'], 2],
#  [['facebook', 'needs'], 1],
#  [['cause', 'bitch', 'tae'], 1],
#  [['kirk', 'aint', 'nothing', 'bitch', 'amphiphop'], 1],
#  [['niggas', 'sleepin', 'bitches', 'lmfao', 'maury', 'fake'], 0],
#  [['cant', 'bomb', 'single', 'bitches', 'available'], 1],
#  [['swear', 'god', 'bitch', 'bouta', 'delete', 'twitter', 'account'], 1],
#  [['bitch', 'choosinh', 'letr'], 1],
#  [['cant', 'hoe', 'saying', 'another', 'girls', 'hoe', 'cancels'], 1],
#  [['hoes', 'fucking', 'dick', 'turn', 'lol', 'fuckem'], 1],
#  [['tall', 'tee', 'sum', 'slouch', 'shoes', 'couldve', 'fucc', 'bitch'], 1],
#  [['bitch', 'mouth', 'made', 'honor', 'roll'], 1],
#  [['someone',
#    'recently',
#    'told',
#    'local',
#    'yokel',
#    'going',
#    'use',
#    'twitter',
#    'account',
#    'damage',
#    'yeah'],
#   2],
#  [['aint', 'mad', 'thats', 'hoes'], 1],
#  [['charlie', 'mountain', 'top', 'music', 'fest'], 2],
#  [['bae',
#    'always',
#    'bae',
#    'even',
#    'bae',
#    'not',
#    'thats',
#    'still',
#    'bae',
#    'therefore',
#    'hoes',
#    'move',
#    'around',
#    'please'],
#   1],
#  [[], 1],
#  [['american', 'version', 'trash'], 2],
#  [['hit', 'bitch'], 1],
#  [['weve', 'used', 'word', 'cunt', 'almost', 'times', 'beautiful'], 1],
#  [['two', 'months', 'tho', 'hoe'], 1],
#  [['nigga',
#    'lol',
#    'idk',
#    'elway',
#    'trying',
#    'snatch',
#    'come',
#    'redskins',
#    'shitttt',
#    'sign',
#    'revis',
#    'idk',
#    'want',
#    'lls'],
#   1],
#  [['like', 'queer', 'cmon', 'jen', 'even', 'need', 'ask'], 1],
#  [['since', 'hoes', 'wanna', 'childish'], 1],
#  [['nah',
#    'aint',
#    'hoe',
#    'niggah',
#    'bitch',
#    'niggah',
#    'rich',
#    'niggah',
#    'shits',
#    'niggah',
#    'getchu',
#    'chipped',
#    'niggah'],
#   1],
#  [['see', 'tweets', 'lmfao', 'von', 'kick', 'curb', 'call', 'curse', 'ass'],
#   1],
#  [['thats', 'logic', 'hoe', 'single', 'nobody', 'tell'], 1],
#  [['apparently',
#    'little',
#    'pussy',
#    'cant',
#    'converse',
#    'nevermind',
#    'fight',
#    'ive',
#    'blocked',
#    'well',
#    'youth',
#    'gets',
#    'frustrated',
#    'easy'],
#   1],
#  [['shouldnt',
#    'club',
#    'done',
#    'club',
#    'saw',
#    'bitches',
#    'reject',
#    'dance',
#    'man'],
#   1],
#  [['bitch', 'plz', 'whatever'], 1],
#  [['sore',
#    'loser',
#    'charlie',
#    'crist',
#    'wont',
#    'give',
#    'concession',
#    'calls',
#    'recount'],
#   2],
#  [['way',
#    'dude',
#    'fat',
#    'diet',
#    'twinkies',
#    'breakfast',
#    'tacos',
#    'miss',
#    'breakfast',
#    'tacos'],
#   2],
#  [['texans', 'wont', 'play', 'redskins', 'year'], 2],
#  [['bitch', 'took', 'phone'], 1],
#  [['yall', 'defense', 'trash'], 2],
#  [['male',
#    'rap',
#    'artist',
#    'not',
#    'talking',
#    'bitches',
#    'drugs',
#    'niggas',
#    'dont',
#    'wanna',
#    'hear',
#    'shit'],
#   1],
#  [['dont', 'mind', 'retarded', 'ass'], 1],
#  [['smoke', 'sum', 'bitch'], 1],
#  [['god',
#    'bless',
#    'delusional',
#    'bitches',
#    'still',
#    'trying',
#    'keep',
#    'duck',
#    'face',
#    'alive'],
#   1],
#  [['flex',
#    'aint',
#    'turning',
#    'take',
#    'bitch',
#    'fly',
#    'town',
#    'macin',
#    'stackin',
#    'ready',
#    'get',
#    'crackin',
#    'aint'],
#   1],
#  [['pie', 'crust', 'trash', 'flaky', 'dry', 'shit'], 1],
#  [['fuckin', 'rent', 'lame', 'hoe'], 1],
#  [['right', 'pussy'], 1],
#  [['bitch', 'shut', 'hand', 'flowers', 'light', 'change'], 1],
#  [['colored', 'contacts'], 2],
#  [['aint', 'hoe', 'get', 'trap'], 1],
#  [['suckin', 'cuz', 'pretty', 'bitch'], 1],
#  [['used',
#    'dollar',
#    'menu',
#    'amp',
#    'spectate',
#    'mall',
#    'buying',
#    'bitch',
#    'cause',
#    'shit',
#    'want'],
#   1],
#  [['hey', 'bitchadam', 'showed', 'upbring', 'beer'], 1],
#  [['dont',
#    'get',
#    'twisted',
#    'said',
#    'aint',
#    'playin',
#    'state',
#    'mind',
#    'bitches',
#    'around'],
#   1],
#  [['side',
#    'bitch',
#    'main',
#    'bitch',
#    'cause',
#    'main',
#    'bitch',
#    'aint',
#    'feelin',
#    'moe'],
#   1],
#  [['hick', 'accent', 'comes', 'get', 'around', 'family'], 2],
#  [['could', 'brownie', 'right'], 2],
#  [['ill',
#    'pay',
#    'yall',
#    'niggas',
#    'get',
#    'much',
#    'yall',
#    'hoe',
#    'niggas',
#    'gunna',
#    'cost'],
#   1],
#  [['drinking', 'away', 'stress', 'got', 'new', 'hoes'], 1],
#  [['mary', 'isnt', 'backstabbing', 'bitch', 'lies', 'deceives'], 1],
#  [['stupid', 'bitch', 'apparently'], 1],
#  [['fucking', 'douche', 'bro', 'youre', 'fag'], 1],
#  [['dont', 'bitch', 'someone', 'bitch'], 1],
#  [['touched', 'pussy'], 1],
#  [['dad', 'brought', 'home', 'watermelon', 'dont', 'like', 'going', 'trash'],
#   2],
#  [['nigga', 'fuckin', 'faggot'], 0],
#  [['please', 'youre', 'pussy'], 1],
#  [['wonder',
#    'latino',
#    'strategy',
#    'goper',
#    'doubles',
#    'wetbacks',
#    'backpedals',
#    'shoot',
#    'sight'],
#   0],
#  [['fugly', 'queer', 'white', 'trash'], 0],
#  [['girls',
#    'still',
#    'virgins',
#    'got',
#    'months',
#    'live',
#    'bitch',
#    'better',
#    'throw',
#    'ass',
#    'back'],
#   1],
#  [['scared',
#    'orientationi',
#    'hate',
#    'meetin',
#    'new',
#    'peopletheyre',
#    'gonna',
#    'think',
#    'quiet',
#    'girl',
#    'really',
#    'craziest',
#    'bitch',
#    'theyll',
#    'ever',
#    'meet'],
#   1],
#  [['shit', 'baltimore', 'man', 'hoes', 'fine', 'amp', 'crazy'], 1],
#  [['playing', 'tonight', 'not', 'friends'], 2],
#  [['eat', 'lot', 'protein', 'eat', 'lot', 'pussy', 'eat', 'whole', 'ass'], 1],
#  [['yer', 'gonna', 'continue', 'contrarian', 'bitch', 'die', 'ive', 'time'],
#   0],
#  [['ronny', 'kamm', 'pussy'], 1],
#  [['chris', 'faggot'], 1],
#  [['lmao', 'dad', 'raised', 'bitch', 'made', 'nigga'], 0],
#  [['talking',
#    'hate',
#    'men',
#    'done',
#    'penis',
#    'get',
#    'manly',
#    'looking',
#    'chick',
#    'uses',
#    'strap',
#    'bitch',
#    'stfu'],
#   1],
#  [['nigga',
#    'santa',
#    'come',
#    'hood',
#    'niggas',
#    'gonna',
#    'rob',
#    'sleigh',
#    'hoes'],
#   1],
#  [['didnt', 'get', 'write', 'thank', 'god', 'lol', 'dumb', 'white', 'bitch'],
#   1],
#  [['personality',
#    'fat',
#    'bitches',
#    'relationships',
#    'pretty',
#    'lets',
#    'see',
#    'answers',
#    'lol'],
#   1],
#  [['time',
#    'year',
#    'lightskin',
#    'hoes',
#    'swore',
#    'brown',
#    'cuz',
#    'summer',
#    'tan',
#    'come',
#    'back'],
#   1],
#  [['one', 'time', 'band', 'stuck', 'flute', 'pussy', 'springs'], 1],
#  [['iont', 'got', 'typebad', 'bitches', 'thing', 'like'], 1],
#  [['put', 'touch', 'mix'], 2],
#  [['niggas', 'send', 'hate', 'thru', 'bitches'], 1],
#  [['ghetto', 'ass', 'bands', 'gets'], 1],
#  [['not',
#    'animal',
#    'crackers',
#    'want',
#    'animal',
#    'crackers',
#    'shaped',
#    'like',
#    'master',
#    'chiefs',
#    'trolls',
#    'guns',
#    'thatd',
#    'rule'],
#   1],
#  [['friday'], 1],
#  [['tyler',
#    'creator',
#    'said',
#    'rape',
#    'pregnant',
#    'bitch',
#    'tell',
#    'friends',
#    'threesome'],
#   1],
#  [['idc', 'none', 'bitches'], 1],
#  [['awkward', 'moment', 'hoe', 'says', 'shes', 'not', 'hoe'], 1],
#  [['lemme', 'throw', 'hows'], 2],
#  [['one', 'mans', 'trash', 'another', 'mans', 'wife'], 2],
#  [['reading',
#    'sexual',
#    'assault',
#    'case',
#    'takes',
#    'back',
#    'collegeill',
#    'never',
#    'forget',
#    'walk',
#    'would',
#    'say',
#    'dont',
#    'run',
#    'trains',
#    'hoesstraight',
#    'trouble'],
#   1],
#  [['cant', 'fuck', 'sentimental', 'bitches'], 1],
#  [['ant', 'pussy', 'dont', 'make', 'pull'], 1],
#  [['really', 'thou', 'looking', 'like', 'hulk', 'hogan', 'bitch'], 1],
#  [['lmfao', 'putting', 'twitter', 'see', 'fat', 'bitch'], 1],
#  [['fuck',
#    'cock',
#    'sucker',
#    'hulk',
#    'hogan',
#    'put',
#    'camel',
#    'clutch',
#    'fuck',
#    'ass',
#    'make',
#    'humble'],
#   1],
#  [['glad',
#    'bey',
#    'shitnow',
#    'bitches',
#    'wit',
#    'one',
#    'shaved',
#    'side',
#    'ahead',
#    'amp',
#    'shave',
#    'side'],
#   1],
#  [['want', 'clams', 'half', 'shell'], 2],
#  [['fag'], 0],
#  [['woman',
#    'take',
#    'serious',
#    'youre',
#    'mean',
#    'nigga',
#    'take',
#    'serious',
#    'youre',
#    'lol',
#    'like'],
#   1],
#  [['bitch', 'anyway'], 1],
#  [['crafty', 'bitches', 'best', 'way', 'cheat', 'test'], 1],
#  [['cunt'], 1],
#  [['hoe', 'tripppped', 'people', 'wildin'], 1],
#  [['fugly', 'bitch', 'john', 'dump', 'ratchet', 'ass'], 1],
#  [['lmaoo', 'bad', 'hit', 'matching', 'bad', 'matching'], 1],
#  [['blacks', 'typical', 'niggers'], 0],
#  [['bitch', 'got', 'zero', 'kills', 'yet', 'got', 'legendary', 'absolute'], 1],
#  [['little', 'bitch', 'cuz', 'feeling'], 1],
#  [['amp', 'xavier', 'bitch'], 1],
#  [['shoot', 'shorty', 'bitch'], 1],
#  [['facebook', 'fags'], 1],
#  [['big', 'night'], 2],
#  [['show',
#    'last',
#    'night',
#    'badass',
#    'thanks',
#    'everyone',
#    'came',
#    'didnt',
#    'come',
#    'youre',
#    'retard',
#    'unless',
#    'cock',
#    'sparrer'],
#   1],
#  [['thats',
#    'not',
#    'even',
#    'real',
#    'must',
#    'hit',
#    'blunt',
#    'started',
#    'making',
#    'shit',
#    'nigger',
#    'ass',
#    'lol'],
#   0],
#  [['grade', 'pussy'], 1],
#  [['bitch', 'called', 'bougie', 'whore', 'angry', 'lmao'], 1],
#  [['one', 'biggest', 'arrests', 'gotta', 'act', 'like'], 1],
#  [['boys',
#    'faith',
#    'bitch',
#    'shut',
#    'youre',
#    'high',
#    'school',
#    'acting',
#    'like',
#    'going',
#    'person',
#    'marry'],
#   1],
#  [['yall',
#    'saw',
#    'mad',
#    'little',
#    'chunky',
#    'boy',
#    'wouldnt',
#    'even',
#    'let',
#    'dad',
#    'touch',
#    'bruh',
#    'lmao'],
#   2],
#  [['okay',
#    'know',
#    'like',
#    'ten',
#    'years',
#    'late',
#    'freaking',
#    'hate',
#    'ana',
#    'sofia',
#    'lost',
#    'fuck',
#    'dumb',
#    'bitch',
#    'wtf',
#    'problem'],
#   1],
#  [['sitting', 'pretty', 'makes', 'bitches', 'mad', 'pretty', 'much'], 1],
#  [['sharkeishad',
#    'lose',
#    'ones',
#    'face',
#    'due',
#    'brute',
#    'force',
#    'knockout',
#    'punch',
#    'dat',
#    'bitch',
#    'got',
#    'sharkeishad'],
#   1],
#  [['swore', 'school', 'bitch', 'open', 'home'], 1],
#  [['irritating',
#    'reading',
#    'ppl',
#    'bitch',
#    'abt',
#    'yet',
#    'offer',
#    'shit',
#    'evidence',
#    'even',
#    'support',
#    'slant',
#    'simply',
#    'complaining',
#    'easy',
#    'part'],
#   1],
#  [['ass',
#    'slapping',
#    'one',
#    'greatest',
#    'things',
#    'haha',
#    'slapped',
#    'girl',
#    'ass',
#    'got',
#    'mad',
#    'aint',
#    'get',
#    'pussy',
#    'week'],
#   1],
#  [['marilyn', 'monroe', 'set', 'standard', 'hoes', 'achieve', 'society'], 1],
#  [['bitch', 'official', 'dick', 'harder', 'missile'], 1],
#  [['sent', 'bitch', 'smiley', 'bitches', 'love', 'smiley', 'faces'], 1],
#  [['grandmas',
#    'always',
#    'asking',
#    'noi',
#    'got',
#    'hoes',
#    'mean',
#    'real',
#    'shit'],
#   1],
#  [['fag', 'back'], 1],
#  [['aint',
#    'fenna',
#    'locked',
#    'hours',
#    'day',
#    'beating',
#    'dick',
#    'guilty',
#    'fucking',
#    'free',
#    'world',
#    'pussy'],
#   1],
#  [['cannot', 'worried', 'bout', 'bitch'], 1],
#  [['hate', 'wcw', 'ass', 'bitches'], 1],
#  [['looking',
#    'like',
#    'hillbilly',
#    'not',
#    'matching',
#    'best',
#    'goodnight',
#    'losers'],
#   0],
#  [['wrong',
#    'laughin',
#    'dem',
#    'niccas',
#    'cryin',
#    'interrogation',
#    'roomhell',
#    'noooopussy',
#    'ass'],
#   1],
#  [['side', 'bitch', 'made'], 1],
#  [['country', 'bumpkin', 'word', 'day', 'yokel'], 2],
#  [['sense', 'humor', 'back', 'backs', 'lil', 'bitch'], 1],
#  [['nigga',
#    'beat',
#    'ass',
#    'bitch',
#    'weve',
#    'never',
#    'even',
#    'fought',
#    'need',
#    'stop',
#    'making',
#    'shit',
#    'bring',
#    'ass'],
#   1],
#  [['people', 'site', 'fucking', 'retarded', 'sometimes'], 0],
#  [['bitch', 'got', 'acting', 'crazy', 'hell', 'lately'], 1],
#  [['music', 'suggestion', 'lil', 'spook'], 2],
#  [['girl', 'bring', 'hoes', 'trying', 'get', 'know'], 1],
#  [['got', 'hoes', 'got', 'hoes', 'got', 'hoes', 'got', 'hoes'], 1],
#  [['going', 'kill', 'dont', 'killin', 'hoes'], 1],
#  [['get', 'shit', 'hoe'], 1],
#  [['reports',
#    'say',
#    'female',
#    'victim',
#    'shot',
#    'waiting',
#    'oreo',
#    'mcflurry'],
#   2],
#  [['really', 'tired', 'constant', 'bitch', 'face'], 1],
#  [['funny',
#    'read',
#    'retard',
#    'liberal',
#    'tweets',
#    'anand',
#    'didnt',
#    'delete',
#    'salwar',
#    'tweet',
#    'anyway',
#    'say'],
#   1],
#  [['sources', 'confirmed', 'iggy', 'concert', 'last', 'night', 'trash'], 2],
#  [['cants', 'even', 'fool', 'colored', 'man', 'wit', 'dis', 'bullshit'], 1],
#  [['ride', 'nigga', 'whole', 'life', 'new', 'pussy', 'fuck', 'one', 'night'],
#   1],
#  [['fat',
#    'ass',
#    'inbred',
#    'rednecks',
#    'like',
#    'paula',
#    'deen',
#    'breed',
#    'going',
#    'extinct',
#    'mean',
#    'look',
#    'would',
#    'hate',
#    'scale'],
#   0],
#  [['wills',
#    'tweets',
#    'scream',
#    'look',
#    'pansy',
#    'ass',
#    'bitch',
#    'like',
#    'days',
#    'week'],
#   1],
#  [['got', 'like', 'hoes', 'low', 'pro'], 1],
#  [['shout',
#    'bitches',
#    'dont',
#    'dress',
#    'half',
#    'naked',
#    'get',
#    'mans',
#    'attention',
#    'stay'],
#   1],
#  [[], 1],
#  [['thick', 'bitch', 'tried', 'front', 'earlier'], 1],
#  [['gots',
#    'bet',
#    'msnbc',
#    'wit',
#    'dat',
#    'colored',
#    'reverend',
#    'listen',
#    'coloreds',
#    'else'],
#   0],
#  [['pickin', 'white', 'bitches', 'bare', 'like', 'chicken', 'leg'], 1],
#  [['poppy', 'give', 'discou', 'bitch', 'get'], 1],
#  [['boyfriend', 'tells', 'hoes', 'real', 'ass', 'dude'], 1],
#  [['didnt', 'know', 'alberta', 'brampton', 'bitches'], 1],
#  [['yall', 'hoes', 'nasty', 'letting', 'body', 'hit', 'eat', 'yall', 'smh'],
#   1],
#  [['got', 'bitch', 'haymon', 'antonio', 'tarver'], 1],
#  [['catch', 'lingo', 'itty', 'bitty', 'bitch'], 1],
#  [['eager',
#    'hoe',
#    'didnt',
#    'even',
#    'read',
#    'twitpic',
#    'selfie',
#    'wearing',
#    'leotard'],
#   1],
#  [['dont', 'cat', 'youre', 'big', 'pussy'], 1],
#  [['entertain',
#    'flirtin',
#    'ass',
#    'niggah',
#    'want',
#    'thats',
#    'gon',
#    'niggah',
#    'friendly',
#    'ass'],
#   1],
#  [['one', 'best', 'time', 'anybody', 'seen', 'believe', 'hes', 'dressed'], 1],
#  [['pull', 'make', 'bitch', 'mad'], 1],
#  [['purple', 'headed', 'cunt'], 1],
#  [['bitch', 'died', 'read'], 1],
#  [['ever', 'randomly', 'woke', 'bitch', 'standing', 'staring'], 1],
#  [['sorry', 'came', 'pussy', 'like', 'wrecking', 'ball'], 1],
#  [['nigga', 'future', 'always', 'hoes'], 1],
#  [['ask',
#    'every',
#    'bitch',
#    'gay',
#    'not',
#    'sexual',
#    'wtf',
#    'dont',
#    'mind',
#    'asking'],
#   1],
#  [['jason',
#    'admitted',
#    'youre',
#    'stuck',
#    'bitch',
#    'think',
#    'youre',
#    'much',
#    'better',
#    'naaaaa'],
#   0],
#  [['bravoquality', 'trash'], 2],
#  [['bad', 'bitch', 'knows', 'carsgtgtgt'], 1],
#  [['damn',
#    'sick',
#    'damn',
#    'lie',
#    'smfhskinny',
#    'girls',
#    'look',
#    'like',
#    'iphones',
#    'jeans',
#    'come',
#    'bitch',
#    'stop'],
#   1],
#  [['tell', 'baddest', 'hoes', 'beat', 'unless', 'gone', 'strip'], 1],
#  [['bitches', 'gone', 'wat', 'bitches'], 1],
#  [['imma', 'get', 'crew', 'dis', 'fuckin', 'fag', 'real', 'talk', 'nigga'], 1],
#  [['fucking',
#    'ignorant',
#    'talk',
#    'lot',
#    'shit',
#    'someone',
#    'dont',
#    'wanna',
#    'fight',
#    'mama',
#    'raised',
#    'bitch'],
#   1],
#  [['impress',
#    'young',
#    'white',
#    'girl',
#    'next',
#    'doe',
#    'taking',
#    'giant',
#    'negro',
#    'thang',
#    'usin',
#    'flip',
#    'hamburgers'],
#   1],
#  [['last',
#    'time',
#    'wore',
#    'shirt',
#    'wearing',
#    'today',
#    'fought',
#    'bitch',
#    'ratchet',
#    'yanked',
#    'fuck',
#    'outta',
#    'shirt'],
#   1],
#  [['get', 'two', 'birds', 'stoned', 'one', 'time'], 2],
#  [['cant',
#    'get',
#    'smoke',
#    'unless',
#    'bitch',
#    'struggles',
#    'girl',
#    'doesnt',
#    'actuality',
#    'great',
#    'thing'],
#   1],
#  [['crazy',
#    'female',
#    'wrong',
#    'shes',
#    'every',
#    'type',
#    'hoe',
#    'guy',
#    'theres',
#    'justific'],
#   2],
#  [['hes', 'clue'], 1],
#  [['officially', 'fucking', 'retarded'], 0],
#  [['girls',
#    'going',
#    'school',
#    'kind',
#    'aquatic',
#    'colored',
#    'weaves',
#    'headfuck',
#    'going'],
#   1],
#  [['school', 'flow', 'dumb', 'hoe'], 1],
#  [['swear', 'care', 'bout', 'everything', 'bitches'], 1],
#  [['jennas', 'faggot'], 0],
#  [['species',
#    'birds',
#    'reported',
#    'chesterfield',
#    'great',
#    'backyard',
#    'bird',
#    'count',
#    'many'],
#   2],
#  [['news', 'bitch', 'cook'], 1],
#  [['new', 'way', 'look', 'find', 'trash'], 2],
#  [['fresh',
#    'jail',
#    'got',
#    'chopper',
#    'bitches',
#    'like',
#    'vick',
#    'number',
#    'like',
#    'whopper'],
#   1],
#  [['bitch', 'see', 'katy', 'perry', 'pic', 'katy', 'perry', 'fit'], 1],
#  [['mud', 'shark', 'black', 'friends', 'makes', 'perfect', 'sense'], 2],
#  [['follow', 'back', 'bitch'], 1],
#  [['dont', 'trust', 'niggas', 'bitches'], 1],
#  [['leave', 'nicca', 'traumatized'], 1],
#  [['good',
#    'morning',
#    'lightskin',
#    'dyke',
#    'bitches',
#    'steven',
#    'segal',
#    'ponytails'],
#   0],
#  [['run', 'dick', 'inside', 'pussy', 'straight', 'dudes', 'know', 'dick'], 1],
#  [['feel', 'like', 'swag', 'fag', 'shirt', 'lmao'], 1],
#  [['great',
#    'loser',
#    'amp',
#    'coward',
#    'grabbed',
#    'iphone',
#    'threw',
#    'street',
#    'hes',
#    'pussy'],
#   1],
#  [['dear', 'von', 'karmas', 'bitch'], 1],
#  [['two', 'bad', 'bitches', 'giving', 'head', 'dam', 'time', 'lol', 'aww'], 1],
#  [['bitches'], 1],
#  [['exactly',
#    'tweet',
#    'shit',
#    'fuck',
#    'dont',
#    'like',
#    'everybody',
#    'aint',
#    'monkey',
#    'see',
#    'monkey',
#    'koiya'],
#   1],
#  [['aint',
#    'nothin',
#    'piece',
#    'cheese',
#    'corners',
#    'words',
#    'aint',
#    'never',
#    'gone',
#    'slice',
#    'bitch'],
#   1],
#  [['youre', 'faggotyoure', 'texas', 'fan'], 0],
#  [['bitches', 'came', 'wit'], 1],
#  [['shit',
#    'using',
#    'linkedin',
#    'work',
#    'lmfaoo',
#    'bagging',
#    'linkiden',
#    'hoes',
#    'lol'],
#   1],
#  [['people', 'ghetto', 'rising', 'fighting', 'back', 'whose', 'side'], 2],
#  [['bih', 'stay', 'ghetto', 'ass', 'neighborhood'], 1],
#  [['youre',
#    'killin',
#    'not',
#    'conservatives',
#    'like',
#    'not',
#    'nbp',
#    'hate',
#    'honkies'],
#   1],
#  [['kush', 'god', 'bitch'], 1],
#  [['pass', 'sticks'], 1],
#  [['trash',
#    'guess',
#    'got',
#    'tired',
#    'chalmers',
#    'trash',
#    'starting',
#    'chalmers',
#    'lose',
#    'job',
#    'norris',
#    'lmfaoooo'],
#   1],
#  [['sweet', 'yellow', 'bone', 'call', 'honey', 'mustard'], 2],
#  [['hoes', 'aint', 'loyal'], 1],
#  [['wont',
#    'say',
#    'many',
#    'bitches',
#    'fucked',
#    'might',
#    'say',
#    'many',
#    'touched'],
#   1],
#  [['well',
#    'iguess',
#    'make',
#    'hoes',
#    'loyal',
#    'bro',
#    'theyll',
#    'never',
#    'loyal',
#    'hoes',
#    'nig'],
#   1],
#  [['jihadi',
#    'pop',
#    'music',
#    'hear',
#    'latest',
#    'abu',
#    'yasser',
#    'totally',
#    'abu',
#    'hajar',
#    'fan'],
#   2],
#  [['got', 'bitch', 'work', 'mad', 'bitch', 'dick'], 1],
#  [['niqqa', 'straight', 'pussy', 'whipped'], 1],
#  [['wow', 'avoiding', 'bitch'], 1],
#  [['floyd', 'mayweather', 'stay', 'badd', 'bitch', 'lol'], 1],
#  [['bitches',
#    'lol',
#    'cute',
#    'tho',
#    'wassup',
#    'gimmi',
#    'numba',
#    'imma',
#    'natural',
#    'lmfaoo'],
#   1],
#  [['bad', 'bitch', 'without', 'come', 'meet', 'without'], 1],
#  [['well', 'maybe', 'youre', 'whore', 'stupid', 'ugly', 'homeless', 'bitch'],
#   0],
#  [['cost',
#    'aint',
#    'buying',
#    'pussy',
#    'got',
#    'many',
#    'followers',
#    'vegas',
#    'dont',
#    'miss',
#    'opportunities'],
#   1],
#  [['know', 'right', 'much', 'retard'], 1],
#  [['girl',
#    'tweeted',
#    'might',
#    'ghetto',
#    'bring',
#    'food',
#    'outside',
#    'movies',
#    'might',
#    'stupid',
#    'pay'],
#   1],
#  [['currently', 'sitting', 'wishing', 'bitch', 'would'], 1],
#  [['kicking', 'bitches', 'house', 'like', 'pam'], 1],
#  [['please',
#    'stay',
#    'safe',
#    'love',
#    'hoe',
#    'one',
#    'day',
#    'meet',
#    'happy',
#    'halloween'],
#   2],
#  [['besides', 'one', 'two', 'bitches', 'always', 'catch'], 1],
#  [['one',
#    'managers',
#    'tried',
#    'talking',
#    'stay',
#    'till',
#    'aint',
#    'nobody',
#    'ordering',
#    'walked',
#    'shmoove',
#    'bitch'],
#   1],
#  [['liked', 'video', 'sock', 'short', 'film'], 2],
#  [['geminis', 'rule', 'hoe'], 1],
#  [['rest',
#    'peace',
#    'bad',
#    'boys',
#    'bad',
#    'advise',
#    'made',
#    'let',
#    'old',
#    'asian',
#    'dude',
#    'glue',
#    'sole'],
#   2],
#  [['bitch'], 1],
#  [['hoes', 'twerkin', 'new', 'weave'], 1],
#  [['babymama', 'drama', 'side', 'hoes'], 1],
#  [['lauderdale', 'thats', 'hoes'], 1],
#  [['nigga', 'train', 'treating', 'bitch', 'phone', 'lmao'], 1],
#  [['send', 'hoe'], 1],
#  [['queer', 'ass', 'shorts', 'rabchenko', 'got'], 0],
#  [['faggot'], 1],
#  [['monkey', 'back', 'keeps', 'smearing', 'poop', 'hair'], 2],
#  [['dis', 'bitch', 'gots'], 1],
#  [['bad', 'bitches', 'aint', 'cheap'], 1],
#  [['see', 'jig'], 2],
#  [['two', 'best', 'yankees', 'derek', 'jeter', 'joe', 'torre'], 2],
#  [['man',
#    'bitch',
#    'not',
#    'gonna',
#    'damn',
#    'dont',
#    'like',
#    'got',
#    'say',
#    'unfollow'],
#   0],
#  [['everyone',
#    'needs',
#    'stop',
#    'bitchin',
#    'jeter',
#    'youre',
#    'witnessing',
#    'last',
#    'week',
#    'baseball',
#    'greatest',
#    'player',
#    'wear',
#    'yankees',
#    'uniform'],
#   1],
#  [['nevermind', 'found', 'trash'], 2],
#  [['nah', 'laps', 'around', 'dam', 'lol'], 2],
#  [['pussy', 'rap', 'sheet', 'whole', 'lot', 'bros'], 1],
#  [['got',
#    'dawg',
#    'norris',
#    'blue',
#    'flames',
#    'bday',
#    'dat',
#    'bitch',
#    'couldnt',
#    'even',
#    'drink',
#    'pop',
#    'alcoholic',
#    'ass',
#    'downed'],
#   1],
#  [['want', 'cowboy', 'killer'], 2],
#  [['forms', 'bitch', 'still', 'dont', 'get', 'saiyan'], 1],
#  [['new',
#    'iphone',
#    'software',
#    'maybe',
#    'ill',
#    'sue',
#    'cunts',
#    'amp',
#    'request',
#    'damages',
#    'based',
#    'pussy',
#    'ive',
#    'missed'],
#   1],
#  [['dick', 'called', 'eggo', 'bitches', 'never', 'want', 'leggo', 'eggo'], 1],
#  [['wtf', 'bitches', 'seen', 'without'], 1],
#  [['drunk', 'eat', 'fucking', 'twat'], 1],
#  [['flag', 'bitch', 'ghat', 'damn', 'night', 'well', 'playing'], 1],
#  [['fireball',
#    'turned',
#    'cool',
#    'liquor',
#    'used',
#    'sponsored',
#    'byto',
#    'drink',
#    'pussy',
#    'country',
#    'dudes',
#    'hear',
#    'song'],
#   1],
#  [['mom', 'came', 'home', 'tacos', 'brownies'], 2],
#  [['foo', 'came', 'club', 'wit', 'bitch', 'leash'], 1],
#  [['got',
#    'bomb',
#    'dick',
#    'amptwo',
#    'professors',
#    'month',
#    'not',
#    'hoei',
#    'say'],
#   1],
#  [['bitch',
#    'phone',
#    'stfu',
#    'talking',
#    'dont',
#    'worry',
#    'make',
#    'sure',
#    'show'],
#   1],
#  [['nicca', 'fucc'], 1],
#  [['dude', 'video', 'birds', 'work', 'fuckin'], 1],
#  [['screaming', 'like', 'little', 'bitch', 'lmaooo'], 1],
#  [['women',
#    'think',
#    'angels',
#    'denial',
#    'hoe',
#    'actions',
#    'dont',
#    'fall',
#    'facade',
#    'see',
#    'past'],
#   1],
#  [['fuck', 'said'], 1],
#  [['hoe', 'gone', 'hoe', 'aint'], 1],
#  [['like',
#    'tattoo',
#    'head',
#    'forms',
#    'mullet',
#    'white',
#    'trash',
#    'people',
#    'entertaining',
#    'sometimes'],
#   1],
#  [['bad', 'man', 'want'], 1],
#  [['ref',
#    'finally',
#    'calls',
#    'arm',
#    'ball',
#    'hoes',
#    'didnt',
#    'count',
#    'hand',
#    'ball',
#    'mexico',
#    'game'],
#   1],
#  [['gonna', 'pop', 'pussy', 'real', 'niggaa'], 1],
#  [['dawg', 'told', 'must', 'saturday', 'rockin', 'bitch', 'wit', 'tha'], 1],
#  [['feeling', 'tonight', 'trash'], 2],
#  [['like',
#    'really',
#    'doubt',
#    'even',
#    'plays',
#    'already',
#    'got',
#    'lot',
#    'big',
#    'man',
#    'rotation',
#    'committed',
#    'bosh',
#    'bird',
#    'mcbob',
#    'amp',
#    'shawne'],
#   2],
#  [['yall',
#    'tweakin',
#    'wit',
#    'wce',
#    'shit',
#    'aint',
#    'way',
#    'hell',
#    'like',
#    'bitch',
#    'every',
#    'single',
#    'day'],
#   1],
#  [['omgwhat',
#    'retardshould',
#    'asked',
#    'weighs',
#    'thousand',
#    'pounds',
#    'feathers',
#    'thousand',
#    'pounds'],
#   1],
#  [['beat', 'pussy'], 1],
#  [['know', 'bitch', 'know', 'mexican'], 1],
#  [['anything',
#    'ive',
#    'ever',
#    'said',
#    'offended',
#    'thats',
#    'problem',
#    'not',
#    'problem',
#    'dont',
#    'little',
#    'bitch'],
#   1],
#  [['karate', 'bitch'], 1],
#  [['nine', 'straight', 'hits', 'price', 'not', 'night'], 2],
#  [['want', 'bitch', 'get', 'smashed', 'wont', 'let'], 1],
#  [['hope', 'dropped', 'four', 'new', 'songs'], 2],
#  [['hoes',
#    'use',
#    'theit',
#    'happened',
#    'excuse',
#    'means',
#    'cope',
#    'wit',
#    'make',
#    'seem',
#    'control'],
#   1],
#  [['make', 'paper', 'ball', 'trash'], 2],
#  [['every',
#    'time',
#    'bitch',
#    'makes',
#    'status',
#    'guys',
#    'texts',
#    'like',
#    'whatttt',
#    'loll'],
#   1],
#  [['bitches', 'fake', 'gay'], 1],
#  [['bitch', 'dennis'], 1],
#  [['bitch', 'ass', 'chick', 'flick', 'ever', 'sad', 'movie'], 1],
#  [['shes', 'nigger'], 0],
#  [['may', 'dumb', 'even', 'sarah', 'mocks'], 2],
#  [['umm', 'sure', 'hoes', 'talk', 'arent', 'ugly'], 1],
#  [['bitches',
#    'saying',
#    'ray',
#    'rice',
#    'got',
#    'deserved',
#    'month',
#    'ago',
#    'wanted',
#    'man',
#    'free'],
#   1],
#  [['sticking',
#    'theory',
#    'black',
#    'pussy',
#    'tastes',
#    'like',
#    'strawberry',
#    'milk'],
#   1],
#  [['whipped', 'home', 'cripple', 'made'], 2],
#  [['niggas',
#    'bitchin',
#    'tell',
#    'suck',
#    'sumn',
#    'bitches',
#    'see',
#    'vision',
#    'tell',
#    'fuck',
#    'sumn'],
#   1],
#  [['hoes', 'dont', 'deserve', 'respect', 'ask'], 1],
#  [['yall',
#    'fuckin',
#    'womens',
#    'men',
#    'risking',
#    'life',
#    'amp',
#    'freedom',
#    'single',
#    'amp',
#    'dolo',
#    'bitch',
#    'gotta',
#    'worry'],
#   1],
#  [['pussy'], 1],
#  [['east',
#    'coast',
#    'theres',
#    'colored',
#    'hair',
#    'everywhere',
#    'must',
#    'sweetest',
#    'wave',
#    'ever'],
#   2],
#  [['get', 'dream', 'happy', 'dreams'], 1],
#  [['bruh',
#    'def',
#    'wanted',
#    'call',
#    'rock',
#    'nigger',
#    'last',
#    'lmaoooooooooooooooooooooooooooo'],
#   1],
#  [['nice',
#    'girls',
#    'make',
#    'get',
#    'naughty',
#    'bad',
#    'yello',
#    'real',
#    'nice',
#    'body',
#    'south',
#    'like',
#    'real',
#    'thick'],
#   1],
#  [['paper'], 1],
#  [['pacer',
#    'amp',
#    'member',
#    'loving',
#    'hair',
#    'dog',
#    'came',
#    'quadraphonic',
#    'stereo',
#    'could',
#    'say',
#    'bitchlol'],
#   1],
#  [['best', 'asian', 'massage', 'park', 'slope', 'rated', 'spa'], 2],
#  [['whos',
#    'yous',
#    'whos',
#    'yous',
#    'yes',
#    'womp',
#    'womp',
#    'lord',
#    'save',
#    'parched',
#    'hoes'],
#   1],
#  [['niggas', 'talk', 'bout', 'hoes', 'beds', 'night', 'ctfuu'], 1],
#  [['yeah', 'sucks', 'like', 'fags', 'nevermind', 'fags'], 0],
#  [['suck', 'momma', 'flappy'], 1],
#  [['bad', 'bitch', 'bouncing', 'pogo', 'screamin', 'yolo', 'nigga', 'juelz'],
#   1],
#  [['lmaoo',
#    'shouldve',
#    'seen',
#    'coming',
#    'fat',
#    'bitches',
#    'need',
#    'love',
#    'craig'],
#   1],
#  [['ashley', 'young', 'tried', 'deny', 'bird', 'landed', 'mouth', 'hahaha'],
#   2],
#  [['dont', 'girl', 'lol', 'yall', 'threesomes', 'girl', 'eat', 'pussy'], 1],
#  [['going',
#    'pussy',
#    'dont',
#    'want',
#    'love',
#    'life',
#    'seein',
#    'scared',
#    'shit'],
#   1],
#  [['terms',
#    'like',
#    'peckerwood',
#    'stereotypes',
#    'white',
#    'people',
#    'fucking',
#    'kids',
#    'sisters',
#    'isnt'],
#   0],
#  [['ill', 'continue', 'dis', 'later', 'ill', 'back', 'bitch'], 1],
#  [['light',
#    'skin',
#    'niccas',
#    'always',
#    'wanna',
#    'try',
#    'ike',
#    'lol',
#    'take',
#    'one',
#    'back'],
#   1],
#  [['fucking', 'bad', 'bitch', 'gone', 'need', 'money', 'lil'], 1],
#  [['hes', 'drinking', 'much', 'shitty', 'canadian', 'hoser'], 1],
#  [['implying',
#    'bro',
#    'amp',
#    'two',
#    'aint',
#    'nothin',
#    'lil',
#    'hoescmon',
#    'kim'],
#   1],
#  [['bitch', 'ill', 'end', 'fucking', 'life', 'fuckboy'], 1],
#  [['song', 'come', 'hit', 'blunt', 'hard', 'cause', 'hoe', 'dat', 'hard'], 1],
#  [['katy', 'clear', 'lake', 'hoes'], 1],
#  [['fucking', 'dare', 'faggot'], 1],
#  [['talked', 'ghetto', 'lol', 'annoyed', 'self'], 2],
#  [['playing',
#    'games',
#    'wrestling',
#    'ways',
#    'bind',
#    'brothers',
#    'sex',
#    'talk',
#    'amp',
#    'providing',
#    'condoms',
#    'raw',
#    'dogging',
#    'hoes'],
#   1],
#  [['lmao',
#    'dont',
#    'fight',
#    'dont',
#    'know',
#    'ghetto',
#    'ass',
#    'school',
#    'dude',
#    'highly',
#    'doubt',
#    'since',
#    'dont',
#    'give',
#    'fuck'],
#   1],
#  [['pussy', 'good', 'cant', 'pull', 'ever'], 1],
#  [['youre',
#    'concerned',
#    'much',
#    'lady',
#    'makes',
#    'thats',
#    'bitch',
#    'shit',
#    'need',
#    'ego',
#    'stroked'],
#   1],
#  [['yes',
#    'protest',
#    'sexism',
#    'right',
#    'home',
#    'beg',
#    'guy',
#    'beat',
#    'pussy',
#    'lost',
#    'times'],
#   1],
#  [['hitting',
#    'women',
#    'wrong',
#    'morally',
#    'bitches',
#    'get',
#    'kidknappedbeat',
#    'sold',
#    'sex',
#    'gonna',
#    'end'],
#   1],
#  [['mother', 'fuck', 'flappy'], 1],
#  [['bitch', 'gmfu'], 1],
#  [['bitches', 'bitches', 'bitches'], 1],
#  [['wouldnt', 'share', 'wave', 'trash', 'cans'], 2],
#  [['niggas', 'develop', 'superpowers', 'comes', 'getting', 'pussy'], 1],
#  [['drawing',
#    'organic',
#    'powdered',
#    'goats',
#    'milk',
#    'bath',
#    'rose',
#    'petals',
#    'chopped',
#    'clams',
#    'eww',
#    'kidding',
#    'bubbl'],
#   2],
#  [['bet', 'bitch', 'try', 'slide', 'let', 'hair'], 1],
#  [['pussy'], 1],
#  [['life', 'short', 'walkin', 'round', 'mad', 'bitches'], 1],
#  [['lmaooooo',
#    'relax',
#    'mark',
#    'bitch',
#    'ass',
#    'roll',
#    'fuck',
#    'state',
#    'texas'],
#   1],
#  [['new',
#    'boyfriend',
#    'every',
#    'month',
#    'doesnt',
#    'mean',
#    'youre',
#    'gorgeous',
#    'means',
#    'youre',
#    'retarded'],
#   1],
#  [['bahaha', 'omg', 'bitch', 'crazyyy'], 1],
#  [['nah', 'talk', 'hoes', 'since', 'dont', 'wanna', 'text', 'back', 'shit'],
#   1],
#  [['ebola',
#    'not',
#    'scary',
#    'yall',
#    'worried',
#    'ebola',
#    'ima',
#    'getting',
#    'hoes'],
#   1],
#  [['got',
#    'uncle',
#    'marriage',
#    'dude',
#    'got',
#    'hips',
#    'like',
#    'big',
#    'momma',
#    'swear',
#    'lil',
#    'kids',
#    'mock',
#    'walk',
#    'dont',
#    'even',
#    'know'],
#   2],
#  [['boats', 'hoes'], 1],
#  [['stupid', 'ass', 'hoes', 'days'], 1],
#  [['kannie',
#    'amp',
#    'vonnie',
#    'tiny',
#    'ass',
#    'bitches',
#    'hated',
#    'crissi',
#    'started',
#    'calling',
#    'little',
#    'body',
#    'bitches',
#    'hawaii'],
#   1],
#  [['angel', 'stop', 'rting', 'fugly', 'bitch'], 1],
#  [['huge', 'nips', 'scary', 'scary'], 1],
#  [['yall', 'gimped', 'aint', 'tht', 'bitch', 'huh', 'lol'], 1],
#  [['bout',
#    'beback',
#    'old',
#    'shit',
#    'miss',
#    'hoes',
#    'texting',
#    'saying',
#    'wanna',
#    'come',
#    'see'],
#   1],
#  [['never'], 1],
#  [['tommy', 'trash'], 2],
#  [['done', 'hit', 'bout', 'threes', 'bitch'], 1],
#  [['nig', 'gonna', 'come', 'back'], 0],
#  [['espn',
#    'keep',
#    'hiring',
#    'dyke',
#    'bitches',
#    'gay',
#    'spanish',
#    'niggas',
#    'talk',
#    'sports'],
#   0],
#  [['hoes', 'dont', 'want', 'seem', 'like', 'hoe', 'gotta', 'hit', 'low'], 1],
#  [['bitches', 'mann'], 1],
#  [['atleast', 'wipe', 'ass', 'trashy', 'bitch'], 1],
#  [['profesional', 'sports', 'enjoyed', 'white', 'trash'], 1],
#  [['never', 'let', 'another', 'bitch', 'say', 'change', 'actions', 'towards'],
#   1],
#  [['shot', 'main', 'bitches', 'side', 'bitches'], 1],
#  [['snap',
#    'chatted',
#    'one',
#    'night',
#    'lol',
#    'youre',
#    'cute',
#    'snapchat',
#    'back',
#    'nig'],
#   2],
#  [['youre', 'arent', 'rip', 'nigga', 'worthless', 'spear', 'chucker'], 0],
#  [['silencer', 'bitch', 'dont', 'make', 'sound'], 1],
#  [['didnt', 'tag', 'negro', 'lol'], 1],
#  [['gonna', 'ape', 'shit', 'uchida'], 1],
#  [['danny', 'deep', 'deep', 'water', 'many', 'badass', 'sons', 'bitches'], 1],
#  [['think', 'change', 'doctors', 'advocate', 'cunt', 'goes', 'mental'], 1],
#  [['sole',
#    'purpose',
#    'make',
#    'money',
#    'otherwise',
#    'youd',
#    'suggest',
#    'violence',
#    'prevention',
#    'policies',
#    'actually',
#    'work'],
#   2],
#  [['bathing', 'suspended', 'orb', 'tub', 'not', 'shy', 'people', 'yet'], 2],
#  [['boosie',
#    'said',
#    'got',
#    'bitch',
#    'sip',
#    'gonna',
#    'boosies',
#    'bitch',
#    'sip',
#    'bio'],
#   1],
#  [['pack',
#    'head',
#    'please',
#    'enjoy',
#    'called',
#    'hick',
#    'come',
#    'home',
#    'humbled'],
#   2],
#  [['almost', 'stepped', 'bird', 'running', 'around', 'floor', 'creepy'], 2],
#  [['got', 'new', 'bitch', 'got', 'lookin', 'like', 'yeah', 'know', 'mad'], 1],
#  [['wet', 'pussy', 'smell'], 1],
#  [['cole', 'trash', 'ive', 'saying', 'years', 'fuck', 'lol'], 1],
#  [['nigguh', 'sucks'], 1],
#  [['today',
#    'hair',
#    'makeup',
#    'always',
#    'tries',
#    'make',
#    'look',
#    'like',
#    'monkey'],
#   2],
#  [['half', 'bitches', 'say', 'tfti', 'wouldnt', 'even', 'bet'], 1],
#  [['bad', 'optimism', 'dont', 'take', 'colored', 'glasses'], 2],
#  [['majority', 'trash', 'anyway'], 2],
#  [['may', 'may', 'not', 'trash', 'taking', 'pictures', 'together'], 2],
#  [['kobe', 'bryant', 'bitch', 'grow', 'pussy'], 1],
#  [['hate', 'nigger'], 0],
#  [['even', 'bitch', 'admit', 'something', 'isnt', 'right'], 1],
#  [['hawaiian', 'thought', 'aloha', 'muzzie'], 2],
#  [['text', 'bitch'], 1],
#  [['omg', 'bitch', 'said', 'shit'], 1],
#  [['come',
#    'visit',
#    'pussy',
#    'gotta',
#    'move',
#    'city',
#    'within',
#    'months',
#    'yall',
#    'first',
#    'fuck',
#    'aint',
#    'gon',
#    'work'],
#   1],
#  [['gotta',
#    'link',
#    'bro',
#    'rambo',
#    'fashoo',
#    'gotta',
#    'pull',
#    'ona',
#    'pussy',
#    'boys'],
#   1],
#  [['send', 'bitches', 'express', 'mail', 'overnight', 'delivery'], 1],
#  [['real', 'nigga', 'speaking', 'sound', 'like', 'bitch'], 1],
#  [['dont', 'love', 'hoes'], 1],
#  [['woman',
#    'never',
#    'cheated',
#    'unless',
#    'man',
#    'drove',
#    'men',
#    'cheat',
#    'new',
#    'pussy'],
#   1],
#  [['lol', 'nig'], 1],
#  [['blocked', 'fuzzy', 'butt', 'ignore', 'low', 'life', 'creature'], 1],
#  [['real', 'nigga', 'need', 'real', 'bitch', 'somebody', 'chill'], 1],
#  [['strong', 'survive', 'nigga', 'pussy'], 1],
#  [['ive', 'ever', 'offended', 'sorry', 'youre', 'sensitive', 'lil', 'bitch'],
#   1],
#  [['waka', 'flaka', 'lucky', 'retard', 'lol'], 1],
#  [['one', 'thing', 'cant', 'stand', 'texting', 'bitches', 'got', 'droids'], 1],
#  [['spaceship', 'shit', 'retarded'], 1],
#  [['keshawn', 'martin', 'soooooooooo', 'fucking'], 1],
#  [['ugly', 'hoe'], 1],
#  [['belle'], 1],
#  [['wanna',
#    'run',
#    'around',
#    'city',
#    'make',
#    'memories',
#    'barely',
#    'remember',
#    'allow',
#    'talk',
#    'pussy',
#    'power'],
#   1],
#  [['little', 'bitches', 'proven', 'wrong'], 1],
#  [['avery',
#    'adorable',
#    'petite',
#    'red',
#    'haired',
#    'teen',
#    'plays',
#    'shavedpussy'],
#   1],
#  [['new',
#    'jersey',
#    'yellow',
#    'green',
#    'chevron',
#    'stripe',
#    'like',
#    'charlie',
#    'browns',
#    'jersey'],
#   2],
#  [[], 1],
#  [['damn', 'bird', 'nearly', 'gave', 'heart', 'said', 'bitch'], 1],
#  [['hoes', 'days'], 1],
#  [['making', 'first', 'day', 'bitch'], 1],
#  [['nigga', 'use', 'term', 'yassssssssss', 'gonna', 'assume', 'fag'], 1],
#  [['wouldnt', 'fuk', 'lot', 'bitches'], 1],
#  [['dont', 'fuck', 'wit', 'hoe', 'niggas'], 1],
#  [['would', 'think', 'common'], 2],
#  [['glads', 'dis', 'colored', 'man', 'cans', 'soyvice', 'white', 'man'], 1],
#  [['bitch', 'toooo'], 1],
#  [['hes',
#    'eating',
#    'cuz',
#    'hes',
#    'women',
#    'cant',
#    'cook',
#    'gotta',
#    'get',
#    'rid',
#    'hoe'],
#   1],
#  [['broke',
#    'hoes',
#    'always',
#    'wanna',
#    'argue',
#    'aint',
#    'ate',
#    'day',
#    'get',
#    'energy'],
#   1],
#  [['love',
#    'fuckin',
#    'wit',
#    'people',
#    'givin',
#    'greedy',
#    'ass',
#    'nigas',
#    'old',
#    'crackers',
#    'wit',
#    'expired',
#    'cheese',
#    'dey',
#    'callin',
#    'like',
#    'nigga',
#    'shittin',
#    'likea',
#    'goose'],
#   0],
#  [['would', 'call', 'thats', 'frowned', 'upon'], 1],
#  [['yellow', 'rice', 'black', 'beans', 'pork', 'chop', 'sis'], 2],
#  [['getting', 'trash', 'talked', 'year', 'old'], 2],
#  [['still', 'waiting', 'oomf', 'hit', 'hoe', 'lololol'], 1],
#  [['epic', 'storybook', 'derek', 'jeter', 'closes', 'last', 'game', 'bronx'],
#   2],
#  [['anal', 'gaping', 'tranny', 'play', 'panty', 'nylon', 'part'], 1],
#  [['fat',
#    'bitches',
#    'normal',
#    'sized',
#    'legs',
#    'looking',
#    'like',
#    'car',
#    'keys'],
#   1],
#  [['becoming',
#    'cold',
#    'hearted',
#    'bitch',
#    'wasnt',
#    'really',
#    'planned',
#    'life'],
#   1],
#  [['fast', 'cocky', 'cops', 'ditch', 'old', 'gettin', 'sloppy', 'wit', 'pots'],
#   1],
#  [['gotta',
#    'find',
#    'new',
#    'house',
#    'land',
#    'lord',
#    'bitch',
#    'getting',
#    'waaaay',
#    'better',
#    'house',
#    'good',
#    'lol'],
#   1],
#  [['yall',
#    'preppy',
#    'bitches',
#    'ever',
#    'arguing',
#    'like',
#    'party',
#    'dont',
#    'nothing',
#    'yall',
#    'getting',
#    'hit',
#    'bottle'],
#   1],
#  [['lmfao',
#    'shut',
#    'slutty',
#    'white',
#    'hoe',
#    'didnt',
#    'know',
#    'pats',
#    'got',
#    'destroyed',
#    'tonight',
#    'lmfaoooo'],
#   1],
#  [['big', 'titty', 'bitch', 'lmao', 'fuck', 'good', 'party'], 1],
#  [[], 0],
#  [['not', 'shoot', 'ima', 'beat', 'face', 'asphalt'], 0],
#  [['single', 'moms', 'got', 'proven', 'pussy', 'lol', 'fckd', 'truuu'], 1],
#  [['ians', 'retarded'], 0],
#  [['cant',
#    'decide',
#    'wear',
#    'yellow',
#    'rain',
#    'boots',
#    'purposes',
#    'black',
#    'amp',
#    'yellow',
#    'errrrything'],
#   2],
#  [['bitch'], 1],
#  [['father',
#    'born',
#    'nanticoke',
#    'attended',
#    'lehigh',
#    'love',
#    'pennsylvania',
#    'dutch',
#    'cooking'],
#   2],
#  [['hoes',
#    'fucking',
#    'niggas',
#    'got',
#    'news',
#    'monogamous',
#    'bitch',
#    'fucking',
#    'anonymous',
#    'niggas'],
#   1],
#  [['pussy', 'like', 'damn', 'pussy'], 1],
#  [['bagging',
#    'thot',
#    'bitches',
#    'amp',
#    'giving',
#    'nigga',
#    'nasty',
#    'amp',
#    'youre',
#    'better',
#    'dead'],
#   1],
#  [['sorry',
#    'give',
#    'racist',
#    'platform',
#    'trash',
#    'language',
#    'dana',
#    'intvw',
#    'kindergarten',
#    'level'],
#   2],
#  [['art', 'nobody', 'takin'], 1],
#  [['ooh', 'yea', 'getting'], 1],
#  [['superman', 'eyyyy'], 1],
#  [['ight', 'friday', 'nig'], 1],
#  [['pussy', 'doesnt', 'taste', 'like', 'pineapples'], 1],
#  [['said', 'black', 'bitch'], 1],
#  [['another', 'nigga', 'bitch'], 1],
#  [['youre', 'standing', 'slippery', 'slope', 'easy', 'libra'], 2],
#  [['dope', 'pretty', 'bitch', 'side', 'sell', 'dope', 'tryna', 'get', 'high'],
#   1],
#  [['hoes', 'not', 'fat', 'big', 'boned', 'hehehehehe'], 1],
#  [['act',
#    'sound',
#    'infront',
#    'ill',
#    'awfy',
#    'cunt',
#    'break',
#    'fukin',
#    'phone',
#    'tae'],
#   1],
#  [['bitch'], 1],
#  [['happy', 'birthday', 'love', 'faggot'], 1],
#  [['portable', 'septic', 'tank', 'allllll', 'pesky', 'feelings'], 2],
#  [['free', 'birds', 'lol'], 2],
#  [['long',
#    'distance',
#    'sex',
#    'definitely',
#    'thinking',
#    'like',
#    'bitch',
#    'lil',
#    'much'],
#   1],
#  [['bitch',
#    'cause',
#    'wanted',
#    'fight',
#    'didnt',
#    'show',
#    'tryna',
#    'make',
#    'bet',
#    'shit',
#    'get',
#    'friendly',
#    'ass',
#    'twitter'],
#   1],
#  [['like',
#    'momma',
#    'said',
#    'dont',
#    'waste',
#    'time',
#    'plzing',
#    'des',
#    'fake',
#    'ass',
#    'bitches',
#    'bum',
#    'ass',
#    'dudes',
#    'cause',
#    'aint',
#    'gone',
#    'get',
#    'nowhere',
#    'pregnant'],
#   1],
#  [['streets', 'dirty', 'niggad', 'try', 'wife', 'though'], 1],
#  [['positive', 'thoughts', 'nig', 'nog'], 1],
#  [['every', 'nigga', 'new', 'hoe', 'next', 'niggas', 'old', 'hoe'], 1],
#  [['jihadis',
#    'circulating',
#    'video',
#    'killing',
#    'boko',
#    'haram',
#    'nigerian',
#    'pilot',
#    'captured',
#    'helicopter',
#    'shoot'],
#   2],
#  [['answer', 'snapchat', 'faggot'], 0],
#  [['murda', 'mook', 'shit'], 1],
#  [['didnt',
#    'wrong',
#    'started',
#    'talking',
#    'went',
#    'wrong',
#    'trusted',
#    'bitch',
#    'ass'],
#   1],
#  [['youre',
#    'fag',
#    'using',
#    'emoji',
#    'one',
#    'best',
#    'friends',
#    'amp',
#    'never',
#    'dull',
#    'moment'],
#   1],
#  [['thanks',
#    'scaring',
#    'absolute',
#    'fuck',
#    'flatfoot',
#    'look',
#    'like',
#    'pussy',
#    'fucking',
#    'jerk'],
#   1],
#  [['damn', 'well', 'joe', 'move', 'bullpen', 'really', 'helped'], 2],
#  [['fag'], 0],
#  [['not', 'defending', 'ray', 'rice', 'double', 'standard', 'aint'], 1],
#  [['browns', 'redskins', 'shouldnt', 'considered', 'nfl', 'teams'], 2],
#  [['bitches',
#    'failed',
#    'geometry',
#    'know',
#    'exactly',
#    'angle',
#    'use',
#    'take',
#    'perfect',
#    'selfie'],
#   1],
#  [['pussy', 'aching', 'follow', 'bae'], 1],
#  [['like', 'bitch'], 1],
#  [['least', 'went', 'wasnt', 'bitch'], 1],
#  [['fitzpatrick', 'trash', 'bruh'], 2],
#  [['god', 'tweets', 'ghetto'], 1],
#  [['bitch',
#    'tryna',
#    'get',
#    'free',
#    'promoting',
#    'shit',
#    'lmaooo',
#    'see',
#    'tha',
#    'cut'],
#   1],
#  [['got', 'ounce', 'bitch'], 1],
#  [['hate',
#    'drinking',
#    'everyones',
#    'fucking',
#    'boring',
#    'fuck',
#    'ill',
#    'fun',
#    'pussies'],
#   1],
#  [['god',
#    'would',
#    'sell',
#    'nuts',
#    'watch',
#    'lebron',
#    'tear',
#    'acl',
#    'right',
#    'watch',
#    'pussies',
#    'kill'],
#   0],
#  [['day', 'goes', 'bad', 'tell', 'pussy'], 1],
#  [['dis',
#    'wus',
#    'offered',
#    'help',
#    'faggot',
#    'ass',
#    'nigga',
#    'get',
#    'custody',
#    'kids',
#    'lowkey',
#    'heated'],
#   1],
#  [['gotta', 'know', 'difference', 'good', 'girl', 'good', 'pussy'], 1],
#  [['lbum',
#    'tail',
#    'satan',
#    'soul',
#    'mirajane',
#    'strauss',
#    'made',
#    'sims',
#    'happy'],
#   2],
#  [['juan',
#    'likes',
#    'black',
#    'girls',
#    'monday',
#    'spanish',
#    'girls',
#    'thursday',
#    'amp',
#    'amp',
#    'white',
#    'bitches',
#    'weekend',
#    'tbb'],
#   1],
#  [['drink', 'bitches'], 1],
#  [['bitch', 'dont', 'nobody', 'care'], 1],
#  [['remember',
#    'said',
#    'uchihas',
#    'week',
#    'sasuke',
#    'reaffirms',
#    'flying',
#    'colors'],
#   1],
#  [['ball',
#    'roll',
#    'slope',
#    'amp',
#    'found',
#    'natural',
#    'spot',
#    'defending',
#    'brother',
#    'amp',
#    'scumbag'],
#   2],
#  [['suck', 'super', 'monkey', 'balls'], 1],
#  [['dont', 'sloppy', 'might', 'catch', 'somethin'], 1],
#  [['didnt',
#    'open',
#    'das',
#    'asked',
#    'cus',
#    'thought',
#    'ate',
#    'wat',
#    'pork',
#    'chops',
#    'yellow',
#    'rice',
#    'beans'],
#   2],
#  [['young',
#    'thug',
#    'called',
#    'bitch',
#    'twin',
#    'track',
#    'dont',
#    'even',
#    'know',
#    'mean',
#    'definitely',
#    'bout',
#    'start',
#    'calling',
#    'bitches'],
#   1],
#  [['paid', 'hold', 'monkey', 'look', 'monkey', 'real'], 2],
#  [['wonder', 'gon', 'low', 'nigger', 'friday'], 1],
#  [['stupid', 'bitches', 'cant', 'handle', 'johns'], 1],
#  [['love', 'frat', 'boy', 'soft', 'long', 'soles'], 2],
#  [['shimmy', 'shimmy', 'bitch'], 1],
#  [['saw',
#    'men',
#    'saying',
#    'arguing',
#    'women',
#    'gaywhats',
#    'knew',
#    'yall',
#    'really',
#    'try',
#    'hard',
#    'bitches',
#    'attention'],
#   1],
#  [['making', 'pollo', 'brasso', 'today'], 2],
#  [['much', 'knob', 'gobble', 'one', 'youre', 'head', 'blockhead'], 1],
#  [['citi', 'field', 'bitches'], 1],
#  [['happy', 'friday'], 1],
#  [['happened', 'old', 'gonorrhea', 'one'], 1],
#  [['listen',
#    'bands',
#    'ptv',
#    'sws',
#    'atl',
#    'bvb',
#    'adtr',
#    'bmth',
#    'ymas',
#    'fob',
#    'blink',
#    'tdg',
#    'fir',
#    'mcr',
#    'follow',
#    'amp',
#    'everyon'],
#   2],
#  [['original', 'bad', 'bitch'], 1],
#  [['pennsylvania', 'white', 'trash', 'pennsylvanians'], 0],
#  [['dead',
#    'word',
#    'moms',
#    'calling',
#    'cops',
#    'aint',
#    'heard',
#    'four',
#    'days',
#    'probably',
#    'pussy'],
#   1],
#  [['well', 'coon'], 1],
#  [['see', 'bitch', 'nigga', 'subtweet'], 1],
#  [['denkt',
#    'ieder',
#    'wel',
#    'zijne',
#    'zaken',
#    'amp',
#    'mag',
#    'mij',
#    'noemen',
#    'hoe',
#    'ben',
#    'namelijk',
#    'erg',
#    'voor',
#    'vrijheid',
#    'van',
#    'meningsuiting'],
#   1],
#  [['anyone', 'bring', 'monkey'], 2],
#  [['likes',
#    'black',
#    'men',
#    'rap',
#    'huh',
#    'lol',
#    'general',
#    'wants',
#    'colored'],
#   2],
#  [['someones', 'clearly', 'stinky', 'ass', 'beaner'], 0],
#  [['liberal',
#    'ideology',
#    'forged',
#    'unions',
#    'amp',
#    'bankrupted',
#    'dems',
#    'catering'],
#   2],
#  [['freshman',
#    'year',
#    'senior',
#    'year',
#    'really',
#    'niggah',
#    'started',
#    'brothers',
#    'years',
#    'ago',
#    'today',
#    'crazy'],
#   1],
#  [['raided',
#    'nickis',
#    'wig',
#    'closet',
#    'bad',
#    'gals',
#    'wanna',
#    'bitch',
#    'nerve',
#    'smh'],
#   2],
#  [['see', 'againthat', 'son', 'bitch', 'owes', 'tell', 'looking'], 1],
#  [['bitch'], 1],
#  [['good', 'charlie'], 2],
#  [['lmfao', 'new', 'york', 'world', 'series', 'titles'], 2],
#  [['wow',
#    'another',
#    'timatheracer',
#    'wow',
#    'another',
#    'cam',
#    'lolgtgt',
#    'dat',
#    'dude',
#    'nice'],
#   0],
#  [['hoes', 'good', 'woman', 'always', 'good', 'woman'], 1],
#  [['pussy', 'dont', 'cream'], 1],
#  [['pass', 'bitch'], 1],
#  [['muzzy',
#    'lovers',
#    'need',
#    'one',
#    'thing',
#    'tell',
#    'muzzies',
#    'mideast',
#    'leave',
#    'israel',
#    'alone',
#    'dont',
#    'start',
#    'shit',
#    'wont',
#    'shit'],
#   0],
#  [['bitch', 'tweets', 'point', 'minutes'], 1],
#  [['support', 'niggaz', 'bitches', 'dope', 'shit', 'west', 'side', 'city'], 1],
#  [['bitch', 'get', 'twitter', 'hoe'], 1],
#  [['imagine', 'world', 'created', 'trap', 'feed', 'like'], 0],
#  [['bitch',
#    'not',
#    'really',
#    'dont',
#    'fucking',
#    'like',
#    'fuck',
#    'even',
#    'talking'],
#   1],
#  [['wow', 'put', 'slit', 'trophies'], 2],
#  [['really', 'dont', 'tryna', 'hoe', 'nobody', 'eat', 'literally'], 1],
#  [['scale', 'bitch', 'literally'], 1],
#  [['bitches',
#    'love',
#    'beefing',
#    'nigga',
#    'thats',
#    'always',
#    'bitches',
#    'faces'],
#   1],
#  [['retarded'], 1],
#  [['nigger'], 1],
#  [['muslim',
#    'group',
#    'slaughters',
#    'children',
#    'nigerian',
#    'children',
#    'burned',
#    'shot',
#    'amp',
#    'slit',
#    'throats',
#    'tried',
#    'http'],
#   2],
#  [['sang', 'nazi'], 1],
#  [['like', 'pulled', 'track', 'bitches'], 1],
#  [['dont', 'say', 'fuck', 'bitches', 'get', 'money', 'love'], 1],
#  [['make', 'yellow'], 2],
#  [['reason',
#    'use',
#    'mega',
#    'whatsoever',
#    'pure',
#    'favoritism',
#    'also',
#    'sweet',
#    'fuzzy',
#    'wings'],
#   2],
#  [['purge', 'come', 'city', 'ima', 'like', 'bitch', 'active'], 1],
#  [['leave',
#    'car',
#    'windows',
#    'rains',
#    'car',
#    'looks',
#    'like',
#    'hurricane',
#    'katrina',
#    'ran',
#    'bitch'],
#   1],
#  [['man', 'bitch', 'smells', 'like', 'cheap', 'lip', 'stick'], 1],
#  [['youre', 'stupid', 'fucking', 'bitch'], 1],
#  [['first',
#    'congratulate',
#    'years',
#    'hoes',
#    'smarter',
#    'last',
#    'years',
# ...
#  [['niggas',
#    'mentally',
#    'dating',
#    'females',
#    'never',
#    'met',
#    'instagram',
#    'double',
#    'tapn',
#    'much',
#    'mane'],
#   1],
#  [['lima', 'fears', 'change', 'yet', 'wants', 'bitch', 'much', 'sucks'], 1],
#  [['made',
#    'homemade',
#    'chili',
#    'cornbread',
#    'dinner',
#    'watching',
#    'supernatural',
#    'fave',
#    'happy',
#    'saturday'],
#   1],
#  [['boolin', 'bando', 'wit', 'bitches'], 1],
#  [['day', 'unblock', 'become', 'man', 'wont', 'happen', 'bitch', 'lol'], 1],
#  [['youre', 'bad', 'bitch', 'want'], 1],
#  [['shit', 'sorry', 'hoe'], 1],
#  [['people', 'say', 'coloured'], 2],
#  [['rarely', 'drink', 'drunk', 'bitches', 'irritate'], 1],
#  [['iphone',
#    'million',
#    'times',
#    'storage',
#    'apollo',
#    'spacecraft',
#    'computer',
#    'went',
#    'moon',
#    'throw',
#    'bird'],
#   2],
#  [['kevin', 'hart', 'make', 'funny', 'faces', 'curriculum', 'kinda', 'trash'],
#   2],
#  [['chick', 'gorgeous', 'fine', 'pussy', 'stinks'], 1],
#  [['didnt',
#    'hes',
#    'little',
#    'bitch',
#    'valerie',
#    'jarrett',
#    'betcha',
#    'guy',
#    'knows',
#    'eve'],
#   1],
#  [['pretty', 'much', 'confirmed', 'best', 'bitch', 'face', 'planet'], 1],
#  [['confessgt', 'sneaks', 'pussy', 'nightgt', 'paints', 'wife'], 1],
#  [['cant',
#    'eat',
#    'pussy',
#    'thats',
#    'got',
#    'hair',
#    'not',
#    'even',
#    'sure',
#    'really',
#    'know',
#    'eat',
#    'pussy'],
#   1],
#  [['dont', 'bitch', 'attitude', 'youre', 'reason', 'one'], 1],
#  [['wanna', 'trash', 'talk', 'concert'], 2],
#  [['yeaaa',
#    'bitch',
#    'dog',
#    'like',
#    'shaggy',
#    'yea',
#    'stay',
#    'clean',
#    'get',
#    'dirty',
#    'like',
#    'harry'],
#   1],
#  [['like',
#    'said',
#    'might',
#    'check',
#    'not',
#    'sure',
#    'bird',
#    'shot',
#    'counts',
#    'getting',
#    'shot'],
#   2],
#  [['words',
#    'babe',
#    'love',
#    'hate',
#    'need',
#    'forget',
#    'youre',
#    'everything',
#    'youre',
#    'nothing'],
#   1],
#  [['sen',
#    'harry',
#    'reid',
#    'lists',
#    'things',
#    'republicans',
#    'blocked',
#    'senate',
#    'via'],
#   2],
#  [['lil', 'bitch', 'dont', 'read', 'receipt'], 1],
#  [['deleting',
#    'pic',
#    'realized',
#    'dike',
#    'back',
#    'ground',
#    'dressed',
#    'like',
#    'nigga',
#    'wedges',
#    'bitch'],
#   0],
#  [['charlie', 'lapdance'], 2],
#  [['touch', 'muzzie', 'hope', 'set', 'full', 'bacon', 'pork', 'rinds'], 1],
#  [['fronting',
#    'bitches',
#    'get',
#    'got',
#    'island',
#    'dick',
#    'never',
#    'hit',
#    'fronting',
#    'ass',
#    'nigga'],
#   1],
#  [['ole',
#    'girl',
#    'really',
#    'told',
#    'doesnt',
#    'care',
#    'boyfriend',
#    'hoes',
#    'whats',
#    'wrong',
#    'generation'],
#   1],
#  [['crazy',
#    'animals',
#    'like',
#    'grabbed',
#    'mama',
#    'like',
#    'aint',
#    'going',
#    'like',
#    'bitch'],
#   1],
#  [['sonia',
#    'never',
#    'criticises',
#    'kejriwal',
#    'trashes',
#    'every',
#    'never',
#    'criticises',
#    'sonia',
#    'touching'],
#   2],
#  [['phone', 'fucking', 'bitch'], 1],
#  [['nicca',
#    'read',
#    'typed',
#    'aint',
#    'slo',
#    'long',
#    'shot',
#    'dont',
#    'play',
#    'dumb',
#    'litebrite',
#    'lol'],
#   1],
#  [['fuck', 'simplest', 'things', 'lighten', 'bitches'], 1],
#  [['niggas', 'pure', 'pussy', 'see', 'faces'], 1],
#  [['well',
#    'gahdamn',
#    'wooooow',
#    'good',
#    'job',
#    'mommy',
#    'cutest',
#    'thing',
#    'blue',
#    'ivy',
#    'ever',
#    'done',
#    'still',
#    'ugly',
#    'nigger',
#    'baby'],
#   0],
#  [['not', 'leave', 'nigga', 'bitch'], 1],
#  [['shutup',
#    'fag',
#    'real',
#    'shit',
#    'females',
#    'love',
#    'real',
#    'nigga',
#    'like'],
#   1],
#  [['aye', 'fucked', 'bitch', 'mistake'], 1],
#  [['smoking', 'brooklyn', 'got', 'high', 'giraffe', 'pussy'], 1],
#  [['fuck', 'bad', 'bitches', 'stacy', 'niggas', 'balls', 'blue', 'like'], 1],
#  [['fuckin',
#    'call',
#    'venue',
#    'theyll',
#    'cancel',
#    'lost',
#    'tickets',
#    'reprint',
#    'new',
#    'ones',
#    'dumb',
#    'bitch'],
#   1],
#  [['reason',
#    'rap',
#    'pussy',
#    'supposed',
#    'talk',
#    'smh',
#    'bout',
#    'make',
#    'music',
#    'aint'],
#   1],
#  [['niggas', 'cheat', 'loyal', 'beautiful', 'women', 'fucking', 'trash'], 1],
#  [['hoe', 'grandma', 'got', 'tattoo'], 1],
#  [['shy', 'bitch', 'homosexual'], 1],
#  [['herd',
#    'random',
#    'creepiest',
#    'sound',
#    'fuck',
#    'going',
#    'outside',
#    'windows',
#    'not',
#    'looking',
#    'bitch'],
#   1],
#  [['full',
#    'called',
#    'children',
#    'not',
#    'children',
#    'illegal',
#    'border',
#    'jumpers',
#    'gang',
#    'members'],
#   0],
#  [['using', 'measure', 'slope', 'ass', 'girl'], 1],
#  [['cause', 'would', 'tip', 'hand', 'instead', 'whine', 'like', 'little'], 1],
#  [['moest',
#    'van',
#    'plisie',
#    'niet',
#    'meteen',
#    'wild',
#    'gaan',
#    'wel',
#    'meer',
#    'mensen',
#    'mij',
#    'vertellen',
#    'hoe',
#    'moet',
#    'denken'],
#   2],
#  [['lol', 'baddest', 'bitches', 'porn', 'stars', 'strippers'], 1],
#  [['big', 'homie', 'drizzy', 'threatening', 'hoes'], 1],
#  [['real',
#    'man',
#    'gonna',
#    'keep',
#    'real',
#    'bitches',
#    'lmaooooo',
#    'shut',
#    'not',
#    'tellin',
#    'women',
#    'mind',
#    'business'],
#   1],
#  [['exactly',
#    'shit',
#    'saidgtgtgt',
#    'nobody',
#    'think',
#    'mimi',
#    'outta',
#    'line',
#    'inviting',
#    'stevie',
#    'gay',
#    'nicca'],
#   0],
#  [['yall',
#    'take',
#    'note',
#    'aint',
#    'never',
#    'tornadoes',
#    'colored',
#    'folk',
#    'live'],
#   2],
#  [['ending', 'retarded'], 1],
#  [['wasnt', 'hoe', 'azz', 'boi', 'sniff', 'sorry'], 1],
#  [['work', 'support', 'military', 'organization', 'today'], 2],
#  [['slept', 'good', 'thenna', 'bitch', 'tho'], 1],
#  [['rock', 'cock', 'jam', 'clam'], 1],
#  [['like', 'women', 'whos', 'pussy', 'smell', 'like', 'burnt', 'cheese'], 1],
#  [['know', 'considered', 'like', 'wait', 'little', 'baby', 'back', 'bitch'],
#   1],
#  [['real', 'niggah', 'want'], 1],
#  [['lmaoooo',
#    'gucci',
#    'really',
#    'ass',
#    'hoes',
#    'ill',
#    'bump',
#    'couple',
#    'songs'],
#   1],
#  [['idk', 'really', 'surely', 'trash', 'rapper'], 2],
#  [['couldnt', 'help', 'man', 'niggas', 'pussy', 'robbing', 'chick', 'shootin'],
#   1],
#  [['would', 'rather', 'call', 'bitch', 'sir', 'manager'], 1],
#  [['baddest',
#    'bitch',
#    'didnt',
#    'win',
#    'queen',
#    'fuck',
#    'mexicans',
#    'ill',
#    'buy',
#    'house'],
#   1],
#  [['got', 'giggles', 'aint', 'gon', 'lie', 'lol'], 1],
#  [['hope', 'realize', 'retarded'], 1],
#  [['lit', 'stupid', 'ass', 'bitch', 'aint', 'fuccin', 'witchuuuu'], 1],
#  [['confused',
#    'lefties',
#    'using',
#    'hashtag',
#    'mock',
#    'bridge',
#    'situation',
#    'seriously',
#    'equating'],
#   2],
#  [['fuck', 'wcwlet', 'see', 'wat', 'current', 'bitch', 'look', 'like', 'oowe'],
#   1],
#  [['learn',
#    'first',
#    'seconds',
#    'flesh',
#    'power',
#    'death',
#    'riff',
#    'would',
#    'cool',
#    'bird',
#    'lol'],
#   2],
#  [['know', 'outback', 'see', 'hoe'], 1],
#  [['damn', 'charlie', 'wilson', 'still'], 2],
#  [['fearful', 'wrath', 'god', 'country', 'many', 'mock', 'embrace', 'bows'],
#   2],
#  [['ratchet', 'ass', 'bitches', 'gonna', 'nobody', 'blame', 'get', 'std'], 1],
#  [['zoom', 'see', 'hairy', 'nipples'], 1],
#  [['bitch',
#    'hmu',
#    'say',
#    'need',
#    'sex',
#    'right',
#    'bitch',
#    'nigga',
#    'hmu',
#    'saying',
#    'upset',
#    'right'],
#   1],
#  [['many', 'hoes', 'whipped', 'would', 'thought', 'still', 'slavery'], 0],
#  [['bitches', 'yal', 'cant', 'know', 'bouta', 'start', 'popping', 'bitches'],
#   1],
#  [['try', 'pussy'], 1],
#  [['ballsack', 'hairy', 'gtfo', 'tranny', 'prude', 'bitch'], 0],
#  [['yeah', 'hoe'], 1],
#  [['lemme', 'find', 'bitch', 'nigga', 'talking', 'shit'], 0],
#  [['nigga', 'hungry', 'bitch'], 1],
#  [['thats', 'ghetto', 'super', 'current', 'generations', 'best', 'complement'],
#   2],
#  [['hopes', 'recruiting', 'isis', 'opens', 'jihadi', 'finishing', 'school'],
#   2],
#  [['fuking',
#    'every',
#    'night',
#    'new',
#    'house',
#    'cause',
#    'bitch',
#    'worked',
#    'hard',
#    'new',
#    'house'],
#   1],
#  [['rts', 'ill', 'say', 'fuck', 'right', 'pussy'], 1],
#  [['someone', 'love', 'bitch', 'ass', 'wont', 'someone', 'love'], 1],
#  [['hardly',
#    'get',
#    'sexso',
#    'opportunity',
#    'sick',
#    'presents',
#    'giving',
#    'pussyand',
#    'boy',
#    'generous'],
#   1],
#  [['love',
#    'people',
#    'bitch',
#    'athletes',
#    'payed',
#    'much',
#    'like',
#    'theyd',
#    'turn',
#    'millions',
#    'fuck'],
#   1],
#  [['man',
#    'call',
#    'bitch',
#    'yall',
#    'arguing',
#    'dont',
#    'think',
#    'really',
#    'actin',
#    'like',
#    'one'],
#   1],
#  [['least',
#    'nearly',
#    'two',
#    'decades',
#    'complete',
#    'trash',
#    'put',
#    'atysyc',
#    'redeem'],
#   1],
#  [['nigga', 'wus', 'graduating', 'wasnt', 'grade', 'hoe'], 1],
#  [['keep', 'bitch', 'amp', 'ill', 'stay', 'grind'], 1],
#  [['oomf', 'hoe', 'hopper'], 1],
#  [['need', 'bitches'], 1],
#  [['iont',
#    'got',
#    'not',
#    'type',
#    'bad',
#    'bitches',
#    'thing',
#    'like',
#    'throw',
#    'ass',
#    'sphere'],
#   1],
#  [['ill', 'make', 'brownies'], 2],
#  [['skippin', 'spanish', 'class', 'rest', 'week', 'fuck', 'dat', 'bitch'], 1],
#  [['everybody', 'got', 'foreign', 'bitches', 'foreign', 'cars'], 1],
#  [['sorry', 'love', 'not', 'stand', 'legs', 'open', 'easy'], 1],
#  [['live',
#    'cant',
#    'afraid',
#    'two',
#    'black',
#    'dicks',
#    'butt',
#    'fucking',
#    'queer'],
#   0],
#  [['happy', 'bob', 'comedic', 'legend', 'turns'], 2],
#  [['like', 'bitch', 'gotta', 'pretty', 'pussy', 'loose'], 1],
#  [['twitter', 'hoe'], 1],
#  [['aint', 'worried', 'nigga', 'takin', 'bitch'], 1],
#  [['punk', 'ass', 'cop', 'jus', 'bulldogged', 'bitch'], 1],
#  [['thanks', 'bitch'], 1],
#  [['youre', 'whiney', 'zima', 'shut', 'fuck'], 1],
#  [['told',
#    'niggah',
#    'maya',
#    'angelo',
#    'died',
#    'niggah',
#    'gon',
#    'ask',
#    'red',
#    'ninja',
#    'turtle',
#    'wtf'],
#   1],
#  [['really', 'committed', 'fucking', 'richest', 'bitches'], 1],
#  [['cant',
#    'bitch',
#    'living',
#    'say',
#    'brought',
#    'michael',
#    'kors',
#    'need',
#    'guys',
#    'like'],
#   1],
#  [['bust', 'nicca', 'hoe', 'shoot', 'club'], 1],
#  [['well',
#    'else',
#    'white',
#    'ppl',
#    'get',
#    'forget',
#    'horrific',
#    'past',
#    'paint',
#    'pretty',
#    'picture'],
#   0],
#  [['ill', 'fucking', 'merk', 'bitch', 'dont', 'fuck'], 1],
#  [['dope', 'ass', 'nigga', 'bitches'], 1],
#  [['lol', 'maybe', 'give', 'date', 'hoes', 'dateslet', 'know', 'work', 'lol'],
#   1],
#  [['bulls',
#    'still',
#    'not',
#    'winning',
#    'title',
#    'bland',
#    'ass',
#    'offense',
#    'pau',
#    'still',
#    'pussy',
#    'darkskin',
#    'niggas',
#    'starting',
#    'line'],
#   1],
#  [['lmfao', 'eating', 'pussy', 'really', 'want', 'braces', 'way'], 1],
#  [['feeling', 'like', 'wintertime', 'bitches'], 1],
#  [['bitch', 'get'], 1],
#  [['whoever', 'ramlogan', 'uwi', 'business', 'law', 'racist', 'mudda', 'cunt'],
#   0],
#  [['fuck', 'bitch'], 1],
#  [['heard',
#    'rumors',
#    'traitorous',
#    'bitch',
#    'named',
#    'pelosi',
#    'parading',
#    'around',
#    'illegal',
#    'aliens',
#    'vets',
#    'get',
#    'shaft'],
#   1],
#  [['cutler',
#    'didnt',
#    'step',
#    'throw',
#    'threw',
#    'int',
#    'nice',
#    'flat',
#    'footed',
#    'throw',
#    'cunt'],
#   1],
#  [['anxiety', 'person', 'kill', 'bitch', 'fuckin', 'fast'], 1],
#  [['gotta', 'phone', 'avi', 'texting', 'got', 'negative'], 1],
#  [['get', 'bitch', 'cell', 'mate'], 1],
#  [['view', 'ghetto', 'aint', 'rio'], 2],
#  [['big', 'booty', 'hoe'], 1],
#  [['vraag',
#    'maanden',
#    'hoe',
#    'pers',
#    'zich',
#    'als',
#    'een',
#    'stel',
#    'hoeren',
#    'gaan'],
#   2],
#  [['dont', 'ever', 'kiss', 'girl', 'dont', 'hug', 'hoe', 'none'], 1],
#  [['old',
#    'fellas',
#    'water',
#    'froze',
#    'funeral',
#    'home',
#    'got',
#    'unthawed',
#    'wants',
#    'help',
#    'get',
#    'pump',
#    'going',
#    'place',
#    'spooks',
#    'manboo'],
#   2],
#  [['bitch', 'car', 'way', 'fucked', 'cuss', 'bitch', 'via'], 1],
#  [['youre',
#    'way',
#    'trying',
#    'make',
#    'feel',
#    'bad',
#    'calling',
#    'fat',
#    'etc',
#    'rethink',
#    'life'],
#   1],
#  [['yes',
#    'white',
#    'washed',
#    'dont',
#    'around',
#    'repping',
#    'hood',
#    'saying',
#    'bunch',
#    'ignorant',
#    'nig',
#    'terms'],
#   0],
#  [['dont',
#    'light',
#    'skin',
#    'bitches',
#    'unread',
#    'texts',
#    'amp',
#    'still',
#    'tweet',
#    'nobody',
#    'talk',
#    'bitches',
#    'outta',
#    'control'],
#   1],
#  [['rino',
#    'trash',
#    'like',
#    'see',
#    'conservatives',
#    'democrat',
#    'party',
#    'see',
#    'blacks',
#    'slave',
#    'property'],
#   0],
#  [['lmfaoooo', 'tryna', 'see', 'many', 'hoes', 'lure'], 1],
#  [['nips', 'cold'], 2],
#  [['vice', 'versa', 'hoes'], 1],
#  [['knowing', 'picture', 'hoe', 'head', 'good', 'knocked', 'wind', 'boy'], 1],
#  [['dont', 'get', 'shit', 'bow', 'bitches'], 1],
#  [['birds', 'feather', 'stand', 'peta', 'stand', 'sanity'], 2],
#  [['glad',
#    'none',
#    'followers',
#    'say',
#    'fucked',
#    'yall',
#    'hoes',
#    'really',
#    'make',
#    'goal'],
#   1],
#  [['hey', 'boy', 'half', 'breed', 'chiricahua', 'apache', 'ass'], 1],
#  [['austin', 'mahone', 'making', 'bitches', 'horny', 'right'], 1],
#  [['dont',
#    'confidence',
#    'nonwhatsoever',
#    'youre',
#    'sole',
#    'reason',
#    'country',
#    'thi'],
#   2],
#  [['nudes', 'trash'], 2],
#  [['pollos',
#    'last',
#    'dos',
#    'pollos',
#    'estaban',
#    'dando',
#    'vueltas',
#    'una',
#    'pollera',
#    'mientras',
#    'los',
#    'estaban',
#    'cocinando',
#    'cuando'],
#   2],
#  [['imma',
#    'hit',
#    'ground',
#    'work',
#    'pussy',
#    'gone',
#    'come',
#    'back',
#    'everytime'],
#   1],
#  [['love', 'say', 'bitch'], 1],
#  [['nig',
#    'jus',
#    'said',
#    'aint',
#    'nuttin',
#    'worse',
#    'den',
#    'fat',
#    'loud',
#    'hoetru',
#    'fuckin',
#    'story'],
#   0],
#  [['bitch', 'add'], 1],
#  [['ate', 'wees', 'brownie', 'seeing', 'random', 'cats'], 2],
#  [['get', 'pussy', 'quicker', 'days'], 1],
#  [['soooo', 'bitch', 'aint', 'even', 'funny', 'lbs'], 1],
#  [['lol',
#    'cool',
#    'son',
#    'know',
#    'grandma',
#    'bald',
#    'mouthshe',
#    'got',
#    'teeth',
#    'hoe'],
#   1],
#  [['dyke', 'almost', 'came', 'didnt', 'send', 'ltltltlt'], 1],
#  [['know',
#    'bitches',
#    'never',
#    'gonna',
#    'happy',
#    'following',
#    'social',
#    'sites'],
#   1],
#  [['ill', 'kill', 'bitch', 'hesitation'], 0],
#  [['cant',
#    'watch',
#    'charlie',
#    'cloud',
#    'cry',
#    'like',
#    'little',
#    'baby',
#    'every',
#    'single',
#    'time'],
#   2],
#  [['grade', 'hoes', 'aint', 'loyal'], 1],
#  [['chest', 'tattoos', 'females', 'trash'], 2],
#  [['girl', 'stress', 'ion', 'even', 'hoes', 'shit', 'saying', 'lol'], 1],
#  [['never', 'actually', 'seen', 'yellow', 'duck'], 2],
#  [['straight',
#    'grizzly',
#    'would',
#    'buy',
#    'gay',
#    'ass',
#    'teddy',
#    'youre',
#    'already'],
#   1],
#  [['cant', 'date', 'youre', 'going', 'little', 'bitch', 'everything'], 1],
#  [['yasssss', 'bitch', 'yasssss'], 1],
#  [['feel',
#    'way',
#    'new',
#    'england',
#    'patriots',
#    'amp',
#    'new',
#    'york',
#    'yankees',
#    'unlike',
#    'ive',
#    'worked',
#    'boston',
#    'amp',
#    'nyc',
#    'texas',
#    'prison',
#    'upgrade'],
#   2],
#  [['not', 'coon', 'sick', 'fake', 'bougie', 'ass', 'coons', 'lol'], 1],
#  [['see', 'bae', 'retweet', 'mention', 'hoe'], 1],
#  [['people',
#    'focus',
#    'skin',
#    'tones',
#    'dating',
#    'someone',
#    'fucking',
#    'retarded',
#    'brainwashed'],
#   1],
#  [['green', 'summer', 'yellow', 'cucumber', 'set', 'road', 'today', 'free'],
#   2],
#  [['niggas',
#    'fall',
#    'love',
#    'evil',
#    'bitch',
#    'turn',
#    'back',
#    'friends',
#    'cool',
#    'tho'],
#   1],
#  [['old', 'bitch', 'floppy', 'tits', 'riding', 'elevator', 'nerping', 'bad'],
#   1],
#  [['soon',
#    'left',
#    'iraq',
#    'towel',
#    'heads',
#    'think',
#    'fucking',
#    'barge',
#    'take',
#    'worked',
#    'hard',
#    'set',
#    'pisses'],
#   0],
#  [['eats', 'pussy'], 1],
#  [['stockboy',
#    'talk',
#    'tweet',
#    'lies',
#    'childish',
#    'shit',
#    'obamayoure',
#    'unqualified',
#    'appeal',
#    'dumb',
#    'rednecks'],
#   1],
#  [['picture',
#    'far',
#    'reason',
#    'makes',
#    'teabaggers',
#    'poor',
#    'spelling',
#    'really',
#    'angry'],
#   2],
#  [['year',
#    'old',
#    'gay',
#    'driving',
#    'back',
#    'roads',
#    'redneck',
#    'virginia',
#    'blasting',
#    'cheetah',
#    'girls',
#    'doesnt',
#    'scream'],
#   2],
#  [['hear', 'someone', 'show', 'niggas', 'play'], 1],
#  ...]

# %%
documents
# Out:
# [[['yall',
#    'say',
#    'dating',
#    'lil',
#    'girls',
#    'like',
#    'mature',
#    'hoes',
#    'rampage',
#    'outside'],
#   1],
#  [['back'], 1],
#  [['lmfao', 'bitch', 'giving', 'head', 'back', 'classroom', 'better', 'ahead'],
#   1],
#  [['dont', 'say', 'shit', 'like', 'lil', 'nig', 'ill', 'give', 'stamp'], 1],
#  [['young', 'jezzy', 'dat', 'nigguh'], 1],
#  [['shit', 'wanna', 'fuck', 'may', 'god', 'aint', 'hoe'], 1],
#  [['shy', 'bunny'], 2],
#  [['bitch', 'always', 'got', 'shit', 'say', 'people', 'like'], 1],
#  [['wanna', 'pimp', 'amp', 'ride', 'rarris'], 1],
#  [['heard', 'pussy', 'niggas', 'hatin'], 1],
#  [['inmate', 'sums', 'return', 'means'], 2],
#  [['want', 'ian', 'trippin', 'hoes'], 1],
#  [['yall',
#    'men',
#    'need',
#    'watch',
#    'cream',
#    'pies',
#    'bitches',
#    'yeast',
#    'infections',
#    'amp',
#    'day',
#    'monistat',
#    'treatment',
#    'know',
#    'difference'],
#   1],
#  [['gradeschool',
#    'dance',
#    'tried',
#    'worm',
#    'impress',
#    'bitch',
#    'slammed',
#    'dick',
#    'unforgiving',
#    'ceramic'],
#   1],
#  [['perhaps',
#    'not',
#    'diehard',
#    'yankee',
#    'theres',
#    'point',
#    'watching',
#    'debacle',
#    'else',
#    'lol'],
#   2],
#  [['homie', 'reallly', 'love', 'fat', 'bitches', 'like', 'love'], 1],
#  [['orr', 'thts', 'lor', 'bae', 'tho', 'wyd', 'fucking'], 1],
#  [['time', 'bounce', 'bronx'], 2],
#  [['bitches',
#    'rather',
#    'petty',
#    'hoes',
#    'instead',
#    'posting',
#    'bail',
#    'really',
#    'fck',
#    'uppsa'],
#   1],
#  [['pissed', 'lad', 'past', 'would', 'lick', 'dirty', 'soles', 'slept'], 2],
#  [['jealous', 'bitches', 'smh'], 1],
#  [['pussy'], 1],
#  [['fuck', 'outta', 'faggot', 'wouldnt', 'even', 'fair'], 0],
#  [['wish', 'got', 'hoes', 'like', 'james', 'bond'], 1],
#  [['pick',
#    'president',
#    'uncle',
#    'tom',
#    'association',
#    'would',
#    'pick',
#    'larry',
#    'elder'],
#   2],
#  [['bitches', 'dont', 'want', 'boyfriend', 'want', 'pimp'], 1],
#  [['fuk', 'dat', 'bitch', 'lol', 'voice'], 1],
#  [['someone',
#    'tell',
#    'dreads',
#    'part',
#    'uniform',
#    'pull',
#    'hair',
#    'trash',
#    'cut',
#    'doodoo',
#    'braids'],
#   2],
#  [['appropriately', 'guy', 'wears', 'yellow', 'rick', 'james', 'face'], 2],
#  [['good', 'riddance', 'bitches'], 1],
#  [['pirates', 'made', 'playoffs', 'yankees', 'outhell', 'frozen'], 2],
#  [['swear',
#    'needa',
#    'back',
#    'old',
#    'bitches',
#    'think',
#    'game',
#    'apparently',
#    'lets',
#    'real'],
#   1],
#  [['naw', 'bryan', 'said', 'trash', 'hotel', 'staying', 'somewhere', 'else'],
#   2],
#  [['fuck', 'yaw', 'sayin', 'bitch', 'hood', 'love'], 1],
#  [['fucking', 'gook'], 0],
#  [['night', 'cap', 'nonsense'], 2],
#  [['facebook', 'needs'], 1],
#  [['cause', 'bitch', 'tae'], 1],
#  [['kirk', 'aint', 'nothing', 'bitch', 'amphiphop'], 1],
#  [['niggas', 'sleepin', 'bitches', 'lmfao', 'maury', 'fake'], 0],
#  [['cant', 'bomb', 'single', 'bitches', 'available'], 1],
#  [['swear', 'god', 'bitch', 'bouta', 'delete', 'twitter', 'account'], 1],
#  [['bitch', 'choosinh', 'letr'], 1],
#  [['cant', 'hoe', 'saying', 'another', 'girls', 'hoe', 'cancels'], 1],
#  [['hoes', 'fucking', 'dick', 'turn', 'lol', 'fuckem'], 1],
#  [['tall', 'tee', 'sum', 'slouch', 'shoes', 'couldve', 'fucc', 'bitch'], 1],
#  [['bitch', 'mouth', 'made', 'honor', 'roll'], 1],
#  [['someone',
#    'recently',
#    'told',
#    'local',
#    'yokel',
#    'going',
#    'use',
#    'twitter',
#    'account',
#    'damage',
#    'yeah'],
#   2],
#  [['aint', 'mad', 'thats', 'hoes'], 1],
#  [['charlie', 'mountain', 'top', 'music', 'fest'], 2],
#  [['bae',
#    'always',
#    'bae',
#    'even',
#    'bae',
#    'not',
#    'thats',
#    'still',
#    'bae',
#    'therefore',
#    'hoes',
#    'move',
#    'around',
#    'please'],
#   1],
#  [[], 1],
#  [['american', 'version', 'trash'], 2],
#  [['hit', 'bitch'], 1],
#  [['weve', 'used', 'word', 'cunt', 'almost', 'times', 'beautiful'], 1],
#  [['two', 'months', 'tho', 'hoe'], 1],
#  [['nigga',
#    'lol',
#    'idk',
#    'elway',
#    'trying',
#    'snatch',
#    'come',
#    'redskins',
#    'shitttt',
#    'sign',
#    'revis',
#    'idk',
#    'want',
#    'lls'],
#   1],
#  [['like', 'queer', 'cmon', 'jen', 'even', 'need', 'ask'], 1],
#  [['since', 'hoes', 'wanna', 'childish'], 1],
#  [['nah',
#    'aint',
#    'hoe',
#    'niggah',
#    'bitch',
#    'niggah',
#    'rich',
#    'niggah',
#    'shits',
#    'niggah',
#    'getchu',
#    'chipped',
#    'niggah'],
#   1],
#  [['see', 'tweets', 'lmfao', 'von', 'kick', 'curb', 'call', 'curse', 'ass'],
#   1],
#  [['thats', 'logic', 'hoe', 'single', 'nobody', 'tell'], 1],
#  [['apparently',
#    'little',
#    'pussy',
#    'cant',
#    'converse',
#    'nevermind',
#    'fight',
#    'ive',
#    'blocked',
#    'well',
#    'youth',
#    'gets',
#    'frustrated',
#    'easy'],
#   1],
#  [['shouldnt',
#    'club',
#    'done',
#    'club',
#    'saw',
#    'bitches',
#    'reject',
#    'dance',
#    'man'],
#   1],
#  [['bitch', 'plz', 'whatever'], 1],
#  [['sore',
#    'loser',
#    'charlie',
#    'crist',
#    'wont',
#    'give',
#    'concession',
#    'calls',
#    'recount'],
#   2],
#  [['way',
#    'dude',
#    'fat',
#    'diet',
#    'twinkies',
#    'breakfast',
#    'tacos',
#    'miss',
#    'breakfast',
#    'tacos'],
#   2],
#  [['texans', 'wont', 'play', 'redskins', 'year'], 2],
#  [['bitch', 'took', 'phone'], 1],
#  [['yall', 'defense', 'trash'], 2],
#  [['male',
#    'rap',
#    'artist',
#    'not',
#    'talking',
#    'bitches',
#    'drugs',
#    'niggas',
#    'dont',
#    'wanna',
#    'hear',
#    'shit'],
#   1],
#  [['dont', 'mind', 'retarded', 'ass'], 1],
#  [['smoke', 'sum', 'bitch'], 1],
#  [['god',
#    'bless',
#    'delusional',
#    'bitches',
#    'still',
#    'trying',
#    'keep',
#    'duck',
#    'face',
#    'alive'],
#   1],
#  [['flex',
#    'aint',
#    'turning',
#    'take',
#    'bitch',
#    'fly',
#    'town',
#    'macin',
#    'stackin',
#    'ready',
#    'get',
#    'crackin',
#    'aint'],
#   1],
#  [['pie', 'crust', 'trash', 'flaky', 'dry', 'shit'], 1],
#  [['fuckin', 'rent', 'lame', 'hoe'], 1],
#  [['right', 'pussy'], 1],
#  [['bitch', 'shut', 'hand', 'flowers', 'light', 'change'], 1],
#  [['colored', 'contacts'], 2],
#  [['aint', 'hoe', 'get', 'trap'], 1],
#  [['suckin', 'cuz', 'pretty', 'bitch'], 1],
#  [['used',
#    'dollar',
#    'menu',
#    'amp',
#    'spectate',
#    'mall',
#    'buying',
#    'bitch',
#    'cause',
#    'shit',
#    'want'],
#   1],
#  [['hey', 'bitchadam', 'showed', 'upbring', 'beer'], 1],
#  [['dont',
#    'get',
#    'twisted',
#    'said',
#    'aint',
#    'playin',
#    'state',
#    'mind',
#    'bitches',
#    'around'],
#   1],
#  [['side',
#    'bitch',
#    'main',
#    'bitch',
#    'cause',
#    'main',
#    'bitch',
#    'aint',
#    'feelin',
#    'moe'],
#   1],
#  [['hick', 'accent', 'comes', 'get', 'around', 'family'], 2],
#  [['could', 'brownie', 'right'], 2],
#  [['ill',
#    'pay',
#    'yall',
#    'niggas',
#    'get',
#    'much',
#    'yall',
#    'hoe',
#    'niggas',
#    'gunna',
#    'cost'],
#   1],
#  [['drinking', 'away', 'stress', 'got', 'new', 'hoes'], 1],
#  [['mary', 'isnt', 'backstabbing', 'bitch', 'lies', 'deceives'], 1],
#  [['stupid', 'bitch', 'apparently'], 1],
#  [['fucking', 'douche', 'bro', 'youre', 'fag'], 1],
#  [['dont', 'bitch', 'someone', 'bitch'], 1],
#  [['touched', 'pussy'], 1],
#  [['dad', 'brought', 'home', 'watermelon', 'dont', 'like', 'going', 'trash'],
#   2],
#  [['nigga', 'fuckin', 'faggot'], 0],
#  [['please', 'youre', 'pussy'], 1],
#  [['wonder',
#    'latino',
#    'strategy',
#    'goper',
#    'doubles',
#    'wetbacks',
#    'backpedals',
#    'shoot',
#    'sight'],
#   0],
#  [['fugly', 'queer', 'white', 'trash'], 0],
#  [['girls',
#    'still',
#    'virgins',
#    'got',
#    'months',
#    'live',
#    'bitch',
#    'better',
#    'throw',
#    'ass',
#    'back'],
#   1],
#  [['scared',
#    'orientationi',
#    'hate',
#    'meetin',
#    'new',
#    'peopletheyre',
#    'gonna',
#    'think',
#    'quiet',
#    'girl',
#    'really',
#    'craziest',
#    'bitch',
#    'theyll',
#    'ever',
#    'meet'],
#   1],
#  [['shit', 'baltimore', 'man', 'hoes', 'fine', 'amp', 'crazy'], 1],
#  [['playing', 'tonight', 'not', 'friends'], 2],
#  [['eat', 'lot', 'protein', 'eat', 'lot', 'pussy', 'eat', 'whole', 'ass'], 1],
#  [['yer', 'gonna', 'continue', 'contrarian', 'bitch', 'die', 'ive', 'time'],
#   0],
#  [['ronny', 'kamm', 'pussy'], 1],
#  [['chris', 'faggot'], 1],
#  [['lmao', 'dad', 'raised', 'bitch', 'made', 'nigga'], 0],
#  [['talking',
#    'hate',
#    'men',
#    'done',
#    'penis',
#    'get',
#    'manly',
#    'looking',
#    'chick',
#    'uses',
#    'strap',
#    'bitch',
#    'stfu'],
#   1],
#  [['nigga',
#    'santa',
#    'come',
#    'hood',
#    'niggas',
#    'gonna',
#    'rob',
#    'sleigh',
#    'hoes'],
#   1],
#  [['didnt', 'get', 'write', 'thank', 'god', 'lol', 'dumb', 'white', 'bitch'],
#   1],
#  [['personality',
#    'fat',
#    'bitches',
#    'relationships',
#    'pretty',
#    'lets',
#    'see',
#    'answers',
#    'lol'],
#   1],
#  [['time',
#    'year',
#    'lightskin',
#    'hoes',
#    'swore',
#    'brown',
#    'cuz',
#    'summer',
#    'tan',
#    'come',
#    'back'],
#   1],
#  [['one', 'time', 'band', 'stuck', 'flute', 'pussy', 'springs'], 1],
#  [['iont', 'got', 'typebad', 'bitches', 'thing', 'like'], 1],
#  [['put', 'touch', 'mix'], 2],
#  [['niggas', 'send', 'hate', 'thru', 'bitches'], 1],
#  [['ghetto', 'ass', 'bands', 'gets'], 1],
#  [['not',
#    'animal',
#    'crackers',
#    'want',
#    'animal',
#    'crackers',
#    'shaped',
#    'like',
#    'master',
#    'chiefs',
#    'trolls',
#    'guns',
#    'thatd',
#    'rule'],
#   1],
#  [['friday'], 1],
#  [['tyler',
#    'creator',
#    'said',
#    'rape',
#    'pregnant',
#    'bitch',
#    'tell',
#    'friends',
#    'threesome'],
#   1],
#  [['idc', 'none', 'bitches'], 1],
#  [['awkward', 'moment', 'hoe', 'says', 'shes', 'not', 'hoe'], 1],
#  [['lemme', 'throw', 'hows'], 2],
#  [['one', 'mans', 'trash', 'another', 'mans', 'wife'], 2],
#  [['reading',
#    'sexual',
#    'assault',
#    'case',
#    'takes',
#    'back',
#    'collegeill',
#    'never',
#    'forget',
#    'walk',
#    'would',
#    'say',
#    'dont',
#    'run',
#    'trains',
#    'hoesstraight',
#    'trouble'],
#   1],
#  [['cant', 'fuck', 'sentimental', 'bitches'], 1],
#  [['ant', 'pussy', 'dont', 'make', 'pull'], 1],
#  [['really', 'thou', 'looking', 'like', 'hulk', 'hogan', 'bitch'], 1],
#  [['lmfao', 'putting', 'twitter', 'see', 'fat', 'bitch'], 1],
#  [['fuck',
#    'cock',
#    'sucker',
#    'hulk',
#    'hogan',
#    'put',
#    'camel',
#    'clutch',
#    'fuck',
#    'ass',
#    'make',
#    'humble'],
#   1],
#  [['glad',
#    'bey',
#    'shitnow',
#    'bitches',
#    'wit',
#    'one',
#    'shaved',
#    'side',
#    'ahead',
#    'amp',
#    'shave',
#    'side'],
#   1],
#  [['want', 'clams', 'half', 'shell'], 2],
#  [['fag'], 0],
#  [['woman',
#    'take',
#    'serious',
#    'youre',
#    'mean',
#    'nigga',
#    'take',
#    'serious',
#    'youre',
#    'lol',
#    'like'],
#   1],
#  [['bitch', 'anyway'], 1],
#  [['crafty', 'bitches', 'best', 'way', 'cheat', 'test'], 1],
#  [['cunt'], 1],
#  [['hoe', 'tripppped', 'people', 'wildin'], 1],
#  [['fugly', 'bitch', 'john', 'dump', 'ratchet', 'ass'], 1],
#  [['lmaoo', 'bad', 'hit', 'matching', 'bad', 'matching'], 1],
#  [['blacks', 'typical', 'niggers'], 0],
#  [['bitch', 'got', 'zero', 'kills', 'yet', 'got', 'legendary', 'absolute'], 1],
#  [['little', 'bitch', 'cuz', 'feeling'], 1],
#  [['amp', 'xavier', 'bitch'], 1],
#  [['shoot', 'shorty', 'bitch'], 1],
#  [['facebook', 'fags'], 1],
#  [['big', 'night'], 2],
#  [['show',
#    'last',
#    'night',
#    'badass',
#    'thanks',
#    'everyone',
#    'came',
#    'didnt',
#    'come',
#    'youre',
#    'retard',
#    'unless',
#    'cock',
#    'sparrer'],
#   1],
#  [['thats',
#    'not',
#    'even',
#    'real',
#    'must',
#    'hit',
#    'blunt',
#    'started',
#    'making',
#    'shit',
#    'nigger',
#    'ass',
#    'lol'],
#   0],
#  [['grade', 'pussy'], 1],
#  [['bitch', 'called', 'bougie', 'whore', 'angry', 'lmao'], 1],
#  [['one', 'biggest', 'arrests', 'gotta', 'act', 'like'], 1],
#  [['boys',
#    'faith',
#    'bitch',
#    'shut',
#    'youre',
#    'high',
#    'school',
#    'acting',
#    'like',
#    'going',
#    'person',
#    'marry'],
#   1],
#  [['yall',
#    'saw',
#    'mad',
#    'little',
#    'chunky',
#    'boy',
#    'wouldnt',
#    'even',
#    'let',
#    'dad',
#    'touch',
#    'bruh',
#    'lmao'],
#   2],
#  [['okay',
#    'know',
#    'like',
#    'ten',
#    'years',
#    'late',
#    'freaking',
#    'hate',
#    'ana',
#    'sofia',
#    'lost',
#    'fuck',
#    'dumb',
#    'bitch',
#    'wtf',
#    'problem'],
#   1],
#  [['sitting', 'pretty', 'makes', 'bitches', 'mad', 'pretty', 'much'], 1],
#  [['sharkeishad',
#    'lose',
#    'ones',
#    'face',
#    'due',
#    'brute',
#    'force',
#    'knockout',
#    'punch',
#    'dat',
#    'bitch',
#    'got',
#    'sharkeishad'],
#   1],
#  [['swore', 'school', 'bitch', 'open', 'home'], 1],
#  [['irritating',
#    'reading',
#    'ppl',
#    'bitch',
#    'abt',
#    'yet',
#    'offer',
#    'shit',
#    'evidence',
#    'even',
#    'support',
#    'slant',
#    'simply',
#    'complaining',
#    'easy',
#    'part'],
#   1],
#  [['ass',
#    'slapping',
#    'one',
#    'greatest',
#    'things',
#    'haha',
#    'slapped',
#    'girl',
#    'ass',
#    'got',
#    'mad',
#    'aint',
#    'get',
#    'pussy',
#    'week'],
#   1],
#  [['marilyn', 'monroe', 'set', 'standard', 'hoes', 'achieve', 'society'], 1],
#  [['bitch', 'official', 'dick', 'harder', 'missile'], 1],
#  [['sent', 'bitch', 'smiley', 'bitches', 'love', 'smiley', 'faces'], 1],
#  [['grandmas',
#    'always',
#    'asking',
#    'noi',
#    'got',
#    'hoes',
#    'mean',
#    'real',
#    'shit'],
#   1],
#  [['fag', 'back'], 1],
#  [['aint',
#    'fenna',
#    'locked',
#    'hours',
#    'day',
#    'beating',
#    'dick',
#    'guilty',
#    'fucking',
#    'free',
#    'world',
#    'pussy'],
#   1],
#  [['cannot', 'worried', 'bout', 'bitch'], 1],
#  [['hate', 'wcw', 'ass', 'bitches'], 1],
#  [['looking',
#    'like',
#    'hillbilly',
#    'not',
#    'matching',
#    'best',
#    'goodnight',
#    'losers'],
#   0],
#  [['wrong',
#    'laughin',
#    'dem',
#    'niccas',
#    'cryin',
#    'interrogation',
#    'roomhell',
#    'noooopussy',
#    'ass'],
#   1],
#  [['side', 'bitch', 'made'], 1],
#  [['country', 'bumpkin', 'word', 'day', 'yokel'], 2],
#  [['sense', 'humor', 'back', 'backs', 'lil', 'bitch'], 1],
#  [['nigga',
#    'beat',
#    'ass',
#    'bitch',
#    'weve',
#    'never',
#    'even',
#    'fought',
#    'need',
#    'stop',
#    'making',
#    'shit',
#    'bring',
#    'ass'],
#   1],
#  [['people', 'site', 'fucking', 'retarded', 'sometimes'], 0],
#  [['bitch', 'got', 'acting', 'crazy', 'hell', 'lately'], 1],
#  [['music', 'suggestion', 'lil', 'spook'], 2],
#  [['girl', 'bring', 'hoes', 'trying', 'get', 'know'], 1],
#  [['got', 'hoes', 'got', 'hoes', 'got', 'hoes', 'got', 'hoes'], 1],
#  [['going', 'kill', 'dont', 'killin', 'hoes'], 1],
#  [['get', 'shit', 'hoe'], 1],
#  [['reports',
#    'say',
#    'female',
#    'victim',
#    'shot',
#    'waiting',
#    'oreo',
#    'mcflurry'],
#   2],
#  [['really', 'tired', 'constant', 'bitch', 'face'], 1],
#  [['funny',
#    'read',
#    'retard',
#    'liberal',
#    'tweets',
#    'anand',
#    'didnt',
#    'delete',
#    'salwar',
#    'tweet',
#    'anyway',
#    'say'],
#   1],
#  [['sources', 'confirmed', 'iggy', 'concert', 'last', 'night', 'trash'], 2],
#  [['cants', 'even', 'fool', 'colored', 'man', 'wit', 'dis', 'bullshit'], 1],
#  [['ride', 'nigga', 'whole', 'life', 'new', 'pussy', 'fuck', 'one', 'night'],
#   1],
#  [['fat',
#    'ass',
#    'inbred',
#    'rednecks',
#    'like',
#    'paula',
#    'deen',
#    'breed',
#    'going',
#    'extinct',
#    'mean',
#    'look',
#    'would',
#    'hate',
#    'scale'],
#   0],
#  [['wills',
#    'tweets',
#    'scream',
#    'look',
#    'pansy',
#    'ass',
#    'bitch',
#    'like',
#    'days',
#    'week'],
#   1],
#  [['got', 'like', 'hoes', 'low', 'pro'], 1],
#  [['shout',
#    'bitches',
#    'dont',
#    'dress',
#    'half',
#    'naked',
#    'get',
#    'mans',
#    'attention',
#    'stay'],
#   1],
#  [[], 1],
#  [['thick', 'bitch', 'tried', 'front', 'earlier'], 1],
#  [['gots',
#    'bet',
#    'msnbc',
#    'wit',
#    'dat',
#    'colored',
#    'reverend',
#    'listen',
#    'coloreds',
#    'else'],
#   0],
#  [['pickin', 'white', 'bitches', 'bare', 'like', 'chicken', 'leg'], 1],
#  [['poppy', 'give', 'discou', 'bitch', 'get'], 1],
#  [['boyfriend', 'tells', 'hoes', 'real', 'ass', 'dude'], 1],
#  [['didnt', 'know', 'alberta', 'brampton', 'bitches'], 1],
#  [['yall', 'hoes', 'nasty', 'letting', 'body', 'hit', 'eat', 'yall', 'smh'],
#   1],
#  [['got', 'bitch', 'haymon', 'antonio', 'tarver'], 1],
#  [['catch', 'lingo', 'itty', 'bitty', 'bitch'], 1],
#  [['eager',
#    'hoe',
#    'didnt',
#    'even',
#    'read',
#    'twitpic',
#    'selfie',
#    'wearing',
#    'leotard'],
#   1],
#  [['dont', 'cat', 'youre', 'big', 'pussy'], 1],
#  [['entertain',
#    'flirtin',
#    'ass',
#    'niggah',
#    'want',
#    'thats',
#    'gon',
#    'niggah',
#    'friendly',
#    'ass'],
#   1],
#  [['one', 'best', 'time', 'anybody', 'seen', 'believe', 'hes', 'dressed'], 1],
#  [['pull', 'make', 'bitch', 'mad'], 1],
#  [['purple', 'headed', 'cunt'], 1],
#  [['bitch', 'died', 'read'], 1],
#  [['ever', 'randomly', 'woke', 'bitch', 'standing', 'staring'], 1],
#  [['sorry', 'came', 'pussy', 'like', 'wrecking', 'ball'], 1],
#  [['nigga', 'future', 'always', 'hoes'], 1],
#  [['ask',
#    'every',
#    'bitch',
#    'gay',
#    'not',
#    'sexual',
#    'wtf',
#    'dont',
#    'mind',
#    'asking'],
#   1],
#  [['jason',
#    'admitted',
#    'youre',
#    'stuck',
#    'bitch',
#    'think',
#    'youre',
#    'much',
#    'better',
#    'naaaaa'],
#   0],
#  [['bravoquality', 'trash'], 2],
#  [['bad', 'bitch', 'knows', 'carsgtgtgt'], 1],
#  [['damn',
#    'sick',
#    'damn',
#    'lie',
#    'smfhskinny',
#    'girls',
#    'look',
#    'like',
#    'iphones',
#    'jeans',
#    'come',
#    'bitch',
#    'stop'],
#   1],
#  [['tell', 'baddest', 'hoes', 'beat', 'unless', 'gone', 'strip'], 1],
#  [['bitches', 'gone', 'wat', 'bitches'], 1],
#  [['imma', 'get', 'crew', 'dis', 'fuckin', 'fag', 'real', 'talk', 'nigga'], 1],
#  [['fucking',
#    'ignorant',
#    'talk',
#    'lot',
#    'shit',
#    'someone',
#    'dont',
#    'wanna',
#    'fight',
#    'mama',
#    'raised',
#    'bitch'],
#   1],
#  [['impress',
#    'young',
#    'white',
#    'girl',
#    'next',
#    'doe',
#    'taking',
#    'giant',
#    'negro',
#    'thang',
#    'usin',
#    'flip',
#    'hamburgers'],
#   1],
#  [['last',
#    'time',
#    'wore',
#    'shirt',
#    'wearing',
#    'today',
#    'fought',
#    'bitch',
#    'ratchet',
#    'yanked',
#    'fuck',
#    'outta',
#    'shirt'],
#   1],
#  [['get', 'two', 'birds', 'stoned', 'one', 'time'], 2],
#  [['cant',
#    'get',
#    'smoke',
#    'unless',
#    'bitch',
#    'struggles',
#    'girl',
#    'doesnt',
#    'actuality',
#    'great',
#    'thing'],
#   1],
#  [['crazy',
#    'female',
#    'wrong',
#    'shes',
#    'every',
#    'type',
#    'hoe',
#    'guy',
#    'theres',
#    'justific'],
#   2],
#  [['hes', 'clue'], 1],
#  [['officially', 'fucking', 'retarded'], 0],
#  [['girls',
#    'going',
#    'school',
#    'kind',
#    'aquatic',
#    'colored',
#    'weaves',
#    'headfuck',
#    'going'],
#   1],
#  [['school', 'flow', 'dumb', 'hoe'], 1],
#  [['swear', 'care', 'bout', 'everything', 'bitches'], 1],
#  [['jennas', 'faggot'], 0],
#  [['species',
#    'birds',
#    'reported',
#    'chesterfield',
#    'great',
#    'backyard',
#    'bird',
#    'count',
#    'many'],
#   2],
#  [['news', 'bitch', 'cook'], 1],
#  [['new', 'way', 'look', 'find', 'trash'], 2],
#  [['fresh',
#    'jail',
#    'got',
#    'chopper',
#    'bitches',
#    'like',
#    'vick',
#    'number',
#    'like',
#    'whopper'],
#   1],
#  [['bitch', 'see', 'katy', 'perry', 'pic', 'katy', 'perry', 'fit'], 1],
#  [['mud', 'shark', 'black', 'friends', 'makes', 'perfect', 'sense'], 2],
#  [['follow', 'back', 'bitch'], 1],
#  [['dont', 'trust', 'niggas', 'bitches'], 1],
#  [['leave', 'nicca', 'traumatized'], 1],
#  [['good',
#    'morning',
#    'lightskin',
#    'dyke',
#    'bitches',
#    'steven',
#    'segal',
#    'ponytails'],
#   0],
#  [['run', 'dick', 'inside', 'pussy', 'straight', 'dudes', 'know', 'dick'], 1],
#  [['feel', 'like', 'swag', 'fag', 'shirt', 'lmao'], 1],
#  [['great',
#    'loser',
#    'amp',
#    'coward',
#    'grabbed',
#    'iphone',
#    'threw',
#    'street',
#    'hes',
#    'pussy'],
#   1],
#  [['dear', 'von', 'karmas', 'bitch'], 1],
#  [['two', 'bad', 'bitches', 'giving', 'head', 'dam', 'time', 'lol', 'aww'], 1],
#  [['bitches'], 1],
#  [['exactly',
#    'tweet',
#    'shit',
#    'fuck',
#    'dont',
#    'like',
#    'everybody',
#    'aint',
#    'monkey',
#    'see',
#    'monkey',
#    'koiya'],
#   1],
#  [['aint',
#    'nothin',
#    'piece',
#    'cheese',
#    'corners',
#    'words',
#    'aint',
#    'never',
#    'gone',
#    'slice',
#    'bitch'],
#   1],
#  [['youre', 'faggotyoure', 'texas', 'fan'], 0],
#  [['bitches', 'came', 'wit'], 1],
#  [['shit',
#    'using',
#    'linkedin',
#    'work',
#    'lmfaoo',
#    'bagging',
#    'linkiden',
#    'hoes',
#    'lol'],
#   1],
#  [['people', 'ghetto', 'rising', 'fighting', 'back', 'whose', 'side'], 2],
#  [['bih', 'stay', 'ghetto', 'ass', 'neighborhood'], 1],
#  [['youre',
#    'killin',
#    'not',
#    'conservatives',
#    'like',
#    'not',
#    'nbp',
#    'hate',
#    'honkies'],
#   1],
#  [['kush', 'god', 'bitch'], 1],
#  [['pass', 'sticks'], 1],
#  [['trash',
#    'guess',
#    'got',
#    'tired',
#    'chalmers',
#    'trash',
#    'starting',
#    'chalmers',
#    'lose',
#    'job',
#    'norris',
#    'lmfaoooo'],
#   1],
#  [['sweet', 'yellow', 'bone', 'call', 'honey', 'mustard'], 2],
#  [['hoes', 'aint', 'loyal'], 1],
#  [['wont',
#    'say',
#    'many',
#    'bitches',
#    'fucked',
#    'might',
#    'say',
#    'many',
#    'touched'],
#   1],
#  [['well',
#    'iguess',
#    'make',
#    'hoes',
#    'loyal',
#    'bro',
#    'theyll',
#    'never',
#    'loyal',
#    'hoes',
#    'nig'],
#   1],
#  [['jihadi',
#    'pop',
#    'music',
#    'hear',
#    'latest',
#    'abu',
#    'yasser',
#    'totally',
#    'abu',
#    'hajar',
#    'fan'],
#   2],
#  [['got', 'bitch', 'work', 'mad', 'bitch', 'dick'], 1],
#  [['niqqa', 'straight', 'pussy', 'whipped'], 1],
#  [['wow', 'avoiding', 'bitch'], 1],
#  [['floyd', 'mayweather', 'stay', 'badd', 'bitch', 'lol'], 1],
#  [['bitches',
#    'lol',
#    'cute',
#    'tho',
#    'wassup',
#    'gimmi',
#    'numba',
#    'imma',
#    'natural',
#    'lmfaoo'],
#   1],
#  [['bad', 'bitch', 'without', 'come', 'meet', 'without'], 1],
#  [['well', 'maybe', 'youre', 'whore', 'stupid', 'ugly', 'homeless', 'bitch'],
#   0],
#  [['cost',
#    'aint',
#    'buying',
#    'pussy',
#    'got',
#    'many',
#    'followers',
#    'vegas',
#    'dont',
#    'miss',
#    'opportunities'],
#   1],
#  [['know', 'right', 'much', 'retard'], 1],
#  [['girl',
#    'tweeted',
#    'might',
#    'ghetto',
#    'bring',
#    'food',
#    'outside',
#    'movies',
#    'might',
#    'stupid',
#    'pay'],
#   1],
#  [['currently', 'sitting', 'wishing', 'bitch', 'would'], 1],
#  [['kicking', 'bitches', 'house', 'like', 'pam'], 1],
#  [['please',
#    'stay',
#    'safe',
#    'love',
#    'hoe',
#    'one',
#    'day',
#    'meet',
#    'happy',
#    'halloween'],
#   2],
#  [['besides', 'one', 'two', 'bitches', 'always', 'catch'], 1],
#  [['one',
#    'managers',
#    'tried',
#    'talking',
#    'stay',
#    'till',
#    'aint',
#    'nobody',
#    'ordering',
#    'walked',
#    'shmoove',
#    'bitch'],
#   1],
#  [['liked', 'video', 'sock', 'short', 'film'], 2],
#  [['geminis', 'rule', 'hoe'], 1],
#  [['rest',
#    'peace',
#    'bad',
#    'boys',
#    'bad',
#    'advise',
#    'made',
#    'let',
#    'old',
#    'asian',
#    'dude',
#    'glue',
#    'sole'],
#   2],
#  [['bitch'], 1],
#  [['hoes', 'twerkin', 'new', 'weave'], 1],
#  [['babymama', 'drama', 'side', 'hoes'], 1],
#  [['lauderdale', 'thats', 'hoes'], 1],
#  [['nigga', 'train', 'treating', 'bitch', 'phone', 'lmao'], 1],
#  [['send', 'hoe'], 1],
#  [['queer', 'ass', 'shorts', 'rabchenko', 'got'], 0],
#  [['faggot'], 1],
#  [['monkey', 'back', 'keeps', 'smearing', 'poop', 'hair'], 2],
#  [['dis', 'bitch', 'gots'], 1],
#  [['bad', 'bitches', 'aint', 'cheap'], 1],
#  [['see', 'jig'], 2],
#  [['two', 'best', 'yankees', 'derek', 'jeter', 'joe', 'torre'], 2],
#  [['man',
#    'bitch',
#    'not',
#    'gonna',
#    'damn',
#    'dont',
#    'like',
#    'got',
#    'say',
#    'unfollow'],
#   0],
#  [['everyone',
#    'needs',
#    'stop',
#    'bitchin',
#    'jeter',
#    'youre',
#    'witnessing',
#    'last',
#    'week',
#    'baseball',
#    'greatest',
#    'player',
#    'wear',
#    'yankees',
#    'uniform'],
#   1],
#  [['nevermind', 'found', 'trash'], 2],
#  [['nah', 'laps', 'around', 'dam', 'lol'], 2],
#  [['pussy', 'rap', 'sheet', 'whole', 'lot', 'bros'], 1],
#  [['got',
#    'dawg',
#    'norris',
#    'blue',
#    'flames',
#    'bday',
#    'dat',
#    'bitch',
#    'couldnt',
#    'even',
#    'drink',
#    'pop',
#    'alcoholic',
#    'ass',
#    'downed'],
#   1],
#  [['want', 'cowboy', 'killer'], 2],
#  [['forms', 'bitch', 'still', 'dont', 'get', 'saiyan'], 1],
#  [['new',
#    'iphone',
#    'software',
#    'maybe',
#    'ill',
#    'sue',
#    'cunts',
#    'amp',
#    'request',
#    'damages',
#    'based',
#    'pussy',
#    'ive',
#    'missed'],
#   1],
#  [['dick', 'called', 'eggo', 'bitches', 'never', 'want', 'leggo', 'eggo'], 1],
#  [['wtf', 'bitches', 'seen', 'without'], 1],
#  [['drunk', 'eat', 'fucking', 'twat'], 1],
#  [['flag', 'bitch', 'ghat', 'damn', 'night', 'well', 'playing'], 1],
#  [['fireball',
#    'turned',
#    'cool',
#    'liquor',
#    'used',
#    'sponsored',
#    'byto',
#    'drink',
#    'pussy',
#    'country',
#    'dudes',
#    'hear',
#    'song'],
#   1],
#  [['mom', 'came', 'home', 'tacos', 'brownies'], 2],
#  [['foo', 'came', 'club', 'wit', 'bitch', 'leash'], 1],
#  [['got',
#    'bomb',
#    'dick',
#    'amptwo',
#    'professors',
#    'month',
#    'not',
#    'hoei',
#    'say'],
#   1],
#  [['bitch',
#    'phone',
#    'stfu',
#    'talking',
#    'dont',
#    'worry',
#    'make',
#    'sure',
#    'show'],
#   1],
#  [['nicca', 'fucc'], 1],
#  [['dude', 'video', 'birds', 'work', 'fuckin'], 1],
#  [['screaming', 'like', 'little', 'bitch', 'lmaooo'], 1],
#  [['women',
#    'think',
#    'angels',
#    'denial',
#    'hoe',
#    'actions',
#    'dont',
#    'fall',
#    'facade',
#    'see',
#    'past'],
#   1],
#  [['fuck', 'said'], 1],
#  [['hoe', 'gone', 'hoe', 'aint'], 1],
#  [['like',
#    'tattoo',
#    'head',
#    'forms',
#    'mullet',
#    'white',
#    'trash',
#    'people',
#    'entertaining',
#    'sometimes'],
#   1],
#  [['bad', 'man', 'want'], 1],
#  [['ref',
#    'finally',
#    'calls',
#    'arm',
#    'ball',
#    'hoes',
#    'didnt',
#    'count',
#    'hand',
#    'ball',
#    'mexico',
#    'game'],
#   1],
#  [['gonna', 'pop', 'pussy', 'real', 'niggaa'], 1],
#  [['dawg', 'told', 'must', 'saturday', 'rockin', 'bitch', 'wit', 'tha'], 1],
#  [['feeling', 'tonight', 'trash'], 2],
#  [['like',
#    'really',
#    'doubt',
#    'even',
#    'plays',
#    'already',
#    'got',
#    'lot',
#    'big',
#    'man',
#    'rotation',
#    'committed',
#    'bosh',
#    'bird',
#    'mcbob',
#    'amp',
#    'shawne'],
#   2],
#  [['yall',
#    'tweakin',
#    'wit',
#    'wce',
#    'shit',
#    'aint',
#    'way',
#    'hell',
#    'like',
#    'bitch',
#    'every',
#    'single',
#    'day'],
#   1],
#  [['omgwhat',
#    'retardshould',
#    'asked',
#    'weighs',
#    'thousand',
#    'pounds',
#    'feathers',
#    'thousand',
#    'pounds'],
#   1],
#  [['beat', 'pussy'], 1],
#  [['know', 'bitch', 'know', 'mexican'], 1],
#  [['anything',
#    'ive',
#    'ever',
#    'said',
#    'offended',
#    'thats',
#    'problem',
#    'not',
#    'problem',
#    'dont',
#    'little',
#    'bitch'],
#   1],
#  [['karate', 'bitch'], 1],
#  [['nine', 'straight', 'hits', 'price', 'not', 'night'], 2],
#  [['want', 'bitch', 'get', 'smashed', 'wont', 'let'], 1],
#  [['hope', 'dropped', 'four', 'new', 'songs'], 2],
#  [['hoes',
#    'use',
#    'theit',
#    'happened',
#    'excuse',
#    'means',
#    'cope',
#    'wit',
#    'make',
#    'seem',
#    'control'],
#   1],
#  [['make', 'paper', 'ball', 'trash'], 2],
#  [['every',
#    'time',
#    'bitch',
#    'makes',
#    'status',
#    'guys',
#    'texts',
#    'like',
#    'whatttt',
#    'loll'],
#   1],
#  [['bitches', 'fake', 'gay'], 1],
#  [['bitch', 'dennis'], 1],
#  [['bitch', 'ass', 'chick', 'flick', 'ever', 'sad', 'movie'], 1],
#  [['shes', 'nigger'], 0],
#  [['may', 'dumb', 'even', 'sarah', 'mocks'], 2],
#  [['umm', 'sure', 'hoes', 'talk', 'arent', 'ugly'], 1],
#  [['bitches',
#    'saying',
#    'ray',
#    'rice',
#    'got',
#    'deserved',
#    'month',
#    'ago',
#    'wanted',
#    'man',
#    'free'],
#   1],
#  [['sticking',
#    'theory',
#    'black',
#    'pussy',
#    'tastes',
#    'like',
#    'strawberry',
#    'milk'],
#   1],
#  [['whipped', 'home', 'cripple', 'made'], 2],
#  [['niggas',
#    'bitchin',
#    'tell',
#    'suck',
#    'sumn',
#    'bitches',
#    'see',
#    'vision',
#    'tell',
#    'fuck',
#    'sumn'],
#   1],
#  [['hoes', 'dont', 'deserve', 'respect', 'ask'], 1],
#  [['yall',
#    'fuckin',
#    'womens',
#    'men',
#    'risking',
#    'life',
#    'amp',
#    'freedom',
#    'single',
#    'amp',
#    'dolo',
#    'bitch',
#    'gotta',
#    'worry'],
#   1],
#  [['pussy'], 1],
#  [['east',
#    'coast',
#    'theres',
#    'colored',
#    'hair',
#    'everywhere',
#    'must',
#    'sweetest',
#    'wave',
#    'ever'],
#   2],
#  [['get', 'dream', 'happy', 'dreams'], 1],
#  [['bruh',
#    'def',
#    'wanted',
#    'call',
#    'rock',
#    'nigger',
#    'last',
#    'lmaoooooooooooooooooooooooooooo'],
#   1],
#  [['nice',
#    'girls',
#    'make',
#    'get',
#    'naughty',
#    'bad',
#    'yello',
#    'real',
#    'nice',
#    'body',
#    'south',
#    'like',
#    'real',
#    'thick'],
#   1],
#  [['paper'], 1],
#  [['pacer',
#    'amp',
#    'member',
#    'loving',
#    'hair',
#    'dog',
#    'came',
#    'quadraphonic',
#    'stereo',
#    'could',
#    'say',
#    'bitchlol'],
#   1],
#  [['best', 'asian', 'massage', 'park', 'slope', 'rated', 'spa'], 2],
#  [['whos',
#    'yous',
#    'whos',
#    'yous',
#    'yes',
#    'womp',
#    'womp',
#    'lord',
#    'save',
#    'parched',
#    'hoes'],
#   1],
#  [['niggas', 'talk', 'bout', 'hoes', 'beds', 'night', 'ctfuu'], 1],
#  [['yeah', 'sucks', 'like', 'fags', 'nevermind', 'fags'], 0],
#  [['suck', 'momma', 'flappy'], 1],
#  [['bad', 'bitch', 'bouncing', 'pogo', 'screamin', 'yolo', 'nigga', 'juelz'],
#   1],
#  [['lmaoo',
#    'shouldve',
#    'seen',
#    'coming',
#    'fat',
#    'bitches',
#    'need',
#    'love',
#    'craig'],
#   1],
#  [['ashley', 'young', 'tried', 'deny', 'bird', 'landed', 'mouth', 'hahaha'],
#   2],
#  [['dont', 'girl', 'lol', 'yall', 'threesomes', 'girl', 'eat', 'pussy'], 1],
#  [['going',
#    'pussy',
#    'dont',
#    'want',
#    'love',
#    'life',
#    'seein',
#    'scared',
#    'shit'],
#   1],
#  [['terms',
#    'like',
#    'peckerwood',
#    'stereotypes',
#    'white',
#    'people',
#    'fucking',
#    'kids',
#    'sisters',
#    'isnt'],
#   0],
#  [['ill', 'continue', 'dis', 'later', 'ill', 'back', 'bitch'], 1],
#  [['light',
#    'skin',
#    'niccas',
#    'always',
#    'wanna',
#    'try',
#    'ike',
#    'lol',
#    'take',
#    'one',
#    'back'],
#   1],
#  [['fucking', 'bad', 'bitch', 'gone', 'need', 'money', 'lil'], 1],
#  [['hes', 'drinking', 'much', 'shitty', 'canadian', 'hoser'], 1],
#  [['implying',
#    'bro',
#    'amp',
#    'two',
#    'aint',
#    'nothin',
#    'lil',
#    'hoescmon',
#    'kim'],
#   1],
#  [['bitch', 'ill', 'end', 'fucking', 'life', 'fuckboy'], 1],
#  [['song', 'come', 'hit', 'blunt', 'hard', 'cause', 'hoe', 'dat', 'hard'], 1],
#  [['katy', 'clear', 'lake', 'hoes'], 1],
#  [['fucking', 'dare', 'faggot'], 1],
#  [['talked', 'ghetto', 'lol', 'annoyed', 'self'], 2],
#  [['playing',
#    'games',
#    'wrestling',
#    'ways',
#    'bind',
#    'brothers',
#    'sex',
#    'talk',
#    'amp',
#    'providing',
#    'condoms',
#    'raw',
#    'dogging',
#    'hoes'],
#   1],
#  [['lmao',
#    'dont',
#    'fight',
#    'dont',
#    'know',
#    'ghetto',
#    'ass',
#    'school',
#    'dude',
#    'highly',
#    'doubt',
#    'since',
#    'dont',
#    'give',
#    'fuck'],
#   1],
#  [['pussy', 'good', 'cant', 'pull', 'ever'], 1],
#  [['youre',
#    'concerned',
#    'much',
#    'lady',
#    'makes',
#    'thats',
#    'bitch',
#    'shit',
#    'need',
#    'ego',
#    'stroked'],
#   1],
#  [['yes',
#    'protest',
#    'sexism',
#    'right',
#    'home',
#    'beg',
#    'guy',
#    'beat',
#    'pussy',
#    'lost',
#    'times'],
#   1],
#  [['hitting',
#    'women',
#    'wrong',
#    'morally',
#    'bitches',
#    'get',
#    'kidknappedbeat',
#    'sold',
#    'sex',
#    'gonna',
#    'end'],
#   1],
#  [['mother', 'fuck', 'flappy'], 1],
#  [['bitch', 'gmfu'], 1],
#  [['bitches', 'bitches', 'bitches'], 1],
#  [['wouldnt', 'share', 'wave', 'trash', 'cans'], 2],
#  [['niggas', 'develop', 'superpowers', 'comes', 'getting', 'pussy'], 1],
#  [['drawing',
#    'organic',
#    'powdered',
#    'goats',
#    'milk',
#    'bath',
#    'rose',
#    'petals',
#    'chopped',
#    'clams',
#    'eww',
#    'kidding',
#    'bubbl'],
#   2],
#  [['bet', 'bitch', 'try', 'slide', 'let', 'hair'], 1],
#  [['pussy'], 1],
#  [['life', 'short', 'walkin', 'round', 'mad', 'bitches'], 1],
#  [['lmaooooo',
#    'relax',
#    'mark',
#    'bitch',
#    'ass',
#    'roll',
#    'fuck',
#    'state',
#    'texas'],
#   1],
#  [['new',
#    'boyfriend',
#    'every',
#    'month',
#    'doesnt',
#    'mean',
#    'youre',
#    'gorgeous',
#    'means',
#    'youre',
#    'retarded'],
#   1],
#  [['bahaha', 'omg', 'bitch', 'crazyyy'], 1],
#  [['nah', 'talk', 'hoes', 'since', 'dont', 'wanna', 'text', 'back', 'shit'],
#   1],
#  [['ebola',
#    'not',
#    'scary',
#    'yall',
#    'worried',
#    'ebola',
#    'ima',
#    'getting',
#    'hoes'],
#   1],
#  [['got',
#    'uncle',
#    'marriage',
#    'dude',
#    'got',
#    'hips',
#    'like',
#    'big',
#    'momma',
#    'swear',
#    'lil',
#    'kids',
#    'mock',
#    'walk',
#    'dont',
#    'even',
#    'know'],
#   2],
#  [['boats', 'hoes'], 1],
#  [['stupid', 'ass', 'hoes', 'days'], 1],
#  [['kannie',
#    'amp',
#    'vonnie',
#    'tiny',
#    'ass',
#    'bitches',
#    'hated',
#    'crissi',
#    'started',
#    'calling',
#    'little',
#    'body',
#    'bitches',
#    'hawaii'],
#   1],
#  [['angel', 'stop', 'rting', 'fugly', 'bitch'], 1],
#  [['huge', 'nips', 'scary', 'scary'], 1],
#  [['yall', 'gimped', 'aint', 'tht', 'bitch', 'huh', 'lol'], 1],
#  [['bout',
#    'beback',
#    'old',
#    'shit',
#    'miss',
#    'hoes',
#    'texting',
#    'saying',
#    'wanna',
#    'come',
#    'see'],
#   1],
#  [['never'], 1],
#  [['tommy', 'trash'], 2],
#  [['done', 'hit', 'bout', 'threes', 'bitch'], 1],
#  [['nig', 'gonna', 'come', 'back'], 0],
#  [['espn',
#    'keep',
#    'hiring',
#    'dyke',
#    'bitches',
#    'gay',
#    'spanish',
#    'niggas',
#    'talk',
#    'sports'],
#   0],
#  [['hoes', 'dont', 'want', 'seem', 'like', 'hoe', 'gotta', 'hit', 'low'], 1],
#  [['bitches', 'mann'], 1],
#  [['atleast', 'wipe', 'ass', 'trashy', 'bitch'], 1],
#  [['profesional', 'sports', 'enjoyed', 'white', 'trash'], 1],
#  [['never', 'let', 'another', 'bitch', 'say', 'change', 'actions', 'towards'],
#   1],
#  [['shot', 'main', 'bitches', 'side', 'bitches'], 1],
#  [['snap',
#    'chatted',
#    'one',
#    'night',
#    'lol',
#    'youre',
#    'cute',
#    'snapchat',
#    'back',
#    'nig'],
#   2],
#  [['youre', 'arent', 'rip', 'nigga', 'worthless', 'spear', 'chucker'], 0],
#  [['silencer', 'bitch', 'dont', 'make', 'sound'], 1],
#  [['didnt', 'tag', 'negro', 'lol'], 1],
#  [['gonna', 'ape', 'shit', 'uchida'], 1],
#  [['danny', 'deep', 'deep', 'water', 'many', 'badass', 'sons', 'bitches'], 1],
#  [['think', 'change', 'doctors', 'advocate', 'cunt', 'goes', 'mental'], 1],
#  [['sole',
#    'purpose',
#    'make',
#    'money',
#    'otherwise',
#    'youd',
#    'suggest',
#    'violence',
#    'prevention',
#    'policies',
#    'actually',
#    'work'],
#   2],
#  [['bathing', 'suspended', 'orb', 'tub', 'not', 'shy', 'people', 'yet'], 2],
#  [['boosie',
#    'said',
#    'got',
#    'bitch',
#    'sip',
#    'gonna',
#    'boosies',
#    'bitch',
#    'sip',
#    'bio'],
#   1],
#  [['pack',
#    'head',
#    'please',
#    'enjoy',
#    'called',
#    'hick',
#    'come',
#    'home',
#    'humbled'],
#   2],
#  [['almost', 'stepped', 'bird', 'running', 'around', 'floor', 'creepy'], 2],
#  [['got', 'new', 'bitch', 'got', 'lookin', 'like', 'yeah', 'know', 'mad'], 1],
#  [['wet', 'pussy', 'smell'], 1],
#  [['cole', 'trash', 'ive', 'saying', 'years', 'fuck', 'lol'], 1],
#  [['nigguh', 'sucks'], 1],
#  [['today',
#    'hair',
#    'makeup',
#    'always',
#    'tries',
#    'make',
#    'look',
#    'like',
#    'monkey'],
#   2],
#  [['half', 'bitches', 'say', 'tfti', 'wouldnt', 'even', 'bet'], 1],
#  [['bad', 'optimism', 'dont', 'take', 'colored', 'glasses'], 2],
#  [['majority', 'trash', 'anyway'], 2],
#  [['may', 'may', 'not', 'trash', 'taking', 'pictures', 'together'], 2],
#  [['kobe', 'bryant', 'bitch', 'grow', 'pussy'], 1],
#  [['hate', 'nigger'], 0],
#  [['even', 'bitch', 'admit', 'something', 'isnt', 'right'], 1],
#  [['hawaiian', 'thought', 'aloha', 'muzzie'], 2],
#  [['text', 'bitch'], 1],
#  [['omg', 'bitch', 'said', 'shit'], 1],
#  [['come',
#    'visit',
#    'pussy',
#    'gotta',
#    'move',
#    'city',
#    'within',
#    'months',
#    'yall',
#    'first',
#    'fuck',
#    'aint',
#    'gon',
#    'work'],
#   1],
#  [['gotta',
#    'link',
#    'bro',
#    'rambo',
#    'fashoo',
#    'gotta',
#    'pull',
#    'ona',
#    'pussy',
#    'boys'],
#   1],
#  [['send', 'bitches', 'express', 'mail', 'overnight', 'delivery'], 1],
#  [['real', 'nigga', 'speaking', 'sound', 'like', 'bitch'], 1],
#  [['dont', 'love', 'hoes'], 1],
#  [['woman',
#    'never',
#    'cheated',
#    'unless',
#    'man',
#    'drove',
#    'men',
#    'cheat',
#    'new',
#    'pussy'],
#   1],
#  [['lol', 'nig'], 1],
#  [['blocked', 'fuzzy', 'butt', 'ignore', 'low', 'life', 'creature'], 1],
#  [['real', 'nigga', 'need', 'real', 'bitch', 'somebody', 'chill'], 1],
#  [['strong', 'survive', 'nigga', 'pussy'], 1],
#  [['ive', 'ever', 'offended', 'sorry', 'youre', 'sensitive', 'lil', 'bitch'],
#   1],
#  [['waka', 'flaka', 'lucky', 'retard', 'lol'], 1],
#  [['one', 'thing', 'cant', 'stand', 'texting', 'bitches', 'got', 'droids'], 1],
#  [['spaceship', 'shit', 'retarded'], 1],
#  [['keshawn', 'martin', 'soooooooooo', 'fucking'], 1],
#  [['ugly', 'hoe'], 1],
#  [['belle'], 1],
#  [['wanna',
#    'run',
#    'around',
#    'city',
#    'make',
#    'memories',
#    'barely',
#    'remember',
#    'allow',
#    'talk',
#    'pussy',
#    'power'],
#   1],
#  [['little', 'bitches', 'proven', 'wrong'], 1],
#  [['avery',
#    'adorable',
#    'petite',
#    'red',
#    'haired',
#    'teen',
#    'plays',
#    'shavedpussy'],
#   1],
#  [['new',
#    'jersey',
#    'yellow',
#    'green',
#    'chevron',
#    'stripe',
#    'like',
#    'charlie',
#    'browns',
#    'jersey'],
#   2],
#  [[], 1],
#  [['damn', 'bird', 'nearly', 'gave', 'heart', 'said', 'bitch'], 1],
#  [['hoes', 'days'], 1],
#  [['making', 'first', 'day', 'bitch'], 1],
#  [['nigga', 'use', 'term', 'yassssssssss', 'gonna', 'assume', 'fag'], 1],
#  [['wouldnt', 'fuk', 'lot', 'bitches'], 1],
#  [['dont', 'fuck', 'wit', 'hoe', 'niggas'], 1],
#  [['would', 'think', 'common'], 2],
#  [['glads', 'dis', 'colored', 'man', 'cans', 'soyvice', 'white', 'man'], 1],
#  [['bitch', 'toooo'], 1],
#  [['hes',
#    'eating',
#    'cuz',
#    'hes',
#    'women',
#    'cant',
#    'cook',
#    'gotta',
#    'get',
#    'rid',
#    'hoe'],
#   1],
#  [['broke',
#    'hoes',
#    'always',
#    'wanna',
#    'argue',
#    'aint',
#    'ate',
#    'day',
#    'get',
#    'energy'],
#   1],
#  [['love',
#    'fuckin',
#    'wit',
#    'people',
#    'givin',
#    'greedy',
#    'ass',
#    'nigas',
#    'old',
#    'crackers',
#    'wit',
#    'expired',
#    'cheese',
#    'dey',
#    'callin',
#    'like',
#    'nigga',
#    'shittin',
#    'likea',
#    'goose'],
#   0],
#  [['would', 'call', 'thats', 'frowned', 'upon'], 1],
#  [['yellow', 'rice', 'black', 'beans', 'pork', 'chop', 'sis'], 2],
#  [['getting', 'trash', 'talked', 'year', 'old'], 2],
#  [['still', 'waiting', 'oomf', 'hit', 'hoe', 'lololol'], 1],
#  [['epic', 'storybook', 'derek', 'jeter', 'closes', 'last', 'game', 'bronx'],
#   2],
#  [['anal', 'gaping', 'tranny', 'play', 'panty', 'nylon', 'part'], 1],
#  [['fat',
#    'bitches',
#    'normal',
#    'sized',
#    'legs',
#    'looking',
#    'like',
#    'car',
#    'keys'],
#   1],
#  [['becoming',
#    'cold',
#    'hearted',
#    'bitch',
#    'wasnt',
#    'really',
#    'planned',
#    'life'],
#   1],
#  [['fast', 'cocky', 'cops', 'ditch', 'old', 'gettin', 'sloppy', 'wit', 'pots'],
#   1],
#  [['gotta',
#    'find',
#    'new',
#    'house',
#    'land',
#    'lord',
#    'bitch',
#    'getting',
#    'waaaay',
#    'better',
#    'house',
#    'good',
#    'lol'],
#   1],
#  [['yall',
#    'preppy',
#    'bitches',
#    'ever',
#    'arguing',
#    'like',
#    'party',
#    'dont',
#    'nothing',
#    'yall',
#    'getting',
#    'hit',
#    'bottle'],
#   1],
#  [['lmfao',
#    'shut',
#    'slutty',
#    'white',
#    'hoe',
#    'didnt',
#    'know',
#    'pats',
#    'got',
#    'destroyed',
#    'tonight',
#    'lmfaoooo'],
#   1],
#  [['big', 'titty', 'bitch', 'lmao', 'fuck', 'good', 'party'], 1],
#  [[], 0],
#  [['not', 'shoot', 'ima', 'beat', 'face', 'asphalt'], 0],
#  [['single', 'moms', 'got', 'proven', 'pussy', 'lol', 'fckd', 'truuu'], 1],
#  [['ians', 'retarded'], 0],
#  [['cant',
#    'decide',
#    'wear',
#    'yellow',
#    'rain',
#    'boots',
#    'purposes',
#    'black',
#    'amp',
#    'yellow',
#    'errrrything'],
#   2],
#  [['bitch'], 1],
#  [['father',
#    'born',
#    'nanticoke',
#    'attended',
#    'lehigh',
#    'love',
#    'pennsylvania',
#    'dutch',
#    'cooking'],
#   2],
#  [['hoes',
#    'fucking',
#    'niggas',
#    'got',
#    'news',
#    'monogamous',
#    'bitch',
#    'fucking',
#    'anonymous',
#    'niggas'],
#   1],
#  [['pussy', 'like', 'damn', 'pussy'], 1],
#  [['bagging',
#    'thot',
#    'bitches',
#    'amp',
#    'giving',
#    'nigga',
#    'nasty',
#    'amp',
#    'youre',
#    'better',
#    'dead'],
#   1],
#  [['sorry',
#    'give',
#    'racist',
#    'platform',
#    'trash',
#    'language',
#    'dana',
#    'intvw',
#    'kindergarten',
#    'level'],
#   2],
#  [['art', 'nobody', 'takin'], 1],
#  [['ooh', 'yea', 'getting'], 1],
#  [['superman', 'eyyyy'], 1],
#  [['ight', 'friday', 'nig'], 1],
#  [['pussy', 'doesnt', 'taste', 'like', 'pineapples'], 1],
#  [['said', 'black', 'bitch'], 1],
#  [['another', 'nigga', 'bitch'], 1],
#  [['youre', 'standing', 'slippery', 'slope', 'easy', 'libra'], 2],
#  [['dope', 'pretty', 'bitch', 'side', 'sell', 'dope', 'tryna', 'get', 'high'],
#   1],
#  [['hoes', 'not', 'fat', 'big', 'boned', 'hehehehehe'], 1],
#  [['act',
#    'sound',
#    'infront',
#    'ill',
#    'awfy',
#    'cunt',
#    'break',
#    'fukin',
#    'phone',
#    'tae'],
#   1],
#  [['bitch'], 1],
#  [['happy', 'birthday', 'love', 'faggot'], 1],
#  [['portable', 'septic', 'tank', 'allllll', 'pesky', 'feelings'], 2],
#  [['free', 'birds', 'lol'], 2],
#  [['long',
#    'distance',
#    'sex',
#    'definitely',
#    'thinking',
#    'like',
#    'bitch',
#    'lil',
#    'much'],
#   1],
#  [['bitch',
#    'cause',
#    'wanted',
#    'fight',
#    'didnt',
#    'show',
#    'tryna',
#    'make',
#    'bet',
#    'shit',
#    'get',
#    'friendly',
#    'ass',
#    'twitter'],
#   1],
#  [['like',
#    'momma',
#    'said',
#    'dont',
#    'waste',
#    'time',
#    'plzing',
#    'des',
#    'fake',
#    'ass',
#    'bitches',
#    'bum',
#    'ass',
#    'dudes',
#    'cause',
#    'aint',
#    'gone',
#    'get',
#    'nowhere',
#    'pregnant'],
#   1],
#  [['streets', 'dirty', 'niggad', 'try', 'wife', 'though'], 1],
#  [['positive', 'thoughts', 'nig', 'nog'], 1],
#  [['every', 'nigga', 'new', 'hoe', 'next', 'niggas', 'old', 'hoe'], 1],
#  [['jihadis',
#    'circulating',
#    'video',
#    'killing',
#    'boko',
#    'haram',
#    'nigerian',
#    'pilot',
#    'captured',
#    'helicopter',
#    'shoot'],
#   2],
#  [['answer', 'snapchat', 'faggot'], 0],
#  [['murda', 'mook', 'shit'], 1],
#  [['didnt',
#    'wrong',
#    'started',
#    'talking',
#    'went',
#    'wrong',
#    'trusted',
#    'bitch',
#    'ass'],
#   1],
#  [['youre',
#    'fag',
#    'using',
#    'emoji',
#    'one',
#    'best',
#    'friends',
#    'amp',
#    'never',
#    'dull',
#    'moment'],
#   1],
#  [['thanks',
#    'scaring',
#    'absolute',
#    'fuck',
#    'flatfoot',
#    'look',
#    'like',
#    'pussy',
#    'fucking',
#    'jerk'],
#   1],
#  [['damn', 'well', 'joe', 'move', 'bullpen', 'really', 'helped'], 2],
#  [['fag'], 0],
#  [['not', 'defending', 'ray', 'rice', 'double', 'standard', 'aint'], 1],
#  [['browns', 'redskins', 'shouldnt', 'considered', 'nfl', 'teams'], 2],
#  [['bitches',
#    'failed',
#    'geometry',
#    'know',
#    'exactly',
#    'angle',
#    'use',
#    'take',
#    'perfect',
#    'selfie'],
#   1],
#  [['pussy', 'aching', 'follow', 'bae'], 1],
#  [['like', 'bitch'], 1],
#  [['least', 'went', 'wasnt', 'bitch'], 1],
#  [['fitzpatrick', 'trash', 'bruh'], 2],
#  [['god', 'tweets', 'ghetto'], 1],
#  [['bitch',
#    'tryna',
#    'get',
#    'free',
#    'promoting',
#    'shit',
#    'lmaooo',
#    'see',
#    'tha',
#    'cut'],
#   1],
#  [['got', 'ounce', 'bitch'], 1],
#  [['hate',
#    'drinking',
#    'everyones',
#    'fucking',
#    'boring',
#    'fuck',
#    'ill',
#    'fun',
#    'pussies'],
#   1],
#  [['god',
#    'would',
#    'sell',
#    'nuts',
#    'watch',
#    'lebron',
#    'tear',
#    'acl',
#    'right',
#    'watch',
#    'pussies',
#    'kill'],
#   0],
#  [['day', 'goes', 'bad', 'tell', 'pussy'], 1],
#  [['dis',
#    'wus',
#    'offered',
#    'help',
#    'faggot',
#    'ass',
#    'nigga',
#    'get',
#    'custody',
#    'kids',
#    'lowkey',
#    'heated'],
#   1],
#  [['gotta', 'know', 'difference', 'good', 'girl', 'good', 'pussy'], 1],
#  [['lbum',
#    'tail',
#    'satan',
#    'soul',
#    'mirajane',
#    'strauss',
#    'made',
#    'sims',
#    'happy'],
#   2],
#  [['juan',
#    'likes',
#    'black',
#    'girls',
#    'monday',
#    'spanish',
#    'girls',
#    'thursday',
#    'amp',
#    'amp',
#    'white',
#    'bitches',
#    'weekend',
#    'tbb'],
#   1],
#  [['drink', 'bitches'], 1],
#  [['bitch', 'dont', 'nobody', 'care'], 1],
#  [['remember',
#    'said',
#    'uchihas',
#    'week',
#    'sasuke',
#    'reaffirms',
#    'flying',
#    'colors'],
#   1],
#  [['ball',
#    'roll',
#    'slope',
#    'amp',
#    'found',
#    'natural',
#    'spot',
#    'defending',
#    'brother',
#    'amp',
#    'scumbag'],
#   2],
#  [['suck', 'super', 'monkey', 'balls'], 1],
#  [['dont', 'sloppy', 'might', 'catch', 'somethin'], 1],
#  [['didnt',
#    'open',
#    'das',
#    'asked',
#    'cus',
#    'thought',
#    'ate',
#    'wat',
#    'pork',
#    'chops',
#    'yellow',
#    'rice',
#    'beans'],
#   2],
#  [['young',
#    'thug',
#    'called',
#    'bitch',
#    'twin',
#    'track',
#    'dont',
#    'even',
#    'know',
#    'mean',
#    'definitely',
#    'bout',
#    'start',
#    'calling',
#    'bitches'],
#   1],
#  [['paid', 'hold', 'monkey', 'look', 'monkey', 'real'], 2],
#  [['wonder', 'gon', 'low', 'nigger', 'friday'], 1],
#  [['stupid', 'bitches', 'cant', 'handle', 'johns'], 1],
#  [['love', 'frat', 'boy', 'soft', 'long', 'soles'], 2],
#  [['shimmy', 'shimmy', 'bitch'], 1],
#  [['saw',
#    'men',
#    'saying',
#    'arguing',
#    'women',
#    'gaywhats',
#    'knew',
#    'yall',
#    'really',
#    'try',
#    'hard',
#    'bitches',
#    'attention'],
#   1],
#  [['making', 'pollo', 'brasso', 'today'], 2],
#  [['much', 'knob', 'gobble', 'one', 'youre', 'head', 'blockhead'], 1],
#  [['citi', 'field', 'bitches'], 1],
#  [['happy', 'friday'], 1],
#  [['happened', 'old', 'gonorrhea', 'one'], 1],
#  [['listen',
#    'bands',
#    'ptv',
#    'sws',
#    'atl',
#    'bvb',
#    'adtr',
#    'bmth',
#    'ymas',
#    'fob',
#    'blink',
#    'tdg',
#    'fir',
#    'mcr',
#    'follow',
#    'amp',
#    'everyon'],
#   2],
#  [['original', 'bad', 'bitch'], 1],
#  [['pennsylvania', 'white', 'trash', 'pennsylvanians'], 0],
#  [['dead',
#    'word',
#    'moms',
#    'calling',
#    'cops',
#    'aint',
#    'heard',
#    'four',
#    'days',
#    'probably',
#    'pussy'],
#   1],
#  [['well', 'coon'], 1],
#  [['see', 'bitch', 'nigga', 'subtweet'], 1],
#  [['denkt',
#    'ieder',
#    'wel',
#    'zijne',
#    'zaken',
#    'amp',
#    'mag',
#    'mij',
#    'noemen',
#    'hoe',
#    'ben',
#    'namelijk',
#    'erg',
#    'voor',
#    'vrijheid',
#    'van',
#    'meningsuiting'],
#   1],
#  [['anyone', 'bring', 'monkey'], 2],
#  [['likes',
#    'black',
#    'men',
#    'rap',
#    'huh',
#    'lol',
#    'general',
#    'wants',
#    'colored'],
#   2],
#  [['someones', 'clearly', 'stinky', 'ass', 'beaner'], 0],
#  [['liberal',
#    'ideology',
#    'forged',
#    'unions',
#    'amp',
#    'bankrupted',
#    'dems',
#    'catering'],
#   2],
#  [['freshman',
#    'year',
#    'senior',
#    'year',
#    'really',
#    'niggah',
#    'started',
#    'brothers',
#    'years',
#    'ago',
#    'today',
#    'crazy'],
#   1],
#  [['raided',
#    'nickis',
#    'wig',
#    'closet',
#    'bad',
#    'gals',
#    'wanna',
#    'bitch',
#    'nerve',
#    'smh'],
#   2],
#  [['see', 'againthat', 'son', 'bitch', 'owes', 'tell', 'looking'], 1],
#  [['bitch'], 1],
#  [['good', 'charlie'], 2],
#  [['lmfao', 'new', 'york', 'world', 'series', 'titles'], 2],
#  [['wow',
#    'another',
#    'timatheracer',
#    'wow',
#    'another',
#    'cam',
#    'lolgtgt',
#    'dat',
#    'dude',
#    'nice'],
#   0],
#  [['hoes', 'good', 'woman', 'always', 'good', 'woman'], 1],
#  [['pussy', 'dont', 'cream'], 1],
#  [['pass', 'bitch'], 1],
#  [['muzzy',
#    'lovers',
#    'need',
#    'one',
#    'thing',
#    'tell',
#    'muzzies',
#    'mideast',
#    'leave',
#    'israel',
#    'alone',
#    'dont',
#    'start',
#    'shit',
#    'wont',
#    'shit'],
#   0],
#  [['bitch', 'tweets', 'point', 'minutes'], 1],
#  [['support', 'niggaz', 'bitches', 'dope', 'shit', 'west', 'side', 'city'], 1],
#  [['bitch', 'get', 'twitter', 'hoe'], 1],
#  [['imagine', 'world', 'created', 'trap', 'feed', 'like'], 0],
#  [['bitch',
#    'not',
#    'really',
#    'dont',
#    'fucking',
#    'like',
#    'fuck',
#    'even',
#    'talking'],
#   1],
#  [['wow', 'put', 'slit', 'trophies'], 2],
#  [['really', 'dont', 'tryna', 'hoe', 'nobody', 'eat', 'literally'], 1],
#  [['scale', 'bitch', 'literally'], 1],
#  [['bitches',
#    'love',
#    'beefing',
#    'nigga',
#    'thats',
#    'always',
#    'bitches',
#    'faces'],
#   1],
#  [['retarded'], 1],
#  [['nigger'], 1],
#  [['muslim',
#    'group',
#    'slaughters',
#    'children',
#    'nigerian',
#    'children',
#    'burned',
#    'shot',
#    'amp',
#    'slit',
#    'throats',
#    'tried',
#    'http'],
#   2],
#  [['sang', 'nazi'], 1],
#  [['like', 'pulled', 'track', 'bitches'], 1],
#  [['dont', 'say', 'fuck', 'bitches', 'get', 'money', 'love'], 1],
#  [['make', 'yellow'], 2],
#  [['reason',
#    'use',
#    'mega',
#    'whatsoever',
#    'pure',
#    'favoritism',
#    'also',
#    'sweet',
#    'fuzzy',
#    'wings'],
#   2],
#  [['purge', 'come', 'city', 'ima', 'like', 'bitch', 'active'], 1],
#  [['leave',
#    'car',
#    'windows',
#    'rains',
#    'car',
#    'looks',
#    'like',
#    'hurricane',
#    'katrina',
#    'ran',
#    'bitch'],
#   1],
#  [['man', 'bitch', 'smells', 'like', 'cheap', 'lip', 'stick'], 1],
#  [['youre', 'stupid', 'fucking', 'bitch'], 1],
#  [['first',
#    'congratulate',
#    'years',
#    'hoes',
#    'smarter',
#    'last',
#    'years',
# ...
#  [['niggas',
#    'mentally',
#    'dating',
#    'females',
#    'never',
#    'met',
#    'instagram',
#    'double',
#    'tapn',
#    'much',
#    'mane'],
#   1],
#  [['lima', 'fears', 'change', 'yet', 'wants', 'bitch', 'much', 'sucks'], 1],
#  [['made',
#    'homemade',
#    'chili',
#    'cornbread',
#    'dinner',
#    'watching',
#    'supernatural',
#    'fave',
#    'happy',
#    'saturday'],
#   1],
#  [['boolin', 'bando', 'wit', 'bitches'], 1],
#  [['day', 'unblock', 'become', 'man', 'wont', 'happen', 'bitch', 'lol'], 1],
#  [['youre', 'bad', 'bitch', 'want'], 1],
#  [['shit', 'sorry', 'hoe'], 1],
#  [['people', 'say', 'coloured'], 2],
#  [['rarely', 'drink', 'drunk', 'bitches', 'irritate'], 1],
#  [['iphone',
#    'million',
#    'times',
#    'storage',
#    'apollo',
#    'spacecraft',
#    'computer',
#    'went',
#    'moon',
#    'throw',
#    'bird'],
#   2],
#  [['kevin', 'hart', 'make', 'funny', 'faces', 'curriculum', 'kinda', 'trash'],
#   2],
#  [['chick', 'gorgeous', 'fine', 'pussy', 'stinks'], 1],
#  [['didnt',
#    'hes',
#    'little',
#    'bitch',
#    'valerie',
#    'jarrett',
#    'betcha',
#    'guy',
#    'knows',
#    'eve'],
#   1],
#  [['pretty', 'much', 'confirmed', 'best', 'bitch', 'face', 'planet'], 1],
#  [['confessgt', 'sneaks', 'pussy', 'nightgt', 'paints', 'wife'], 1],
#  [['cant',
#    'eat',
#    'pussy',
#    'thats',
#    'got',
#    'hair',
#    'not',
#    'even',
#    'sure',
#    'really',
#    'know',
#    'eat',
#    'pussy'],
#   1],
#  [['dont', 'bitch', 'attitude', 'youre', 'reason', 'one'], 1],
#  [['wanna', 'trash', 'talk', 'concert'], 2],
#  [['yeaaa',
#    'bitch',
#    'dog',
#    'like',
#    'shaggy',
#    'yea',
#    'stay',
#    'clean',
#    'get',
#    'dirty',
#    'like',
#    'harry'],
#   1],
#  [['like',
#    'said',
#    'might',
#    'check',
#    'not',
#    'sure',
#    'bird',
#    'shot',
#    'counts',
#    'getting',
#    'shot'],
#   2],
#  [['words',
#    'babe',
#    'love',
#    'hate',
#    'need',
#    'forget',
#    'youre',
#    'everything',
#    'youre',
#    'nothing'],
#   1],
#  [['sen',
#    'harry',
#    'reid',
#    'lists',
#    'things',
#    'republicans',
#    'blocked',
#    'senate',
#    'via'],
#   2],
#  [['lil', 'bitch', 'dont', 'read', 'receipt'], 1],
#  [['deleting',
#    'pic',
#    'realized',
#    'dike',
#    'back',
#    'ground',
#    'dressed',
#    'like',
#    'nigga',
#    'wedges',
#    'bitch'],
#   0],
#  [['charlie', 'lapdance'], 2],
#  [['touch', 'muzzie', 'hope', 'set', 'full', 'bacon', 'pork', 'rinds'], 1],
#  [['fronting',
#    'bitches',
#    'get',
#    'got',
#    'island',
#    'dick',
#    'never',
#    'hit',
#    'fronting',
#    'ass',
#    'nigga'],
#   1],
#  [['ole',
#    'girl',
#    'really',
#    'told',
#    'doesnt',
#    'care',
#    'boyfriend',
#    'hoes',
#    'whats',
#    'wrong',
#    'generation'],
#   1],
#  [['crazy',
#    'animals',
#    'like',
#    'grabbed',
#    'mama',
#    'like',
#    'aint',
#    'going',
#    'like',
#    'bitch'],
#   1],
#  [['sonia',
#    'never',
#    'criticises',
#    'kejriwal',
#    'trashes',
#    'every',
#    'never',
#    'criticises',
#    'sonia',
#    'touching'],
#   2],
#  [['phone', 'fucking', 'bitch'], 1],
#  [['nicca',
#    'read',
#    'typed',
#    'aint',
#    'slo',
#    'long',
#    'shot',
#    'dont',
#    'play',
#    'dumb',
#    'litebrite',
#    'lol'],
#   1],
#  [['fuck', 'simplest', 'things', 'lighten', 'bitches'], 1],
#  [['niggas', 'pure', 'pussy', 'see', 'faces'], 1],
#  [['well',
#    'gahdamn',
#    'wooooow',
#    'good',
#    'job',
#    'mommy',
#    'cutest',
#    'thing',
#    'blue',
#    'ivy',
#    'ever',
#    'done',
#    'still',
#    'ugly',
#    'nigger',
#    'baby'],
#   0],
#  [['not', 'leave', 'nigga', 'bitch'], 1],
#  [['shutup',
#    'fag',
#    'real',
#    'shit',
#    'females',
#    'love',
#    'real',
#    'nigga',
#    'like'],
#   1],
#  [['aye', 'fucked', 'bitch', 'mistake'], 1],
#  [['smoking', 'brooklyn', 'got', 'high', 'giraffe', 'pussy'], 1],
#  [['fuck', 'bad', 'bitches', 'stacy', 'niggas', 'balls', 'blue', 'like'], 1],
#  [['fuckin',
#    'call',
#    'venue',
#    'theyll',
#    'cancel',
#    'lost',
#    'tickets',
#    'reprint',
#    'new',
#    'ones',
#    'dumb',
#    'bitch'],
#   1],
#  [['reason',
#    'rap',
#    'pussy',
#    'supposed',
#    'talk',
#    'smh',
#    'bout',
#    'make',
#    'music',
#    'aint'],
#   1],
#  [['niggas', 'cheat', 'loyal', 'beautiful', 'women', 'fucking', 'trash'], 1],
#  [['hoe', 'grandma', 'got', 'tattoo'], 1],
#  [['shy', 'bitch', 'homosexual'], 1],
#  [['herd',
#    'random',
#    'creepiest',
#    'sound',
#    'fuck',
#    'going',
#    'outside',
#    'windows',
#    'not',
#    'looking',
#    'bitch'],
#   1],
#  [['full',
#    'called',
#    'children',
#    'not',
#    'children',
#    'illegal',
#    'border',
#    'jumpers',
#    'gang',
#    'members'],
#   0],
#  [['using', 'measure', 'slope', 'ass', 'girl'], 1],
#  [['cause', 'would', 'tip', 'hand', 'instead', 'whine', 'like', 'little'], 1],
#  [['moest',
#    'van',
#    'plisie',
#    'niet',
#    'meteen',
#    'wild',
#    'gaan',
#    'wel',
#    'meer',
#    'mensen',
#    'mij',
#    'vertellen',
#    'hoe',
#    'moet',
#    'denken'],
#   2],
#  [['lol', 'baddest', 'bitches', 'porn', 'stars', 'strippers'], 1],
#  [['big', 'homie', 'drizzy', 'threatening', 'hoes'], 1],
#  [['real',
#    'man',
#    'gonna',
#    'keep',
#    'real',
#    'bitches',
#    'lmaooooo',
#    'shut',
#    'not',
#    'tellin',
#    'women',
#    'mind',
#    'business'],
#   1],
#  [['exactly',
#    'shit',
#    'saidgtgtgt',
#    'nobody',
#    'think',
#    'mimi',
#    'outta',
#    'line',
#    'inviting',
#    'stevie',
#    'gay',
#    'nicca'],
#   0],
#  [['yall',
#    'take',
#    'note',
#    'aint',
#    'never',
#    'tornadoes',
#    'colored',
#    'folk',
#    'live'],
#   2],
#  [['ending', 'retarded'], 1],
#  [['wasnt', 'hoe', 'azz', 'boi', 'sniff', 'sorry'], 1],
#  [['work', 'support', 'military', 'organization', 'today'], 2],
#  [['slept', 'good', 'thenna', 'bitch', 'tho'], 1],
#  [['rock', 'cock', 'jam', 'clam'], 1],
#  [['like', 'women', 'whos', 'pussy', 'smell', 'like', 'burnt', 'cheese'], 1],
#  [['know', 'considered', 'like', 'wait', 'little', 'baby', 'back', 'bitch'],
#   1],
#  [['real', 'niggah', 'want'], 1],
#  [['lmaoooo',
#    'gucci',
#    'really',
#    'ass',
#    'hoes',
#    'ill',
#    'bump',
#    'couple',
#    'songs'],
#   1],
#  [['idk', 'really', 'surely', 'trash', 'rapper'], 2],
#  [['couldnt', 'help', 'man', 'niggas', 'pussy', 'robbing', 'chick', 'shootin'],
#   1],
#  [['would', 'rather', 'call', 'bitch', 'sir', 'manager'], 1],
#  [['baddest',
#    'bitch',
#    'didnt',
#    'win',
#    'queen',
#    'fuck',
#    'mexicans',
#    'ill',
#    'buy',
#    'house'],
#   1],
#  [['got', 'giggles', 'aint', 'gon', 'lie', 'lol'], 1],
#  [['hope', 'realize', 'retarded'], 1],
#  [['lit', 'stupid', 'ass', 'bitch', 'aint', 'fuccin', 'witchuuuu'], 1],
#  [['confused',
#    'lefties',
#    'using',
#    'hashtag',
#    'mock',
#    'bridge',
#    'situation',
#    'seriously',
#    'equating'],
#   2],
#  [['fuck', 'wcwlet', 'see', 'wat', 'current', 'bitch', 'look', 'like', 'oowe'],
#   1],
#  [['learn',
#    'first',
#    'seconds',
#    'flesh',
#    'power',
#    'death',
#    'riff',
#    'would',
#    'cool',
#    'bird',
#    'lol'],
#   2],
#  [['know', 'outback', 'see', 'hoe'], 1],
#  [['damn', 'charlie', 'wilson', 'still'], 2],
#  [['fearful', 'wrath', 'god', 'country', 'many', 'mock', 'embrace', 'bows'],
#   2],
#  [['ratchet', 'ass', 'bitches', 'gonna', 'nobody', 'blame', 'get', 'std'], 1],
#  [['zoom', 'see', 'hairy', 'nipples'], 1],
#  [['bitch',
#    'hmu',
#    'say',
#    'need',
#    'sex',
#    'right',
#    'bitch',
#    'nigga',
#    'hmu',
#    'saying',
#    'upset',
#    'right'],
#   1],
#  [['many', 'hoes', 'whipped', 'would', 'thought', 'still', 'slavery'], 0],
#  [['bitches', 'yal', 'cant', 'know', 'bouta', 'start', 'popping', 'bitches'],
#   1],
#  [['try', 'pussy'], 1],
#  [['ballsack', 'hairy', 'gtfo', 'tranny', 'prude', 'bitch'], 0],
#  [['yeah', 'hoe'], 1],
#  [['lemme', 'find', 'bitch', 'nigga', 'talking', 'shit'], 0],
#  [['nigga', 'hungry', 'bitch'], 1],
#  [['thats', 'ghetto', 'super', 'current', 'generations', 'best', 'complement'],
#   2],
#  [['hopes', 'recruiting', 'isis', 'opens', 'jihadi', 'finishing', 'school'],
#   2],
#  [['fuking',
#    'every',
#    'night',
#    'new',
#    'house',
#    'cause',
#    'bitch',
#    'worked',
#    'hard',
#    'new',
#    'house'],
#   1],
#  [['rts', 'ill', 'say', 'fuck', 'right', 'pussy'], 1],
#  [['someone', 'love', 'bitch', 'ass', 'wont', 'someone', 'love'], 1],
#  [['hardly',
#    'get',
#    'sexso',
#    'opportunity',
#    'sick',
#    'presents',
#    'giving',
#    'pussyand',
#    'boy',
#    'generous'],
#   1],
#  [['love',
#    'people',
#    'bitch',
#    'athletes',
#    'payed',
#    'much',
#    'like',
#    'theyd',
#    'turn',
#    'millions',
#    'fuck'],
#   1],
#  [['man',
#    'call',
#    'bitch',
#    'yall',
#    'arguing',
#    'dont',
#    'think',
#    'really',
#    'actin',
#    'like',
#    'one'],
#   1],
#  [['least',
#    'nearly',
#    'two',
#    'decades',
#    'complete',
#    'trash',
#    'put',
#    'atysyc',
#    'redeem'],
#   1],
#  [['nigga', 'wus', 'graduating', 'wasnt', 'grade', 'hoe'], 1],
#  [['keep', 'bitch', 'amp', 'ill', 'stay', 'grind'], 1],
#  [['oomf', 'hoe', 'hopper'], 1],
#  [['need', 'bitches'], 1],
#  [['iont',
#    'got',
#    'not',
#    'type',
#    'bad',
#    'bitches',
#    'thing',
#    'like',
#    'throw',
#    'ass',
#    'sphere'],
#   1],
#  [['ill', 'make', 'brownies'], 2],
#  [['skippin', 'spanish', 'class', 'rest', 'week', 'fuck', 'dat', 'bitch'], 1],
#  [['everybody', 'got', 'foreign', 'bitches', 'foreign', 'cars'], 1],
#  [['sorry', 'love', 'not', 'stand', 'legs', 'open', 'easy'], 1],
#  [['live',
#    'cant',
#    'afraid',
#    'two',
#    'black',
#    'dicks',
#    'butt',
#    'fucking',
#    'queer'],
#   0],
#  [['happy', 'bob', 'comedic', 'legend', 'turns'], 2],
#  [['like', 'bitch', 'gotta', 'pretty', 'pussy', 'loose'], 1],
#  [['twitter', 'hoe'], 1],
#  [['aint', 'worried', 'nigga', 'takin', 'bitch'], 1],
#  [['punk', 'ass', 'cop', 'jus', 'bulldogged', 'bitch'], 1],
#  [['thanks', 'bitch'], 1],
#  [['youre', 'whiney', 'zima', 'shut', 'fuck'], 1],
#  [['told',
#    'niggah',
#    'maya',
#    'angelo',
#    'died',
#    'niggah',
#    'gon',
#    'ask',
#    'red',
#    'ninja',
#    'turtle',
#    'wtf'],
#   1],
#  [['really', 'committed', 'fucking', 'richest', 'bitches'], 1],
#  [['cant',
#    'bitch',
#    'living',
#    'say',
#    'brought',
#    'michael',
#    'kors',
#    'need',
#    'guys',
#    'like'],
#   1],
#  [['bust', 'nicca', 'hoe', 'shoot', 'club'], 1],
#  [['well',
#    'else',
#    'white',
#    'ppl',
#    'get',
#    'forget',
#    'horrific',
#    'past',
#    'paint',
#    'pretty',
#    'picture'],
#   0],
#  [['ill', 'fucking', 'merk', 'bitch', 'dont', 'fuck'], 1],
#  [['dope', 'ass', 'nigga', 'bitches'], 1],
#  [['lol', 'maybe', 'give', 'date', 'hoes', 'dateslet', 'know', 'work', 'lol'],
#   1],
#  [['bulls',
#    'still',
#    'not',
#    'winning',
#    'title',
#    'bland',
#    'ass',
#    'offense',
#    'pau',
#    'still',
#    'pussy',
#    'darkskin',
#    'niggas',
#    'starting',
#    'line'],
#   1],
#  [['lmfao', 'eating', 'pussy', 'really', 'want', 'braces', 'way'], 1],
#  [['feeling', 'like', 'wintertime', 'bitches'], 1],
#  [['bitch', 'get'], 1],
#  [['whoever', 'ramlogan', 'uwi', 'business', 'law', 'racist', 'mudda', 'cunt'],
#   0],
#  [['fuck', 'bitch'], 1],
#  [['heard',
#    'rumors',
#    'traitorous',
#    'bitch',
#    'named',
#    'pelosi',
#    'parading',
#    'around',
#    'illegal',
#    'aliens',
#    'vets',
#    'get',
#    'shaft'],
#   1],
#  [['cutler',
#    'didnt',
#    'step',
#    'throw',
#    'threw',
#    'int',
#    'nice',
#    'flat',
#    'footed',
#    'throw',
#    'cunt'],
#   1],
#  [['anxiety', 'person', 'kill', 'bitch', 'fuckin', 'fast'], 1],
#  [['gotta', 'phone', 'avi', 'texting', 'got', 'negative'], 1],
#  [['get', 'bitch', 'cell', 'mate'], 1],
#  [['view', 'ghetto', 'aint', 'rio'], 2],
#  [['big', 'booty', 'hoe'], 1],
#  [['vraag',
#    'maanden',
#    'hoe',
#    'pers',
#    'zich',
#    'als',
#    'een',
#    'stel',
#    'hoeren',
#    'gaan'],
#   2],
#  [['dont', 'ever', 'kiss', 'girl', 'dont', 'hug', 'hoe', 'none'], 1],
#  [['old',
#    'fellas',
#    'water',
#    'froze',
#    'funeral',
#    'home',
#    'got',
#    'unthawed',
#    'wants',
#    'help',
#    'get',
#    'pump',
#    'going',
#    'place',
#    'spooks',
#    'manboo'],
#   2],
#  [['bitch', 'car', 'way', 'fucked', 'cuss', 'bitch', 'via'], 1],
#  [['youre',
#    'way',
#    'trying',
#    'make',
#    'feel',
#    'bad',
#    'calling',
#    'fat',
#    'etc',
#    'rethink',
#    'life'],
#   1],
#  [['yes',
#    'white',
#    'washed',
#    'dont',
#    'around',
#    'repping',
#    'hood',
#    'saying',
#    'bunch',
#    'ignorant',
#    'nig',
#    'terms'],
#   0],
#  [['dont',
#    'light',
#    'skin',
#    'bitches',
#    'unread',
#    'texts',
#    'amp',
#    'still',
#    'tweet',
#    'nobody',
#    'talk',
#    'bitches',
#    'outta',
#    'control'],
#   1],
#  [['rino',
#    'trash',
#    'like',
#    'see',
#    'conservatives',
#    'democrat',
#    'party',
#    'see',
#    'blacks',
#    'slave',
#    'property'],
#   0],
#  [['lmfaoooo', 'tryna', 'see', 'many', 'hoes', 'lure'], 1],
#  [['nips', 'cold'], 2],
#  [['vice', 'versa', 'hoes'], 1],
#  [['knowing', 'picture', 'hoe', 'head', 'good', 'knocked', 'wind', 'boy'], 1],
#  [['dont', 'get', 'shit', 'bow', 'bitches'], 1],
#  [['birds', 'feather', 'stand', 'peta', 'stand', 'sanity'], 2],
#  [['glad',
#    'none',
#    'followers',
#    'say',
#    'fucked',
#    'yall',
#    'hoes',
#    'really',
#    'make',
#    'goal'],
#   1],
#  [['hey', 'boy', 'half', 'breed', 'chiricahua', 'apache', 'ass'], 1],
#  [['austin', 'mahone', 'making', 'bitches', 'horny', 'right'], 1],
#  [['dont',
#    'confidence',
#    'nonwhatsoever',
#    'youre',
#    'sole',
#    'reason',
#    'country',
#    'thi'],
#   2],
#  [['nudes', 'trash'], 2],
#  [['pollos',
#    'last',
#    'dos',
#    'pollos',
#    'estaban',
#    'dando',
#    'vueltas',
#    'una',
#    'pollera',
#    'mientras',
#    'los',
#    'estaban',
#    'cocinando',
#    'cuando'],
#   2],
#  [['imma',
#    'hit',
#    'ground',
#    'work',
#    'pussy',
#    'gone',
#    'come',
#    'back',
#    'everytime'],
#   1],
#  [['love', 'say', 'bitch'], 1],
#  [['nig',
#    'jus',
#    'said',
#    'aint',
#    'nuttin',
#    'worse',
#    'den',
#    'fat',
#    'loud',
#    'hoetru',
#    'fuckin',
#    'story'],
#   0],
#  [['bitch', 'add'], 1],
#  [['ate', 'wees', 'brownie', 'seeing', 'random', 'cats'], 2],
#  [['get', 'pussy', 'quicker', 'days'], 1],
#  [['soooo', 'bitch', 'aint', 'even', 'funny', 'lbs'], 1],
#  [['lol',
#    'cool',
#    'son',
#    'know',
#    'grandma',
#    'bald',
#    'mouthshe',
#    'got',
#    'teeth',
#    'hoe'],
#   1],
#  [['dyke', 'almost', 'came', 'didnt', 'send', 'ltltltlt'], 1],
#  [['know',
#    'bitches',
#    'never',
#    'gonna',
#    'happy',
#    'following',
#    'social',
#    'sites'],
#   1],
#  [['ill', 'kill', 'bitch', 'hesitation'], 0],
#  [['cant',
#    'watch',
#    'charlie',
#    'cloud',
#    'cry',
#    'like',
#    'little',
#    'baby',
#    'every',
#    'single',
#    'time'],
#   2],
#  [['grade', 'hoes', 'aint', 'loyal'], 1],
#  [['chest', 'tattoos', 'females', 'trash'], 2],
#  [['girl', 'stress', 'ion', 'even', 'hoes', 'shit', 'saying', 'lol'], 1],
#  [['never', 'actually', 'seen', 'yellow', 'duck'], 2],
#  [['straight',
#    'grizzly',
#    'would',
#    'buy',
#    'gay',
#    'ass',
#    'teddy',
#    'youre',
#    'already'],
#   1],
#  [['cant', 'date', 'youre', 'going', 'little', 'bitch', 'everything'], 1],
#  [['yasssss', 'bitch', 'yasssss'], 1],
#  [['feel',
#    'way',
#    'new',
#    'england',
#    'patriots',
#    'amp',
#    'new',
#    'york',
#    'yankees',
#    'unlike',
#    'ive',
#    'worked',
#    'boston',
#    'amp',
#    'nyc',
#    'texas',
#    'prison',
#    'upgrade'],
#   2],
#  [['not', 'coon', 'sick', 'fake', 'bougie', 'ass', 'coons', 'lol'], 1],
#  [['see', 'bae', 'retweet', 'mention', 'hoe'], 1],
#  [['people',
#    'focus',
#    'skin',
#    'tones',
#    'dating',
#    'someone',
#    'fucking',
#    'retarded',
#    'brainwashed'],
#   1],
#  [['green', 'summer', 'yellow', 'cucumber', 'set', 'road', 'today', 'free'],
#   2],
#  [['niggas',
#    'fall',
#    'love',
#    'evil',
#    'bitch',
#    'turn',
#    'back',
#    'friends',
#    'cool',
#    'tho'],
#   1],
#  [['old', 'bitch', 'floppy', 'tits', 'riding', 'elevator', 'nerping', 'bad'],
#   1],
#  [['soon',
#    'left',
#    'iraq',
#    'towel',
#    'heads',
#    'think',
#    'fucking',
#    'barge',
#    'take',
#    'worked',
#    'hard',
#    'set',
#    'pisses'],
#   0],
#  [['eats', 'pussy'], 1],
#  [['stockboy',
#    'talk',
#    'tweet',
#    'lies',
#    'childish',
#    'shit',
#    'obamayoure',
#    'unqualified',
#    'appeal',
#    'dumb',
#    'rednecks'],
#   1],
#  [['picture',
#    'far',
#    'reason',
#    'makes',
#    'teabaggers',
#    'poor',
#    'spelling',
#    'really',
#    'angry'],
#   2],
#  [['year',
#    'old',
#    'gay',
#    'driving',
#    'back',
#    'roads',
#    'redneck',
#    'virginia',
#    'blasting',
#    'cheetah',
#    'girls',
#    'doesnt',
#    'scream'],
#   2],
#  [['hear', 'someone', 'show', 'niggas', 'play'], 1],
#  ...]

# %%
documents_t
# Out:
# [[['mewtwo', 'make', 'pussy'], 1],
#  [['said',
#    'didnt',
#    'like',
#    'fuck',
#    'got',
#    'shit',
#    'made',
#    'stfu',
#    'stop',
#    'assuming',
#    'bitch',
#    'not',
#    'ugly'],
#   1],
#  [['get', 'bitch', 'bruh'], 1],
#  [['lmfao', 'bitch', 'got', 'shit', 'rocked'], 1],
#  [['verizon',
#    'customer',
#    'service',
#    'trash',
#    'fuck',
#    'ive',
#    'store',
#    'havent',
#    'greeted',
#    'nothing'],
#   1],
#  [['youve', 'gone', 'broke', 'wrong', 'heart', 'drove', 'redneck', 'crazy'],
#   2],
#  [['bitch', 'ass', 'arod', 'shorty', 'dont', 'hit', 'back'], 1],
#  [['clock',
#    'hits',
#    'oclock',
#    'imma',
#    'need',
#    'amp',
#    'brightest',
#    'hoes',
#    'door',
#    'give'],
#   1],
#  [['long',
#    'beach',
#    'california',
#    'people',
#    'automatically',
#    'think',
#    'ima',
#    'bitch',
#    'hahha'],
#   1],
#  [['wicked', 'witch', 'east', 'send', 'vile', 'bitch', 'syria'], 1],
#  [['aint', 'squad', 'lil', 'bitch'], 1],
#  [['thought', 'would', 'think', 'cuteyou', 'like', 'shut', 'clam'], 2],
#  [['bitch',
#    'wit',
#    'baby',
#    'ask',
#    'switch',
#    'seats',
#    'family',
#    'could',
#    'together',
#    'said',
#    'bitch',
#    'family',
#    'wasnt'],
#   1],
#  [['ever', 'call', 'youre', 'fucking', 'side', 'yea', 'gonna', 'later'], 1],
#  [['one',
#    'day',
#    'niggas',
#    'gone',
#    'learn',
#    'not',
#    'fuck',
#    'ugly',
#    'bitch',
#    'pregnancies',
#    'need',
#    'stopped'],
#   1],
#  [['wanna', 'state', 'record', 'dont', 'hoes'], 1],
#  [['dont',
#    'pity',
#    'hate',
#    'sexual',
#    'mutations',
#    'necessary',
#    'side',
#    'effect',
#    'proliferation',
#    'sign',
#    'fucked'],
#   1],
#  [['another',
#    'keyboard',
#    'commando',
#    'real',
#    'life',
#    'hide',
#    'like',
#    'little',
#    'bitch'],
#   1],
#  [['bitch', 'bitch', 'bitch'], 1],
#  [['dani',
#    'alves',
#    'pulled',
#    'hairstyle',
#    'neymar',
#    'looks',
#    'like',
#    'faggot'],
#   0],
#  [['ever',
#    'kill',
#    'ant',
#    'sidewalk',
#    'think',
#    'damn',
#    'nigga',
#    'way',
#    'get',
#    'pussy'],
#   1],
#  [['fuck', 'staten', 'place', 'pussies'], 1],
#  [['allergies', 'eyes', 'red', 'chink', 'look', 'like', 'stoned'], 1],
#  [['rubbing',
#    'booty',
#    'another',
#    'mans',
#    'penis',
#    'sure',
#    'fellas',
#    'cool',
#    'girl',
#    'dancing',
#    'nig'],
#   1],
#  [['bitch', 'bitch', 'griiind', 'thug', 'luuuuuuv'], 1],
#  [['everyone', 'calls', 'like', 'wassup', 'like', 'wassup', 'niggah'], 0],
#  [['kick', 'dem', 'fucc', 'niccas', 'spot'], 0],
#  [['real', 'nigga', 'bitch', 'know', 'place'], 1],
#  [['one', 'night', 'stand', 'yall', 'yall', 'aint', 'nothing'], 1],
#  [['never', 'snapchat', 'bishop', 'screenshotting', 'son', 'bitch'], 1],
#  [['little',
#    'scrawny',
#    'white',
#    'boys',
#    'play',
#    'ghetto',
#    'rap',
#    'music',
#    'walk',
#    'around'],
#   1],
#  [['bitches',
#    'grade',
#    'talking',
#    'miss',
#    'bae',
#    'naw',
#    'bitch',
#    'missed',
#    'graduation'],
#   1],
#  [['fuck', 'girls', 'peep', 'change', 'nigga', 'squared', 'bitch', 'ass'], 1],
#  [['niggas', 'talk', 'bitches', 'days'], 1],
#  [['bitches', 'aint', 'real'], 1],
#  [['latino', 'jewish', 'move', 'dont', 'ruin', 'wipe'], 2],
#  [['never', 'full', 'retard'], 0],
#  [['salute', 'derek', 'best', 'yankee'], 2],
#  [['crystal',
#    'star',
#    'leggy',
#    'playful',
#    'babe',
#    'crystal',
#    'star',
#    'spreads',
#    'pussy',
#    'foryou'],
#   1],
#  [['post', 'pic', 'waves', 'bringing', 'back', 'hoes'], 1],
#  [['bitch', 'nigga', 'shit', 'invented', 'created', 'term'], 1],
#  [['adopted', 'bitches'], 1],
#  [['hate', 'ratchet', 'country', 'hoes', 'ashamed'], 1],
#  [['bet', 'pussy', 'smell', 'like', 'dried', 'oysters'], 1],
#  [['bitch'], 1],
#  [['know', 'people', 'ghetto', 'leave', 'plastic', 'shit', 'tvs'], 1],
#  [['tell', 'itty', 'bitty', 'bitch', 'pipe'], 1],
#  [['yall', 'entertained', 'bitch', 'niggas', 'hitting', 'smh', 'raised'], 1],
#  [['bitches',
#    'brag',
#    'goin',
#    'gym',
#    'still',
#    'shaped',
#    'like',
#    'patron',
#    'bottle',
#    'cuh'],
#   1],
#  [['back', 'ive', 'become', 'basic', 'bitch'], 1],
#  [['wayne', 'crazy', 'new', 'orleans', 'ass', 'nicca', 'lol'], 1],
#  [['point', 'bitch', 'like', 'dirk', 'club', 'like', 'dirk', 'nowitzki'], 1],
#  [['rams', 'fags'], 1],
#  [['fail',
#    'realize',
#    'ion',
#    'want',
#    'friends',
#    'bitches',
#    'switch',
#    'quiccer',
#    'change',
#    'channel'],
#   1],
#  [['duh', 'aka', 'shitty', 'nights', 'city', 'nights', 'hella'], 1],
#  [['lol', 'girrrrl', 'bitches', 'crazzzzy'], 1],
#  [['going', 'show', 'bitches', 'done'], 1],
#  [['redskins', 'trash', 'fuck', 'not', 'getting'], 1],
#  [['ball', 'bitch', 'bench', 'life'], 1],
#  [['hey', 'guess', 'yall', 'forgot', 'bitch', 'lol'], 1],
#  [['one', 'thing', 'love', 'russel', 'aint', 'bitch', 'runnin'], 1],
#  [['sorry',
#    'costume',
#    'naughty',
#    'school',
#    'girl',
#    'forever',
#    'consider',
#    'basic',
#    'bitch'],
#   1],
#  [['farmers', 'white', 'trash'], 0],
#  [['top', 'ten', 'rappers', 'hoes', 'ortiz'], 1],
#  [['ugly',
#    'goldigging',
#    'cunt',
#    'probably',
#    'uncircumcised',
#    'penis',
#    'faggot'],
#   1],
#  [['haha',
#    'imma',
#    'catch',
#    'ebola',
#    'trynna',
#    'keep',
#    'warm',
#    'lol',
#    'ewww',
#    'bitch',
#    'well',
#    'stay',
#    'far',
#    'away'],
#   1],
#  [['literally', 'never', 'get', 'shit', 'retarded'], 1],
#  [['hoes', 'like', 'hoes', 'likebut', 'hoes', 'like'], 1],
#  [['bout', 'bitchneed'], 1],
#  [['windoowww', 'bleaching', 'smiling', 'talking', 'breath'], 2],
#  [['coons',
#    'monkeys',
#    'like',
#    'disgust',
#    'minstrel',
#    'show',
#    'negro',
#    'crying',
#    'shit',
#    'time',
#    'youre',
#    'disgrace',
#    'everywhere'],
#   0],
#  [['fuck', 'nigga', 'bitch'], 1],
#  [['called', 'people', 'kikes', 'lot', 'fucks'], 1],
#  [['yall', 'playful', 'dont', 'come', 'dumb', 'hoes'], 1],
#  [['youre',
#    'going',
#    'bitch',
#    'not',
#    'come',
#    'show',
#    'bands',
#    'dropped',
#    'moshing',
#    'room'],
#   1],
#  [['lol', 'youre', 'retarded'], 1],
#  [['ugly', 'white', 'bitch'], 1],
#  [['everyone',
#    'thinks',
#    'not',
#    'person',
#    'like',
#    'look',
#    'dont',
#    'understand',
#    'like',
#    'colored',
#    'hair',
#    'big',
#    'difference'],
#   2],
#  [['sex',
#    'reward',
#    'relationship',
#    'nigga',
#    'never',
#    'done',
#    'anything',
#    'whatsoever',
#    'yet',
#    'still',
#    'give',
#    'pussysmh'],
#   1],
#  [[], 1],
#  [['understand',
#    'stop',
#    'venting',
#    'bitch',
#    'give',
#    'much',
#    'insight',
#    'life',
#    'amp',
#    'people',
#    'dont',
#    'deserve'],
#   1],
#  [['fuck',
#    'church',
#    'attend',
#    'fuck',
#    'fuck',
#    'nigguh',
#    'call',
#    'savior',
#    'fucking',
#    'new',
#    'world',
#    'order',
#    'baby'],
#   1],
#  [['keep', 'never', 'fucked', 'squirter', 'bitch'], 1],
#  [['uou'], 2],
#  [['fucked', 'bitch', 'fucked', 'every', 'nigga', 'state'], 1],
#  [['drop', 'dead', 'gorgeous', 'bitch', 'aint', 'dying', 'nigga'], 1],
#  [['rather',
#    'sit',
#    'house',
#    'day',
#    'jack',
#    'bust',
#    'mission',
#    'literally',
#    'chill',
#    'bitch'],
#   1],
#  [['thats', 'logical', 'bitches', 'love', 'using', 'face', 'toilet'], 1],
#  [['watching',
#    'deadly',
#    'women',
#    'malicious',
#    'bitch',
#    'left',
#    'babies',
#    'sun',
#    'bake',
#    'death',
#    'wtf'],
#   1],
#  [['got', 'hoes', 'one', 'hoes', 'not', 'shutup', 'amp', 'never', 'say'], 1],
#  [['ever', 'fuck', 'bitches', 'amp', 'count', 'stacks'], 1],
#  [['fuck',
#    'stand',
#    'dizzy',
#    'bitch',
#    'two',
#    'unique',
#    'amp',
#    'separate',
#    'phrases',
#    'overheard',
#    'relative',
#    'saying',
#    'younger'],
#   1],
#  [['bitch', 'fuck', 'cut', 'get', 'snacks', 'fat', 'boys'], 1],
#  [['good',
#    'pussy',
#    'pussy',
#    'makes',
#    'really',
#    'think',
#    'bout',
#    'making',
#    'breakfast',
#    'pussy',
#    'makes',
#    'think',
#    'father'],
#   1],
#  [['partner', 'crime', 'yesss', 'bitch', 'stole', 'hah'], 1],
#  [['hate', 'girls', 'bitch'], 1],
#  [['thats', 'aint', 'cuffing', 'grown', 'hoes', 'aint', 'loyal'], 1],
#  [['kill', 'ugly', 'ass', 'monkey', 'looking', 'shit'], 0],
#  [['new',
#    'bus',
#    'stop',
#    'guy',
#    'across',
#    'street',
#    'yelling',
#    'david',
#    'lee',
#    'roth',
#    'kicks',
#    'swooping',
#    'crows',
#    'learn',
#    'karate'],
#   2],
#  [['wont',
#    'love',
#    'cant',
#    'love',
#    'unless',
#    'pussy',
#    'got',
#    'super',
#    'powers'],
#   1],
#  [['ready', 'get', 'fried', 'oreos'], 2],
#  [['early', 'bird', 'gets', 'dick'], 1],
#  [['bitches', 'look', 'wen', 'hear', 'song', 'club'], 1],
#  [['turn', 'turn', 'wheres', 'bitches'], 1],
#  [['sweet', 'innocent', 'schoolgirl', 'minami', 'asakas', 'pussyeaten'], 1],
#  [['dis', 'crack', 'ass', 'cracker'], 0],
#  [['broke', 'real', 'bitches', 'stick', 'around'], 1],
#  [['cant',
#    'blame',
#    'bitches',
#    'attract',
#    'yall',
#    'say',
#    'ima',
#    'asshole',
#    'talk',
#    'hoes',
#    'thats',
#    'kinda'],
#   1],
#  [['happy', 'bday', 'love', 'nigguh'], 1],
#  [['dont',
#    'burn',
#    'bridges',
#    'look',
#    'like',
#    'holding',
#    'grudge',
#    'lil',
#    'bitch',
#    'shit',
#    'happens',
#    'youll',
#    'fine'],
#   1],
#  [['thought', 'bros', 'hoes', 'guess', 'not'], 1],
#  [['ampamp', 'hoes'], 1],
#  [['whats', 'like', 'cold', 'hearted'], 1],
#  [['getting',
#    'checks',
#    'like',
#    'nike',
#    'icy',
#    'bitch',
#    'like',
#    'dice',
#    'soho'],
#   1],
#  [['actually',
#    'boys',
#    'right',
#    'dorky',
#    'ass',
#    'mom',
#    'amp',
#    'dad',
#    'watching',
#    'streit',
#    'make',
#    'bitch'],
#   1],
#  [['youre', 'crows', 'power', 'lines'], 2],
#  [['making',
#    'shittiest',
#    'pigs',
#    'blanket',
#    'theyre',
#    'gonna',
#    'good',
#    'not',
#    'tryna',
#    'impress',
#    'gordon',
#    'ramseys',
#    'bitch',
#    'ass',
#    'trying',
#    'make',
#    'poop'],
#   1],
#  [['gansitos', 'atg', 'beaner', 'candy'], 1],
#  [['feat', 'tori', 'amos', 'blue', 'skies'], 2],
#  [['like', 'bitch', 'already', 'know', 'answer', 'bri'], 1],
#  [['screen', 'shot', 'djks', 'wiki', 'page', 'updated', 'regarding', 'trash'],
#   2],
#  [['not', 'business', 'submitting', 'bitch', 'bruh', 'bruh'], 1],
#  [['ones',
#    'really',
#    'like',
#    'cant',
#    'get',
#    'got',
#    'one',
#    'really',
#    'like',
#    'lucky',
#    'bitch'],
#   1],
#  [['hoes', 'come', 'hoes', 'revolving', 'cycle'], 1],
#  [['next',
#    'time',
#    'gone',
#    'call',
#    'darky',
#    'niccacall',
#    'dat',
#    'coon',
#    'jungle',
#    'bunny'],
#   0],
#  [['lmao',
#    'hell',
#    'yea',
#    'love',
#    'thick',
#    'bitches',
#    'amp',
#    'thick',
#    'bitches',
#    'love',
#    'fat',
#    'niggas'],
#   1],
#  [['fear', 'niggah', 'trust', 'bitchhh'], 1],
#  [['need', 'bitch', 'drop', 'lol'], 1],
#  [['cant',
#    'bitch',
#    'future',
#    'goals',
#    'love',
#    'kids',
#    'youre',
#    'not',
#    'parent',
#    'first',
#    'cant',
#    'deal'],
#   1],
#  [['got', 'tits', 'big', 'hoe', 'evens'], 1],
#  [['faggot', 'sent', 'hella', 'nudes', 'hmmmm'], 1],
#  [['fuzzy',
#    'wuzzy',
#    'kitten',
#    'wants',
#    'know',
#    'raven',
#    'like',
#    'writing',
#    'desk',
#    'find'],
#   2],
#  [['jihadi', 'patron', 'hajjaj', 'arrested', 'kuwait', 'airport'], 2],
#  [['nigguh', 'naturally', 'forever'], 1],
#  [['really',
#    'dont',
#    'give',
#    'fuck',
#    'start',
#    'got',
#    'hoes',
#    'fuck',
#    'bitches',
#    'shit',
#    'deleting'],
#   1],
#  [['lol', 'tell', 'hoe', 'grow', 'ahaha'], 1],
#  [['sorry', 'fucked', 'bitch', 'really', 'dig', 'nigga'], 1],
#  [['welcome',
#    'new',
#    'eastern',
#    'panhandle',
#    'hope',
#    'better',
#    'job',
#    'yokels',
#    'got',
#    'first',
#    'place'],
#   2],
#  [['might', 'faggot', 'pull', 'outta', 'pussy', 'bust', 'bro'], 1],
#  [['necks'], 1],
#  [['bad', 'bitches', 'get', 'free', 'night', 'weenie', 'hut', 'jrs'], 1],
#  [['jihadi',
#    'posted',
#    'bio',
#    'boss',
#    'awad',
#    'excellent',
#    'sociological',
#    'info',
#    'cant',
#    'thank',
#    'enough',
#    'gift'],
#   2],
#  [['girl', 'eating', 'pussy', 'girl', 'nigga'], 1],
#  [['fenkell', 'bitch'], 1],
#  [['hey', 'dude', 'watch', 'calling', 'bitch'], 1],
#  [['yea', 'see', 'hoe'], 1],
#  [['warm', 'pussy'], 1],
#  [['bitches',
#    'tell',
#    'angles',
#    'watching',
#    'bitch',
#    'take',
#    'selfies',
#    'get',
#    'right'],
#   1],
#  [['day',
#    'february',
#    'waylon',
#    'jennings',
#    'left',
#    'sky',
#    'dreaming',
#    'dreams'],
#   2],
#  [['gobble', 'gook'], 2],
#  [['free',
#    'patterns',
#    'adorable',
#    'crochet',
#    'borders',
#    'flower',
#    'bumblebee',
#    'hat'],
#   2],
#  [['dont',
#    'care',
#    'old',
#    'put',
#    'front',
#    'bag',
#    'takis',
#    'ill',
#    'eat',
#    'bitch'],
#   1],
#  [['making', 'every', 'bitch', 'feel', 'important'], 1],
#  [['hate',
#    'extra',
#    'ass',
#    'bitch',
#    'extra',
#    'ass',
#    'nigga',
#    'youre',
#    'much',
#    'stop',
#    'unnecessary'],
#   1],
#  [['seriously', 'steal', 'halloween', 'oreos'], 2],
#  [['hat',
#    'paint',
#    'beard',
#    'shit',
#    'eat',
#    'pussy',
#    'grow',
#    'one',
#    'dawg',
#    'quit',
#    'tryin',
#    'shortcut'],
#   1],
#  [['niggas',
#    'living',
#    'like',
#    'hoes',
#    'dats',
#    'dey',
#    'dying',
#    'bout',
#    'nothing'],
#   1],
#  [['opinion', 'irrelevant', 'youre', 'cunt'], 1],
#  [['hoes', 'goin'], 1],
#  [['gardy', 'goes', 'yardy', 'leads', 'game', 'second', 'straight'], 2],
#  [['last',
#    'night',
#    'cunt',
#    'slapping',
#    'texted',
#    'grandpas',
#    'sorry',
#    'didnt',
#    'get',
#    'back'],
#   1],
#  [['fucking', 'gay', 'faggot', 'look', 'gay', 'ass', 'pink', 'shirt', 'haha'],
#   0],
#  [['fact',
#    'male',
#    'brain',
#    'cannot',
#    'always',
#    'hear',
#    'high',
#    'pitched',
#    'voice',
#    'women',
#    'bitch',
#    'dont',
#    'get',
#    'madi',
#    'really',
#    'didnt',
#    'hear'],
#   1],
#  [['one',
#    'thing',
#    'hate',
#    'lightskin',
#    'confused',
#    'bitch',
#    'like',
#    'either',
#    'fwm',
#    'gon',
#    'niggas'],
#   1],
#  [['told', 'months', 'ago', 'charlie', 'wasnt', 'bullshittin', 'bevo', 'next'],
#   1],
#  [['aint', 'really', 'wit', 'talkin', 'bitch', 'bout', 'action'], 1],
#  [['like', 'argue', 'sent', 'dat', 'bitch', 'law', 'school'], 1],
#  [['apparently',
#    'not',
#    'wanting',
#    'trade',
#    'nitro',
#    'csgo',
#    'makes',
#    'collossal',
#    'faggot'],
#   1],
#  [['haha', 'hit'], 1],
#  [['chief',
#    'keef',
#    'changed',
#    'rap',
#    'game',
#    'said',
#    'bitch',
#    'cooler',
#    'cooler'],
#   1],
#  [['ill', 'write', 'poem', 'hoe'], 1],
#  [['dont', 'give', 'shits', 'ship', 'beaners', 'back'], 0],
#  [['bad', 'little', 'bitch'], 1],
#  [['main', 'bae', 'gonn', 'think', 'sumn', 'wit', 'pussy'], 1],
#  [['wishing'], 2],
#  [['lol',
#    'bitches',
#    'tryna',
#    'chill',
#    'like',
#    'kno',
#    'mother',
#    'fuxin',
#    'dory',
#    'hoe',
#    'touched',
#    'butt'],
#   1],
#  [['victorias', 'real', 'five', 'nipples', 'sideways', 'vagina'], 1],
#  [['yanks', 'military', 'history', 'united', 'states', 'world', 'war', 'via'],
#   2],
#  [['whole',
#    'lot',
#    'better',
#    'youre',
#    'driving',
#    'vehicle',
#    'white',
#    'pussy',
#    'uhhh',
#    'get'],
#   1],
#  [['pregnant',
#    'cupps',
#    'classic',
#    'response',
#    'liberal',
#    'dem',
#    'calls',
#    'chunky',
#    'bonus',
#    'tweets',
#    'via'],
#   2],
#  [['talk', 'back', 'aint', 'getting', 'pussy'], 1],
#  [['know',
#    'yall',
#    'bitches',
#    'tell',
#    'yall',
#    'selfs',
#    'would',
#    'hustlelinaa',
#    'cuz',
#    'yall',
#    'asses',
#    'stay',
#    'following'],
#   1],
#  [['name', 'stefanie', 'stefaniefuck', 'hoe'], 1],
#  [['teen',
#    'running',
#    'around',
#    'target',
#    'monkey',
#    'pjs',
#    'screaming',
#    'amp',
#    'fitting',
#    'room',
#    'girls',
#    'cackling',
#    'today',
#    'designed',
#    'annoy'],
#   2],
#  [['retards', 'dads', 'roll', 'lawful', 'good'], 2],
#  [['ronnie', 'radkes', 'fucking', 'fag', 'fronz', 'owns', 'ass'], 1],
#  [['lil', 'thot', 'bitch', 'really', 'tried', 'run', 'game'], 1],
#  [['swear',
#    'god',
#    'hoes',
#    'look',
#    'like',
#    'take',
#    'exact',
#    'picture',
#    'everytime',
#    'change',
#    'godamn'],
#   1],
#  [['bad', 'bitches', 'thing', 'like'], 1],
#  [['would',
#    'never',
#    'trip',
#    'bitch',
#    'aint',
#    'mine',
#    'niggas',
#    'clowns',
#    'man'],
#   1],
#  [['yanks', 'sox', 'get', 'things', 'usually', 'smoothly'], 2],
#  [['bitches', 'happy', 'maybe', 'one', 'female', 'friends', 'find', 'bitvj'],
#   1],
#  [['tell', 'bitches', 'ill', 'always', 'mrs'], 1],
#  [['maaaaannnn', 'hope', 'get', 'rid', 'john', 'legend', 'looking', 'charlie'],
#   2],
#  [['well', 'thats', 'cracker', 'jack', 'secret', 'service', 'work', 'jfk'], 2],
#  [['bitch',
#    'say',
#    'love',
#    'hit',
#    'wit',
#    'reverse',
#    'psychology',
#    'amp',
#    'say',
#    'work',
#    'time',
#    'cuh'],
#   1],
#  [['pussy',
#    'not',
#    'think',
#    'gotta',
#    'favorite',
#    'naked',
#    'picture',
#    'everdamn'],
#   1],
#  [['clingy',
#    'girlfriends',
#    'best',
#    'stop',
#    'lying',
#    'hoes',
#    'bro',
#    'shit',
#    'annoying'],
#   1],
#  [['hungry',
#    'ionn',
#    'wanna',
#    'spend',
#    'money',
#    'foodbroke',
#    'hoe',
#    'problems'],
#   1],
#  [['spy', 'couple', 'thirsty', 'hoes', 'insta'], 1],
#  [['like',
#    'seat',
#    'low',
#    'window',
#    'slightly',
#    'riding',
#    'wit',
#    'bad',
#    'hoe',
#    'wit',
#    'girlfriend',
#    'back'],
#   1],
#  [['someone', 'pushes', 'hard', 'may', 'surprised', 'capricorn'], 2],
#  [['miss', 'yall', 'yall', 'brothers', 'mikey', 'lmfao'], 0],
#  [['cause', 'tired', 'big', 'bitches', 'coming', 'skinny'], 1],
#  [['niggas', 'bugging', 'think', 'bitch', 'aint', 'gunna', 'tell'], 1],
#  [['trynna', 'find', 'bitch', 'fat', 'ass'], 1],
#  [['hate',
#    'people',
#    'ask',
#    'shoot',
#    'dont',
#    'need',
#    'pussy',
#    'shit',
#    'bigger',
#    'unswole',
#    'niggas'],
#   1],
#  [['dumb',
#    'bitches',
#    'one',
#    'thing',
#    'thatll',
#    'never',
#    'become',
#    'extinct',
#    'thats',
#    'real'],
#   1],
#  [['peyton',
#    'mannings',
#    'remarkable',
#    'pass',
#    'yds',
#    'pass',
#    'completions',
#    'likely'],
#   2],
#  [['many',
#    'hoes',
#    'bad',
#    'ass',
#    'little',
#    'kids',
#    'dont',
#    'medication',
#    'cut',
#    'school',
#    'every'],
#   1],
#  [['big', 'booty', 'sour', 'face', 'hair', 'hoe'], 1],
#  [['lmaoooo', 'lol', 'pal', 'bitch', 'gone', 'tell'], 1],
#  [['yankees', 'acquire', 'lebron', 'james', 'team', 'deal', 'per', 'sources'],
#   2],
#  [['percent', 'bitch', 'percent', 'scrap'], 1],
#  [['cant', 'stand', 'fuck', 'niggas', 'ass', 'bitch'], 1],
#  [['biggest', 'two', 'faced', 'bitch', 'ever', 'met', 'wont'], 1],
#  [['saying', 'panties', 'ion', 'look', 'like', 'bitches', 'tho'], 1],
#  [['choke', 'bread', 'bitch'], 1],
#  [['yall', 'hoes', 'going', 'learn', 'spell'], 1],
#  [['aaaaaaaaand', 'begins', 'fucking', 'niggers', 'thats', 'kentucky', 'ever'],
#   0],
#  [['bust', 'dat', 'bitch', 'face', 'dont', 'want'], 1],
#  [['internet', 'make', 'think', 'bitches', 'theyre', 'actually', 'not'], 1],
#  [['niggas', 'aint', 'shit', 'hoes', 'tricks'], 1],
#  [['naw', 'negro'], 1],
#  [['truth', 'hurts', 'nigguh'], 1],
#  [['waives', 'pussy', 'feesgtgtgtgt', 'bye', 'lawrence'], 1],
#  [['dont',
#    'follow',
#    'astros',
#    'said',
#    'theyre',
#    'trash',
#    'said',
#    'well',
#    'look'],
#   2],
#  [['nee',
#    'dat',
#    'langdurig',
#    'gepest',
#    'wordenzoals',
#    'kiem',
#    'smorenis',
#    'ook',
#    'voor',
#    'kind',
#    'hoe',
#    'moet',
#    'optreden'],
#   2],
#  [['good', 'morning', 'coons'], 0],
#  [['deions', 'bitch'], 1],
#  [['whats',
#    'black',
#    'yellow',
#    'not',
#    'going',
#    'win',
#    'answer',
#    'tiger',
#    'woods'],
#   0],
#  [['omg', 'youre', 'nigger'], 1],
#  [['pussy', 'good', 'amp', 'forget', 'pull'], 1],
#  [['young', 'nigga', 'turned', 'catchmeifyoucanim', 'field', 'nig'], 1],
#  [['poor',
#    'poor',
#    'parker',
#    'nothingwithout',
#    'aaryn',
#    'bitch',
#    'would',
#    'even',
#    'know',
#    'around',
#    'looser'],
#   1],
#  [['sesh',
#    'say',
#    'like',
#    'white',
#    'kid',
#    'yes',
#    'kush',
#    'betta',
#    'whore',
#    'please',
#    'kill',
#    'self',
#    'fool',
#    'bitch',
#    'ass'],
#   1],
#  [['everybody',
#    'got',
#    'one',
#    'bitch',
#    'dey',
#    'insta',
#    'got',
#    'baby',
#    'amp',
#    'gets',
#    'likes',
#    'yall',
#    'fucked',
#    'lmao'],
#   1],
#  [['cant', 'ugly', 'shitty', 'fucking', 'person', 'pick', 'struggle', 'bitch'],
#   1],
#  [['youre',
#    'attractive',
#    'amp',
#    'think',
#    'straight',
#    'guy',
#    'wants',
#    'friendbitch',
#    'stupid'],
#   1],
#  [['bad', 'bitch', 'pussy', 'aquafina', 'call', 'crystalina'], 1],
#  [['biden',
#    'winner',
#    'last',
#    'yea',
#    'right',
#    'like',
#    'charlie',
#    'sheen',
#    'really',
#    'winner',
#    'lol'],
#   2],
#  [['prove', 'youre', 'blissfully', 'group', 'political', 'chump', 'race'], 2],
#  [['used', 'got', 'hoes', 'lookin', 'good', 'fuckin', 'low'], 1],
#  [['one', 'mans', 'trash', 'another', 'mans', 'wife'], 1],
#  [['cant', 'stand', 'playin', 'ass'], 1],
#  [['hate',
#    'bitches',
#    'get',
#    'boyfriends',
#    'forget',
#    'like',
#    'wasnt',
#    'got',
#    'together'],
#   1],
#  [['bitch', 'says', 'eeeeeee', 'hoe'], 1],
#  [['someone', 'casually', 'ask', 'stood', 'car', 'fking', 'serious', 'bitch'],
#   1],
#  [['got', 'pussy', 'bllod'], 1],
#  [['got', 'bad', 'spanish', 'bitch'], 1],
#  [['cant',
#    'wait',
#    'till',
#    'get',
#    'full',
#    'appetite',
#    'back',
#    'ate',
#    'half',
#    'ghetto',
#    'sandwich',
#    'nothing'],
#   2],
#  [['yaaas', 'bitch', 'yaas', 'hot', 'bitch', 'yaaas'], 1],
#  [['ross', 'got', 'amber', 'rose', 'naked', 'hoes', 'aint', 'loyal', 'wiz'],
#   1],
#  [['dick', 'hang', 'wobble', 'tie', 'stick'], 1],
#  [['yellow', 'otl'], 2],
#  [['avi',
#    'prolly',
#    'shoot',
#    'dust',
#    'phone',
#    'cuz',
#    'shit',
#    'old',
#    'cat',
#    'fishing',
#    'bitches',
#    'lmao'],
#   1],
#  [['call', 'ghetto', 'nunchucksthe', 'reason', 'went', 'jail', 'well'], 1],
#  [['ever',
#    'ate',
#    'pussy',
#    'fucked',
#    'niggas',
#    'let',
#    'know',
#    'right',
#    'owe',
#    'dirty',
#    'bitch'],
#   1],
#  [['lmao', 'live', 'wit', 'girl', 'dishes', 'faggot'], 0],
#  [['youre', 'pussy'], 1],
#  [['fucking', 'creepy', 'ass', 'nigguh', 'lmao'], 1],
#  [['aint', 'got', 'pussy', 'bitch', 'suck', 'dick', 'diet'], 1],
#  [['assholes', 'know', 'referring', 'girl', 'bitch', 'doesnt', 'make', 'dick'],
#   0],
#  [['lil', 'bitch', 'coulda', 'let', 'right', 'house'], 1],
#  [['boutta', 'deck', 'bitch', 'face'], 1],
#  [['hoe', 'niggas', 'havnt', 'seen', 'half'], 1],
#  [['always',
#    'pathetic',
#    'mutt',
#    'desperately',
#    'seeking',
#    'attention',
#    'amp',
#    'purpose',
#    'matter',
#    'writes',
#    'never',
#    'change'],
#   2],
#  [['hate', 'lil', 'lol', 'hate', 'steelers', 'dawg'], 0],
#  [['wipe',
#    'cum',
#    'faggot',
#    'contact',
#    'lens',
#    'wildin',
#    'cant',
#    'see',
#    'shit'],
#   1],
#  [['bitch'], 1],
#  [['hahahhahaa',
#    'boyfriend',
#    'trash',
#    'stop',
#    'tryna',
#    'convince',
#    'otherwise',
#    'tweets'],
#   1],
#  [['yall', 'see', 'chojis', 'big', 'ass', 'black', 'bitch'], 1],
#  [['former',
#    'towie',
#    'star',
#    'charlie',
#    'king',
#    'comes',
#    'inspiring',
#    'congrats',
#    'welcome',
#    'family'],
#   2],
#  [['need',
#    'mexican',
#    'flea',
#    'market',
#    'grab',
#    'fake',
#    'gucci',
#    'sandals',
#    'stunt',
#    'hoes'],
#   1],
#  [['tellin',
#    'disrespectful',
#    'aint',
#    'one',
#    'callin',
#    'everybody',
#    'bitch',
#    'free'],
#   1],
#  [['need',
#    'sox',
#    'fuck',
#    'yeah',
#    'love',
#    'kinky',
#    'scally',
#    'lad',
#    'rank',
#    'sox',
#    'sneaks'],
#   1],
#  [['cus',
#    'french',
#    'montanas',
#    'bitch',
#    'fucks',
#    'think',
#    'selling',
#    'drugs',
#    'cool',
#    'lamest'],
#   1],
#  [['love', 'dont', 'even', 'smoke', 'bday', 'bitch', 'gone', 'turntttt'], 1],
#  [['lmao', 'still', 'feel', 'played', 'bout', 'hoe'], 1],
#  [['hoes',
#    'running',
#    'back',
#    'tellin',
#    'shit',
#    'hoes',
#    'trynna',
#    'fuck',
#    'niggas',
#    'tellin',
#    'shit',
#    'mayne'],
#   1],
#  [['oreo', 'adorable'], 2],
#  [['talking', 'almost', 'aint', 'pussy'], 1],
#  [['boys', 'discover', 'hoe'], 1],
#  [['lol', 'bitch', 'dont', 'read', 'books', 'eat', 'fruits', 'hoe'], 1],
#  [['lifelong', 'miss'], 2],
#  [['still', 'wont', 'get', 'bitches', 'wow', 'wtf'], 1],
#  [['katys',
#    'grand',
#    'exit',
#    'tonight',
#    'firehouse',
#    'gtgtgtgt',
#    'hasta',
#    'bye',
#    'bye',
#    'bitches'],
#   1],
#  [['cue', 'liberal', 'lefts', 'uncle', 'tom', 'attacks', 'tim', 'scott'], 2],
#  [['wanna',
#    'lie',
#    'hes',
#    'fuccing',
#    'joke',
#    'ajay',
#    'gotta',
#    'whole',
#    'bitch',
#    'oml',
#    'trynna',
#    'argue',
#    'wit',
#    'amp',
#    'shit',
#    'like',
#    'fir',
#    'boi'],
#   1],
#  [['guys', 'tweet', 'shit', 'get', 'bunch', 'favorites', 'level', 'hoes'], 1],
#  [['ill', 'bitch', 'slap', 'shadow'], 1],
#  [['lol',
#    'bitch',
#    'youve',
#    'put',
#    'lotion',
#    'butt',
#    'amp',
#    'orajel',
#    'mouth',
#    'youd',
#    'paint',
#    'toes'],
#   1],
#  [['regular',
#    'joes',
#    'rockin',
#    'tha',
#    'boat',
#    'thats',
#    'redneck',
#    'yacht',
#    'clubbb'],
#   2],
#  [['ayyy', 'fags'], 1],
#  [['riding', 'bros', 'still', 'dont', 'trust', 'hoes'], 1],
#  [['generate',
#    'ascii',
#    'boxes',
#    'nodejs',
#    'see',
#    'ability',
#    'bring',
#    'node',
#    'via',
#    'ascii',
#    'tubes',
#    'bird'],
#   2],
#  [['girl', 'hold', 'dick', 'like', 'wii', 'controller', 'wheres', 'control'],
#   1],
#  [['fat', 'bitch', 'whats'], 1],
#  [['fucking', 'bitch', 'rachel', 'needs', 'die', 'please'], 1],
#  [['hairy', 'like', 'monkey'], 2],
#  [['dumb',
#    'ass',
#    'fake',
#    'bitches',
#    'childish',
#    'talk',
#    'mad',
#    'shit',
#    'back',
#    'best',
#    'lmao'],
#   1],
#  [['youre', 'acting', 'like', 'bitch', 'bitch', 'theres', 'problem'], 1],
#  [['last',
#    'tweet',
#    'song',
#    'lyrics',
#    'dont',
#    'really',
#    'like',
#    'bad',
#    'like',
#    'pretty',
#    'chicks',
#    'bad',
#    'bitches',
#    'cheat',
#    'easily',
#    'often'],
#   1],
#  [['telling', 'shaved', 'pussy', 'ugly'], 1],
#  [['cars', 'clothes'], 1],
#  [['ion', 'pay', 'pussy', 'priceless', 'fishin', 'aint', 'pisces'], 1],
#  [['need', 'bitch', 'dance', 'lmfao', 'ode'], 1],
#  [['sierra', 'almost', 'got', 'caught', 'ole', 'hick'], 2],
#  [['aint', 'never', 'pregnancy', 'scare', 'pussy', 'trash', 'ladies'], 1],
#  [['three',
#    'arrsted',
#    'german',
#    'gay',
#    'guy',
#    'left',
#    'critical',
#    'condition',
#    'fag',
#    'bashed',
#    'belgrade'],
#   1],
#  [['stupid', 'ass', 'hoe'], 1],
#  [['hoe', 'shit'], 1],
#  [['wussup', 'bitch'], 1],
#  [['spurs', 'bitch', 'thats', 'dont', 'want', 'problems'], 1],
#  [['bitch', 'crazy'], 1],
#  [['idk', 'gotta', 'think', 'cause', 'bitches', 'small', 'shit'], 1],
#  [['flights', 'liberia', 'rerouted', 'ferguson', 'birds', 'stone'], 2],
#  [['better', 'called', 'kid'], 1],
#  [['bitches', 'amp', 'mix'], 1],
#  [['lil', 'stupid', 'ass', 'bitch', 'aint', 'fucking', 'wit', 'youuuu'], 1],
#  [['know', 'twitter', 'password', 'bitch', 'please'], 1],
#  [['dont',
#    'feel',
#    'like',
#    'black',
#    'people',
#    'niggers',
#    'youre',
#    'black',
#    'youre',
#    'imma',
#    'tell',
#    'idc'],
#   1],
#  [['yall',
#    'gorgeous',
#    'women',
#    'aint',
#    'gorgeous',
#    'realize',
#    'got',
#    'ugly',
#    'bitch',
#    'attitude'],
#   1],
#  [['nah',
#    'definitely',
#    'gotta',
#    'find',
#    'bitch',
#    'drive',
#    'around',
#    'whip',
#    'drunk',
#    'dolla',
#    'tape',
#    'right'],
#   1],
#  [['long', 'story', 'lol', 'ive', 'missed', 'faggot'], 1],
#  [['joan',
#    'rivers',
#    'said',
#    'gay',
#    'michelle',
#    'tranny',
#    'perhaps',
#    'death',
#    'accident',
#    'see',
#    'clintons',
#    'ron'],
#   1],
#  [['cho', 'name', 'wanna', 'fuck', 'bitch', 'things', 'says'], 1],
#  [['year', 'starting', 'street', 'put', 'fag'], 1],
#  [['hes', 'right', 'bitches', 'smh'], 1],
#  [['yeah', 'fuck', 'bitch'], 1],
#  [['show',
#    'love',
#    'everybody',
#    'not',
#    'joe',
#    'time',
#    'hate',
#    'stuck',
#    'people',
#    'thats',
#    'hoe',
#    'shit'],
#   1],
#  [['hoes', 'wake'], 1],
#  [['hell',
#    'cause',
#    'brad',
#    'still',
#    'walked',
#    'away',
#    'like',
#    'yeah',
#    'fucked',
#    'niggas',
#    'bitch'],
#   1],
#  [['every',
#    'time',
#    'ask',
#    'something',
#    'waitress',
#    'touches',
#    'knee',
#    'till',
#    'done',
#    'asking',
#    'mean',
#    'tryna',
#    'give',
#    'nigga',
#    'pussy',
#    'dont'],
#   1],
#  [['wait',
#    'min',
#    'pussy',
#    'rihanna',
#    'cologne',
#    'men',
#    'probably',
#    'smell',
#    'like',
#    'curry',
#    'goat',
#    'nail',
#    'clippings'],
#   1],
#  [['new', 'strategy', 'get', 'bruno', 'mars'], 1],
#  [['hoes', 'fake', 'like', 'really', 'hating', 'lowkey'], 1],
#  [['nigga', 'gotta', 'find', 'hoes', 'quick'], 1],
#  [['alright', 'fag'], 0],
#  [['trash', 'thats', 'lot', 'stolen', 'shoes'], 2],
#  [['dont', 'iphone', 'manually', 'ignore', 'hoes'], 1],
#  [['not',
#    'liberal',
#    'amp',
#    'support',
#    'changing',
#    'name',
#    'transcends',
#    'standard',
#    'political',
#    'grandstanding'],
#   2],
#  [['damn',
#    'makin',
#    'bitches',
#    'jealous',
#    'reality',
#    'amp',
#    'prolly',
#    'mad',
#    'pic',
#    'posted',
#    'wouldnt',
#    'taken'],
#   1],
#  [['mother',
#    'manchester',
#    'terror',
#    'twins',
#    'went',
#    'syria',
#    'become',
#    'jihadi',
#    'brides',
#    'snatched',
#    'isis'],
#   2],
#  [['yeah',
#    'definitely',
#    'wasnt',
#    'guy',
#    'fought',
#    'lara',
#    'cuts',
#    'ring',
#    'well',
#    'huge',
#    'boon',
#    'canelo'],
#   2],
#  [['driving',
#    'nice',
#    'not',
#    'pay',
#    'lot',
#    'rent',
#    'drive',
#    'pay',
#    'little',
#    'rent',
#    'saying'],
#   2],
#  [['one', 'day', 'nip', 'well', 'ready', 'wet'], 2],
#  [['bitch', 'going', 'nawl'], 1],
#  [['old', 'ratchet', 'hoes', 'bruh'], 1],
#  [['bet',
#    'yall',
#    'bitches',
#    'deaf',
#    'lytes',
#    'words',
#    'treated',
#    'like',
#    'queen',
#    'huh'],
#   1],
#  [['lets',
#    'see',
#    'look',
#    'like',
#    'without',
#    'filters',
#    'colored',
#    'contact',
#    'followers',
#    'dying',
#    'know'],
#   2],
#  [['tryna', 'turn'], 1],
#  [['bitches', 'aint', 'shit', 'hoes', 'tricks'], 1],
#  [['theres', 'nothing', 'hotter', 'pale', 'albino', 'chick', 'play', 'guitar'],
#   2],
#  [['bust', 'dat', 'pussy', 'wide', 'open'], 1],
#  [['ima',
#    'start',
#    'fuck',
#    'buddies',
#    'save',
#    'lives',
#    'program',
#    'lol',
#    'match',
#    'dry',
#    'bitter',
#    'ass',
#    'folks',
#    'wit',
#    'good',
#    'dick',
#    'pussy'],
#   1],
#  [['fuck', 'opp', 'thot', 'well', 'shoot', 'bitch'], 1],
#  [['got', 'bitches', 'dont', 'ever', 'readem', 'top'], 1],
#  [['starks', 'faggot'], 1],
#  [['niggas',
#    'get',
#    'married',
#    'start',
#    'dissin',
#    'single',
#    'bitches',
#    'smh',
#    'bitches',
#    'want',
#    'allowance',
#    'dates',
#    'still',
#    'singl'],
#   1],
#  [['keep',
#    'running',
#    'trees',
#    'birds',
#    'fly',
#    'avoid',
#    'targeted',
#    'lack',
#    'digestive',
#    'system'],
#   2],
#  [['need', 'scale', 'ghetto'], 2],
#  [['doesnt', 'really', 'look', 'back', 'exs', 'things', 'look', 'better'], 1],
#  [['nerve', 'nicca', 'step', 'crispy', 'ass', 'shoes', 'wit', 'dusty', 'ass'],
#   1],
#  [['know', 'youre', 'ugly', 'ape', 'chosen', 'man', 'crush', 'youve', 'never'],
#   2],
#  [['das',
#    'calld',
#    'usen',
#    'brain',
#    'retard',
#    'would',
#    'whoop',
#    'ass',
#    'front',
#    'police'],
#   0],
#  [['niggas',
#    'slope',
#    'intercept',
#    'form',
#    'equations',
#    'cant',
#    'make',
#    'scrambled',
#    'fuckin',
#    'eggs',
#    'thats',
#    'lil',
#    'backwards'],
#   1],
#  [['puss'], 1],
#  [['breakfast',
#    'fried',
#    'chicken',
#    'jerk',
#    'chicken',
#    'tater',
#    'tots',
#    'white',
#    'rice',
#    'press',
#    'yellow',
#    'rice',
#    'beans',
#    'mac',
#    'cheese'],
#   2],
#  [['girlfriend', 'doesnt', 'like', 'dont', 'talk', 'bitch'], 1],
#  [['sitting',
#    'next',
#    'neighborhood',
#    'crazy',
#    'bitch',
#    'amp',
#    'keeps',
#    'randomly',
#    'busting',
#    'laughing'],
#   1],
#  [['theres',
#    'apparently',
#    'wee',
#    'cunt',
#    'whos',
#    'year',
#    'younger',
#    'called',
#    'sean',
#    'brown',
#    'cheeky',
#    'lol'],
#   1],
#  [['face', 'ugly', 'amp', 'nudes', 'trash'], 2],
#  [['couldnt', 'care', 'less'], 1],
#  [['kid', 'straight', 'watched', 'bitch', 'eat', 'bloody', 'tampon'], 1],
#  [['playing', 'show', 'today', 'papa', 'charlies'], 2],
#  [['pussy', 'boy', 'dont', 'want', 'war'], 1],
#  [['hoes',
#    'everybody',
#    'clothes',
#    'got',
#    'nerve',
#    'take',
#    'picture',
#    'man',
#    'shit',
#    'crazy'],
#   1],
#  [['man',
#    'pussy',
#    'coward',
#    'overpowered',
#    'easily',
#    'took',
#    'clearly',
#    'much',
#    'less'],
#   1],
#  [['oreo', 'shake'], 2],
#  [['eva', 'wanted', 'muh', 'fuckin', 'guala'], 1],
#  [['said', 'like', 'got', 'money', 'dont', 'forget', 'not', 'aint', 'broke'],
#   1],
#  [['energy', 'hoes'], 1],
#  [['watch'], 2],
#  [['bitch',
#    'shutcho',
#    'got',
#    'damn',
#    'mouf',
#    'hoe',
#    'mallett',
#    'aint',
#    'gon',
#    'help',
#    'funky',
#    'ass',
#    'texans'],
#   1],
#  [['say', 'something', 'one', 'drake', 'song', 'listen', 'feelingsfag'], 1],
#  [['got',
#    'pic',
#    'lines',
#    'stay',
#    'grind',
#    'tell',
#    'bitch',
#    'time',
#    'bitch',
#    'get',
#    'car',
#    'got',
#    'ridin',
#    'dayton',
#    'spokes'],
#   1],
#  [['girls',
#    'women',
#    'ladies',
#    'bitches',
#    'beeeitch',
#    'dumb',
#    'ass',
#    'bitch',
#    'hahaha'],
#   1],
#  [['god',
#    'actually',
#    'voted',
#    'give',
#    'people',
#    'affordable',
#    'insurance',
#    'rates',
#    'bitch'],
#   1],
#  [['joke',
#    'hoes',
#    'aint',
#    'looking',
#    'first',
#    'girl',
#    'loved',
#    'bitches',
#    'thats'],
#   1],
#  [['mother',
#    'asked',
#    'wanted',
#    'christmas',
#    'year',
#    'replied',
#    'not',
#    'sister',
#    'not',
#    'bitch'],
#   1],
#  [['maybe',
#    'call',
#    'hootie',
#    'back',
#    'dont',
#    'answer',
#    'anymore',
#    'still',
#    'crows'],
#   2],
#  [['nigga', 'really', 'tried', 'save', 'bitch', 'lol'], 1],
#  [['bitches', 'average', 'lmao', 'baddie', 'pretty', 'girls', 'like'], 1],
#  [['fuck', 'taylors', 'bitch', 'ass'], 1],
#  [['stupidest', 'bitch', 'brb', 'crying', 'called', 'stupid'], 1],
#  [['baseball',
#    'isnt',
#    'without',
#    'yankees',
#    'playoffs',
#    'amp',
#    'basketball',
#    'isnt',
#    'without',
#    'lakers'],
#   2],
#  [['not', 'scanger'], 2],
#  [['bitches', 'singing', 'song', 'tho'], 1],
#  [['cheer', 'awful', 'new', 'york', 'yankees', 'louis', 'cardinals'], 2],
#  [['dont', 'know', 'told', 'love', 'project', 'hoes'], 2],
#  [['slushes', 'hoes', 'nasty', 'anyway', 'fam'], 1],
#  [['ive', 'got', 'best', 'friends', 'functioning', 'retard', 'could'], 1],
#  [['bitch', 'lookin', 'like', 'wana', 'fuck', 'summn'], 1],
#  [['rico', 'full', 'shytfull', 'money', 'hoe'], 1],
#  [['yes', 'suhh', 'fuck', 'chillin', 'gettin', 'live', 'tomorrow'], 1],
#  [['modern', 'day', 'singers', 'talk', 'shit', 'rappers', 'talk', 'lolhoes'],
#   1],
#  [['bitches', 'quick', 'nigga', 'suprised', 'taking', 'care'], 1],
#  [['soft', 'hoes', 'dumb', 'man'], 1],
#  [['problems', 'bitch', 'aint', 'one'], 1],
#  [['nigger', 'fighter', 'huh'], 0],
#  [['boys', 'need', 'damn'], 1],
#  [['pussy', 'pussy', 'pussy', 'marijauna', 'wannnnaaa'], 1],
#  [['single',
#    'cuz',
#    'hoes',
#    'left',
#    'good',
#    'ones',
#    'taken',
#    'female',
#    'thats',
#    'singleyou'],
#   1],
#  [['yall', 'crazy', 'hoes', 'need', 'jesus', 'lol'], 1],
#  [['number', 'hoe'], 1],
#  [['yeah', 'texans', 'much', 'better', 'fucking', 'retard'], 1],
#  [['bitch', 'ass'], 1],
#  [['thats', 'ghetto'], 2],
#  [['pull', 'bitch'], 1],
#  [['dat', 'bitch', 'thot'], 1],
#  [['lmaooo', 'call', 'phone', 'want', 'birds'], 2],
#  [['loyal', 'pussy'], 1],
#  [['said', 'cute', 'byeeee', 'mad', 'come', 'visit'], 1],
#  [['thats', 'thought', 'pussy'], 1],
#  [['yall', 'bitches', 'wanna', 'different', 'yall', 'really', 'basic'], 1],
#  [['birds', 'bees'], 2],
#  [['niggah', 'follow', 'back'], 1],
#  [['nerve', 'bitches', 'champaign'], 1],
#  [['fav', 'pic', 'means', 'hoe'], 1],
#  [['color',
#    'entire',
#    'arm',
#    'black',
#    'sharpie',
#    'fist',
#    'wifes',
#    'asshole',
#    'knows',
#    'nigger',
#    'dick',
#    'feels',
#    'like'],
#   0],
#  [['remember',
#    'trash',
#    'floor',
#    'upgraded',
#    'amp',
#    'put',
#    'wales',
#    'gifted',
#    'feels',
#    'like',
#    'old',
#    'car',
#    'htt'],
#   2],
#  [['give', 'hoe', 'oscar', 'stay', 'acting'], 1],
#  [['whiggers',
#    'tea',
#    'party',
#    'nation',
#    'banned',
#    'didnt',
#    'even',
#    'use',
#    'bad',
#    'maybe',
#    'racist',
#    'founding',
#    'father',
#    'quotes'],
#   1],
#  [['ill',
#    'never',
#    'understand',
#    'people',
#    'fake',
#    'entire',
#    'cant',
#    'even',
#    'fake',
#    'hello',
#    'bitch',
#    'fucking'],
#   1],
#  [['dont', 'fucc', 'wit', 'coward', 'cuz', 'bitch', 'left'], 1],
#  [['alec', 'baldwin', 'mocks', 'forgiven', 'via'], 2],
#  [['fasho', 'youve', 'officially', 'hired', 'bitch'], 1],
#  [['relationships',
#    'come',
#    'hatin',
#    'ass',
#    'arguments',
#    'real',
#    'couples',
#    'laugh',
#    'shit'],
#   1],
#  [['kyrie', 'fast', 'bitch', 'ball', 'look', 'like', 'lollol', 'wish'], 1],
#  [['youre', 'trash', 'like', 'sorry'], 2],
#  [['bitch', 'model', 'yall', 'bitches', 'cant', 'tell', 'nothin'], 1],
#  [['got', 'hoes', 'damn'], 1],
#  [['downloads', 'flappy', 'welp', 'goes', 'school'], 2],
#  [['way', 'gym', 'already', 'thx', 'bitch'], 1],
#  [['puff',
#    'pass',
#    'porn',
#    'run',
#    'bitch',
#    'assless',
#    'chaps',
#    'swearing',
#    'catholic'],
#   1],
#  [['albino', 'hes', 'asian'], 2],
#  [['youre',
#    'bitch',
#    'moms',
#    'bitch',
#    'dads',
#    'bitch',
#    'fucking',
#    'bitch',
#    'whos'],
#   1],
#  [['fuck', 'bitches', 'get', 'money'], 1],
#  [['takes', 'bath', 'hes', 'terrified', 'water', 'wash', 'lol'], 1],
#  [['rule', 'number', 'one', 'never', 'pursue', 'bitch', 'ova', 'side'], 1],
#  [['theres',
#    'lane',
#    'bitches',
#    'need',
#    'stay',
#    'left',
#    'get',
#    'right',
#    'fuck',
#    'outta',
#    'face'],
#   1],
#  [['pick', 'take', 'nip'], 2],
#  [['comcast', 'stop', 'twat', 'actually', 'work', 'thanks'], 1],
#  [['really', 'exploding', 'giant', 'yellow', 'ducks', 'youll', 'appreciate'],
#   2],
#  [['curious',
#    'curious',
#    'little',
#    'monkey',
#    'deranged',
#    'serial',
#    'cat',
#    'story',
#    'man',
#    'yellow',
#    'hat',
#    'doesnt',
#    'want'],
#   2],
#  [['racist',
#    'ntx',
#    'trash',
#    'hate',
#    'see',
#    'particular',
#    'man',
#    'not',
#    'butler'],
#   0],
#  [['quit',
#    'suckin',
#    'dick',
#    'hop',
#    'fat',
#    'ass',
#    'elsewhere',
#    'cuz',
#    'aint',
#    'tryna',
#    'fuck',
#    'globe',
#    'ass',
#    'bitch',
#    'got',
#    'orbit'],
#   1],
#  [['fuck',
#    'yeah',
#    'hot',
#    'big',
#    'blk',
#    'boots',
#    'scally',
#    'lad',
#    'would',
#    'get'],
#   1],
#  [['makes', 'hoes', 'seem', 'attractive'], 1],
#  [['know',
#    'samklef',
#    'said',
#    'wasnt',
#    'lie',
#    'man',
#    'guy',
#    'think',
#    'beast',
#    'naija',
#    'pop',
#    'music',
#    'trash',
#    'not',
#    'wizkid'],
#   2],
#  [['killed', 'whatever', 'ahead', 'pocketsgt'], 1],
#  [['centuries'], 2],
#  [['youre',
#    'not',
#    'fucking',
#    'relevant',
#    'get',
#    'followers',
#    'follow',
#    'trains',
#    'unfollow',
#    'people',
#    'youre',
#    'faggot'],
#   1],
#  [['bitch', 'ass', 'like', 'allergic', 'reaction', 'service', 'faction'], 1],
#  [['claim', 'boss', 'lil', 'broke', 'bitch'], 1],
#  [['wonder',
#    'wrote',
#    'blog',
#    'either',
#    'hoe',
#    'dat',
#    'let',
#    'niggas',
#    'beat',
#    'bitch',
#    'nigga',
#    'hoe',
#    'let',
#    'beat'],
#   1],
#  [['dont', 'talk', 'hoe', 'way'], 1],
#  [['head', 'sole', 'feet'], 2],
#  [['fuck', 'tweaking', 'hoe'], 1],
#  [['know', 'birds', 'dont', 'wear', 'cause', 'peckers', 'way'], 1],
#  [['dont',
#    'mention',
#    'bitch',
#    'past',
#    'first',
#    'dont',
#    'give',
#    'fuck',
#    'second',
#    'dont',
#    'care'],
#   1],
#  [['like', 'honestly', 'embarrassed', 'around', 'someone', 'youre', 'trash'],
#   1],
#  [['text'], 1],
#  [['never',
#    'cuffin',
#    'unless',
#    'bitch',
#    'grown',
#    'act',
#    'grown',
#    'cant',
#    'deal',
#    'wit',
#    'lil',
#    'girls',
#    'nbs'],
#   1],
#  [['two', 'main', 'wiggas'], 1],
#  [['hoes', 'like', 'online'], 1],
#  [['dont', 'broke', 'hoe', 'hating', 'paid'], 1],
#  [['whops', 'yardie', 'smoke', 'blunt', 'tell', 'nigga', 'come', 'stressed'],
#   1],
#  [['lmfao', 'niggas', 'going', 'ham', 'trash', 'class'], 1],
#  [['tired',
#    'bitches',
#    'thinking',
#    'cool',
#    'ugly',
#    'youre',
#    'ugly',
#    'bitch',
#    'thats',
#    'ugly'],
#   1],
#  [['republican', 'teabaggers', 'jailed', 'treason'], 2],
#  [['hate',
#    'seeing',
#    'people',
#    'money',
#    'spend',
#    'stupid',
#    'dont',
#    'need',
#    'tvs',
#    'amp',
#    'shark',
#    'tank',
#    'twat'],
#   1],
#  [['scrum', 'finna', 'smash', 'bitches'], 1],
#  [['asian'], 1],
#  [['amos', 'two', 'walk', 'unless'], 2],
#  [['man', 'wimp', 'gotta', 'drunk', 'know', 'damn', 'well', 'dont'], 1],
#  [['mommy', 'said', 'pussy', 'cats', 'inside', 'dawgs', 'house'], 2],
#  [['really',
#    'deleted',
#    'flappy',
#    'bird',
#    'app',
#    'store',
#    'cus',
#    'someone',
#    'killed',
#    'foreal',
#    'foreal'],
#   2],
#  [['whats', 'good', 'bitch'], 1],
#  [['kanye', 'west', 'faggot'], 0],
#  [['got',
#    'gym',
#    'saw',
#    'old',
#    'black',
#    'hoe',
#    'coldest',
#    'body',
#    'hoe',
#    'jerry',
#    'curl',
#    'like'],
#   1],
#  [['shut', 'bitch', 'swallow'], 1],
#  [['congratulations', 'leadoff', 'base', 'hit', 'hit'], 2],
#  [['chris',
#    'brown',
#    'bitch',
#    'everyone',
#    'talks',
#    'relationship',
#    'come',
#    'two',
#    'charlemagne',
#    'saying',
#    'sam'],
#   1],
#  [['give', 'tankees', 'mean', 'yankees', 'maybe', 'next'], 2],
#  [['always',
#    'thought',
#    'golden',
#    'oreos',
#    'original',
#    'oreos',
#    'god',
#    'climaxed'],
#   2],
#  [['brie',
#    'said',
#    'together',
#    'since',
#    'born',
#    'guys',
#    'twins',
#    'duh',
#    'bitch',
#    'omg',
#    'wrote'],
#   1],
#  [['fake', 'ass', 'bitches', 'bruh', 'lol'], 1],
#  [['see',
#    'didnt',
#    'election',
#    'bird',
#    'america',
#    'okay',
#    'guess',
#    'take',
#    'free',
#    'cookie',
#    'everyo'],
#   2],
#  [['bette', 'fucking', 'davis', 'eyes', 'bitch'], 1],
#  [['get', 'ass', 'back', 'detroit', 'fuckin'], 1],
#  [['peckerwood'], 1],
#  [['said',
#    'want',
#    'man',
#    'pick',
#    'sex',
#    'bitch',
#    'lucky',
#    'picked',
#    'gas',
#    'prices',
#    'high',
#    'hell'],
#   1],
#  [['drink', 'beurs', 'kid', 'plus', 'faggot', 'anyways'], 1],
#  [['not',
#    'brightest',
#    'guess',
#    'game',
#    'lil',
#    'know',
#    'much',
#    'attention',
#    'whores',
#    'bitches'],
#   1],
#  [['duncanville', 'girls', 'cold', 'den', 'hoe'], 1],
#  [['taking', 'pics', 'school', 'bathroom', 'fucking', 'stupid'], 1],
#  [['call',
#    'player',
#    'pussy',
#    'hes',
#    'sidelined',
#    'low',
#    'class',
#    'trash',
#    'might'],
#   1],
#  [['shut', 'bitch'], 1],
#  [['got', 'channing', 'tatum'], 1],
#  [['might',
#    'rain',
#    'hmmm',
#    'dont',
#    'want',
#    'look',
#    'like',
#    'pussy',
#    'carrying',
#    'umbrella',
#    'around',
#    'also',
#    'dont',
#    'want',
#    'risk',
#    'perm',
#    'getting',
#    'wet'],
#   1],
#  [['playstation', 'trash', 'xbox', 'better', 'titties', 'trash'], 1],
#  [['basically', 'like', 'background', 'fag'], 0],
#  [['geeked', 'mine', 'think', 'bitch', 'done', 'stole'], 1],
#  [['sippin', 'hot', 'tea', 'bitch'], 1],
#  [['youre', 'right', 'momma', 'aint', 'raise', 'faggot'], 1],
#  [['youre', 'public', 'side', 'hoe'], 1],
#  [['play', 'cheat', 'wear', 'khaki', 'coloured', 'cargos', 'haircut'], 1],
#  [['learned', 'many', 'retards', 'find', 'search', 'trending', 'topics'], 0],
#  [['amp',
#    'bitches',
#    'bound',
#    'get',
#    'cause',
#    'lotta',
#    'niggas',
#    'playinhell',
#    'yeah'],
#   1],
#  [['music', 'trash'], 2],
#  [['ight', 'nigga', 'tonight', 'burg', 'mall', 'bitch'], 1],
#  [['bitches',
#    'baby',
#    'amp',
#    'like',
#    'dont',
#    'claim',
#    'child',
#    'bitch',
#    'good',
#    'amp',
#    'goddamn',
#    'well',
#    'aint',
#    'nobody',
#    'claiming',
#    'creature'],
#   1],
#  [['bitches', 'know', 'feeling', 'keep', 'sentences', 'short'], 1],
#  [['remember',
#    'laying',
#    'hospital',
#    'bed',
#    'shot',
#    'ranting',
#    'coconut',
#    'shrimp',
#    'trash'],
#   2],
#  [['lowkey', 'got', 'fan', 'hoop', 'skills', 'lbcc', 'aha', 'niggah', 'lol'],
#   1],
#  [['stfu', 'dont', 'get', 'pussy', 'fuck', 'boy'], 1],
#  [['heard',
#    'letting',
#    'people',
#    'know',
#    'relationship',
#    'problems',
#    'amp',
#    'arguing',
#    'thats',
#    'hoes',
#    'stop'],
#   1],
#  [['one',
#    'big',
#    'lecture',
#    'hall',
#    'full',
#    'bitches',
#    'sequins',
#    'limited',
#    'tank',
#    'tops'],
#   1],
#  [['thanks', 'bruh', 'dont', 'ever', 'forget', 'still', 'look', 'faggots'], 1],
#  [['hows', 'bitch', 'wearing', 'high', 'heals', 'right'], 1],
#  [['weird', 'frosted', 'colored', 'lipgloss', 'weird'], 2],
#  [['moment',
#    'truly',
#    'believe',
#    'fucking',
#    'pice',
#    'trash',
#    'lovely',
#    'felling'],
#   1],
#  [['wrote',
#    'dawg',
#    'ass',
#    'amp',
#    'working',
#    'bibliography',
#    'amp',
#    'laptop',
#    'froze',
#    'kill',
#    'bitch',
#    'gets',
#    'cause',
#    'hadnt',
#    'saved'],
#   1],
#  [['somebody', 'says', 'childish', 'gambino', 'trash'], 2],
#  [['bitches'], 1],
#  [['clue', 'bad', 'hoes', 'aint', 'really', 'bad'], 1],
#  [['nah',
#    'hate',
#    'white',
#    'people',
#    'since',
#    'looks',
#    'like',
#    'dyke',
#    'think',
#    'ended',
#    'racism'],
#   0],
#  [['youre', 'stressing', 'someone', 'realize', 'got', 'hoes'], 1],
#  [['sza', 'freckles', 'pussy'], 1],
#  [['hoes', 'like', 'omg', 'love', 'new', 'comb', 'thought', 'perro'], 1],
#  [['dear',
#    'ugly',
#    'stop',
#    'playing',
#    'hard',
#    'youre',
#    'already',
#    'hard',
#    'want'],
#   1],
#  [['ima', 'keep', 'fuckn', 'like', 'love', 'bitch'], 1],
#  [['isis', 'jihadis', 'australia', 'shoot', 'man', 'chanting', 'isis', 'stay'],
#   2],
#  [['text', 'bitch'], 1],
#  [['going',
#    'talk',
#    'shit',
#    'another',
#    'state',
#    'thats',
#    'dat',
#    'pussy',
#    'shit'],
#   1],
#  [['vice',
#    'news',
#    'interview',
#    'canadian',
#    'jihadi',
#    'poem',
#    'translated',
#    'sound',
#    'track'],
#   2],
#  [['charlie',
#    'sheen',
#    'engaged',
#    'porn',
#    'star',
#    'cant',
#    'one',
#    'thinking',
#    'lot',
#    'better'],
#   2],
#  [['hoe', 'gone', 'hoe', 'dats', 'nigga', 'broke', 'hoes', 'act'], 1],
#  [['ayyyyyyeeeeee', 'nigga', 'back', 'bitch'], 1],
#  [['way', 'fuck', 'bitch', 'name', 'lord', 'race'], 0],
#  [['full', 'white', 'trash'], 0],
#  [['got',
#    'niggahs',
#    'salty',
#    'meeeee',
#    'cause',
#    'dream',
#    'bitch',
#    'main',
#    'slide'],
#   1],
#  [['big', 'boring', 'kubrats', 'comin'], 1],
#  [['girls', 'okay', 'aint', 'mad', 'unless', 'stabbed', 'love', 'hoe'], 1],
#  [['pimps', 'hoes'], 1],
#  [['better', 'pray', 'dont', 'send', 'nudes', 'bitch'], 0],
#  [['hoes',
#    'beefing',
#    'bout',
#    'important',
#    'hoes',
#    'queefing',
#    'yall',
#    'blowing',
#    'vaginal',
#    'wind',
#    'back',
#    'amp',
#    'forth',
#    'stfu',
#    'amp',
#    'get'],
#   1],
#  [['nigga', 'byeeeee', 'lmfao', 'ill', 'dammed', 'fag', 'stole', 'girl'], 1],
#  [['space', 'brownies'], 2],
#  [['unblock', 'tell', 'garbage', 'bitch', 'ass', 'playing'], 1],
#  [['gullible', 'ones', 'people', 'college', 'intentions'], 1],
#  [['dont', 'sensitive', 'bitch', 'insult', 'expect', 'insulted', 'back'], 1],
#  [['altyd',
#    'geweest',
#    'hoe',
#    'vaak',
#    'men',
#    'ook',
#    'nooit',
#    'vertonen',
#    'dierngedrag'],
#   2],
#  [['try', 'take', 'othot', 'drugs', 'bitch'], 1],
#  [['fuckin',
#    'wit',
#    'nigga',
#    'getting',
#    'emotional',
#    'remind',
#    'bitch',
#    'blake'],
#   1],
#  [['basic', 'bitches', 'basic', 'cable'], 1],
#  [['omg', 'show', 'made', 'cry', 'pussy', 'manyou', 'really'], 1],
#  [['still',
#    'nigga',
#    'dont',
#    'trip',
#    'hatin',
#    'cause',
#    'got',
#    'bitches',
#    'nigga',
#    'stole',
#    'princess',
#    'punch'],
#   1],
#  [['pussy', 'hole', 'must', 'small', 'adjustment', 'gentle', 'intercourse'],
#   1],
#  [['foh', 'lmao', 'hella', 'skinny', 'bitches', 'dont', 'like'], 1],
#  [['paid', 'bitches', 'always', 'money'], 1],
#  [['thanks', 'kass', 'respect', 'not', 'youre', 'bitch'], 1],
#  [['fuck',
#    'remember',
#    'eat',
#    'drink',
#    'remember',
#    'drink',
#    'water',
#    'youre',
#    'drinking',
#    'also',
#    'eat',
#    'shit',
#    'pussy',
#    'head'],
#   1],
#  [['shit', 'gettin', 'money', 'fuckin', 'hoes', 'dat', 'lmaooooo'], 1],
#  [['cock', 'slappin', 'bitches', 'since'], 1],
#  [['fuck',
#    'bitches',
#    'get',
#    'money',
#    'favorite',
#    'niggas',
#    'line',
#    'girl',
#    'leave',
#    'ass',
#    'another',
#    'man'],
#   1],
#  [['mitt',
#    'romney',
#    'gone',
#    'take',
#    'away',
#    'weave',
#    'become',
#    'hoes',
#    'gone',
#    'walkin',
#    'around',
#    'looking',
#    'like',
#    'lil',
#    'bill',
#    'amp',
#    'calliou'],
#   1],
#  [['wanna', 'cut', 'hair', 'busy', 'bitch'], 1],
#  [['rachet', 'ass', 'bitch'], 1],
#  [['nigga', 'aux', 'cord', 'playin', 'trash', 'shit'], 1],
#  [['stop', 'bitch'], 1],
#  [['bitch', 'ill', 'fuck'], 1],
#  [['thing', 'much', 'pussy'], 1],
#  [['got', 'legacy', 'fuck', 'yall', 'legacy'], 1],
#  [['reasons',
#    'periods',
#    'pants',
#    'perfect',
#    'hair',
#    'get',
#    'lure',
#    'men',
#    'death',
#    'free',
#    'clam'],
#   2],
#  [['lmao', 'yesterday', 'hoes', 'cute', 'lol'], 1],
#  [['joseline', 'audience', 'mad', 'bitch'], 1],
#  [['youre', 'main', 'bitch'], 1],
#  [['tell',
#    'hoes',
#    'come',
#    'cause',
#    'look',
#    'like',
#    'forgot',
#    'bout',
#    'fact',
#    'aint',
#    'seen',
#    'say',
#    'alot',
# ...
#   1],
#  [['pretty', 'boy', 'face', 'awee', 'thanks', 'faggot'], 1],
#  [['cant', 'stand', 'bitch', 'ass', 'niggas'], 0],
#  [['bitch', 'get', 'punched', 'lol'], 1],
#  [['cant', 'put', 'pussy', 'pedestal'], 1],
#  [['dat', 'bitch', 'ass', 'nigga', 'alabama', 'wanna', 'kill'], 1],
#  [['beautiful', 'smiles', 'colored', 'eyes'], 2],
#  [['craving', 'brownies'], 2],
#  [['bitch',
#    'starts',
#    'fukin',
#    'yappin',
#    'ill',
#    'make',
#    'sure',
#    'break',
#    'something',
#    'vital',
#    'call',
#    'polis',
#    'hazard',
#    'results',
#    'permanent',
#    'damage'],
#   1],
#  [['somebody',
#    'couldve',
#    'like',
#    'aye',
#    'man',
#    'dropped',
#    'money',
#    'nooooooo',
#    'fucking',
#    'broke',
#    'faggots',
#    'selfish',
#    'bastards',
#    'hate',
#    'yall'],
#   0],
#  [['fuck',
#    'stupid',
#    'ass',
#    'coward',
#    'ass',
#    'punk',
#    'bitch',
#    'faggot',
#    'ass',
#    'racist',
#    'piece',
#    'shit',
#    'punk',
#    'aint',
#    'worth'],
#   0],
#  [['gotta',
#    'bitch',
#    'suck',
#    'dick',
#    'till',
#    'nut',
#    'spit',
#    'gut',
#    'slurp',
#    'shit',
#    'back',
#    'aint',
#    'slut'],
#   1],
#  [['holy',
#    'fucking',
#    'shit',
#    'game',
#    'third',
#    'string',
#    'redskins',
#    'team',
#    'gut',
#    'wrenching'],
#   1],
#  [['gonna', 'shower', 'sole', 'purpose', 'shampooing', 'beard'], 2],
#  [['racist', 'bitch'], 1],
#  [['smoke', 'fat', 'pound', 'fall', 'faster', 'fat', 'bitch', 'sat', 'fast'],
#   1],
#  [['hoe', 'crying', 'ass', 'pregnant', 'smiles', 'riding', 'dick', 'bitch'],
#   0],
#  [['saying',
#    'bitch',
#    'get',
#    'nigga',
#    'hoe',
#    'cuz',
#    'gonna',
#    'beat',
#    'ass',
#    'like',
#    'gonna',
#    'beat',
#    'nigga',
#    'bitch',
#    'get',
#    'nigga'],
#   1],
#  [['yall', 'hoes', 'would', 'never', 'get', 'skin'], 1],
#  [[], 1],
#  [['coons'], 0],
#  [['welcome',
#    'land',
#    'check',
#    'racist',
#    'whitey',
#    'sitting',
#    'steps',
#    'etc',
#    'woo'],
#   2],
#  [['dont', 'respect', 'nun', 'bitch', 'cause', 'idgaf', 'bout', 'des', 'hoes'],
#   1],
#  [['humble', 'not', 'hoe', 'best', 'feature', 'opposite', 'sex'], 1],
#  [['city', 'bitches'], 1],
#  [['pussy', 'stank'], 1],
#  [['winter', 'time', 'walking', 'hoe', 'ctfu'], 1],
#  [['momma',
#    'dead',
#    'bitch',
#    'really',
#    'think',
#    'cant',
#    'connect',
#    'lucky',
#    'number',
#    'face'],
#   1],
#  [['hahahaha', 'basic', 'bitches', 'funny'], 1],
#  [['hit', 'plans', 'mah', 'nigs'], 1],
#  [['told', 'never', 'fold', 'amp', 'never', 'sell', 'sole'], 2],
#  [['wyd', 'hoe', 'heyyy'], 1],
#  [['black', 'pussy', 'nigga', 'sayin', 'anything'], 1],
#  [['post', 'bid', 'tell', 'nig', 'use', 'jab'], 1],
#  [['hate',
#    'bitches',
#    'keep',
#    'saying',
#    'yassss',
#    'like',
#    'like',
#    'bitch',
#    'sound',
#    'stupid',
#    'stfu'],
#   1],
#  [['ive',
#    'noticed',
#    'mostly',
#    'bitches',
#    'whose',
#    'hair',
#    'dont',
#    'even',
#    'reach',
#    'shoulders',
#    'talk',
#    'shit'],
#   1],
#  [['division', 'trash', 'saints', 'gon', 'win', 'nfc', 'southwatch'], 2],
#  [['bitch', 'want'], 1],
#  [['love',
#    'fat',
#    'hoes',
#    'tight',
#    'clothes',
#    'granny',
#    'panties',
#    'seeeexxaaaay'],
#   1],
#  [['makes', 'nigger', 'fucking', 'goat'], 1],
#  [['love'], 1],
#  [['fat', 'thick'], 1],
#  [['realest', 'bitch', 'amber'], 1],
#  [['caught', 'talking', 'bird', 'pretty', 'embarrassing'], 2],
#  [['thanks', 'saying', 'today'], 1],
#  [['beer', 'ball', 'isnt', 'pussies'], 1],
#  [['needy',
#    'ratchet',
#    'sideline',
#    'beggin',
#    'dumb',
#    'looking',
#    'love',
#    'facebook',
#    'hoes'],
#   1],
#  [['chippah', 'hopes', 'aint', 'hangin', 'wit', 'dis', 'wigger', 'boy'], 1],
#  [['dont', 'hate', 'japs', 'aint', 'forgetting', 'gettin', 'japped', 'either'],
#   0],
#  [['miss', 'fag', 'friends'], 1],
#  [['english',
#    'killed',
#    'leprechauns',
#    'thank',
#    'god',
#    'annoying',
#    'little',
#    'bastards'],
#   1],
#  [['niggas', 'dnt', 'like', 'bet', 'fck', 'bitch', 'tho'], 1],
#  [['mom',
#    'told',
#    'put',
#    'drug',
#    'paraphernalia',
#    'trash',
#    'shitty',
#    'life',
#    'stoner',
#    'cop',
#    'mom',
#    'pretty',
#    'upset'],
#   1],
#  [['solution', 'zog', 'doesnt', 'deal', 'demographics', 'laws', 'solution'],
#   2],
#  [['bitch', 'fuck', 'blog', 'meet', 'get', 'round'], 1],
#  [['hgwells', 'charlie', 'chaplin'], 2],
#  [['least',
#    'agree',
#    'whining',
#    'like',
#    'little',
#    'bitch',
#    'someone',
#    'threw',
#    'phone',
#    'absolutely'],
#   1],
#  [['dont', 'wife', 'bitch', 'night', 'catching', 'bodies', 'might', 'alright'],
#   1],
#  [['gotta', 'find', 'know', 'cali', 'got', 'hoes'], 1],
#  [['talkin', 'nig', 'smashed', 'homies'], 0],
#  [['hoes', 'aint', 'got', 'manners'], 1],
#  [['boats', 'hoes'], 1],
#  [['shutup', 'thirsty', 'hoe'], 1],
#  [['professor', 'said', 'hoes', 'said', 'butt', 'hurt', 'boss'], 1],
#  [['wus', 'fat', 'ass', 'filled', 'application', 'work', 'not', 'bitch'], 1],
#  [['coolin', 'know', 'ole', 'shit', 'different', 'day', 'nig'], 1],
#  [['found',
#    'sloppy',
#    'tried',
#    'drag',
#    'car',
#    'fighting',
#    'back',
#    'bitch',
#    'hea'],
#   1],
#  [['think', 'mans', 'take', 'bitches', 'house', 'see', 'wifi', 'connects'], 1],
#  [['stevie',
#    'turned',
#    'hoe',
#    'housewife',
#    'nikko',
#    'turned',
#    'housewife',
#    'hoe',
#    'swear',
#    'shit',
#    'happen'],
#   1],
#  [['amp', 'fuck', 'bitches'], 1],
#  [['bitches', 'jus', 'love', 'get', 'madd'], 1],
#  [['hell', 'plasticassed'], 1],
#  [['negro', 'amigo', 'pulled', 'gun', 'nate', 'weeks', 'ago'], 0],
#  [['houston',
#    'top',
#    'five',
#    'ahl',
#    'attendance',
#    'aeros',
#    'transplanted',
#    'snow',
#    'bird',
#    'would',
#    'love',
#    'team'],
#   2],
#  [['throw',
#    'rager',
#    'sweet',
#    'everybody',
#    'bring',
#    'presents',
#    'cards',
#    'crib',
#    'bitch',
#    'grandma',
#    'even',
#    'bought',
#    'bday',
#    'cake',
#    'ova'],
#   1],
#  [['sarcastic', 'bitch', 'beautiful'], 1],
#  [['hell',
#    'nahh',
#    'bitch',
#    'respect',
#    'damn',
#    'wouldnt',
#    'wear',
#    'shit',
#    'public'],
#   1],
#  [['cant',
#    'even',
#    'tell',
#    'bitch',
#    'hey',
#    'without',
#    'thinking',
#    'tryna',
#    'get',
#    'lmao',
#    'yall',
#    'sumn',
#    'else',
#    'get',
#    'real'],
#   1],
#  [['hoe',
#    'sooooo',
#    'ugly',
#    'like',
#    'bitch',
#    'ugly',
#    'dog',
#    'like',
#    'dumb',
#    'stupid',
#    'ass',
#    'ugly',
#    'like'],
#   1],
#  [['popped', 'pussy', 'sweating', 'lol'], 1],
#  [['nigga', 'proud', 'bitch', 'going', 'get', 'weed', 'car'], 1],
#  [['hate', 'people', 'ask', 'tryna', 'look', 'good', 'bitch', 'bye'], 1],
#  [['aint', 'jus', 'bitches', 'wan', 'fck'], 1],
#  [['say', 'say', 'woman', 'strong', 'personality', 'doesnt', 'play', 'well'],
#   1],
#  [['bitch', 'probably', 'deserved', 'lol'], 1],
#  [['brownie', 'points'], 2],
#  [['call', 'pussy', 'not', 'senior', 'skip'], 1],
#  [['never',
#    'problem',
#    'girl',
#    'years',
#    'school',
#    'otter',
#    'looking',
#    'twat',
#    'better',
#    'quit',
#    'giving',
#    'looks'],
#   1],
#  [['aint',
#    'trippen',
#    'cause',
#    'like',
#    'anyways',
#    'got',
#    'niggah',
#    'got',
#    'girl',
#    'anyways',
#    'yea',
#    'anyways'],
#   1],
#  [['bitch'], 1],
#  [['full', 'white', 'trash'], 0],
#  [['bitch', 'moreno', 'valley'], 1],
#  [['wyd', 'fag'], 1],
#  [['chase', 'sin', 'falls', 'blessing'], 1],
#  [['youre', 'trash'], 2],
#  [['got', 'alla', 'hoes'], 1],
#  [['ghost', 'picks', 'dive', 'pussy'], 1],
#  [['deletin',
#    'emojis',
#    'contact',
#    'name',
#    'cos',
#    'dont',
#    'mean',
#    'shit',
#    'anymore'],
#   1],
#  [['almost', 'years', 'ago', 'gave', 'bitches', 'away', 'stolen'], 1],
#  [['hoe', 'association', 'real', 'yes'], 1],
#  [['hate',
#    'girls',
#    'say',
#    'forever',
#    'alone',
#    'like',
#    'shut',
#    'forever',
#    'hoe',
#    'not',
#    'forever',
#    'alone',
#    'shut',
#    'get',
#    'dick',
#    'breath'],
#   1],
#  [['wet', 'pussy', 'best', 'pussy'], 1],
#  [['need', 'least', 'not', 'bitch', 'date'], 1],
#  [['rather', 'girl', 'clingy', 'hoe'], 1],
#  [['also', 'math', 'theorem', 'make'], 2],
#  [['pussies'], 1],
#  [['bitch', 'stick'], 1],
#  [['eat', 'shit', 'working', 'nappy', 'bitch'], 1],
#  [['knows',
#    'wordsgt',
#    'jingo',
#    'dangle',
#    'fan',
#    'slang',
#    'ting',
#    'pang',
#    'lick',
#    'drum',
#    'swing',
#    'flick',
#    'alarm',
#    'bicgt',
#    'cant',
#    'hear',
#    'fire'],
#   1],
#  [['girls',
#    'talking',
#    'catching',
#    'feelings',
#    'bitch',
#    'need',
#    'catch',
#    'pass',
#    'throw',
#    'smh'],
#   1],
#  [['flappy', 'bird', 'shit', 'joke', 'real', 'tho'], 1],
#  [['hung', 'dudes', 'wasnt', 'fuckin'], 1],
#  [['pasta', 'fancily', 'prepared', 'trash'], 2],
#  [['every',
#    'female',
#    'think',
#    'every',
#    'nigga',
#    'come',
#    'across',
#    'love',
#    'bitch',
#    'could',
#    'leave',
#    'smoke',
#    'blunt',
#    'amp',
#    'forget'],
#   1],
#  [['coaches', 'retarded', 'would', 'put', 'point', 'guard', 'tho'], 1],
#  [['hey', 'fans', 'good', 'score'], 2],
#  [['okay', 'melo', 'bitch'], 1],
#  [['hate', 'nosey', 'bitch', 'like', 'mind', 'yah', 'business'], 1],
#  [['zack', 'still', 'questions', 'love', 'oreos', 'lol'], 2],
#  [['bitch', 'choosy', 'lover'], 1],
#  [['bitches',
#    'love',
#    'miley',
#    'cyrus',
#    'rihanna',
#    'cuz',
#    'speak',
#    'every',
#    'girls',
#    'inner',
#    'hoe'],
#   1],
#  [['birthday',
#    'wish',
#    'many',
#    'big',
#    'booty',
#    'hoes',
#    'mane',
#    'shit',
#    'ima',
#    'turn',
#    'birthday'],
#   1],
#  [['magic', 'ball', 'hoes'], 1],
#  [['yay', 'like', 'jacob', 'colored', 'layouts'], 2],
#  [['oomfs', 'teeth', 'quite', 'yellow'], 2],
#  [['point', 'jealous', 'cuz', 'dee', 'hoes', 'everybody'], 1],
#  [['cute', 'ass', 'niggah'], 0],
#  [['side', 'lets', 'make', 'official'], 1],
#  [['whatta', 'fags'], 1],
#  [['butler',
#    'unchained',
#    'review',
#    'short',
#    'whitey',
#    'sucks',
#    'potentially',
#    'positive',
#    'film',
#    'simply',
#    'agitprop'],
#   1],
#  [['aint', 'nuttin', 'cut', 'bitch'], 1],
#  [['yellow', 'card', 'issued', 'temple'], 2],
#  [['wont', 'trust', 'bitch'], 1],
#  [['got',
#    'hold',
#    'take',
#    'selfies',
#    'saw',
#    'bunch',
#    'bad',
#    'ass',
#    'birds',
#    'pet',
#    'fucking',
#    'emu',
#    'today',
#    'wtf'],
#   1],
#  [['seaside', 'smell', 'like', 'stank', 'ass', 'pussy', 'bruh'], 1],
#  [['always',
#    'eli',
#    'stupid',
#    'hick',
#    'hayseed',
#    'look',
#    'face',
#    'giants',
#    'fans',
#    'kill',
#    'yaselves',
#    'gonna'],
#   0],
#  [['dont', 'understand', 'rich', 'people', 'dress', 'like', 'trash'], 2],
#  [['swear', 'got', 'shit', 'make', 'bitches', 'insane'], 1],
#  [['houston', 'many', 'trash', 'drivers'], 2],
#  [['gwen',
#    'stefanis',
#    'new',
#    'single',
#    'trash',
#    'hilary',
#    'britney',
#    'fergie',
#    'give',
#    'raise',
#    'kids',
#    'judg'],
#   2],
#  [['not', 'type', 'guy', 'bitch', 'hot', 'still', 'sweating'], 1],
#  [['ahah', 'chill', 'bitch', 'look', 'better'], 1],
#  [['braxton',
#    'curti',
#    'hoe',
#    'ass',
#    'nigga',
#    'wen',
#    'see',
#    'ima',
#    'smack',
#    'like',
#    'lil',
#    'bitch'],
#   1],
#  [['trash',
#    'black',
#    'people',
#    'play',
#    'rampb',
#    'amp',
#    'hip',
#    'hop',
#    'partiesplay',
#    'dubstep',
#    'houseyall',
#    'coons',
#    'need',
#    'expand'],
#   1],
#  [['yall',
#    'mean',
#    'whoever',
#    'running',
#    'back',
#    'telling',
#    'tunchi',
#    'wtf',
#    'thats',
#    'not',
#    'nigga',
#    'dog',
#    'niggas',
#    'bitches'],
#   1],
#  [['sucha', 'hoe'], 1],
#  [['lol', 'replaced', 'big', 'yellow', 'chicken', 'homer'], 2],
#  [['hoes', 'live', 'jus', 'hit', 'clubs', 'every', 'weekend'], 1],
#  [['called',
#    'charlie',
#    'baker',
#    'concede',
#    'around',
#    'morning',
#    'plans',
#    'address',
#    'supporters'],
#   2],
#  [['got', 'every', 'niggah', 'lookin', 'like', 'dam'], 0],
#  [['old', 'people', 'cant', 'drunk', 'people'], 0],
#  [['ima', 'shmurda', 'dance', 'pussy', 'hoe'], 1],
#  [['stay'], 1],
#  [['multiple', 'dna', 'girl', 'man', 'ran', 'train', 'hoe'], 1],
#  [['serious',
#    'right',
#    'hypocritical',
#    'double',
#    'fuck',
#    'outta',
#    'face',
#    'trash'],
#   1],
#  [['nobody',
#    'want',
#    'nigga',
#    'take',
#    'expensive',
#    'date',
#    'dont',
#    'expect',
#    'pussy',
#    'cause',
#    'took',
#    'girl',
#    'like'],
#   1],
#  [['stupid', 'bitches', 'ltltlt', 'fuck'], 1],
#  [['ugly', 'ass', 'hoe', 'wanna', 'bad', 'bitch', 'gone'], 1],
#  [['screaming',
#    'wes',
#    'bitch',
#    'annalise',
#    'losing',
#    'damn',
#    'mind',
#    'need',
#    'put',
#    'big',
#    'girl',
#    'panties',
#    'back'],
#   1],
#  [['managers', 'stupid', 'cunt', 'yes', 'said'], 0],
#  [['wear',
#    'vineyard',
#    'vines',
#    'american',
#    'flag',
#    'chubbies',
#    'opposite',
#    'wigga'],
#   1],
#  [['killed', 'hoe'], 1],
#  [['cant', 'spell', 'slut', 'without', 'bitch'], 1],
#  [['sick', 'bitches', 'bitching', 'bitches'], 1],
#  [['types', 'niggas', 'world', 'real', 'niggas', 'amp', 'bitch', 'niggas'], 1],
#  [['dont', 'know', 'bitch', 'tuat', 'aint', 'sayin'], 1],
#  [['mcm',
#    'tomorrows',
#    'months',
#    'fuck',
#    'everyone',
#    'said',
#    'wouldnt',
#    'last',
#    'proved',
#    'bitches',
#    'wrong'],
#   1],
#  [['nice', 'pussy'], 1],
#  [['lol', 'thirst', 'real', 'dis', 'bitch'], 1],
#  [['guy',
#    'orientation',
#    'got',
#    'asked',
#    'top',
#    'favorite',
#    'music',
#    'artists',
#    'first',
#    'thing',
#    'bitch',
#    'said',
#    'usher'],
#   1],
#  [['burn', 'bitch'], 1],
#  [['lifes', 'bitch', 'amp', 'die'], 1],
#  [['straight', 'except', 'math', 'bitch', 'hows', 'lol'], 1],
#  [['drinking',
#    'veuve',
#    'cliquot',
#    'eating',
#    'marshmallows',
#    'basically',
#    'classy',
#    'bitch'],
#   1],
#  [['pussy', 'ass', 'niggas', 'aint', 'bout', 'life'], 1],
#  [['pussy', 'ass', 'hoe', 'cant', 'fuck', 'wit', 'yall'], 1],
#  [['hoes',
#    'cmon',
#    'thru',
#    'hatchys',
#    'utica',
#    'tdt',
#    'rock',
#    'dis',
#    'biiaaaatch'],
#   1],
#  [['never', 'seen', 'toddler', 'chug', 'water', 'bottle', 'fast', 'lol'], 2],
#  [['hahahahaa', 'fuckin', 'crow', 'looking', 'bitch'], 1],
#  [['faggot',
#    'truck',
#    'tailgating',
#    'hit',
#    'cut',
#    'switched',
#    'lanes',
#    'cuts',
#    'little',
#    'biatch'],
#   1],
#  [['niggas',
#    'long',
#    'ass',
#    'monkey',
#    'arms',
#    'make',
#    'best',
#    'cuddle',
#    'buddiesso',
#    'heard',
#    'ahaha',
#    'female',
#    'told'],
#   1],
#  [['guess',
#    'used',
#    'getting',
#    'bitch',
#    'cause',
#    'idk',
#    'anybody',
#    'juss',
#    'let',
#    'ppl',
#    'disrespect',
#    'sit',
#    'thts'],
#   1],
#  [['hoes'], 1],
#  [['not',
#    'going',
#    'bitch',
#    'dont',
#    'speak',
#    'reasons',
#    'decision',
#    'done',
#    'start'],
#   1],
#  [['next', 'time', 'rednecks', 'ill', 'see', 'rednecks', 'paychecks'], 1],
#  [['girl',
#    'skipping',
#    'school',
#    'aint',
#    'nothing',
#    'made',
#    'say',
#    'head',
#    'bitch',
#    'supposed',
#    'school',
#    'catch'],
#   1],
#  [['fuck', 'throwing', 'batting', 'practice', 'holy', 'shit'], 1],
#  [['zuko', 'gets', 'bitches'], 1],
#  [['make', 'paper', 'ball', 'trash'], 2],
#  [['said', 'ready', 'bitch', 'okay', 'lmfaoooooooo', 'done'], 1],
#  [['welcome', 'twitter'], 1],
#  [['put', 'ass', 'let', 'know', 'baddest', 'lit', 'bitch'], 1],
#  [['fox', 'say'], 1],
#  [['think',
#    'addicted',
#    'naked',
#    'pictures',
#    'sit',
#    'talking',
#    'bout',
#    'bitches',
#    'almost'],
#   1],
#  [['ass', 'retarted', 'belongs', 'short', 'yellow', 'bus'], 1],
#  [['messy',
#    'asss',
#    'bitches',
#    'would',
#    'blast',
#    'yall',
#    'dumb',
#    'bitches',
#    'not',
#    'even',
#    'gon',
#    'stoop',
#    'yalls',
#    'level'],
#   1],
#  [['every',
#    'spic',
#    'cop',
#    'raped',
#    'thought',
#    'raping',
#    'white',
#    'woman',
#    'thats',
#    'get',
#    'jobs',
#    'pigs'],
#   0],
#  [['top', 'notch', 'bitches'], 1],
#  [['people',
#    'beg',
#    'see',
#    'womens',
#    'bodies',
#    'minute',
#    'theyre',
#    'seen',
#    'woman',
#    'hoe',
#    'okay'],
#   1],
#  [['fuck', 'twerking', 'bitch', 'cook'], 1],
#  [['honey', 'bbq', 'oreos', 'monstrous', 'glass', 'right', 'poster', 'boy'],
#   2],
#  [['need', 'pussy', 'ate'], 1],
#  [['know', 'fat', 'hoes', 'not', 'big', 'boned', 'jus', 'fat'], 1],
#  [['guess',
#    'none',
#    'deez',
#    'rappin',
#    'ass',
#    'niggas',
#    'wanna',
#    'throw',
#    'dem',
#    'bitches',
#    'wit',
#    'big',
#    'homie'],
#   1],
#  [['might', 'get', 'riches', 'might', 'broke', 'bitches'], 1],
#  [['awwww', 'dont', 'pussy', 'ill', 'show', 'good', 'turbo', 'lol'], 1],
#  [['lol', 'matches', 'early', 'champion', 'bitches', 'really', 'would', 'ham'],
#   1],
#  ...]

# %%
documents_test
# Out:
# [['mewtwo', 'make', 'pussy'],
#  ['said',
#   'didnt',
#   'like',
#   'fuck',
#   'got',
#   'shit',
#   'made',
#   'stfu',
#   'stop',
#   'assuming',
#   'bitch',
#   'not',
#   'ugly'],
#  ['get', 'bitch', 'bruh'],
#  ['lmfao', 'bitch', 'got', 'shit', 'rocked'],
#  ['verizon',
#   'customer',
#   'service',
#   'trash',
#   'fuck',
#   'ive',
#   'store',
#   'havent',
#   'greeted',
#   'nothing'],
#  ['youve', 'gone', 'broke', 'wrong', 'heart', 'drove', 'redneck', 'crazy'],
#  ['bitch', 'ass', 'arod', 'shorty', 'dont', 'hit', 'back'],
#  ['clock',
#   'hits',
#   'oclock',
#   'imma',
#   'need',
#   'amp',
#   'brightest',
#   'hoes',
#   'door',
#   'give'],
#  ['long',
#   'beach',
#   'california',
#   'people',
#   'automatically',
#   'think',
#   'ima',
#   'bitch',
#   'hahha'],
#  ['wicked', 'witch', 'east', 'send', 'vile', 'bitch', 'syria'],
#  ['aint', 'squad', 'lil', 'bitch'],
#  ['thought', 'would', 'think', 'cuteyou', 'like', 'shut', 'clam'],
#  ['bitch',
#   'wit',
#   'baby',
#   'ask',
#   'switch',
#   'seats',
#   'family',
#   'could',
#   'together',
#   'said',
#   'bitch',
#   'family',
#   'wasnt'],
#  ['ever', 'call', 'youre', 'fucking', 'side', 'yea', 'gonna', 'later'],
#  ['one',
#   'day',
#   'niggas',
#   'gone',
#   'learn',
#   'not',
#   'fuck',
#   'ugly',
#   'bitch',
#   'pregnancies',
#   'need',
#   'stopped'],
#  ['wanna', 'state', 'record', 'dont', 'hoes'],
#  ['dont',
#   'pity',
#   'hate',
#   'sexual',
#   'mutations',
#   'necessary',
#   'side',
#   'effect',
#   'proliferation',
#   'sign',
#   'fucked'],
#  ['another',
#   'keyboard',
#   'commando',
#   'real',
#   'life',
#   'hide',
#   'like',
#   'little',
#   'bitch'],
#  ['bitch', 'bitch', 'bitch'],
#  ['dani', 'alves', 'pulled', 'hairstyle', 'neymar', 'looks', 'like', 'faggot'],
#  ['ever',
#   'kill',
#   'ant',
#   'sidewalk',
#   'think',
#   'damn',
#   'nigga',
#   'way',
#   'get',
#   'pussy'],
#  ['fuck', 'staten', 'place', 'pussies'],
#  ['allergies', 'eyes', 'red', 'chink', 'look', 'like', 'stoned'],
#  ['rubbing',
#   'booty',
#   'another',
#   'mans',
#   'penis',
#   'sure',
#   'fellas',
#   'cool',
#   'girl',
#   'dancing',
#   'nig'],
#  ['bitch', 'bitch', 'griiind', 'thug', 'luuuuuuv'],
#  ['everyone', 'calls', 'like', 'wassup', 'like', 'wassup', 'niggah'],
#  ['kick', 'dem', 'fucc', 'niccas', 'spot'],
#  ['real', 'nigga', 'bitch', 'know', 'place'],
#  ['one', 'night', 'stand', 'yall', 'yall', 'aint', 'nothing'],
#  ['never', 'snapchat', 'bishop', 'screenshotting', 'son', 'bitch'],
#  ['little',
#   'scrawny',
#   'white',
#   'boys',
#   'play',
#   'ghetto',
#   'rap',
#   'music',
#   'walk',
#   'around'],
#  ['bitches',
#   'grade',
#   'talking',
#   'miss',
#   'bae',
#   'naw',
#   'bitch',
#   'missed',
#   'graduation'],
#  ['fuck', 'girls', 'peep', 'change', 'nigga', 'squared', 'bitch', 'ass'],
#  ['niggas', 'talk', 'bitches', 'days'],
#  ['bitches', 'aint', 'real'],
#  ['latino', 'jewish', 'move', 'dont', 'ruin', 'wipe'],
#  ['never', 'full', 'retard'],
#  ['salute', 'derek', 'best', 'yankee'],
#  ['crystal',
#   'star',
#   'leggy',
#   'playful',
#   'babe',
#   'crystal',
#   'star',
#   'spreads',
#   'pussy',
#   'foryou'],
#  ['post', 'pic', 'waves', 'bringing', 'back', 'hoes'],
#  ['bitch', 'nigga', 'shit', 'invented', 'created', 'term'],
#  ['adopted', 'bitches'],
#  ['hate', 'ratchet', 'country', 'hoes', 'ashamed'],
#  ['bet', 'pussy', 'smell', 'like', 'dried', 'oysters'],
#  ['bitch'],
#  ['know', 'people', 'ghetto', 'leave', 'plastic', 'shit', 'tvs'],
#  ['tell', 'itty', 'bitty', 'bitch', 'pipe'],
#  ['yall', 'entertained', 'bitch', 'niggas', 'hitting', 'smh', 'raised'],
#  ['bitches',
#   'brag',
#   'goin',
#   'gym',
#   'still',
#   'shaped',
#   'like',
#   'patron',
#   'bottle',
#   'cuh'],
#  ['back', 'ive', 'become', 'basic', 'bitch'],
#  ['wayne', 'crazy', 'new', 'orleans', 'ass', 'nicca', 'lol'],
#  ['point', 'bitch', 'like', 'dirk', 'club', 'like', 'dirk', 'nowitzki'],
#  ['rams', 'fags'],
#  ['fail',
#   'realize',
#   'ion',
#   'want',
#   'friends',
#   'bitches',
#   'switch',
#   'quiccer',
#   'change',
#   'channel'],
#  ['duh', 'aka', 'shitty', 'nights', 'city', 'nights', 'hella'],
#  ['lol', 'girrrrl', 'bitches', 'crazzzzy'],
#  ['going', 'show', 'bitches', 'done'],
#  ['redskins', 'trash', 'fuck', 'not', 'getting'],
#  ['ball', 'bitch', 'bench', 'life'],
#  ['hey', 'guess', 'yall', 'forgot', 'bitch', 'lol'],
#  ['one', 'thing', 'love', 'russel', 'aint', 'bitch', 'runnin'],
#  ['sorry',
#   'costume',
#   'naughty',
#   'school',
#   'girl',
#   'forever',
#   'consider',
#   'basic',
#   'bitch'],
#  ['farmers', 'white', 'trash'],
#  ['top', 'ten', 'rappers', 'hoes', 'ortiz'],
#  ['ugly',
#   'goldigging',
#   'cunt',
#   'probably',
#   'uncircumcised',
#   'penis',
#   'faggot'],
#  ['haha',
#   'imma',
#   'catch',
#   'ebola',
#   'trynna',
#   'keep',
#   'warm',
#   'lol',
#   'ewww',
#   'bitch',
#   'well',
#   'stay',
#   'far',
#   'away'],
#  ['literally', 'never', 'get', 'shit', 'retarded'],
#  ['hoes', 'like', 'hoes', 'likebut', 'hoes', 'like'],
#  ['bout', 'bitchneed'],
#  ['windoowww', 'bleaching', 'smiling', 'talking', 'breath'],
#  ['coons',
#   'monkeys',
#   'like',
#   'disgust',
#   'minstrel',
#   'show',
#   'negro',
#   'crying',
#   'shit',
#   'time',
#   'youre',
#   'disgrace',
#   'everywhere'],
#  ['fuck', 'nigga', 'bitch'],
#  ['called', 'people', 'kikes', 'lot', 'fucks'],
#  ['yall', 'playful', 'dont', 'come', 'dumb', 'hoes'],
#  ['youre',
#   'going',
#   'bitch',
#   'not',
#   'come',
#   'show',
#   'bands',
#   'dropped',
#   'moshing',
#   'room'],
#  ['lol', 'youre', 'retarded'],
#  ['ugly', 'white', 'bitch'],
#  ['everyone',
#   'thinks',
#   'not',
#   'person',
#   'like',
#   'look',
#   'dont',
#   'understand',
#   'like',
#   'colored',
#   'hair',
#   'big',
#   'difference'],
#  ['sex',
#   'reward',
#   'relationship',
#   'nigga',
#   'never',
#   'done',
#   'anything',
#   'whatsoever',
#   'yet',
#   'still',
#   'give',
#   'pussysmh'],
#  [],
#  ['understand',
#   'stop',
#   'venting',
#   'bitch',
#   'give',
#   'much',
#   'insight',
#   'life',
#   'amp',
#   'people',
#   'dont',
#   'deserve'],
#  ['fuck',
#   'church',
#   'attend',
#   'fuck',
#   'fuck',
#   'nigguh',
#   'call',
#   'savior',
#   'fucking',
#   'new',
#   'world',
#   'order',
#   'baby'],
#  ['keep', 'never', 'fucked', 'squirter', 'bitch'],
#  ['uou'],
#  ['fucked', 'bitch', 'fucked', 'every', 'nigga', 'state'],
#  ['drop', 'dead', 'gorgeous', 'bitch', 'aint', 'dying', 'nigga'],
#  ['rather',
#   'sit',
#   'house',
#   'day',
#   'jack',
#   'bust',
#   'mission',
#   'literally',
#   'chill',
#   'bitch'],
#  ['thats', 'logical', 'bitches', 'love', 'using', 'face', 'toilet'],
#  ['watching',
#   'deadly',
#   'women',
#   'malicious',
#   'bitch',
#   'left',
#   'babies',
#   'sun',
#   'bake',
#   'death',
#   'wtf'],
#  ['got', 'hoes', 'one', 'hoes', 'not', 'shutup', 'amp', 'never', 'say'],
#  ['ever', 'fuck', 'bitches', 'amp', 'count', 'stacks'],
#  ['fuck',
#   'stand',
#   'dizzy',
#   'bitch',
#   'two',
#   'unique',
#   'amp',
#   'separate',
#   'phrases',
#   'overheard',
#   'relative',
#   'saying',
#   'younger'],
#  ['bitch', 'fuck', 'cut', 'get', 'snacks', 'fat', 'boys'],
#  ['good',
#   'pussy',
#   'pussy',
#   'makes',
#   'really',
#   'think',
#   'bout',
#   'making',
#   'breakfast',
#   'pussy',
#   'makes',
#   'think',
#   'father'],
#  ['partner', 'crime', 'yesss', 'bitch', 'stole', 'hah'],
#  ['hate', 'girls', 'bitch'],
#  ['thats', 'aint', 'cuffing', 'grown', 'hoes', 'aint', 'loyal'],
#  ['kill', 'ugly', 'ass', 'monkey', 'looking', 'shit'],
#  ['new',
#   'bus',
#   'stop',
#   'guy',
#   'across',
#   'street',
#   'yelling',
#   'david',
#   'lee',
#   'roth',
#   'kicks',
#   'swooping',
#   'crows',
#   'learn',
#   'karate'],
#  ['wont', 'love', 'cant', 'love', 'unless', 'pussy', 'got', 'super', 'powers'],
#  ['ready', 'get', 'fried', 'oreos'],
#  ['early', 'bird', 'gets', 'dick'],
#  ['bitches', 'look', 'wen', 'hear', 'song', 'club'],
#  ['turn', 'turn', 'wheres', 'bitches'],
#  ['sweet', 'innocent', 'schoolgirl', 'minami', 'asakas', 'pussyeaten'],
#  ['dis', 'crack', 'ass', 'cracker'],
#  ['broke', 'real', 'bitches', 'stick', 'around'],
#  ['cant',
#   'blame',
#   'bitches',
#   'attract',
#   'yall',
#   'say',
#   'ima',
#   'asshole',
#   'talk',
#   'hoes',
#   'thats',
#   'kinda'],
#  ['happy', 'bday', 'love', 'nigguh'],
#  ['dont',
#   'burn',
#   'bridges',
#   'look',
#   'like',
#   'holding',
#   'grudge',
#   'lil',
#   'bitch',
#   'shit',
#   'happens',
#   'youll',
#   'fine'],
#  ['thought', 'bros', 'hoes', 'guess', 'not'],
#  ['ampamp', 'hoes'],
#  ['whats', 'like', 'cold', 'hearted'],
#  ['getting', 'checks', 'like', 'nike', 'icy', 'bitch', 'like', 'dice', 'soho'],
#  ['actually',
#   'boys',
#   'right',
#   'dorky',
#   'ass',
#   'mom',
#   'amp',
#   'dad',
#   'watching',
#   'streit',
#   'make',
#   'bitch'],
#  ['youre', 'crows', 'power', 'lines'],
#  ['making',
#   'shittiest',
#   'pigs',
#   'blanket',
#   'theyre',
#   'gonna',
#   'good',
#   'not',
#   'tryna',
#   'impress',
#   'gordon',
#   'ramseys',
#   'bitch',
#   'ass',
#   'trying',
#   'make',
#   'poop'],
#  ['gansitos', 'atg', 'beaner', 'candy'],
#  ['feat', 'tori', 'amos', 'blue', 'skies'],
#  ['like', 'bitch', 'already', 'know', 'answer', 'bri'],
#  ['screen', 'shot', 'djks', 'wiki', 'page', 'updated', 'regarding', 'trash'],
#  ['not', 'business', 'submitting', 'bitch', 'bruh', 'bruh'],
#  ['ones',
#   'really',
#   'like',
#   'cant',
#   'get',
#   'got',
#   'one',
#   'really',
#   'like',
#   'lucky',
#   'bitch'],
#  ['hoes', 'come', 'hoes', 'revolving', 'cycle'],
#  ['next',
#   'time',
#   'gone',
#   'call',
#   'darky',
#   'niccacall',
#   'dat',
#   'coon',
#   'jungle',
#   'bunny'],
#  ['lmao',
#   'hell',
#   'yea',
#   'love',
#   'thick',
#   'bitches',
#   'amp',
#   'thick',
#   'bitches',
#   'love',
#   'fat',
#   'niggas'],
#  ['fear', 'niggah', 'trust', 'bitchhh'],
#  ['need', 'bitch', 'drop', 'lol'],
#  ['cant',
#   'bitch',
#   'future',
#   'goals',
#   'love',
#   'kids',
#   'youre',
#   'not',
#   'parent',
#   'first',
#   'cant',
#   'deal'],
#  ['got', 'tits', 'big', 'hoe', 'evens'],
#  ['faggot', 'sent', 'hella', 'nudes', 'hmmmm'],
#  ['fuzzy',
#   'wuzzy',
#   'kitten',
#   'wants',
#   'know',
#   'raven',
#   'like',
#   'writing',
#   'desk',
#   'find'],
#  ['jihadi', 'patron', 'hajjaj', 'arrested', 'kuwait', 'airport'],
#  ['nigguh', 'naturally', 'forever'],
#  ['really',
#   'dont',
#   'give',
#   'fuck',
#   'start',
#   'got',
#   'hoes',
#   'fuck',
#   'bitches',
#   'shit',
#   'deleting'],
#  ['lol', 'tell', 'hoe', 'grow', 'ahaha'],
#  ['sorry', 'fucked', 'bitch', 'really', 'dig', 'nigga'],
#  ['welcome',
#   'new',
#   'eastern',
#   'panhandle',
#   'hope',
#   'better',
#   'job',
#   'yokels',
#   'got',
#   'first',
#   'place'],
#  ['might', 'faggot', 'pull', 'outta', 'pussy', 'bust', 'bro'],
#  ['necks'],
#  ['bad', 'bitches', 'get', 'free', 'night', 'weenie', 'hut', 'jrs'],
#  ['jihadi',
#   'posted',
#   'bio',
#   'boss',
#   'awad',
#   'excellent',
#   'sociological',
#   'info',
#   'cant',
#   'thank',
#   'enough',
#   'gift'],
#  ['girl', 'eating', 'pussy', 'girl', 'nigga'],
#  ['fenkell', 'bitch'],
#  ['hey', 'dude', 'watch', 'calling', 'bitch'],
#  ['yea', 'see', 'hoe'],
#  ['warm', 'pussy'],
#  ['bitches',
#   'tell',
#   'angles',
#   'watching',
#   'bitch',
#   'take',
#   'selfies',
#   'get',
#   'right'],
#  ['day',
#   'february',
#   'waylon',
#   'jennings',
#   'left',
#   'sky',
#   'dreaming',
#   'dreams'],
#  ['gobble', 'gook'],
#  ['free',
#   'patterns',
#   'adorable',
#   'crochet',
#   'borders',
#   'flower',
#   'bumblebee',
#   'hat'],
#  ['dont',
#   'care',
#   'old',
#   'put',
#   'front',
#   'bag',
#   'takis',
#   'ill',
#   'eat',
#   'bitch'],
#  ['making', 'every', 'bitch', 'feel', 'important'],
#  ['hate',
#   'extra',
#   'ass',
#   'bitch',
#   'extra',
#   'ass',
#   'nigga',
#   'youre',
#   'much',
#   'stop',
#   'unnecessary'],
#  ['seriously', 'steal', 'halloween', 'oreos'],
#  ['hat',
#   'paint',
#   'beard',
#   'shit',
#   'eat',
#   'pussy',
#   'grow',
#   'one',
#   'dawg',
#   'quit',
#   'tryin',
#   'shortcut'],
#  ['niggas',
#   'living',
#   'like',
#   'hoes',
#   'dats',
#   'dey',
#   'dying',
#   'bout',
#   'nothing'],
#  ['opinion', 'irrelevant', 'youre', 'cunt'],
#  ['hoes', 'goin'],
#  ['gardy', 'goes', 'yardy', 'leads', 'game', 'second', 'straight'],
#  ['last',
#   'night',
#   'cunt',
#   'slapping',
#   'texted',
#   'grandpas',
#   'sorry',
#   'didnt',
#   'get',
#   'back'],
#  ['fucking', 'gay', 'faggot', 'look', 'gay', 'ass', 'pink', 'shirt', 'haha'],
#  ['fact',
#   'male',
#   'brain',
#   'cannot',
#   'always',
#   'hear',
#   'high',
#   'pitched',
#   'voice',
#   'women',
#   'bitch',
#   'dont',
#   'get',
#   'madi',
#   'really',
#   'didnt',
#   'hear'],
#  ['one',
#   'thing',
#   'hate',
#   'lightskin',
#   'confused',
#   'bitch',
#   'like',
#   'either',
#   'fwm',
#   'gon',
#   'niggas'],
#  ['told', 'months', 'ago', 'charlie', 'wasnt', 'bullshittin', 'bevo', 'next'],
#  ['aint', 'really', 'wit', 'talkin', 'bitch', 'bout', 'action'],
#  ['like', 'argue', 'sent', 'dat', 'bitch', 'law', 'school'],
#  ['apparently',
#   'not',
#   'wanting',
#   'trade',
#   'nitro',
#   'csgo',
#   'makes',
#   'collossal',
#   'faggot'],
#  ['haha', 'hit'],
#  ['chief',
#   'keef',
#   'changed',
#   'rap',
#   'game',
#   'said',
#   'bitch',
#   'cooler',
#   'cooler'],
#  ['ill', 'write', 'poem', 'hoe'],
#  ['dont', 'give', 'shits', 'ship', 'beaners', 'back'],
#  ['bad', 'little', 'bitch'],
#  ['main', 'bae', 'gonn', 'think', 'sumn', 'wit', 'pussy'],
#  ['wishing'],
#  ['lol',
#   'bitches',
#   'tryna',
#   'chill',
#   'like',
#   'kno',
#   'mother',
#   'fuxin',
#   'dory',
#   'hoe',
#   'touched',
#   'butt'],
#  ['victorias', 'real', 'five', 'nipples', 'sideways', 'vagina'],
#  ['yanks', 'military', 'history', 'united', 'states', 'world', 'war', 'via'],
#  ['whole',
#   'lot',
#   'better',
#   'youre',
#   'driving',
#   'vehicle',
#   'white',
#   'pussy',
#   'uhhh',
#   'get'],
#  ['pregnant',
#   'cupps',
#   'classic',
#   'response',
#   'liberal',
#   'dem',
#   'calls',
#   'chunky',
#   'bonus',
#   'tweets',
#   'via'],
#  ['talk', 'back', 'aint', 'getting', 'pussy'],
#  ['know',
#   'yall',
#   'bitches',
#   'tell',
#   'yall',
#   'selfs',
#   'would',
#   'hustlelinaa',
#   'cuz',
#   'yall',
#   'asses',
#   'stay',
#   'following'],
#  ['name', 'stefanie', 'stefaniefuck', 'hoe'],
#  ['teen',
#   'running',
#   'around',
#   'target',
#   'monkey',
#   'pjs',
#   'screaming',
#   'amp',
#   'fitting',
#   'room',
#   'girls',
#   'cackling',
#   'today',
#   'designed',
#   'annoy'],
#  ['retards', 'dads', 'roll', 'lawful', 'good'],
#  ['ronnie', 'radkes', 'fucking', 'fag', 'fronz', 'owns', 'ass'],
#  ['lil', 'thot', 'bitch', 'really', 'tried', 'run', 'game'],
#  ['swear',
#   'god',
#   'hoes',
#   'look',
#   'like',
#   'take',
#   'exact',
#   'picture',
#   'everytime',
#   'change',
#   'godamn'],
#  ['bad', 'bitches', 'thing', 'like'],
#  ['would',
#   'never',
#   'trip',
#   'bitch',
#   'aint',
#   'mine',
#   'niggas',
#   'clowns',
#   'man'],
#  ['yanks', 'sox', 'get', 'things', 'usually', 'smoothly'],
#  ['bitches', 'happy', 'maybe', 'one', 'female', 'friends', 'find', 'bitvj'],
#  ['tell', 'bitches', 'ill', 'always', 'mrs'],
#  ['maaaaannnn', 'hope', 'get', 'rid', 'john', 'legend', 'looking', 'charlie'],
#  ['well', 'thats', 'cracker', 'jack', 'secret', 'service', 'work', 'jfk'],
#  ['bitch',
#   'say',
#   'love',
#   'hit',
#   'wit',
#   'reverse',
#   'psychology',
#   'amp',
#   'say',
#   'work',
#   'time',
#   'cuh'],
#  ['pussy',
#   'not',
#   'think',
#   'gotta',
#   'favorite',
#   'naked',
#   'picture',
#   'everdamn'],
#  ['clingy',
#   'girlfriends',
#   'best',
#   'stop',
#   'lying',
#   'hoes',
#   'bro',
#   'shit',
#   'annoying'],
#  ['hungry', 'ionn', 'wanna', 'spend', 'money', 'foodbroke', 'hoe', 'problems'],
#  ['spy', 'couple', 'thirsty', 'hoes', 'insta'],
#  ['like',
#   'seat',
#   'low',
#   'window',
#   'slightly',
#   'riding',
#   'wit',
#   'bad',
#   'hoe',
#   'wit',
#   'girlfriend',
#   'back'],
#  ['someone', 'pushes', 'hard', 'may', 'surprised', 'capricorn'],
#  ['miss', 'yall', 'yall', 'brothers', 'mikey', 'lmfao'],
#  ['cause', 'tired', 'big', 'bitches', 'coming', 'skinny'],
#  ['niggas', 'bugging', 'think', 'bitch', 'aint', 'gunna', 'tell'],
#  ['trynna', 'find', 'bitch', 'fat', 'ass'],
#  ['hate',
#   'people',
#   'ask',
#   'shoot',
#   'dont',
#   'need',
#   'pussy',
#   'shit',
#   'bigger',
#   'unswole',
#   'niggas'],
#  ['dumb',
#   'bitches',
#   'one',
#   'thing',
#   'thatll',
#   'never',
#   'become',
#   'extinct',
#   'thats',
#   'real'],
#  ['peyton',
#   'mannings',
#   'remarkable',
#   'pass',
#   'yds',
#   'pass',
#   'completions',
#   'likely'],
#  ['many',
#   'hoes',
#   'bad',
#   'ass',
#   'little',
#   'kids',
#   'dont',
#   'medication',
#   'cut',
#   'school',
#   'every'],
#  ['big', 'booty', 'sour', 'face', 'hair', 'hoe'],
#  ['lmaoooo', 'lol', 'pal', 'bitch', 'gone', 'tell'],
#  ['yankees', 'acquire', 'lebron', 'james', 'team', 'deal', 'per', 'sources'],
#  ['percent', 'bitch', 'percent', 'scrap'],
#  ['cant', 'stand', 'fuck', 'niggas', 'ass', 'bitch'],
#  ['biggest', 'two', 'faced', 'bitch', 'ever', 'met', 'wont'],
#  ['saying', 'panties', 'ion', 'look', 'like', 'bitches', 'tho'],
#  ['choke', 'bread', 'bitch'],
#  ['yall', 'hoes', 'going', 'learn', 'spell'],
#  ['aaaaaaaaand', 'begins', 'fucking', 'niggers', 'thats', 'kentucky', 'ever'],
#  ['bust', 'dat', 'bitch', 'face', 'dont', 'want'],
#  ['internet', 'make', 'think', 'bitches', 'theyre', 'actually', 'not'],
#  ['niggas', 'aint', 'shit', 'hoes', 'tricks'],
#  ['naw', 'negro'],
#  ['truth', 'hurts', 'nigguh'],
#  ['waives', 'pussy', 'feesgtgtgtgt', 'bye', 'lawrence'],
#  ['dont',
#   'follow',
#   'astros',
#   'said',
#   'theyre',
#   'trash',
#   'said',
#   'well',
#   'look'],
#  ['nee',
#   'dat',
#   'langdurig',
#   'gepest',
#   'wordenzoals',
#   'kiem',
#   'smorenis',
#   'ook',
#   'voor',
#   'kind',
#   'hoe',
#   'moet',
#   'optreden'],
#  ['good', 'morning', 'coons'],
#  ['deions', 'bitch'],
#  ['whats',
#   'black',
#   'yellow',
#   'not',
#   'going',
#   'win',
#   'answer',
#   'tiger',
#   'woods'],
#  ['omg', 'youre', 'nigger'],
#  ['pussy', 'good', 'amp', 'forget', 'pull'],
#  ['young', 'nigga', 'turned', 'catchmeifyoucanim', 'field', 'nig'],
#  ['poor',
#   'poor',
#   'parker',
#   'nothingwithout',
#   'aaryn',
#   'bitch',
#   'would',
#   'even',
#   'know',
#   'around',
#   'looser'],
#  ['sesh',
#   'say',
#   'like',
#   'white',
#   'kid',
#   'yes',
#   'kush',
#   'betta',
#   'whore',
#   'please',
#   'kill',
#   'self',
#   'fool',
#   'bitch',
#   'ass'],
#  ['everybody',
#   'got',
#   'one',
#   'bitch',
#   'dey',
#   'insta',
#   'got',
#   'baby',
#   'amp',
#   'gets',
#   'likes',
#   'yall',
#   'fucked',
#   'lmao'],
#  ['cant', 'ugly', 'shitty', 'fucking', 'person', 'pick', 'struggle', 'bitch'],
#  ['youre',
#   'attractive',
#   'amp',
#   'think',
#   'straight',
#   'guy',
#   'wants',
#   'friendbitch',
#   'stupid'],
#  ['bad', 'bitch', 'pussy', 'aquafina', 'call', 'crystalina'],
#  ['biden',
#   'winner',
#   'last',
#   'yea',
#   'right',
#   'like',
#   'charlie',
#   'sheen',
#   'really',
#   'winner',
#   'lol'],
#  ['prove', 'youre', 'blissfully', 'group', 'political', 'chump', 'race'],
#  ['used', 'got', 'hoes', 'lookin', 'good', 'fuckin', 'low'],
#  ['one', 'mans', 'trash', 'another', 'mans', 'wife'],
#  ['cant', 'stand', 'playin', 'ass'],
#  ['hate',
#   'bitches',
#   'get',
#   'boyfriends',
#   'forget',
#   'like',
#   'wasnt',
#   'got',
#   'together'],
#  ['bitch', 'says', 'eeeeeee', 'hoe'],
#  ['someone', 'casually', 'ask', 'stood', 'car', 'fking', 'serious', 'bitch'],
#  ['got', 'pussy', 'bllod'],
#  ['got', 'bad', 'spanish', 'bitch'],
#  ['cant',
#   'wait',
#   'till',
#   'get',
#   'full',
#   'appetite',
#   'back',
#   'ate',
#   'half',
#   'ghetto',
#   'sandwich',
#   'nothing'],
#  ['yaaas', 'bitch', 'yaas', 'hot', 'bitch', 'yaaas'],
#  ['ross', 'got', 'amber', 'rose', 'naked', 'hoes', 'aint', 'loyal', 'wiz'],
#  ['dick', 'hang', 'wobble', 'tie', 'stick'],
#  ['yellow', 'otl'],
#  ['avi',
#   'prolly',
#   'shoot',
#   'dust',
#   'phone',
#   'cuz',
#   'shit',
#   'old',
#   'cat',
#   'fishing',
#   'bitches',
#   'lmao'],
#  ['call', 'ghetto', 'nunchucksthe', 'reason', 'went', 'jail', 'well'],
#  ['ever',
#   'ate',
#   'pussy',
#   'fucked',
#   'niggas',
#   'let',
#   'know',
#   'right',
#   'owe',
#   'dirty',
#   'bitch'],
#  ['lmao', 'live', 'wit', 'girl', 'dishes', 'faggot'],
#  ['youre', 'pussy'],
#  ['fucking', 'creepy', 'ass', 'nigguh', 'lmao'],
#  ['aint', 'got', 'pussy', 'bitch', 'suck', 'dick', 'diet'],
#  ['assholes', 'know', 'referring', 'girl', 'bitch', 'doesnt', 'make', 'dick'],
#  ['lil', 'bitch', 'coulda', 'let', 'right', 'house'],
#  ['boutta', 'deck', 'bitch', 'face'],
#  ['hoe', 'niggas', 'havnt', 'seen', 'half'],
#  ['always',
#   'pathetic',
#   'mutt',
#   'desperately',
#   'seeking',
#   'attention',
#   'amp',
#   'purpose',
#   'matter',
#   'writes',
#   'never',
#   'change'],
#  ['hate', 'lil', 'lol', 'hate', 'steelers', 'dawg'],
#  ['wipe', 'cum', 'faggot', 'contact', 'lens', 'wildin', 'cant', 'see', 'shit'],
#  ['bitch'],
#  ['hahahhahaa',
#   'boyfriend',
#   'trash',
#   'stop',
#   'tryna',
#   'convince',
#   'otherwise',
#   'tweets'],
#  ['yall', 'see', 'chojis', 'big', 'ass', 'black', 'bitch'],
#  ['former',
#   'towie',
#   'star',
#   'charlie',
#   'king',
#   'comes',
#   'inspiring',
#   'congrats',
#   'welcome',
#   'family'],
#  ['need',
#   'mexican',
#   'flea',
#   'market',
#   'grab',
#   'fake',
#   'gucci',
#   'sandals',
#   'stunt',
#   'hoes'],
#  ['tellin',
#   'disrespectful',
#   'aint',
#   'one',
#   'callin',
#   'everybody',
#   'bitch',
#   'free'],
#  ['need',
#   'sox',
#   'fuck',
#   'yeah',
#   'love',
#   'kinky',
#   'scally',
#   'lad',
#   'rank',
#   'sox',
#   'sneaks'],
#  ['cus',
#   'french',
#   'montanas',
#   'bitch',
#   'fucks',
#   'think',
#   'selling',
#   'drugs',
#   'cool',
#   'lamest'],
#  ['love', 'dont', 'even', 'smoke', 'bday', 'bitch', 'gone', 'turntttt'],
#  ['lmao', 'still', 'feel', 'played', 'bout', 'hoe'],
#  ['hoes',
#   'running',
#   'back',
#   'tellin',
#   'shit',
#   'hoes',
#   'trynna',
#   'fuck',
#   'niggas',
#   'tellin',
#   'shit',
#   'mayne'],
#  ['oreo', 'adorable'],
#  ['talking', 'almost', 'aint', 'pussy'],
#  ['boys', 'discover', 'hoe'],
#  ['lol', 'bitch', 'dont', 'read', 'books', 'eat', 'fruits', 'hoe'],
#  ['lifelong', 'miss'],
#  ['still', 'wont', 'get', 'bitches', 'wow', 'wtf'],
#  ['katys',
#   'grand',
#   'exit',
#   'tonight',
#   'firehouse',
#   'gtgtgtgt',
#   'hasta',
#   'bye',
#   'bye',
#   'bitches'],
#  ['cue', 'liberal', 'lefts', 'uncle', 'tom', 'attacks', 'tim', 'scott'],
#  ['wanna',
#   'lie',
#   'hes',
#   'fuccing',
#   'joke',
#   'ajay',
#   'gotta',
#   'whole',
#   'bitch',
#   'oml',
#   'trynna',
#   'argue',
#   'wit',
#   'amp',
#   'shit',
#   'like',
#   'fir',
#   'boi'],
#  ['guys', 'tweet', 'shit', 'get', 'bunch', 'favorites', 'level', 'hoes'],
#  ['ill', 'bitch', 'slap', 'shadow'],
#  ['lol',
#   'bitch',
#   'youve',
#   'put',
#   'lotion',
#   'butt',
#   'amp',
#   'orajel',
#   'mouth',
#   'youd',
#   'paint',
#   'toes'],
#  ['regular',
#   'joes',
#   'rockin',
#   'tha',
#   'boat',
#   'thats',
#   'redneck',
#   'yacht',
#   'clubbb'],
#  ['ayyy', 'fags'],
#  ['riding', 'bros', 'still', 'dont', 'trust', 'hoes'],
#  ['generate',
#   'ascii',
#   'boxes',
#   'nodejs',
#   'see',
#   'ability',
#   'bring',
#   'node',
#   'via',
#   'ascii',
#   'tubes',
#   'bird'],
#  ['girl', 'hold', 'dick', 'like', 'wii', 'controller', 'wheres', 'control'],
#  ['fat', 'bitch', 'whats'],
#  ['fucking', 'bitch', 'rachel', 'needs', 'die', 'please'],
#  ['hairy', 'like', 'monkey'],
#  ['dumb',
#   'ass',
#   'fake',
#   'bitches',
#   'childish',
#   'talk',
#   'mad',
#   'shit',
#   'back',
#   'best',
#   'lmao'],
#  ['youre', 'acting', 'like', 'bitch', 'bitch', 'theres', 'problem'],
#  ['last',
#   'tweet',
#   'song',
#   'lyrics',
#   'dont',
#   'really',
#   'like',
#   'bad',
#   'like',
#   'pretty',
#   'chicks',
#   'bad',
#   'bitches',
#   'cheat',
#   'easily',
#   'often'],
#  ['telling', 'shaved', 'pussy', 'ugly'],
#  ['cars', 'clothes'],
#  ['ion', 'pay', 'pussy', 'priceless', 'fishin', 'aint', 'pisces'],
#  ['need', 'bitch', 'dance', 'lmfao', 'ode'],
#  ['sierra', 'almost', 'got', 'caught', 'ole', 'hick'],
#  ['aint', 'never', 'pregnancy', 'scare', 'pussy', 'trash', 'ladies'],
#  ['three',
#   'arrsted',
#   'german',
#   'gay',
#   'guy',
#   'left',
#   'critical',
#   'condition',
#   'fag',
#   'bashed',
#   'belgrade'],
#  ['stupid', 'ass', 'hoe'],
#  ['hoe', 'shit'],
#  ['wussup', 'bitch'],
#  ['spurs', 'bitch', 'thats', 'dont', 'want', 'problems'],
#  ['bitch', 'crazy'],
#  ['idk', 'gotta', 'think', 'cause', 'bitches', 'small', 'shit'],
#  ['flights', 'liberia', 'rerouted', 'ferguson', 'birds', 'stone'],
#  ['better', 'called', 'kid'],
#  ['bitches', 'amp', 'mix'],
#  ['lil', 'stupid', 'ass', 'bitch', 'aint', 'fucking', 'wit', 'youuuu'],
#  ['know', 'twitter', 'password', 'bitch', 'please'],
#  ['dont',
#   'feel',
#   'like',
#   'black',
#   'people',
#   'niggers',
#   'youre',
#   'black',
#   'youre',
#   'imma',
#   'tell',
#   'idc'],
#  ['yall',
#   'gorgeous',
#   'women',
#   'aint',
#   'gorgeous',
#   'realize',
#   'got',
#   'ugly',
#   'bitch',
#   'attitude'],
#  ['nah',
#   'definitely',
#   'gotta',
#   'find',
#   'bitch',
#   'drive',
#   'around',
#   'whip',
#   'drunk',
#   'dolla',
#   'tape',
#   'right'],
#  ['long', 'story', 'lol', 'ive', 'missed', 'faggot'],
#  ['joan',
#   'rivers',
#   'said',
#   'gay',
#   'michelle',
#   'tranny',
#   'perhaps',
#   'death',
#   'accident',
#   'see',
#   'clintons',
#   'ron'],
#  ['cho', 'name', 'wanna', 'fuck', 'bitch', 'things', 'says'],
#  ['year', 'starting', 'street', 'put', 'fag'],
#  ['hes', 'right', 'bitches', 'smh'],
#  ['yeah', 'fuck', 'bitch'],
#  ['show',
#   'love',
#   'everybody',
#   'not',
#   'joe',
#   'time',
#   'hate',
#   'stuck',
#   'people',
#   'thats',
#   'hoe',
#   'shit'],
#  ['hoes', 'wake'],
#  ['hell',
#   'cause',
#   'brad',
#   'still',
#   'walked',
#   'away',
#   'like',
#   'yeah',
#   'fucked',
#   'niggas',
#   'bitch'],
#  ['every',
#   'time',
#   'ask',
#   'something',
#   'waitress',
#   'touches',
#   'knee',
#   'till',
#   'done',
#   'asking',
#   'mean',
#   'tryna',
#   'give',
#   'nigga',
#   'pussy',
#   'dont'],
#  ['wait',
#   'min',
#   'pussy',
#   'rihanna',
#   'cologne',
#   'men',
#   'probably',
#   'smell',
#   'like',
#   'curry',
#   'goat',
#   'nail',
#   'clippings'],
#  ['new', 'strategy', 'get', 'bruno', 'mars'],
#  ['hoes', 'fake', 'like', 'really', 'hating', 'lowkey'],
#  ['nigga', 'gotta', 'find', 'hoes', 'quick'],
#  ['alright', 'fag'],
#  ['trash', 'thats', 'lot', 'stolen', 'shoes'],
#  ['dont', 'iphone', 'manually', 'ignore', 'hoes'],
#  ['not',
#   'liberal',
#   'amp',
#   'support',
#   'changing',
#   'name',
#   'transcends',
#   'standard',
#   'political',
#   'grandstanding'],
#  ['damn',
#   'makin',
#   'bitches',
#   'jealous',
#   'reality',
#   'amp',
#   'prolly',
#   'mad',
#   'pic',
#   'posted',
#   'wouldnt',
#   'taken'],
#  ['mother',
#   'manchester',
#   'terror',
#   'twins',
#   'went',
#   'syria',
#   'become',
#   'jihadi',
#   'brides',
#   'snatched',
#   'isis'],
#  ['yeah',
#   'definitely',
#   'wasnt',
#   'guy',
#   'fought',
#   'lara',
#   'cuts',
#   'ring',
#   'well',
#   'huge',
#   'boon',
#   'canelo'],
#  ['driving',
#   'nice',
#   'not',
#   'pay',
#   'lot',
#   'rent',
#   'drive',
#   'pay',
#   'little',
#   'rent',
#   'saying'],
#  ['one', 'day', 'nip', 'well', 'ready', 'wet'],
#  ['bitch', 'going', 'nawl'],
#  ['old', 'ratchet', 'hoes', 'bruh'],
#  ['bet',
#   'yall',
#   'bitches',
#   'deaf',
#   'lytes',
#   'words',
#   'treated',
#   'like',
#   'queen',
#   'huh'],
#  ['lets',
#   'see',
#   'look',
#   'like',
#   'without',
#   'filters',
#   'colored',
#   'contact',
#   'followers',
#   'dying',
#   'know'],
#  ['tryna', 'turn'],
#  ['bitches', 'aint', 'shit', 'hoes', 'tricks'],
#  ['theres', 'nothing', 'hotter', 'pale', 'albino', 'chick', 'play', 'guitar'],
#  ['bust', 'dat', 'pussy', 'wide', 'open'],
#  ['ima',
#   'start',
#   'fuck',
#   'buddies',
#   'save',
#   'lives',
#   'program',
#   'lol',
#   'match',
#   'dry',
#   'bitter',
#   'ass',
#   'folks',
#   'wit',
#   'good',
#   'dick',
#   'pussy'],
#  ['fuck', 'opp', 'thot', 'well', 'shoot', 'bitch'],
#  ['got', 'bitches', 'dont', 'ever', 'readem', 'top'],
#  ['starks', 'faggot'],
#  ['niggas',
#   'get',
#   'married',
#   'start',
#   'dissin',
#   'single',
#   'bitches',
#   'smh',
#   'bitches',
#   'want',
#   'allowance',
#   'dates',
#   'still',
#   'singl'],
#  ['keep',
#   'running',
#   'trees',
#   'birds',
#   'fly',
#   'avoid',
#   'targeted',
#   'lack',
#   'digestive',
#   'system'],
#  ['need', 'scale', 'ghetto'],
#  ['doesnt', 'really', 'look', 'back', 'exs', 'things', 'look', 'better'],
#  ['nerve', 'nicca', 'step', 'crispy', 'ass', 'shoes', 'wit', 'dusty', 'ass'],
#  ['know', 'youre', 'ugly', 'ape', 'chosen', 'man', 'crush', 'youve', 'never'],
#  ['das',
#   'calld',
#   'usen',
#   'brain',
#   'retard',
#   'would',
#   'whoop',
#   'ass',
#   'front',
#   'police'],
#  ['niggas',
#   'slope',
#   'intercept',
#   'form',
#   'equations',
#   'cant',
#   'make',
#   'scrambled',
#   'fuckin',
#   'eggs',
#   'thats',
#   'lil',
#   'backwards'],
#  ['puss'],
#  ['breakfast',
#   'fried',
#   'chicken',
#   'jerk',
#   'chicken',
#   'tater',
#   'tots',
#   'white',
#   'rice',
#   'press',
#   'yellow',
#   'rice',
#   'beans',
#   'mac',
#   'cheese'],
#  ['girlfriend', 'doesnt', 'like', 'dont', 'talk', 'bitch'],
#  ['sitting',
#   'next',
#   'neighborhood',
#   'crazy',
#   'bitch',
#   'amp',
#   'keeps',
#   'randomly',
#   'busting',
#   'laughing'],
#  ['theres',
#   'apparently',
#   'wee',
#   'cunt',
#   'whos',
#   'year',
#   'younger',
#   'called',
#   'sean',
#   'brown',
#   'cheeky',
#   'lol'],
#  ['face', 'ugly', 'amp', 'nudes', 'trash'],
#  ['couldnt', 'care', 'less'],
#  ['kid', 'straight', 'watched', 'bitch', 'eat', 'bloody', 'tampon'],
#  ['playing', 'show', 'today', 'papa', 'charlies'],
#  ['pussy', 'boy', 'dont', 'want', 'war'],
#  ['hoes',
#   'everybody',
#   'clothes',
#   'got',
#   'nerve',
#   'take',
#   'picture',
#   'man',
#   'shit',
#   'crazy'],
#  ['man',
#   'pussy',
#   'coward',
#   'overpowered',
#   'easily',
#   'took',
#   'clearly',
#   'much',
#   'less'],
#  ['oreo', 'shake'],
#  ['eva', 'wanted', 'muh', 'fuckin', 'guala'],
#  ['said', 'like', 'got', 'money', 'dont', 'forget', 'not', 'aint', 'broke'],
#  ['energy', 'hoes'],
#  ['watch'],
#  ['bitch',
#   'shutcho',
#   'got',
#   'damn',
#   'mouf',
#   'hoe',
#   'mallett',
#   'aint',
#   'gon',
#   'help',
#   'funky',
#   'ass',
#   'texans'],
#  ['say', 'something', 'one', 'drake', 'song', 'listen', 'feelingsfag'],
#  ['got',
#   'pic',
#   'lines',
#   'stay',
#   'grind',
#   'tell',
#   'bitch',
#   'time',
#   'bitch',
#   'get',
#   'car',
#   'got',
#   'ridin',
#   'dayton',
#   'spokes'],
#  ['girls',
#   'women',
#   'ladies',
#   'bitches',
#   'beeeitch',
#   'dumb',
#   'ass',
#   'bitch',
#   'hahaha'],
#  ['god',
#   'actually',
#   'voted',
#   'give',
#   'people',
#   'affordable',
#   'insurance',
#   'rates',
#   'bitch'],
#  ['joke',
#   'hoes',
#   'aint',
#   'looking',
#   'first',
#   'girl',
#   'loved',
#   'bitches',
#   'thats'],
#  ['mother',
#   'asked',
#   'wanted',
#   'christmas',
#   'year',
#   'replied',
#   'not',
#   'sister',
#   'not',
#   'bitch'],
#  ['maybe',
#   'call',
#   'hootie',
#   'back',
#   'dont',
#   'answer',
#   'anymore',
#   'still',
#   'crows'],
#  ['nigga', 'really', 'tried', 'save', 'bitch', 'lol'],
#  ['bitches', 'average', 'lmao', 'baddie', 'pretty', 'girls', 'like'],
#  ['fuck', 'taylors', 'bitch', 'ass'],
#  ['stupidest', 'bitch', 'brb', 'crying', 'called', 'stupid'],
#  ['baseball',
#   'isnt',
#   'without',
#   'yankees',
#   'playoffs',
#   'amp',
#   'basketball',
#   'isnt',
#   'without',
#   'lakers'],
#  ['not', 'scanger'],
#  ['bitches', 'singing', 'song', 'tho'],
#  ['cheer', 'awful', 'new', 'york', 'yankees', 'louis', 'cardinals'],
#  ['dont', 'know', 'told', 'love', 'project', 'hoes'],
#  ['slushes', 'hoes', 'nasty', 'anyway', 'fam'],
#  ['ive', 'got', 'best', 'friends', 'functioning', 'retard', 'could'],
#  ['bitch', 'lookin', 'like', 'wana', 'fuck', 'summn'],
#  ['rico', 'full', 'shytfull', 'money', 'hoe'],
#  ['yes', 'suhh', 'fuck', 'chillin', 'gettin', 'live', 'tomorrow'],
#  ['modern', 'day', 'singers', 'talk', 'shit', 'rappers', 'talk', 'lolhoes'],
#  ['bitches', 'quick', 'nigga', 'suprised', 'taking', 'care'],
#  ['soft', 'hoes', 'dumb', 'man'],
#  ['problems', 'bitch', 'aint', 'one'],
#  ['nigger', 'fighter', 'huh'],
#  ['boys', 'need', 'damn'],
#  ['pussy', 'pussy', 'pussy', 'marijauna', 'wannnnaaa'],
#  ['single',
#   'cuz',
#   'hoes',
#   'left',
#   'good',
#   'ones',
#   'taken',
#   'female',
#   'thats',
#   'singleyou'],
#  ['yall', 'crazy', 'hoes', 'need', 'jesus', 'lol'],
#  ['number', 'hoe'],
#  ['yeah', 'texans', 'much', 'better', 'fucking', 'retard'],
#  ['bitch', 'ass'],
#  ['thats', 'ghetto'],
#  ['pull', 'bitch'],
#  ['dat', 'bitch', 'thot'],
#  ['lmaooo', 'call', 'phone', 'want', 'birds'],
#  ['loyal', 'pussy'],
#  ['said', 'cute', 'byeeee', 'mad', 'come', 'visit'],
#  ['thats', 'thought', 'pussy'],
#  ['yall', 'bitches', 'wanna', 'different', 'yall', 'really', 'basic'],
#  ['birds', 'bees'],
#  ['niggah', 'follow', 'back'],
#  ['nerve', 'bitches', 'champaign'],
#  ['fav', 'pic', 'means', 'hoe'],
#  ['color',
#   'entire',
#   'arm',
#   'black',
#   'sharpie',
#   'fist',
#   'wifes',
#   'asshole',
#   'knows',
#   'nigger',
#   'dick',
#   'feels',
#   'like'],
#  ['remember',
#   'trash',
#   'floor',
#   'upgraded',
#   'amp',
#   'put',
#   'wales',
#   'gifted',
#   'feels',
#   'like',
#   'old',
#   'car',
#   'htt'],
#  ['give', 'hoe', 'oscar', 'stay', 'acting'],
#  ['whiggers',
#   'tea',
#   'party',
#   'nation',
#   'banned',
#   'didnt',
#   'even',
#   'use',
#   'bad',
#   'maybe',
#   'racist',
#   'founding',
#   'father',
#   'quotes'],
#  ['ill',
#   'never',
#   'understand',
#   'people',
#   'fake',
#   'entire',
#   'cant',
#   'even',
#   'fake',
#   'hello',
#   'bitch',
#   'fucking'],
#  ['dont', 'fucc', 'wit', 'coward', 'cuz', 'bitch', 'left'],
#  ['alec', 'baldwin', 'mocks', 'forgiven', 'via'],
#  ['fasho', 'youve', 'officially', 'hired', 'bitch'],
#  ['relationships',
#   'come',
#   'hatin',
#   'ass',
#   'arguments',
#   'real',
#   'couples',
#   'laugh',
#   'shit'],
#  ['kyrie', 'fast', 'bitch', 'ball', 'look', 'like', 'lollol', 'wish'],
#  ['youre', 'trash', 'like', 'sorry'],
#  ['bitch', 'model', 'yall', 'bitches', 'cant', 'tell', 'nothin'],
#  ['got', 'hoes', 'damn'],
#  ['downloads', 'flappy', 'welp', 'goes', 'school'],
#  ['way', 'gym', 'already', 'thx', 'bitch'],
#  ['puff',
#   'pass',
#   'porn',
#   'run',
#   'bitch',
#   'assless',
#   'chaps',
#   'swearing',
#   'catholic'],
#  ['albino', 'hes', 'asian'],
#  ['youre',
#   'bitch',
#   'moms',
#   'bitch',
#   'dads',
#   'bitch',
#   'fucking',
#   'bitch',
#   'whos'],
#  ['fuck', 'bitches', 'get', 'money'],
#  ['takes', 'bath', 'hes', 'terrified', 'water', 'wash', 'lol'],
#  ['rule', 'number', 'one', 'never', 'pursue', 'bitch', 'ova', 'side'],
#  ['theres',
#   'lane',
#   'bitches',
#   'need',
#   'stay',
#   'left',
#   'get',
#   'right',
#   'fuck',
#   'outta',
#   'face'],
#  ['pick', 'take', 'nip'],
#  ['comcast', 'stop', 'twat', 'actually', 'work', 'thanks'],
#  ['really', 'exploding', 'giant', 'yellow', 'ducks', 'youll', 'appreciate'],
#  ['curious',
#   'curious',
#   'little',
#   'monkey',
#   'deranged',
#   'serial',
#   'cat',
#   'story',
#   'man',
#   'yellow',
#   'hat',
#   'doesnt',
#   'want'],
#  ['racist',
#   'ntx',
#   'trash',
#   'hate',
#   'see',
#   'particular',
#   'man',
#   'not',
#   'butler'],
#  ['quit',
#   'suckin',
#   'dick',
#   'hop',
#   'fat',
#   'ass',
#   'elsewhere',
#   'cuz',
#   'aint',
#   'tryna',
#   'fuck',
#   'globe',
#   'ass',
#   'bitch',
#   'got',
#   'orbit'],
#  ['fuck',
#   'yeah',
#   'hot',
#   'big',
#   'blk',
#   'boots',
#   'scally',
#   'lad',
#   'would',
#   'get'],
#  ['makes', 'hoes', 'seem', 'attractive'],
#  ['know',
#   'samklef',
#   'said',
#   'wasnt',
#   'lie',
#   'man',
#   'guy',
#   'think',
#   'beast',
#   'naija',
#   'pop',
#   'music',
#   'trash',
#   'not',
#   'wizkid'],
#  ['killed', 'whatever', 'ahead', 'pocketsgt'],
#  ['centuries'],
#  ['youre',
#   'not',
#   'fucking',
#   'relevant',
#   'get',
#   'followers',
#   'follow',
#   'trains',
#   'unfollow',
#   'people',
#   'youre',
#   'faggot'],
#  ['bitch', 'ass', 'like', 'allergic', 'reaction', 'service', 'faction'],
#  ['claim', 'boss', 'lil', 'broke', 'bitch'],
#  ['wonder',
#   'wrote',
#   'blog',
#   'either',
#   'hoe',
#   'dat',
#   'let',
#   'niggas',
#   'beat',
#   'bitch',
#   'nigga',
#   'hoe',
#   'let',
#   'beat'],
#  ['dont', 'talk', 'hoe', 'way'],
#  ['head', 'sole', 'feet'],
#  ['fuck', 'tweaking', 'hoe'],
#  ['know', 'birds', 'dont', 'wear', 'cause', 'peckers', 'way'],
#  ['dont',
#   'mention',
#   'bitch',
#   'past',
#   'first',
#   'dont',
#   'give',
#   'fuck',
#   'second',
#   'dont',
#   'care'],
#  ['like', 'honestly', 'embarrassed', 'around', 'someone', 'youre', 'trash'],
#  ['text'],
#  ['never',
#   'cuffin',
#   'unless',
#   'bitch',
#   'grown',
#   'act',
#   'grown',
#   'cant',
#   'deal',
#   'wit',
#   'lil',
#   'girls',
#   'nbs'],
#  ['two', 'main', 'wiggas'],
#  ['hoes', 'like', 'online'],
#  ['dont', 'broke', 'hoe', 'hating', 'paid'],
#  ['whops', 'yardie', 'smoke', 'blunt', 'tell', 'nigga', 'come', 'stressed'],
#  ['lmfao', 'niggas', 'going', 'ham', 'trash', 'class'],
#  ['tired',
#   'bitches',
#   'thinking',
#   'cool',
#   'ugly',
#   'youre',
#   'ugly',
#   'bitch',
#   'thats',
#   'ugly'],
#  ['republican', 'teabaggers', 'jailed', 'treason'],
#  ['hate',
#   'seeing',
#   'people',
#   'money',
#   'spend',
#   'stupid',
#   'dont',
#   'need',
#   'tvs',
#   'amp',
#   'shark',
#   'tank',
#   'twat'],
#  ['scrum', 'finna', 'smash', 'bitches'],
#  ['asian'],
#  ['amos', 'two', 'walk', 'unless'],
#  ['man', 'wimp', 'gotta', 'drunk', 'know', 'damn', 'well', 'dont'],
#  ['mommy', 'said', 'pussy', 'cats', 'inside', 'dawgs', 'house'],
#  ['really',
#   'deleted',
#   'flappy',
#   'bird',
#   'app',
#   'store',
#   'cus',
#   'someone',
#   'killed',
#   'foreal',
#   'foreal'],
#  ['whats', 'good', 'bitch'],
#  ['kanye', 'west', 'faggot'],
#  ['got',
#   'gym',
#   'saw',
#   'old',
#   'black',
#   'hoe',
#   'coldest',
#   'body',
#   'hoe',
#   'jerry',
#   'curl',
#   'like'],
#  ['shut', 'bitch', 'swallow'],
#  ['congratulations', 'leadoff', 'base', 'hit', 'hit'],
#  ['chris',
#   'brown',
#   'bitch',
#   'everyone',
#   'talks',
#   'relationship',
#   'come',
#   'two',
#   'charlemagne',
#   'saying',
#   'sam'],
#  ['give', 'tankees', 'mean', 'yankees', 'maybe', 'next'],
#  ['always',
#   'thought',
#   'golden',
#   'oreos',
#   'original',
#   'oreos',
#   'god',
#   'climaxed'],
#  ['brie',
#   'said',
#   'together',
#   'since',
#   'born',
#   'guys',
#   'twins',
#   'duh',
#   'bitch',
#   'omg',
#   'wrote'],
#  ['fake', 'ass', 'bitches', 'bruh', 'lol'],
#  ['see',
#   'didnt',
#   'election',
#   'bird',
#   'america',
#   'okay',
#   'guess',
#   'take',
#   'free',
#   'cookie',
#   'everyo'],
#  ['bette', 'fucking', 'davis', 'eyes', 'bitch'],
#  ['get', 'ass', 'back', 'detroit', 'fuckin'],
#  ['peckerwood'],
#  ['said',
#   'want',
#   'man',
#   'pick',
#   'sex',
#   'bitch',
#   'lucky',
#   'picked',
#   'gas',
#   'prices',
#   'high',
#   'hell'],
#  ['drink', 'beurs', 'kid', 'plus', 'faggot', 'anyways'],
#  ['not',
#   'brightest',
#   'guess',
#   'game',
#   'lil',
#   'know',
#   'much',
#   'attention',
#   'whores',
#   'bitches'],
#  ['duncanville', 'girls', 'cold', 'den', 'hoe'],
#  ['taking', 'pics', 'school', 'bathroom', 'fucking', 'stupid'],
#  ['call',
#   'player',
#   'pussy',
#   'hes',
#   'sidelined',
#   'low',
#   'class',
#   'trash',
#   'might'],
#  ['shut', 'bitch'],
#  ['got', 'channing', 'tatum'],
#  ['might',
#   'rain',
#   'hmmm',
#   'dont',
#   'want',
#   'look',
#   'like',
#   'pussy',
#   'carrying',
#   'umbrella',
#   'around',
#   'also',
#   'dont',
#   'want',
#   'risk',
#   'perm',
#   'getting',
#   'wet'],
#  ['playstation', 'trash', 'xbox', 'better', 'titties', 'trash'],
#  ['basically', 'like', 'background', 'fag'],
#  ['geeked', 'mine', 'think', 'bitch', 'done', 'stole'],
#  ['sippin', 'hot', 'tea', 'bitch'],
#  ['youre', 'right', 'momma', 'aint', 'raise', 'faggot'],
#  ['youre', 'public', 'side', 'hoe'],
#  ['play', 'cheat', 'wear', 'khaki', 'coloured', 'cargos', 'haircut'],
#  ['learned', 'many', 'retards', 'find', 'search', 'trending', 'topics'],
#  ['amp',
#   'bitches',
#   'bound',
#   'get',
#   'cause',
#   'lotta',
#   'niggas',
#   'playinhell',
#   'yeah'],
#  ['music', 'trash'],
#  ['ight', 'nigga', 'tonight', 'burg', 'mall', 'bitch'],
#  ['bitches',
#   'baby',
#   'amp',
#   'like',
#   'dont',
#   'claim',
#   'child',
#   'bitch',
#   'good',
#   'amp',
#   'goddamn',
#   'well',
#   'aint',
#   'nobody',
#   'claiming',
#   'creature'],
#  ['bitches', 'know', 'feeling', 'keep', 'sentences', 'short'],
#  ['remember',
#   'laying',
#   'hospital',
#   'bed',
#   'shot',
#   'ranting',
#   'coconut',
#   'shrimp',
#   'trash'],
#  ['lowkey', 'got', 'fan', 'hoop', 'skills', 'lbcc', 'aha', 'niggah', 'lol'],
#  ['stfu', 'dont', 'get', 'pussy', 'fuck', 'boy'],
#  ['heard',
#   'letting',
#   'people',
#   'know',
#   'relationship',
#   'problems',
#   'amp',
#   'arguing',
#   'thats',
#   'hoes',
#   'stop'],
#  ['one',
#   'big',
#   'lecture',
#   'hall',
#   'full',
#   'bitches',
#   'sequins',
#   'limited',
#   'tank',
#   'tops'],
#  ['thanks', 'bruh', 'dont', 'ever', 'forget', 'still', 'look', 'faggots'],
#  ['hows', 'bitch', 'wearing', 'high', 'heals', 'right'],
#  ['weird', 'frosted', 'colored', 'lipgloss', 'weird'],
#  ['moment',
#   'truly',
#   'believe',
#   'fucking',
#   'pice',
#   'trash',
#   'lovely',
#   'felling'],
#  ['wrote',
#   'dawg',
#   'ass',
#   'amp',
#   'working',
#   'bibliography',
#   'amp',
#   'laptop',
#   'froze',
#   'kill',
#   'bitch',
#   'gets',
#   'cause',
#   'hadnt',
#   'saved'],
#  ['somebody', 'says', 'childish', 'gambino', 'trash'],
#  ['bitches'],
#  ['clue', 'bad', 'hoes', 'aint', 'really', 'bad'],
#  ['nah',
#   'hate',
#   'white',
#   'people',
#   'since',
#   'looks',
#   'like',
#   'dyke',
#   'think',
#   'ended',
#   'racism'],
#  ['youre', 'stressing', 'someone', 'realize', 'got', 'hoes'],
#  ['sza', 'freckles', 'pussy'],
#  ['hoes', 'like', 'omg', 'love', 'new', 'comb', 'thought', 'perro'],
#  ['dear',
#   'ugly',
#   'stop',
#   'playing',
#   'hard',
#   'youre',
#   'already',
#   'hard',
#   'want'],
#  ['ima', 'keep', 'fuckn', 'like', 'love', 'bitch'],
#  ['isis', 'jihadis', 'australia', 'shoot', 'man', 'chanting', 'isis', 'stay'],
#  ['text', 'bitch'],
#  ['going',
#   'talk',
#   'shit',
#   'another',
#   'state',
#   'thats',
#   'dat',
#   'pussy',
#   'shit'],
#  ['vice',
#   'news',
#   'interview',
#   'canadian',
#   'jihadi',
#   'poem',
#   'translated',
#   'sound',
#   'track'],
#  ['charlie',
#   'sheen',
#   'engaged',
#   'porn',
#   'star',
#   'cant',
#   'one',
#   'thinking',
#   'lot',
#   'better'],
#  ['hoe', 'gone', 'hoe', 'dats', 'nigga', 'broke', 'hoes', 'act'],
#  ['ayyyyyyeeeeee', 'nigga', 'back', 'bitch'],
#  ['way', 'fuck', 'bitch', 'name', 'lord', 'race'],
#  ['full', 'white', 'trash'],
#  ['got',
#   'niggahs',
#   'salty',
#   'meeeee',
#   'cause',
#   'dream',
#   'bitch',
#   'main',
#   'slide'],
#  ['big', 'boring', 'kubrats', 'comin'],
#  ['girls', 'okay', 'aint', 'mad', 'unless', 'stabbed', 'love', 'hoe'],
#  ['pimps', 'hoes'],
#  ['better', 'pray', 'dont', 'send', 'nudes', 'bitch'],
#  ['hoes',
#   'beefing',
#   'bout',
#   'important',
#   'hoes',
#   'queefing',
#   'yall',
#   'blowing',
#   'vaginal',
#   'wind',
#   'back',
#   'amp',
#   'forth',
#   'stfu',
#   'amp',
#   'get'],
#  ['nigga', 'byeeeee', 'lmfao', 'ill', 'dammed', 'fag', 'stole', 'girl'],
#  ['space', 'brownies'],
#  ['unblock', 'tell', 'garbage', 'bitch', 'ass', 'playing'],
#  ['gullible', 'ones', 'people', 'college', 'intentions'],
#  ['dont', 'sensitive', 'bitch', 'insult', 'expect', 'insulted', 'back'],
#  ['altyd',
#   'geweest',
#   'hoe',
#   'vaak',
#   'men',
#   'ook',
#   'nooit',
#   'vertonen',
#   'dierngedrag'],
#  ['try', 'take', 'othot', 'drugs', 'bitch'],
#  ['fuckin',
#   'wit',
#   'nigga',
#   'getting',
#   'emotional',
#   'remind',
#   'bitch',
#   'blake'],
#  ['basic', 'bitches', 'basic', 'cable'],
#  ['omg', 'show', 'made', 'cry', 'pussy', 'manyou', 'really'],
#  ['still',
#   'nigga',
#   'dont',
#   'trip',
#   'hatin',
#   'cause',
#   'got',
#   'bitches',
#   'nigga',
#   'stole',
#   'princess',
#   'punch'],
#  ['pussy', 'hole', 'must', 'small', 'adjustment', 'gentle', 'intercourse'],
#  ['foh', 'lmao', 'hella', 'skinny', 'bitches', 'dont', 'like'],
#  ['paid', 'bitches', 'always', 'money'],
#  ['thanks', 'kass', 'respect', 'not', 'youre', 'bitch'],
#  ['fuck',
#   'remember',
#   'eat',
#   'drink',
#   'remember',
#   'drink',
#   'water',
#   'youre',
#   'drinking',
#   'also',
#   'eat',
#   'shit',
#   'pussy',
#   'head'],
#  ['shit', 'gettin', 'money', 'fuckin', 'hoes', 'dat', 'lmaooooo'],
#  ['cock', 'slappin', 'bitches', 'since'],
#  ['fuck',
#   'bitches',
#   'get',
#   'money',
#   'favorite',
#   'niggas',
#   'line',
#   'girl',
#   'leave',
#   'ass',
#   'another',
#   'man'],
#  ['mitt',
#   'romney',
#   'gone',
#   'take',
#   'away',
#   'weave',
#   'become',
#   'hoes',
#   'gone',
#   'walkin',
#   'around',
#   'looking',
#   'like',
#   'lil',
#   'bill',
#   'amp',
#   'calliou'],
#  ['wanna', 'cut', 'hair', 'busy', 'bitch'],
#  ['rachet', 'ass', 'bitch'],
#  ['nigga', 'aux', 'cord', 'playin', 'trash', 'shit'],
#  ['stop', 'bitch'],
#  ['bitch', 'ill', 'fuck'],
#  ['thing', 'much', 'pussy'],
#  ['got', 'legacy', 'fuck', 'yall', 'legacy'],
#  ['reasons',
#   'periods',
#   'pants',
#   'perfect',
#   'hair',
#   'get',
#   'lure',
#   'men',
#   'death',
#   'free',
#   'clam'],
#  ['lmao', 'yesterday', 'hoes', 'cute', 'lol'],
#  ['joseline', 'audience', 'mad', 'bitch'],
#  ['youre', 'main', 'bitch'],
#  ['tell',
#   'hoes',
#   'come',
#   'cause',
#   'look',
#   'like',
#   'forgot',
#   'bout',
#   'fact',
#   'aint',
#   'seen',
#   'say',
#   'alot',
#   'bout'],
#  ['hoes',
#   'turn',
#   'contortionist',
#   'see',
#   'ass',
#   'amp',
#   'smile',
#   'picture',
#   'hard',
#   'work',
#   'thir'],
#  ['sick',
#   'dudes',
#   'posting',
#   'videos',
#   'singing',
#   'vine',
#   'shit',
#   'shower',
#   'something',
#   'fags'],
#  ['youre', 'gay', 'bitch'],
#  ['nicca', 'swear', 'see', 'madden', 'lol'],
#  ['damn', 'use', 'big', 'fan', 'far', 'shes', 'big', 'cunt'],
#  ['gucci',
#   'rude',
#   'lol',
#   'thats',
#   'not',
#   'nice',
#   'bitch',
#   'aint',
#   'worth',
#   'quarter'],
#  ['sure', 'tweet', 'protect', 'karmic', 'bitch'],
#  ['people',
#   'like',
#   'give',
#   'bad',
#   'disgusting',
#   'piece',
#   'shit',
#   'person',
#   'nigger'],
#  ['single', 'isnt', 'excuse', 'hoe'],
#  ['like',
#   'bad',
#   'bitches',
#   'cause',
#   'like',
#   'bad',
#   'bitches',
#   'hay',
#   'stunna'],
#  ['wish', 'twitter', 'stalk', 'bitch', 'button'],
#  ['yea', 'hot', 'skillet', 'bitch'],
#  ['come', 'break', 'dem', 'hoes'],
#  ['lees',
#   'hoe',
#   'een',
#   'gepeste',
#   'jongen',
#   'zich',
#   'probeert',
#   'verdedigen',
#   'ingezonden',
#   'brief',
#   'volkskrant'],
#  ['know',
#   'dont',
#   'move',
#   'next',
#   'year',
#   'mom',
#   'gonna',
#   'bitch',
#   'whole',
#   'time',
#   'live'],
#  ['want', 'monkey', 'bread'],
#  ['bro', 'fuck', 'lol', 'great', 'time', 'dont', 'forgot', 'bros', 'back'],
#  ['youre', 'fake', 'bitch', 'cannot', 'stand', 'read', 'wonder', 'probably'],
#  ['mine', 'niggah'],
#  ['turnt', 'bitch', 'house', 'party'],
#  ['pet', 'guinea', 'pig', 'die', 'fucking', 'blows'],
#  ['fuck', 'mean', 'macklemore', 'trash'],
#  ['titties', 'pussy'],
#  ['hoes', 'carrying', 'yaw', 'niggas', 'better', 'rap', 'dat', 'haha'],
#  ['told', 'hoe', 'suck', 'got', 'lips', 'like', 'rubber', 'ducks'],
#  ['sit', 'face', 'sit', 'hot', 'stove', 'bitch'],
#  ['lifes', 'bitch', 'thats', 'get', 'high'],
#  ['see',
#   'timeline',
#   'ebola',
#   'ebola',
#   'ebola',
#   'hate',
#   'school',
#   'ebola',
#   'ebola',
#   'twitter',
#   'hoes',
#   'selfie',
#   'ebola',
#   'ebola',
#   'pull'],
#  ['old', 'bitches', 'love', 'garden'],
#  ['going', 'strip', 'club', 'every', 'never', 'experience', 'earned', 'pussy'],
#  ['joba', 'chamberlain', 'looks', 'like', 'homeless', 'guy', 'contest'],
#  ['well', 'genos', 'ultimate', 'faggot', 'got', 'show', 'queer', 'eat'],
#  ['not', 'want', 'nobody', 'else', 'girl', 'niggah'],
#  ['fucking', 'trash', 'drake', 'jewish', 'young', 'money', 'reich'],
#  ['faggots',
#   'keep',
#   'posting',
#   'gay',
#   'ass',
#   'videos',
#   'cuddling',
#   'gfs',
#   'facebook'],
#  ['crying',
#   'guy',
#   'nah',
#   'bitch',
#   'pick',
#   'head',
#   'making',
#   'turkey',
#   'soggy',
#   'thanks',
#   'ashanni',
#   'turkey'],
#  ['squirrels', 'faggots'],
#  ['bitches', 'swear', 'pussy', 'aint'],
#  ['aint', 'fuckin', 'wit', 'nomore', 'hoes', 'got', 'want'],
#  ['fuck', 'cowboys', 'birthday', 'two', 'days'],
#  ['salsa', 'negro', 'awesome'],
#  ['little',
#   'girls',
#   'simons',
#   'telling',
#   'like',
#   'huf',
#   'bitch',
#   'home',
#   'amp',
#   'homework'],
#  ['bitch', 'fuk', 'wat', 'hater', 'gotta', 'say', 'brickk', 'ent', 'bitch'],
#  ['meanif', 'blow', 'foul', 'yellow', 'situation'],
#  ['stop',
#   'giving',
#   'nigga',
#   'pussy',
#   'stop',
#   'actin',
#   'like',
#   'care',
#   'true',
#   'totally'],
#  ['tokyo',
#   'get',
#   'higher',
#   'jet',
#   'killing',
#   'dog',
#   'ass',
#   'hoes',
#   'send',
#   'produced'],
#  ['kike', 'soft', 'nigga'],
#  ['wonder', 'twerking', 'hoes', 'became', 'world', 'star', 'famous', 'lives'],
#  ['females', 'thirsty', 'attention', 'males', 'pussy'],
#  ['seton',
#   'catholic',
#   'students',
#   'talk',
#   'trash',
#   'low',
#   'division',
#   'football',
#   'team'],
#  ['obersturmfuhrer',
#   'wife',
#   'superb',
#   'financial',
#   'brian',
#   'carry',
#   'labelling',
#   'see'],
#  ['rams', 'finna', 'smack', 'steven', 'wackson', 'bitch', 'ass'],
#  ['better',
#   'play',
#   'part',
#   'bitch',
#   'dont',
#   'smart',
#   'bitch',
#   'cuz',
#   'might',
#   'change',
#   'heart'],
#  ['life',
#   'sucks',
#   'everyone',
#   'equal',
#   'opportunity',
#   'lose',
#   'shirt',
#   'divorce',
#   'court'],
#  [],
#  ['pink', 'hat', 'either', 'way', 'emotional', 'bitch'],
#  ['never', 'take', 'bitch', 'stay', 'never', 'keep', 'work', 'lay'],
#  ['shes', 'dyke', 'amp', 'looks', 'like', 'shes'],
#  ['pisses', 'much', 'brett', 'screams', 'fag', 'whore', 'window', 'people'],
#  ['aye', 'hoe'],
#  ['never',
#   'knew',
#   'possible',
#   'look',
#   'like',
#   'buy',
#   'pussy',
#   'still',
#   'look',
#   'cool',
#   'tha'],
#  ['hoe'],
#  ['lmaooo', 'djs', 'stranger', 'coon'],
#  ['finding',
#   'female',
#   'hoe',
#   'record',
#   'like',
#   'tryna',
#   'find',
#   'nigga',
#   'felony'],
#  ['arguin', 'bout', 'bitch', 'god', 'damn', 'slutttt'],
#  ['sheehey', 'back', 'door', 'cuts', 'still'],
#  ['waka', 'suck', 'dragon', 'balls', 'bitch', 'call'],
#  ['half', 'yall', 'bitches', 'side', 'hoes', 'dont', 'even', 'know'],
#  ['pussy', 'farts', 'embarrassing'],
#  ['hate',
#   'people',
#   'talk',
#   'ignorant',
#   'ass',
#   'mother',
#   'fuckers',
#   'ghetto',
#   'people'],
#  ['chief', 'keef', 'trashim', 'glad', 'someone', 'said'],
#  ['lady',
#   'talking',
#   'sit',
#   'seat',
#   'hours',
#   'piss',
#   'like',
#   'bruh',
#   'already',
#   'tried',
#   'cant',
#   'fucking',
#   'pee'],
#  ['thats',
#   'man',
#   'want',
#   'hoe',
#   'guy',
#   'holding',
#   'omgod',
#   'kobeshia',
#   'shut'],
#  ['not', 'going', 'chase', 'dumb', 'bitch'],
#  ['know', 'pussy', 'ass', 'coward', 'weaker', 'smaller', 'like'],
#  ['lit', 'bitch', 'jayonna', 'class', 'aide', 'sooo', 'funny'],
#  ['not',
#   'every',
#   'girl',
#   'likes',
#   'sweet',
#   'ass',
#   'emoji',
#   'ass',
# ...
#   'set',
#   'cunt',
#   'fire',
#   'send',
#   'straight',
#   'hell'],
#  ['momma',
#   'told',
#   'tell',
#   'mind',
#   'yoooo',
#   'damn',
#   'motha',
#   'fuckin',
#   'business',
#   'not',
#   'knowin'],
#  ['give',
#   'hipster',
#   'bitch',
#   'yellow',
#   'stick',
#   'suckin',
#   'dick',
#   'hood',
#   'shit'],
#  ['mom',
#   'seen',
#   'progress',
#   'report',
#   'amp',
#   'like',
#   'wtf',
#   'wit',
#   'bitch',
#   'wtf',
#   'not',
#   'see',
#   'ungreatful'],
#  ['lmaooo', 'nigga', 'said', 'hol', 'dyke', 'background'],
#  ['fuck',
#   'bitches',
#   'stop',
#   'women',
#   'bashing',
#   'women',
#   'dont',
#   'exist',
#   'generation'],
#  ['soo', 'putting', 'crackers'],
#  ['exit'],
#  ['cant', 'trust', 'niggas', 'come', 'bitches'],
#  ['crazy', 'hoe', 'ken', 'folks', 'talking', 'friends', 'family'],
#  ['cute', 'teen', 'gets', 'pussy', 'flooded', 'withcum'],
#  ['wouldnt', 'want', 'girl', 'showing', 'goodies', 'every', 'niggah'],
#  ['nicca', 'need', 'maid'],
#  ['bitch', 'get', 'nerves'],
#  ['talmbout',
#   'graduate',
#   'next',
#   'month',
#   'safe',
#   'food',
#   'handling',
#   'bitchif',
#   'dont',
#   'flee'],
#  ['last', 'planet', 'apes', 'kids', 'minute'],
#  ['international',
#   'law',
#   'enforcement',
#   'operation',
#   'disrupts',
#   'shylock',
#   'banking',
#   'malware',
#   'international',
#   'law',
#   'enforcem'],
#  ['hoes'],
#  ['ride', 'bitch', 'handle', 'bars'],
#  ['remember',
#   'fat',
#   'bitch',
#   'stealing',
#   'kfc',
#   'bucket',
#   'amp',
#   'hauling',
#   'ass'],
#  ['would', 'relationship', 'theses', 'hoes', 'still'],
#  ['fed', 'real', 'hoe', 'boys'],
#  ['trash', 'wheel', 'googly'],
#  ['suge', 'knight', 'deserved', 'get', 'shot', 'nigga', 'karma'],
#  ['fitted', 'girbuad', 'bitches', 'would', 'raw', 'hell'],
#  ['tha', 'hoe'],
#  ['love'],
#  ['boys', 'still', 'got', 'birds', 'lol'],
#  ['feel', 'like', 'entertaining', 'hoes', 'fall', 'back', 'even', 'harder'],
#  ['pretty', 'boy', 'face', 'awee', 'thanks', 'faggot'],
#  ['cant', 'stand', 'bitch', 'ass', 'niggas'],
#  ['bitch', 'get', 'punched', 'lol'],
#  ['cant', 'put', 'pussy', 'pedestal'],
#  ['dat', 'bitch', 'ass', 'nigga', 'alabama', 'wanna', 'kill'],
#  ['beautiful', 'smiles', 'colored', 'eyes'],
#  ['craving', 'brownies'],
#  ['bitch',
#   'starts',
#   'fukin',
#   'yappin',
#   'ill',
#   'make',
#   'sure',
#   'break',
#   'something',
#   'vital',
#   'call',
#   'polis',
#   'hazard',
#   'results',
#   'permanent',
#   'damage'],
#  ['somebody',
#   'couldve',
#   'like',
#   'aye',
#   'man',
#   'dropped',
#   'money',
#   'nooooooo',
#   'fucking',
#   'broke',
#   'faggots',
#   'selfish',
#   'bastards',
#   'hate',
#   'yall'],
#  ['fuck',
#   'stupid',
#   'ass',
#   'coward',
#   'ass',
#   'punk',
#   'bitch',
#   'faggot',
#   'ass',
#   'racist',
#   'piece',
#   'shit',
#   'punk',
#   'aint',
#   'worth'],
#  ['gotta',
#   'bitch',
#   'suck',
#   'dick',
#   'till',
#   'nut',
#   'spit',
#   'gut',
#   'slurp',
#   'shit',
#   'back',
#   'aint',
#   'slut'],
#  ['holy',
#   'fucking',
#   'shit',
#   'game',
#   'third',
#   'string',
#   'redskins',
#   'team',
#   'gut',
#   'wrenching'],
#  ['gonna', 'shower', 'sole', 'purpose', 'shampooing', 'beard'],
#  ['racist', 'bitch'],
#  ['smoke', 'fat', 'pound', 'fall', 'faster', 'fat', 'bitch', 'sat', 'fast'],
#  ['hoe', 'crying', 'ass', 'pregnant', 'smiles', 'riding', 'dick', 'bitch'],
#  ['saying',
#   'bitch',
#   'get',
#   'nigga',
#   'hoe',
#   'cuz',
#   'gonna',
#   'beat',
#   'ass',
#   'like',
#   'gonna',
#   'beat',
#   'nigga',
#   'bitch',
#   'get',
#   'nigga'],
#  ['yall', 'hoes', 'would', 'never', 'get', 'skin'],
#  [],
#  ['coons'],
#  ['welcome',
#   'land',
#   'check',
#   'racist',
#   'whitey',
#   'sitting',
#   'steps',
#   'etc',
#   'woo'],
#  ['dont', 'respect', 'nun', 'bitch', 'cause', 'idgaf', 'bout', 'des', 'hoes'],
#  ['humble', 'not', 'hoe', 'best', 'feature', 'opposite', 'sex'],
#  ['city', 'bitches'],
#  ['pussy', 'stank'],
#  ['winter', 'time', 'walking', 'hoe', 'ctfu'],
#  ['momma',
#   'dead',
#   'bitch',
#   'really',
#   'think',
#   'cant',
#   'connect',
#   'lucky',
#   'number',
#   'face'],
#  ['hahahaha', 'basic', 'bitches', 'funny'],
#  ['hit', 'plans', 'mah', 'nigs'],
#  ['told', 'never', 'fold', 'amp', 'never', 'sell', 'sole'],
#  ['wyd', 'hoe', 'heyyy'],
#  ['black', 'pussy', 'nigga', 'sayin', 'anything'],
#  ['post', 'bid', 'tell', 'nig', 'use', 'jab'],
#  ['hate',
#   'bitches',
#   'keep',
#   'saying',
#   'yassss',
#   'like',
#   'like',
#   'bitch',
#   'sound',
#   'stupid',
#   'stfu'],
#  ['ive',
#   'noticed',
#   'mostly',
#   'bitches',
#   'whose',
#   'hair',
#   'dont',
#   'even',
#   'reach',
#   'shoulders',
#   'talk',
#   'shit'],
#  ['division', 'trash', 'saints', 'gon', 'win', 'nfc', 'southwatch'],
#  ['bitch', 'want'],
#  ['love',
#   'fat',
#   'hoes',
#   'tight',
#   'clothes',
#   'granny',
#   'panties',
#   'seeeexxaaaay'],
#  ['makes', 'nigger', 'fucking', 'goat'],
#  ['love'],
#  ['fat', 'thick'],
#  ['realest', 'bitch', 'amber'],
#  ['caught', 'talking', 'bird', 'pretty', 'embarrassing'],
#  ['thanks', 'saying', 'today'],
#  ['beer', 'ball', 'isnt', 'pussies'],
#  ['needy',
#   'ratchet',
#   'sideline',
#   'beggin',
#   'dumb',
#   'looking',
#   'love',
#   'facebook',
#   'hoes'],
#  ['chippah', 'hopes', 'aint', 'hangin', 'wit', 'dis', 'wigger', 'boy'],
#  ['dont', 'hate', 'japs', 'aint', 'forgetting', 'gettin', 'japped', 'either'],
#  ['miss', 'fag', 'friends'],
#  ['english',
#   'killed',
#   'leprechauns',
#   'thank',
#   'god',
#   'annoying',
#   'little',
#   'bastards'],
#  ['niggas', 'dnt', 'like', 'bet', 'fck', 'bitch', 'tho'],
#  ['mom',
#   'told',
#   'put',
#   'drug',
#   'paraphernalia',
#   'trash',
#   'shitty',
#   'life',
#   'stoner',
#   'cop',
#   'mom',
#   'pretty',
#   'upset'],
#  ['solution', 'zog', 'doesnt', 'deal', 'demographics', 'laws', 'solution'],
#  ['bitch', 'fuck', 'blog', 'meet', 'get', 'round'],
#  ['hgwells', 'charlie', 'chaplin'],
#  ['least',
#   'agree',
#   'whining',
#   'like',
#   'little',
#   'bitch',
#   'someone',
#   'threw',
#   'phone',
#   'absolutely'],
#  ['dont', 'wife', 'bitch', 'night', 'catching', 'bodies', 'might', 'alright'],
#  ['gotta', 'find', 'know', 'cali', 'got', 'hoes'],
#  ['talkin', 'nig', 'smashed', 'homies'],
#  ['hoes', 'aint', 'got', 'manners'],
#  ['boats', 'hoes'],
#  ['shutup', 'thirsty', 'hoe'],
#  ['professor', 'said', 'hoes', 'said', 'butt', 'hurt', 'boss'],
#  ['wus', 'fat', 'ass', 'filled', 'application', 'work', 'not', 'bitch'],
#  ['coolin', 'know', 'ole', 'shit', 'different', 'day', 'nig'],
#  ['found',
#   'sloppy',
#   'tried',
#   'drag',
#   'car',
#   'fighting',
#   'back',
#   'bitch',
#   'hea'],
#  ['think', 'mans', 'take', 'bitches', 'house', 'see', 'wifi', 'connects'],
#  ['stevie',
#   'turned',
#   'hoe',
#   'housewife',
#   'nikko',
#   'turned',
#   'housewife',
#   'hoe',
#   'swear',
#   'shit',
#   'happen'],
#  ['amp', 'fuck', 'bitches'],
#  ['bitches', 'jus', 'love', 'get', 'madd'],
#  ['hell', 'plasticassed'],
#  ['negro', 'amigo', 'pulled', 'gun', 'nate', 'weeks', 'ago'],
#  ['houston',
#   'top',
#   'five',
#   'ahl',
#   'attendance',
#   'aeros',
#   'transplanted',
#   'snow',
#   'bird',
#   'would',
#   'love',
#   'team'],
#  ['throw',
#   'rager',
#   'sweet',
#   'everybody',
#   'bring',
#   'presents',
#   'cards',
#   'crib',
#   'bitch',
#   'grandma',
#   'even',
#   'bought',
#   'bday',
#   'cake',
#   'ova'],
#  ['sarcastic', 'bitch', 'beautiful'],
#  ['hell',
#   'nahh',
#   'bitch',
#   'respect',
#   'damn',
#   'wouldnt',
#   'wear',
#   'shit',
#   'public'],
#  ['cant',
#   'even',
#   'tell',
#   'bitch',
#   'hey',
#   'without',
#   'thinking',
#   'tryna',
#   'get',
#   'lmao',
#   'yall',
#   'sumn',
#   'else',
#   'get',
#   'real'],
#  ['hoe',
#   'sooooo',
#   'ugly',
#   'like',
#   'bitch',
#   'ugly',
#   'dog',
#   'like',
#   'dumb',
#   'stupid',
#   'ass',
#   'ugly',
#   'like'],
#  ['popped', 'pussy', 'sweating', 'lol'],
#  ['nigga', 'proud', 'bitch', 'going', 'get', 'weed', 'car'],
#  ['hate', 'people', 'ask', 'tryna', 'look', 'good', 'bitch', 'bye'],
#  ['aint', 'jus', 'bitches', 'wan', 'fck'],
#  ['say', 'say', 'woman', 'strong', 'personality', 'doesnt', 'play', 'well'],
#  ['bitch', 'probably', 'deserved', 'lol'],
#  ['brownie', 'points'],
#  ['call', 'pussy', 'not', 'senior', 'skip'],
#  ['never',
#   'problem',
#   'girl',
#   'years',
#   'school',
#   'otter',
#   'looking',
#   'twat',
#   'better',
#   'quit',
#   'giving',
#   'looks'],
#  ['aint',
#   'trippen',
#   'cause',
#   'like',
#   'anyways',
#   'got',
#   'niggah',
#   'got',
#   'girl',
#   'anyways',
#   'yea',
#   'anyways'],
#  ['bitch'],
#  ['full', 'white', 'trash'],
#  ['bitch', 'moreno', 'valley'],
#  ['wyd', 'fag'],
#  ['chase', 'sin', 'falls', 'blessing'],
#  ['youre', 'trash'],
#  ['got', 'alla', 'hoes'],
#  ['ghost', 'picks', 'dive', 'pussy'],
#  ['deletin',
#   'emojis',
#   'contact',
#   'name',
#   'cos',
#   'dont',
#   'mean',
#   'shit',
#   'anymore'],
#  ['almost', 'years', 'ago', 'gave', 'bitches', 'away', 'stolen'],
#  ['hoe', 'association', 'real', 'yes'],
#  ['hate',
#   'girls',
#   'say',
#   'forever',
#   'alone',
#   'like',
#   'shut',
#   'forever',
#   'hoe',
#   'not',
#   'forever',
#   'alone',
#   'shut',
#   'get',
#   'dick',
#   'breath'],
#  ['wet', 'pussy', 'best', 'pussy'],
#  ['need', 'least', 'not', 'bitch', 'date'],
#  ['rather', 'girl', 'clingy', 'hoe'],
#  ['also', 'math', 'theorem', 'make'],
#  ['pussies'],
#  ['bitch', 'stick'],
#  ['eat', 'shit', 'working', 'nappy', 'bitch'],
#  ['knows',
#   'wordsgt',
#   'jingo',
#   'dangle',
#   'fan',
#   'slang',
#   'ting',
#   'pang',
#   'lick',
#   'drum',
#   'swing',
#   'flick',
#   'alarm',
#   'bicgt',
#   'cant',
#   'hear',
#   'fire'],
#  ['girls',
#   'talking',
#   'catching',
#   'feelings',
#   'bitch',
#   'need',
#   'catch',
#   'pass',
#   'throw',
#   'smh'],
#  ['flappy', 'bird', 'shit', 'joke', 'real', 'tho'],
#  ['hung', 'dudes', 'wasnt', 'fuckin'],
#  ['pasta', 'fancily', 'prepared', 'trash'],
#  ['every',
#   'female',
#   'think',
#   'every',
#   'nigga',
#   'come',
#   'across',
#   'love',
#   'bitch',
#   'could',
#   'leave',
#   'smoke',
#   'blunt',
#   'amp',
#   'forget'],
#  ['coaches', 'retarded', 'would', 'put', 'point', 'guard', 'tho'],
#  ['hey', 'fans', 'good', 'score'],
#  ['okay', 'melo', 'bitch'],
#  ['hate', 'nosey', 'bitch', 'like', 'mind', 'yah', 'business'],
#  ['zack', 'still', 'questions', 'love', 'oreos', 'lol'],
#  ['bitch', 'choosy', 'lover'],
#  ['bitches',
#   'love',
#   'miley',
#   'cyrus',
#   'rihanna',
#   'cuz',
#   'speak',
#   'every',
#   'girls',
#   'inner',
#   'hoe'],
#  ['birthday',
#   'wish',
#   'many',
#   'big',
#   'booty',
#   'hoes',
#   'mane',
#   'shit',
#   'ima',
#   'turn',
#   'birthday'],
#  ['magic', 'ball', 'hoes'],
#  ['yay', 'like', 'jacob', 'colored', 'layouts'],
#  ['oomfs', 'teeth', 'quite', 'yellow'],
#  ['point', 'jealous', 'cuz', 'dee', 'hoes', 'everybody'],
#  ['cute', 'ass', 'niggah'],
#  ['side', 'lets', 'make', 'official'],
#  ['whatta', 'fags'],
#  ['butler',
#   'unchained',
#   'review',
#   'short',
#   'whitey',
#   'sucks',
#   'potentially',
#   'positive',
#   'film',
#   'simply',
#   'agitprop'],
#  ['aint', 'nuttin', 'cut', 'bitch'],
#  ['yellow', 'card', 'issued', 'temple'],
#  ['wont', 'trust', 'bitch'],
#  ['got',
#   'hold',
#   'take',
#   'selfies',
#   'saw',
#   'bunch',
#   'bad',
#   'ass',
#   'birds',
#   'pet',
#   'fucking',
#   'emu',
#   'today',
#   'wtf'],
#  ['seaside', 'smell', 'like', 'stank', 'ass', 'pussy', 'bruh'],
#  ['always',
#   'eli',
#   'stupid',
#   'hick',
#   'hayseed',
#   'look',
#   'face',
#   'giants',
#   'fans',
#   'kill',
#   'yaselves',
#   'gonna'],
#  ['dont', 'understand', 'rich', 'people', 'dress', 'like', 'trash'],
#  ['swear', 'got', 'shit', 'make', 'bitches', 'insane'],
#  ['houston', 'many', 'trash', 'drivers'],
#  ['gwen',
#   'stefanis',
#   'new',
#   'single',
#   'trash',
#   'hilary',
#   'britney',
#   'fergie',
#   'give',
#   'raise',
#   'kids',
#   'judg'],
#  ['not', 'type', 'guy', 'bitch', 'hot', 'still', 'sweating'],
#  ['ahah', 'chill', 'bitch', 'look', 'better'],
#  ['braxton',
#   'curti',
#   'hoe',
#   'ass',
#   'nigga',
#   'wen',
#   'see',
#   'ima',
#   'smack',
#   'like',
#   'lil',
#   'bitch'],
#  ['trash',
#   'black',
#   'people',
#   'play',
#   'rampb',
#   'amp',
#   'hip',
#   'hop',
#   'partiesplay',
#   'dubstep',
#   'houseyall',
#   'coons',
#   'need',
#   'expand'],
#  ['yall',
#   'mean',
#   'whoever',
#   'running',
#   'back',
#   'telling',
#   'tunchi',
#   'wtf',
#   'thats',
#   'not',
#   'nigga',
#   'dog',
#   'niggas',
#   'bitches'],
#  ['sucha', 'hoe'],
#  ['lol', 'replaced', 'big', 'yellow', 'chicken', 'homer'],
#  ['hoes', 'live', 'jus', 'hit', 'clubs', 'every', 'weekend'],
#  ['called',
#   'charlie',
#   'baker',
#   'concede',
#   'around',
#   'morning',
#   'plans',
#   'address',
#   'supporters'],
#  ['got', 'every', 'niggah', 'lookin', 'like', 'dam'],
#  ['old', 'people', 'cant', 'drunk', 'people'],
#  ['ima', 'shmurda', 'dance', 'pussy', 'hoe'],
#  ['stay'],
#  ['multiple', 'dna', 'girl', 'man', 'ran', 'train', 'hoe'],
#  ['serious',
#   'right',
#   'hypocritical',
#   'double',
#   'fuck',
#   'outta',
#   'face',
#   'trash'],
#  ['nobody',
#   'want',
#   'nigga',
#   'take',
#   'expensive',
#   'date',
#   'dont',
#   'expect',
#   'pussy',
#   'cause',
#   'took',
#   'girl',
#   'like'],
#  ['stupid', 'bitches', 'ltltlt', 'fuck'],
#  ['ugly', 'ass', 'hoe', 'wanna', 'bad', 'bitch', 'gone'],
#  ['screaming',
#   'wes',
#   'bitch',
#   'annalise',
#   'losing',
#   'damn',
#   'mind',
#   'need',
#   'put',
#   'big',
#   'girl',
#   'panties',
#   'back'],
#  ['managers', 'stupid', 'cunt', 'yes', 'said'],
#  ['wear',
#   'vineyard',
#   'vines',
#   'american',
#   'flag',
#   'chubbies',
#   'opposite',
#   'wigga'],
#  ['killed', 'hoe'],
#  ['cant', 'spell', 'slut', 'without', 'bitch'],
#  ['sick', 'bitches', 'bitching', 'bitches'],
#  ['types', 'niggas', 'world', 'real', 'niggas', 'amp', 'bitch', 'niggas'],
#  ['dont', 'know', 'bitch', 'tuat', 'aint', 'sayin'],
#  ['mcm',
#   'tomorrows',
#   'months',
#   'fuck',
#   'everyone',
#   'said',
#   'wouldnt',
#   'last',
#   'proved',
#   'bitches',
#   'wrong'],
#  ['nice', 'pussy'],
#  ['lol', 'thirst', 'real', 'dis', 'bitch'],
#  ['guy',
#   'orientation',
#   'got',
#   'asked',
#   'top',
#   'favorite',
#   'music',
#   'artists',
#   'first',
#   'thing',
#   'bitch',
#   'said',
#   'usher'],
#  ['burn', 'bitch'],
#  ['lifes', 'bitch', 'amp', 'die'],
#  ['straight', 'except', 'math', 'bitch', 'hows', 'lol'],
#  ['drinking',
#   'veuve',
#   'cliquot',
#   'eating',
#   'marshmallows',
#   'basically',
#   'classy',
#   'bitch'],
#  ['pussy', 'ass', 'niggas', 'aint', 'bout', 'life'],
#  ['pussy', 'ass', 'hoe', 'cant', 'fuck', 'wit', 'yall'],
#  ['hoes',
#   'cmon',
#   'thru',
#   'hatchys',
#   'utica',
#   'tdt',
#   'rock',
#   'dis',
#   'biiaaaatch'],
#  ['never', 'seen', 'toddler', 'chug', 'water', 'bottle', 'fast', 'lol'],
#  ['hahahahaa', 'fuckin', 'crow', 'looking', 'bitch'],
#  ['faggot',
#   'truck',
#   'tailgating',
#   'hit',
#   'cut',
#   'switched',
#   'lanes',
#   'cuts',
#   'little',
#   'biatch'],
#  ['niggas',
#   'long',
#   'ass',
#   'monkey',
#   'arms',
#   'make',
#   'best',
#   'cuddle',
#   'buddiesso',
#   'heard',
#   'ahaha',
#   'female',
#   'told'],
#  ['guess',
#   'used',
#   'getting',
#   'bitch',
#   'cause',
#   'idk',
#   'anybody',
#   'juss',
#   'let',
#   'ppl',
#   'disrespect',
#   'sit',
#   'thts'],
#  ['hoes'],
#  ['not',
#   'going',
#   'bitch',
#   'dont',
#   'speak',
#   'reasons',
#   'decision',
#   'done',
#   'start'],
#  ['next', 'time', 'rednecks', 'ill', 'see', 'rednecks', 'paychecks'],
#  ['girl',
#   'skipping',
#   'school',
#   'aint',
#   'nothing',
#   'made',
#   'say',
#   'head',
#   'bitch',
#   'supposed',
#   'school',
#   'catch'],
#  ['fuck', 'throwing', 'batting', 'practice', 'holy', 'shit'],
#  ['zuko', 'gets', 'bitches'],
#  ['make', 'paper', 'ball', 'trash'],
#  ['said', 'ready', 'bitch', 'okay', 'lmfaoooooooo', 'done'],
#  ['welcome', 'twitter'],
#  ['put', 'ass', 'let', 'know', 'baddest', 'lit', 'bitch'],
#  ['fox', 'say'],
#  ['think',
#   'addicted',
#   'naked',
#   'pictures',
#   'sit',
#   'talking',
#   'bout',
#   'bitches',
#   'almost'],
#  ['ass', 'retarted', 'belongs', 'short', 'yellow', 'bus'],
#  ['messy',
#   'asss',
#   'bitches',
#   'would',
#   'blast',
#   'yall',
#   'dumb',
#   'bitches',
#   'not',
#   'even',
#   'gon',
#   'stoop',
#   'yalls',
#   'level'],
#  ['every',
#   'spic',
#   'cop',
#   'raped',
#   'thought',
#   'raping',
#   'white',
#   'woman',
#   'thats',
#   'get',
#   'jobs',
#   'pigs'],
#  ['top', 'notch', 'bitches'],
#  ['people',
#   'beg',
#   'see',
#   'womens',
#   'bodies',
#   'minute',
#   'theyre',
#   'seen',
#   'woman',
#   'hoe',
#   'okay'],
#  ['fuck', 'twerking', 'bitch', 'cook'],
#  ['honey', 'bbq', 'oreos', 'monstrous', 'glass', 'right', 'poster', 'boy'],
#  ['need', 'pussy', 'ate'],
#  ['know', 'fat', 'hoes', 'not', 'big', 'boned', 'jus', 'fat'],
#  ['guess',
#   'none',
#   'deez',
#   'rappin',
#   'ass',
#   'niggas',
#   'wanna',
#   'throw',
#   'dem',
#   'bitches',
#   'wit',
#   'big',
#   'homie'],
#  ['might', 'get', 'riches', 'might', 'broke', 'bitches'],
#  ['awwww', 'dont', 'pussy', 'ill', 'show', 'good', 'turbo', 'lol'],
#  ['lol', 'matches', 'early', 'champion', 'bitches', 'really', 'would', 'ham'],
#  ...]

# %%
#training_documents = documents[0:14869]
#testing_documents = documents[14869:]
training_documents = documents
testing_documents = documents_test
testing_documents_t = documents_t

# %%
all_words = []
for doc in training_documents:
    all_words += doc[0]
freq = nltk.FreqDist(all_words)
common = freq.most_common(1000)
features = [i[0] for i in common]

# %%
all_words

# %%
&;,  :,  a, i, rt , &;: , if, but, just, to , &;&;, ":  ,  dot(.) , &;&;&; , comma(,) , -  , n, " , ...  , ! , 2 , ?, .. , ' , &;&;&;&;&; , "i , | , 3 , 1 ,@ , 4,

# %%
common
# Out:
# [('bitch', 6126),
#  ('bitches', 2353),
#  ('like', 2165),
#  ('hoes', 1772),
#  ('pussy', 1599),
#  ('dont', 1424),
#  ('hoe', 1401),
#  ('ass', 1196),
#  ('get', 1146),
#  ('fuck', 1111),
#  ('got', 1036),
#  ('not', 928),
#  ('shit', 927),
#  ('aint', 921),
#  ('nigga', 901),
#  ('trash', 854),
#  ('lol', 831),
#  ('amp', 651),
#  ('know', 638),
#  ('niggas', 613),
#  ('love', 558),
#  ('one', 546),
#  ('cant', 534),
#  ('yall', 529),
#  ('fucking', 512),
#  ('thats', 483),
#  ('youre', 456),
#  ('want', 448),
#  ('bad', 437),
#  ('good', 402),
#  ('make', 388),
#  ('man', 384),
#  ('still', 383),
#  ('say', 380),
#  ('see', 371),
#  ('hate', 366),
#  ('look', 365),
#  ('need', 364),
#  ('never', 358),
#  ('think', 357),
#  ('time', 347),
#  ('back', 341),
#  ('real', 332),
#  ('really', 327),
#  ('people', 318),
#  ('even', 316),
#  ('girl', 307),
#  ('white', 306),
#  ('faggot', 298),
#  ('would', 297),
#  ('lmao', 285),
#  ('said', 282),
#  ('right', 280),
#  ('let', 276),
#  ('bird', 273),
#  ('wanna', 270),
#  ('bout', 269),
#  ('wit', 268),
#  ('damn', 261),
#  ('little', 259),
#  ('dick', 257),
#  ('stop', 257),
#  ('tell', 251),
#  ('gotta', 250),
#  ('come', 245),
#  ('ill', 244),
#  ('cause', 242),
#  ('talk', 242),
#  ('dat', 239),
#  ('gonna', 238),
#  ('call', 236),
#  ('day', 235),
#  ('new', 235),
#  ('take', 232),
#  ('always', 227),
#  ('every', 226),
#  ('going', 220),
#  ('niggah', 219),
#  ('lil', 218),
#  ('better', 215),
#  ('eat', 215),
#  ('life', 211),
#  ('fuckin', 207),
#  ('charlie', 206),
#  ('girls', 200),
#  ('give', 200),
#  ('dumb', 199),
#  ('put', 199),
#  ('ever', 196),
#  ('retarded', 195),
#  ('ugly', 194),
#  ('getting', 194),
#  ('yellow', 192),
#  ('talking', 190),
#  ('big', 188),
#  ('money', 188),
#  ('keep', 187),
#  ('ghetto', 181),
#  ('twitter', 179),
#  ('hit', 179),
#  ('cunt', 179),
#  ('much', 178),
#  ('tho', 175),
#  ('stupid', 175),
#  ('nigger', 172),
#  ('way', 171),
#  ('black', 169),
#  ('fat', 166),
#  ('made', 165),
#  ('last', 164),
#  ('feel', 164),
#  ('old', 163),
#  ('could', 159),
#  ('birds', 159),
#  ('game', 156),
#  ('fag', 155),
#  ('didnt', 155),
#  ('mad', 153),
#  ('hes', 153),
#  ('around', 152),
#  ('cuz', 152),
#  ('someone', 149),
#  ('called', 148),
#  ('best', 145),
#  ('something', 145),
#  ('yeah', 144),
#  ('boy', 144),
#  ('first', 144),
#  ('fucked', 143),
#  ('smh', 142),
#  ('another', 142),
#  ('well', 142),
#  ('tryna', 142),
#  ('shes', 141),
#  ('gone', 141),
#  ('many', 141),
#  ('play', 139),
#  ('shut', 139),
#  ('side', 137),
#  ('mean', 135),
#  ('happy', 135),
#  ('work', 134),
#  ('next', 133),
#  ('wont', 132),
#  ('colored', 131),
#  ('thing', 130),
#  ('today', 130),
#  ('night', 128),
#  ('face', 127),
#  ('crazy', 124),
#  ('nicca', 123),
#  ('two', 122),
#  ('ima', 121),
#  ('looking', 120),
#  ('school', 120),
#  ('gon', 120),
#  ('haha', 119),
#  ('name', 119),
#  ('told', 118),
#  ('head', 116),
#  ('god', 116),
#  ('find', 116),
#  ('try', 116),
#  ('start', 116),
#  ('high', 115),
#  ('women', 114),
#  ('trying', 113),
#  ('nothing', 112),
#  ('ive', 112),
#  ('hell', 112),
#  ('seen', 112),
#  ('monkey', 112),
#  ('baby', 112),
#  ('yankees', 111),
#  ('beat', 109),
#  ('stay', 109),
#  ('home', 106),
#  ('broke', 106),
#  ('dude', 104),
#  ('act', 104),
#  ('show', 103),
#  ('doesnt', 103),
#  ('house', 102),
#  ('use', 101),
#  ('ask', 101),
#  ('phone', 101),
#  ('thought', 101),
#  ('friends', 100),
#  ('done', 99),
#  ('bro', 99),
#  ('trust', 99),
#  ('loyal', 99),
#  ('hard', 99),
#  ('swear', 98),
#  ('fight', 98),
#  ('pretty', 98),
#  ('bruh', 98),
#  ('watch', 97),
#  ('turn', 97),
#  ('year', 97),
#  ('kill', 97),
#  ('gay', 97),
#  ('guys', 97),
#  ('went', 97),
#  ('already', 96),
#  ('makes', 95),
#  ('tweet', 95),
#  ('sex', 95),
#  ('please', 93),
#  ('tonight', 93),
#  ('wrong', 93),
#  ('bring', 93),
#  ('hope', 92),
#  ('hot', 92),
#  ('nah', 91),
#  ('care', 91),
#  ('wish', 90),
#  ('nobody', 90),
#  ('dis', 90),
#  ('long', 90),
#  ('guy', 89),
#  ('making', 89),
#  ('funny', 89),
#  ('might', 89),
#  ('live', 88),
#  ('cute', 88),
#  ('buy', 88),
#  ('gets', 87),
#  ('straight', 87),
#  ('cut', 86),
#  ('niccas', 86),
#  ('everybody', 86),
#  ('free', 85),
#  ('lot', 84),
#  ('sorry', 84),
#  ('car', 84),
#  ('lets', 83),
#  ('saying', 83),
#  ('since', 83),
#  ('wtf', 83),
#  ('eating', 83),
#  ('wait', 83),
#  ('nig', 82),
#  ('hair', 81),
#  ('days', 81),
#  ('red', 81),
#  ('looks', 81),
#  ('young', 80),
#  ('sure', 80),
#  ('theres', 79),
#  ('world', 79),
#  ('remember', 79),
#  ('whats', 79),
#  ('fake', 78),
#  ('text', 78),
#  ('throw', 77),
#  ('bet', 77),
#  ('everything', 77),
#  ('mom', 77),
#  ('full', 77),
#  ('playing', 76),
#  ('theyre', 76),
#  ('hey', 75),
#  ('whole', 75),
#  ('retard', 75),
#  ('follow', 75),
#  ('song', 75),
#  ('kids', 75),
#  ('away', 74),
#  ('says', 74),
#  ('great', 74),
#  ('leave', 74),
#  ('wear', 74),
#  ('sleep', 74),
#  ('took', 73),
#  ('anything', 73),
#  ('suck', 73),
#  ('wasnt', 73),
#  ('though', 73),
#  ('nigguh', 72),
#  ('woman', 72),
#  ('guess', 72),
#  ('probably', 72),
#  ('brownies', 71),
#  ('faggots', 71),
#  ('jus', 71),
#  ('basic', 71),
#  ('nice', 70),
#  ('pussies', 70),
#  ('left', 70),
#  ('cool', 69),
#  ('ion', 69),
#  ('pull', 68),
#  ('dem', 68),
#  ('calling', 68),
#  ('lmfao', 67),
#  ('wouldnt', 67),
#  ('isnt', 67),
#  ('run', 67),
#  ('thanks', 67),
#  ('job', 67),
#  ('yes', 67),
#  ('redneck', 67),
#  ('word', 66),
#  ('stfu', 66),
#  ('half', 66),
#  ('years', 66),
#  ('son', 66),
#  ('females', 66),
#  ('needs', 65),
#  ('used', 65),
#  ('things', 65),
#  ('wanted', 65),
#  ('saw', 64),
#  ('everyone', 64),
#  ('must', 64),
#  ('mock', 64),
#  ('party', 64),
#  ('wants', 64),
#  ('die', 63),
#  ('niggers', 63),
#  ('maybe', 63),
#  ('friend', 63),
#  ('team', 63),
#  ('pay', 62),
#  ('lost', 62),
#  ('dyke', 62),
#  ('actually', 62),
#  ('fun', 62),
#  ('men', 61),
#  ('single', 61),
#  ('queer', 61),
#  ('tweets', 61),
#  ('miss', 61),
#  ('came', 61),
#  ('boys', 61),
#  ('couldnt', 61),
#  ('either', 61),
#  ('music', 60),
#  ('believe', 60),
#  ('type', 60),
#  ('dead', 60),
#  ('person', 59),
#  ('nasty', 59),
#  ('catch', 59),
#  ('gave', 59),
#  ('yea', 59),
#  ('rather', 58),
#  ('idk', 58),
#  ('mind', 58),
#  ('yet', 58),
#  ('without', 58),
#  ('class', 58),
#  ('weed', 58),
#  ('outta', 57),
#  ('ready', 57),
#  ('wearing', 57),
#  ('pic', 57),
#  ('bae', 56),
#  ('dog', 56),
#  ('birthday', 56),
#  ('reason', 56),
#  ('booty', 56),
#  ('heard', 55),
#  ('watching', 55),
#  ('hear', 55),
#  ('thank', 55),
#  ('wife', 55),
#  ('coming', 55),
#  ('omg', 55),
#  ('stand', 55),
#  ('line', 55),
#  ('else', 54),
#  ('dirty', 54),
#  ('mouth', 54),
#  ('crackers', 54),
#  ('acting', 54),
#  ('sick', 54),
#  ('true', 54),
#  ('club', 53),
#  ('main', 53),
#  ('walk', 53),
#  ('finna', 53),
#  ('sit', 53),
#  ('change', 52),
#  ('female', 52),
#  ('lookin', 52),
#  ('via', 52),
#  ('tried', 51),
#  ('lame', 51),
#  ('comes', 51),
#  ('none', 51),
#  ('imma', 51),
#  ('taking', 51),
#  ('food', 51),
#  ('niggaz', 51),
#  ('also', 51),
#  ('win', 51),
#  ('favorite', 51),
#  ('point', 50),
#  ('top', 50),
#  ('light', 50),
#  ('send', 50),
#  ('fags', 50),
#  ('tired', 50),
#  ('video', 50),
#  ('found', 50),
#  ('somebody', 50),
#  ('chill', 50),
#  ('couple', 50),
#  ('talkin', 50),
#  ('outside', 49),
#  ('may', 49),
#  ('okay', 49),
#  ('boyfriend', 48),
#  ('pregnant', 48),
#  ('ratchet', 48),
#  ('week', 48),
#  ('oreo', 48),
#  ('listen', 48),
#  ('flappy', 48),
#  ('sound', 48),
#  ('goes', 48),
#  ('least', 48),
#  ('place', 48),
#  ('smoke', 47),
#  ('fine', 47),
#  ('cheat', 47),
#  ('open', 47),
#  ('lie', 47),
#  ('pop', 47),
#  ('end', 47),
#  ('gettin', 47),
#  ('early', 47),
#  ('fans', 47),
#  ('pick', 46),
#  ('naw', 46),
#  ('move', 46),
#  ('chick', 46),
#  ('problem', 46),
#  ('number', 46),
#  ('pass', 46),
#  ('sad', 46),
#  ('respect', 46),
#  ('enough', 46),
#  ('hurt', 46),
#  ('drop', 46),
#  ('almost', 45),
#  ('sometimes', 45),
#  ('morning', 45),
#  ('whos', 45),
#  ('racist', 45),
#  ('tomorrow', 45),
#  ('cry', 45),
#  ('lose', 44),
#  ('front', 44),
#  ('dudes', 44),
#  ('arent', 44),
#  ('smell', 44),
#  ('heart', 44),
#  ('cold', 44),
#  ('thinking', 44),
#  ('youll', 44),
#  ('hella', 44),
#  ('giving', 43),
#  ('means', 43),
#  ('sum', 43),
#  ('times', 43),
#  ('rich', 43),
#  ('body', 43),
#  ('till', 43),
#  ('anyone', 43),
#  ('literally', 43),
#  ('room', 43),
#  ('pics', 43),
#  ('instead', 42),
#  ('wonder', 42),
#  ('brown', 42),
#  ('ppl', 42),
#  ('low', 42),
#  ('jihadi', 42),
#  ('wow', 42),
#  ('break', 42),
#  ('cracker', 42),
#  ('quick', 42),
#  ('girlfriend', 42),
#  ('understand', 42),
#  ('kno', 42),
#  ('ride', 41),
#  ('read', 41),
#  ('drunk', 41),
#  ('hold', 41),
#  ('quit', 41),
#  ('check', 41),
#  ('bunch', 41),
#  ('eyes', 41),
#  ('ice', 41),
#  ('thirsty', 41),
#  ('uncle', 40),
#  ('shoot', 40),
#  ('meet', 40),
#  ('unless', 40),
#  ('set', 40),
#  ('self', 40),
#  ('city', 40),
#  ('mine', 40),
#  ('date', 40),
#  ('sexy', 40),
#  ('weak', 40),
#  ('relationship', 40),
#  ('bed', 40),
#  ('annoying', 40),
#  ('hand', 39),
#  ('dad', 39),
#  ('lmaoo', 39),
#  ('games', 39),
#  ('tranny', 39),
#  ('feelings', 39),
#  ('social', 39),
#  ('wake', 39),
#  ('slap', 39),
#  ('worried', 38),
#  ('dress', 38),
#  ('perfect', 38),
#  ('using', 38),
#  ('asked', 38),
#  ('lady', 38),
#  ('met', 38),
#  ('matter', 38),
#  ('cream', 37),
#  ('yankee', 37),
#  ('serious', 37),
#  ('ones', 37),
#  ('kind', 37),
#  ('water', 37),
#  ('together', 37),
#  ('help', 37),
#  ('weekend', 37),
#  ('coon', 37),
#  ('lying', 37),
#  ('drive', 37),
#  ('prolly', 37),
#  ('season', 37),
#  ('different', 37),
#  ('instagram', 37),
#  ('picture', 37),
#  ('attention', 36),
#  ('knows', 36),
#  ('nothin', 36),
#  ('asian', 36),
#  ('deep', 36),
#  ('wet', 36),
#  ('ate', 36),
#  ('likes', 36),
#  ('telling', 36),
#  ('past', 35),
#  ('hood', 35),
#  ('whatever', 35),
#  ('started', 35),
#  ('ball', 35),
#  ('drink', 35),
#  ('momma', 35),
#  ('hahaha', 35),
#  ('running', 35),
#  ('thot', 35),
#  ('post', 35),
#  ('door', 35),
#  ('killed', 35),
#  ('walking', 35),
#  ('crying', 35),
#  ('state', 34),
#  ('glad', 34),
#  ('chicken', 34),
#  ('words', 34),
#  ('later', 34),
#  ('mother', 34),
#  ('grow', 34),
#  ('taste', 34),
#  ('knew', 34),
#  ('business', 34),
#  ('far', 34),
#  ('nudes', 34),
#  ('soon', 34),
#  ('oreos', 34),
#  ('working', 34),
#  ('bag', 34),
#  ('behind', 34),
#  ('forget', 33),
#  ('ago', 33),
#  ('slope', 33),
#  ('skin', 33),
#  ('kid', 33),
#  ('realize', 33),
#  ('hungry', 33),
#  ('skinny', 33),
#  ('fact', 33),
#  ('close', 33),
#  ('obama', 33),
#  ('speak', 33),
#  ('thru', 32),
#  ('shot', 32),
#  ('kinda', 32),
#  ('story', 32),
#  ('bye', 32),
#  ('thinks', 32),
#  ('hands', 32),
#  ('taken', 32),
#  ('everyday', 32),
#  ('clothes', 32),
#  ('media', 32),
#  ('fly', 31),
#  ('brownie', 31),
#  ('scared', 31),
#  ('stuck', 31),
#  ('biggest', 31),
#  ('waiting', 31),
#  ('bullshit', 31),
#  ('cat', 31),
#  ('mama', 31),
#  ('sole', 31),
#  ('lmaooo', 31),
#  ('save', 31),
#  ('round', 31),
#  ('texting', 31),
#  ('pictures', 31),
#  ('strong', 31),
#  ('sell', 31),
#  ('treat', 31),
#  ('clean', 31),
#  ('niggahs', 31),
#  ('seeing', 31),
#  ('worth', 31),
#  ('anymore', 31),
#  ('tweeting', 31),
#  ('lick', 30),
#  ('mans', 30),
#  ('thick', 30),
#  ('fall', 30),
#  ('seem', 30),
#  ('movie', 30),
#  ('park', 30),
#  ('dey', 30),
#  ('dope', 30),
#  ('slut', 30),
#  ('laugh', 30),
#  ('part', 29),
#  ('fucc', 29),
#  ('beautiful', 29),
#  ('redskins', 29),
#  ('late', 29),
#  ('support', 29),
#  ('asking', 29),
#  ('baddest', 29),
#  ('tha', 29),
#  ('jihadis', 29),
#  ('alone', 29),
#  ('den', 29),
#  ('attitude', 29),
#  ('aye', 29),
#  ('block', 29),
#  ('weird', 29),
#  ('ladies', 29),
#  ('america', 29),
#  ('daddy', 29),
#  ('kick', 28),
#  ('shouldnt', 28),
#  ('calls', 28),
#  ('takes', 28),
#  ('country', 28),
#  ('negro', 28),
#  ('jail', 28),
#  ('street', 28),
#  ('piece', 28),
#  ('sweet', 28),
#  ('rest', 28),
#  ('blue', 28),
#  ('super', 28),
#  ('kiss', 28),
#  ('retards', 28),
#  ('hating', 28),
#  ('havent', 28),
#  ('karma', 28),
#  ('fell', 28),
#  ('sounds', 28),
#  ('tom', 27),
#  ('shoes', 27),
#  ('crist', 27),
#  ('beer', 27),
#  ('playin', 27),
#  ('chris', 27),
#  ('friday', 27),
#  ('shirt', 27),
#  ('cheese', 27),
#  ('fan', 27),
#  ('followers', 27),
#  ('halloween', 27),
#  ('joe', 27),
#  ('dawg', 27),
#  ('twat', 27),
#  ('control', 27),
#  ('loves', 27),
#  ('less', 27),
#  ('problems', 27),
#  ('folk', 27),
#  ('youve', 27),
#  ('jesus', 27),
#  ('fam', 27),
#  ('laughing', 27),
#  ('proud', 27),
#  ('looked', 27),
#  ('shy', 26),
#  ('voice', 26),
#  ('rick', 26),
#  ('easy', 26),
#  ('family', 26),
#  ('anyway', 26),
#  ('whore', 26),
#  ('jeter', 26),
#  ('cunts', 26),
#  ('kim', 26),
#  ('lucky', 26),
#  ('green', 26),
#  ('soul', 26),
#  ('chicks', 26),
#  ('poor', 26),
#  ('race', 26),
#  ('second', 26),
#  ('million', 26),
#  ('mess', 26),
#  ('ugh', 26),
#  ('smack', 26),
#  ('middle', 26),
#  ('fire', 26),
#  ('sayin', 25),
#  ('rap', 25),
#  ('town', 25),
#  ('summer', 25),
#  ('naked', 25),
#  ('short', 25),
#  ('finally', 25),
#  ('deserve', 25),
#  ('massage', 25),
#  ('scary', 25),
#  ('fuzzy', 25),
#  ('double', 25),
#  ('boring', 25),
#  ('slit', 25),
#  ('learn', 25),
#  ('special', 25),
#  ('public', 25),
#  ('chug', 25),
#  ('fucks', 25),
#  ('played', 25),
#  ('lonely', 25),
#  ('gold', 25),
#  ('roll', 24),
#  ('brought', 24),
#  ('john', 24),
#  ('feeling', 24),
#  ('woke', 24),
#  ('turned', 24),
#  ('worry', 24),
#  ('excuse', 24),
#  ('rock', 24),
#  ('sucks', 24),
#  ('fast', 24),
#  ('balls', 24),
#  ('ran', 24),
#  ('worst', 24),
#  ('become', 24),
#  ('cheating', 24),
#  ('lips', 24),
#  ('caught', 24),
#  ('actin', 24),
#  ('forgot', 24),
#  ('smoking', 24),
#  ('doin', 24),
#  ('sister', 24),
#  ('hop', 24),
#  ('til', 24),
#  ('goin', 24),
#  ('finger', 24),
#  ('course', 24),
#  ('homie', 23),
#  ('american', 23),
#  ('trap', 23),
#  ('moment', 23),
#  ('blunt', 23),
#  ('grade', 23),
#  ('died', 23),
#  ('dare', 23),
#  ('brother', 23),
#  ('http', 23),
#  ('idgaf', 23),
#  ('weeks', 23),
#  ('teeth', 23),
#  ('honestly', 23),
#  ('bit', 23),
#  ('mane', 23),
#  ('supposed', 23),
#  ('wild', 23),
#  ('seriously', 23),
#  ('death', 23),
#  ('punk', 23),
#  ('living', 23),
#  ('dnt', 23),
#  ('neck', 23),
#  ('especially', 23),
#  ('tight', 23),
#  ('feet', 23),
#  ('dark', 23),
#  ('truth', 23),
#  ('teabagger', 23),
#  ('sheen', 23),
#  ('wack', 23),
#  ('expect', 23),
#  ('slow', 23),
#  ('claim', 23),
#  ('weather', 23),
#  ('sucking', 23),
#  ('trippin', 22),
#  ('animal', 22),
#  ('angry', 22),
#  ('doe', 22),
#  ('paper', 22),
#  ('dream', 22),
#  ('ape', 22),
#  ('lebron', 22),
#  ('cus', 22),
#  ('handle', 22),
#  ('random', 22),
#  ('blame', 22),
#  ('worse', 22),
#  ('complain', 22),
#  ('cares', 22),
#  ('throwing', 22),
#  ('cuh', 22),
#  ('blow', 22),
#  ('apes', 22),
#  ('small', 22),
#  ('steal', 22),
#  ('drake', 22),
#  ('blah', 22),
#  ('soles', 21),
#  ('facebook', 21),
#  ('bomb', 21),
#  ('write', 21),
#  ('touch', 21),
#  ('idc', 21),
#  ('rednecks', 21),
#  ('wat', 21),
#  ('news', 21),
#  ('wassup', 21),
#  ('derek', 21),
#  ('shitty', 21),
#  ('nips', 21),
#  ('enjoy', 21),
#  ('legs', 21),
#  ('paid', 21),
#  ('group', 21),
#  ('forever', 21),
#  ('dese', 21),
#  ('flat', 21),
#  ('tongue', 21),
#  ('eye', 21),
#  ('chocolate', 21),
#  ('retweet', 21),
#  ('whitey', 21),
#  ('jump', 21),
#  ('beef', 21),
#  ('stank', 21),
#  ('teacher', 21),
#  ('extra', 21),
#  ('football', 21),
#  ('deal', 21),
#  ('gun', 21),
#  ('gas', 21),
#  ('bought', 21),
#  ('duck', 20),
#  ('turning', 20),
#  ('dry', 20),
#  ('drinking', 20),
#  ('punch', 20),
#  ('flip', 20),
#  ('count', 20),
#  ('cook', 20),
#  ('swag', 20),
#  ('dam', 20),
#  ('texas', 20),
#  ('mexican', 20),
#  ('cops', 20),
#  ('level', 20),
#  ('definitely', 20),
#  ('stick', 20),
#  ('lunch', 20),
#  ('avi', 20),
#  ('across', 20),
#  ('stuff', 20),
#  ('lmaoooo', 20),
#  ('holy', 20),
#  ('planet', 20),
#  ('porn', 20),
#  ('hairy', 20),
#  ('selling', 20),
#  ('smart', 20),
#  ('boss', 20),
#  ('suppose', 20),
#  ('trip', 20),
#  ('joke', 20),
#  ('blood', 20),
#  ('nope', 20),
#  ('chase', 20),
#  ('college', 20),
#  ('drugs', 19),
#  ('test', 19),
#  ('hillbilly', 19),
#  ('sense', 19),
#  ('shout', 19),
#  ('friendly', 19),
#  ('threw', 19),
#  ('unfollow', 19),
#  ('hitting', 19),
#  ('argue', 19),
#  ('moms', 19),
#  ('thug', 19),
#  ('field', 19),
#  ('clearly', 19),
#  ('minutes', 19),
#  ('feed', 19),
#  ('except', 19),
#  ('throat', 19),
#  ('gucci', 19),
#  ('confused', 19),
#  ('step', 19),
#  ('knowing', 19),
#  ('yesterday', 19),
#  ('seat', 19),
#  ('hang', 19),
#  ('nigs', 19),
#  ('knock', 19),
#  ('minute', 19),
#  ('basically', 19),
#  ('tbh', 19),
#  ('longer', 19),
#  ('parents', 19),
#  ('facts', 19),
#  ('grown', 19),
#  ('jealous', 18),
#  ('blocked', 18),
#  ('lemme', 18),
#  ('cock', 18),
#  ('future', 18),
#  ('thang', 18),
#  ('exactly', 18),
#  ('whipped', 18),
#  ('walked', 18),
#  ('butt', 18),
#  ('power', 18),
#  ('monday', 18),
#  ('somethin', 18),
#  ('soft', 18),
#  ('offensive', 18),
#  ('push', 18),
#  ('entire', 18),
#  ('wifey', 18),
#  ('dollars', 18),
#  ('bigger', 18),
#  ('cake', 18),
#  ('dinner', 18),
#  ('grandma', 18),
#  ('loud', 18),
#  ('add', 18),
#  ('heads', 18),
#  ('teabaggers', 18),
#  ('garbage', 18),
#  ('gym', 18),
#  ('abo', 18),
#  ('names', 18),
#  ('fairy', 18),
#  ('losing', 18),
#  ('smile', 18),
#  ('meant', 18),
#  ('faithful', 18),
#  ('star', 18),
#  ('quote', 18),
#  ('nose', 18),
#  ('three', 18),
#  ('hide', 18),
#  ('bar', 18),
#  ('allowed', 18),
#  ('folks', 18),
#  ('air', 18),
#  ('famous', 18),
#  ('lives', 18),
#  ('difference', 17),
#  ('president', 17),
#  ('apparently', 17),
#  ('months', 17),
#  ('iont', 17),
#  ('sitting', 17)]

# %%
def get_feature_dict(words):
  current_features = {}
  words_set = set(words)
  for w in features:
    current_features[w] = w in words_set
  return current_features

# %%
output = get_feature_dict(training_documents[0][0])
output

# %%
training_data = [(get_feature_dict(doc), category) for doc, category in training_documents]
testing_data = [(get_feature_dict(doc)) for doc in testing_documents]
testing_data_t = [(get_feature_dict(doc), category) for doc, category in testing_documents_t]

# %%
from nltk import NaiveBayesClassifier
classfier = NaiveBayesClassifier.train(training_data)
nltk.classify.accuracy(classfier, testing_data_t)
# Out:
# 0.8721000605204761

# %%
nltk.classify.accuracy(classfier, testing_data_t)
# Out:
# 0.8811157066478362

# %%
tests=['I really like it', 
'I do not think this is good one', 
'this is good one',
'I hate the show!',
'Get this bitch off my TV bruh',
'Perhaps not diehard Yankee fan no point watch debacle LOL',
'Fuck good',
'love asian bitches']

for test in tests:
  t_features = {word: (word in word_tokenize(test.lower())) for word in features}
  print(t_features," : ", classfier.classify(t_features))
  #print(t_features)
# Out:
# {'bitch': False, 'bitches': False, 'like': True, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'love': False, 'one': False, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': False, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': False, 'look': False, 'need': False, 'never': False, 'think': False, 'time': False, 'back': False, 'real': False, 'really': True, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': False, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': False, 'watch': False, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, ' ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': True, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'love': False, 'one': True, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': True, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': False, 'look': False, 'need': False, 'never': False, 'think': True, 'time': False, 'back': False, 'real': False, 'really': False, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': False, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': False, 'watch': False, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, 'mo ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'love': False, 'one': True, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': True, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': False, 'look': False, 'need': False, 'never': False, 'think': False, 'time': False, 'back': False, 'real': False, 'really': False, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': False, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': False, 'watch': False, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, ' ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'love': False, 'one': False, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': False, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': True, 'look': False, 'need': False, 'never': False, 'think': False, 'time': False, 'back': False, 'real': False, 'really': False, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': True, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': False, 'watch': False, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, ' ...
# {'bitch': True, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': True, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'love': False, 'one': False, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': False, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': False, 'look': False, 'need': False, 'never': False, 'think': False, 'time': False, 'back': False, 'real': False, 'really': False, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': False, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': True, 'watch': False, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, 'm ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': True, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': True, 'amp': False, 'know': False, 'niggas': False, 'love': False, 'one': False, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': False, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': False, 'look': False, 'need': False, 'never': False, 'think': False, 'time': False, 'back': False, 'real': False, 'really': False, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': False, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': False, 'watch': True, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, 'm ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': True, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'love': False, 'one': False, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': True, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': False, 'look': False, 'need': False, 'never': False, 'think': False, 'time': False, 'back': False, 'real': False, 'really': False, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': False, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': False, 'watch': False, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, ' ...
# {'bitch': False, 'bitches': True, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'love': True, 'one': False, 'cant': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'good': False, 'make': False, 'man': False, 'still': False, 'say': False, 'see': False, 'hate': False, 'look': False, 'need': False, 'never': False, 'think': False, 'time': False, 'back': False, 'real': False, 'really': False, 'people': False, 'even': False, 'girl': False, 'white': False, 'faggot': False, 'would': False, 'lmao': False, 'said': False, 'right': False, 'let': False, 'bird': False, 'wanna': False, 'bout': False, 'wit': False, 'damn': False, 'little': False, 'dick': False, 'stop': False, 'tell': False, 'gotta': False, 'come': False, 'ill': False, 'cause': False, 'talk': False, 'dat': False, 'gonna': False, 'call': False, 'day': False, 'new': False, 'take': False, 'always': False, 'every': False, 'going': False, 'niggah': False, 'lil': False, 'better': False, 'eat': False, 'life': False, 'fuckin': False, 'charlie': False, 'girls': False, 'give': False, 'dumb': False, 'put': False, 'ever': False, 'retarded': False, 'ugly': False, 'getting': False, 'yellow': False, 'talking': False, 'big': False, 'money': False, 'keep': False, 'ghetto': False, 'twitter': False, 'hit': False, 'cunt': False, 'much': False, 'tho': False, 'stupid': False, 'nigger': False, 'way': False, 'black': False, 'fat': False, 'made': False, 'last': False, 'feel': False, 'old': False, 'could': False, 'birds': False, 'game': False, 'fag': False, 'didnt': False, 'mad': False, 'hes': False, 'around': False, 'cuz': False, 'someone': False, 'called': False, 'best': False, 'something': False, 'yeah': False, 'boy': False, 'first': False, 'fucked': False, 'smh': False, 'another': False, 'well': False, 'tryna': False, 'shes': False, 'gone': False, 'many': False, 'play': False, 'shut': False, 'side': False, 'mean': False, 'happy': False, 'work': False, 'next': False, 'wont': False, 'colored': False, 'thing': False, 'today': False, 'night': False, 'face': False, 'crazy': False, 'nicca': False, 'two': False, 'ima': False, 'looking': False, 'school': False, 'gon': False, 'haha': False, 'name': False, 'told': False, 'head': False, 'god': False, 'find': False, 'try': False, 'start': False, 'high': False, 'women': False, 'trying': False, 'nothing': False, 'ive': False, 'hell': False, 'seen': False, 'monkey': False, 'baby': False, 'yankees': False, 'beat': False, 'stay': False, 'home': False, 'broke': False, 'dude': False, 'act': False, 'show': False, 'doesnt': False, 'house': False, 'use': False, 'ask': False, 'phone': False, 'thought': False, 'friends': False, 'done': False, 'bro': False, 'trust': False, 'loyal': False, 'hard': False, 'swear': False, 'fight': False, 'pretty': False, 'bruh': False, 'watch': False, 'turn': False, 'year': False, 'kill': False, 'gay': False, 'guys': False, 'went': False, 'already': False, 'makes': False, 'tweet': False, 'sex': False, 'please': False, 'tonight': False, 'wrong': False, 'bring': False, 'hope': False, 'hot': False, 'nah': False, 'care': False, 'wish': False, 'nobody': False, 'dis': False, 'long': False, 'guy': False, 'making': False, 'funny': False, 'might': False, 'live': False, 'cute': False, 'buy': False, 'gets': False, 'straight': False, 'cut': False, 'niccas': False, 'everybody': False, 'free': False, 'lot': False, 'sorry': False, 'car': False, 'lets': False, 'saying': False, 'since': False, 'wtf': False, 'eating': False, 'wait': False, 'nig': False, 'hair': False, 'days': False, 'red': False, 'looks': False, 'young': False, 'sure': False, 'theres': False, 'world': False, 'remember': False, 'whats': False, 'fake': False, 'text': False, 'throw': False, 'bet': False, 'everything': False, ' ...

# %%
#df_ = pd.DataFrame(columns=['class'])
classes= []
for test in testing_data_t:
  #print(test[0])
  #print(t_features," : ", classfier.classify(test[0]))
  classes.append(classfier.classify(test[0]))
  #dataframe = dataframe.append({'class':row['class'], 'tweet': ' '.join(clean_sentence)}, ignore_index = True)

# %%
#df_ = pd.DataFrame(columns=['class'])
classes_test= []
for test in testing_data:
  #print(test[0])
  #print(t_features," : ", classfier.classify(test[0]))
  classes_test.append(classfier.classify(test))
  #dataframe = dataframe.append({'class':row['class'], 'tweet': ' '.join(clean_sentence)}, ignore_index = True)

# %%
original = []
for test in testing_data_t:
  original.append(test[1])

# %%
df_ = pd.DataFrame(data = classes, columns=['class_t'])
df_['class_test'] = classes_test
df_['real_class'] = original

# %%
df_.head()
# Out:
#    class_t  class_test
# 0        1           1
# 1        1           1
# 2        1           1
# 3        1           1
# 4        1           1

# %%
raw_test['class']=df_['class_test']

# %%
raw_test.to_excel('hate_speech_874384.xlsx', index = False)

# %%
test_data['predicted'] = df_['class_test']
test_data.to_excel('hate_speech_comparison.xlsx', index = True)

# %%
total = 0
count = 0
for index,row in test_data.iterrows():
  if row['class'] == row['predicted']:
    count+=1
  total+=1

accuracy = ((count/total)*100)
print(accuracy)
# Out:
# 87.2100060520476

# %%
test_data['predicted'].value_counts()
# Out:
# 1    4074
# 2     734
# 0     149
# Name: predicted, dtype: int64

# %%
test_data['class'].value_counts()
# Out:
# 1    3839
# 2     829
# 0     289
# Name: class, dtype: int64

# %%
for test in tests:
    t_features = {word: (word in word_tokenize(test.lower())) for word in features}
    print(t_features)
# Out:
# {'bitch': False, 'bitches': False, 'like': True, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': False, 'love': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': False, 'man': False, 'make': False, 'need': False, 'hate': False, 'say': False, 'see': False, 'look': False, 'time': False, 'think': False, 'back': False, 'really': True, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': False, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': False, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': False, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'fag ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': True, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': True, 'love': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': True, 'man': False, 'make': False, 'need': False, 'hate': False, 'say': False, 'see': False, 'look': False, 'time': False, 'think': True, 'back': False, 'really': False, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': False, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': False, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': False, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'faggo ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': True, 'love': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': True, 'man': False, 'make': False, 'need': False, 'hate': False, 'say': False, 'see': False, 'look': False, 'time': False, 'think': False, 'back': False, 'really': False, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': False, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': False, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': False, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'fag ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': False, 'love': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': False, 'man': False, 'make': False, 'need': False, 'hate': True, 'say': False, 'see': False, 'look': False, 'time': False, 'think': False, 'back': False, 'really': False, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': True, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': False, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': False, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'fag ...
# {'bitch': True, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': True, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': False, 'love': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': False, 'man': False, 'make': False, 'need': False, 'hate': False, 'say': False, 'see': False, 'look': False, 'time': False, 'think': False, 'back': False, 'really': False, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': False, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': False, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': True, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'fagg ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': True, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': True, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': False, 'love': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': False, 'man': False, 'make': False, 'need': False, 'hate': False, 'say': False, 'see': False, 'look': False, 'time': False, 'think': False, 'back': False, 'really': False, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': False, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': True, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': False, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'fagg ...
# {'bitch': False, 'bitches': False, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': True, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': False, 'love': False, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': True, 'man': False, 'make': False, 'need': False, 'hate': False, 'say': False, 'see': False, 'look': False, 'time': False, 'think': False, 'back': False, 'really': False, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': False, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': False, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': False, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'fag ...
# {'bitch': False, 'bitches': True, 'like': False, 'hoes': False, 'pussy': False, 'dont': False, 'hoe': False, 'ass': False, 'get': False, 'fuck': False, 'got': False, 'not': False, 'shit': False, 'aint': False, 'nigga': False, 'trash': False, 'lol': False, 'amp': False, 'know': False, 'niggas': False, 'cant': False, 'one': False, 'love': True, 'yall': False, 'fucking': False, 'thats': False, 'youre': False, 'want': False, 'bad': False, 'still': False, 'good': False, 'man': False, 'make': False, 'need': False, 'hate': False, 'say': False, 'see': False, 'look': False, 'time': False, 'think': False, 'back': False, 'really': False, 'even': False, 'never': False, 'people': False, 'white': False, 'real': False, 'faggot': False, 'would': False, 'girl': False, 'right': False, 'lmao': False, 'said': False, 'wanna': False, 'damn': False, 'bird': False, 'bout': False, 'let': False, 'little': False, 'dick': False, 'wit': False, 'stop': False, 'tell': False, 'talk': False, 'gonna': False, 'dat': False, 'gotta': False, 'come': False, 'going': False, 'take': False, 'ill': False, 'new': False, 'every': False, 'cause': False, 'niggah': False, 'better': False, 'call': False, 'always': False, 'life': False, 'day': False, 'lil': False, 'charlie': False, 'fuckin': False, 'girls': False, 'give': False, 'yellow': False, 'ugly': False, 'ever': False, 'eat': False, 'big': False, 'talking': False, 'money': False, 'retarded': False, 'getting': False, 'twitter': False, 'keep': False, 'dumb': False, 'put': False, 'birds': False, 'cunt': False, 'ghetto': False, 'stupid': False, 'tho': False, 'much': False, 'fat': False, 'hit': False, 'nigger': False, 'made': False, 'way': False, 'last': False, 'tryna': False, 'feel': False, 'black': False, 'mad': False, 'could': False, 'didnt': False, 'around': False, 'shut': False, 'cuz': False, 'another': False, 'first': False, 'old': False, 'game': False, 'play': False, 'called': False, 'someone': False, 'fag': False, 'smh': False, 'boy': False, 'hes': False, 'something': False, 'side': False, 'many': False, 'wont': False, 'gone': False, 'fucked': False, 'well': False, 'happy': False, 'next': False, 'best': False, 'yeah': False, 'shes': False, 'colored': False, 'mean': False, 'today': False, 'work': False, 'god': False, 'two': False, 'face': False, 'thing': False, 'crazy': False, 'night': False, 'haha': False, 'nicca': False, 'yankees': False, 'told': False, 'trying': False, 'women': False, 'ima': False, 'baby': False, 'nothing': False, 'high': False, 'monkey': False, 'name': False, 'school': False, 'head': False, 'looking': False, 'seen': False, 'show': False, 'find': False, 'start': False, 'hell': False, 'gon': False, 'try': False, 'beat': False, 'ive': False, 'act': False, 'doesnt': False, 'please': False, 'stay': False, 'swear': False, 'tonight': False, 'care': False, 'trust': False, 'year': False, 'watch': False, 'use': False, 'fight': False, 'friends': False, 'makes': False, 'house': False, 'broke': False, 'ask': False, 'dude': False, 'bruh': False, 'loyal': False, 'hard': False, 'nah': False, 'pretty': False, 'bro': False, 'home': False, 'tweet': False, 'might': False, 'phone': False, 'sex': False, 'bring': False, 'guys': False, 'thought': False, 'went': False, 'live': False, 'wrong': False, 'already': False, 'hope': False, 'done': False, 'kill': False, 'dis': False, 'hot': False, 'cut': False, 'guy': False, 'whats': False, 'full': False, 'turn': False, 'nobody': False, 'making': False, 'free': False, 'niccas': False, 'buy': False, 'lets': False, 'gay': False, 'eating': False, 'funny': False, 'straight': False, 'saying': False, 'since': False, 'everybody': False, 'cute': False, 'remember': False, 'long': False, 'wait': False, 'nig': False, 'wish': False, 'sorry': False, 'car': False, 'sleep': False, 'gets': False, 'wtf': False, 'days': False, 'bet': False, 'sure': False, 'hair': False, 'fake': False, 'throw': False, 'retard': False, 'wasnt': False, 'lot': False, 'follow': False, 'cool': False, 'looks': False, 'fag ...

# %%
for test in testing_data:
  print(classfier.classify(test))
  break

# %%
classfier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                      ass = True                0 : 2      =    128.0 : 1.0
#                   nigger = True                0 : 2      =     96.3 : 1.0
#                    bitch = True                1 : 2      =     87.0 : 1.0
#                  yankees = True                2 : 1      =     78.1 : 1.0
#                     oreo = True                2 : 1      =     63.4 : 1.0
#                    jeter = True                2 : 1      =     62.8 : 1.0
#                     ho&; = True                2 : 1      =     59.8 : 1.0
#                 niggers. = True                0 : 1      =     59.3 : 1.0
#                   jihadi = True                2 : 1      =     57.9 : 1.0
#                     gook = True                0 : 1      =     50.2 : 1.0
#                  massage = True                2 : 1      =     47.5 : 1.0
#                  charlie = True                2 : 1      =     45.8 : 1.0
#                   yankee = True                2 : 1      =     41.4 : 1.0
#                     chug = True                2 : 1      =     41.4 : 1.0
#                 faggots. = True                0 : 1      =     41.1 : 1.0

# %%
from sklearn.model_selection import train_test_split
X = dataframe.tweet.values
Y = dataframe.classes
Y = Y.astype('int')

x_train, x_test, y_train, y_test = train_test_split(X,Y)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14869,)
# (4957,)
# (14869,)
# (4957,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
my_vectorizer = vectorizer.fit_transform(x_train)
vocab = vectorizer.vocabulary_

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(my_vectorizer,y_train)
my_test_data = vectorizer.transform(x_test)
my_pred = clf.predict(my_test_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
 from sklearn.naive_bayes import MultinomialNB
 nb_clf = MultinomialNB()
 nb_clf.fit(my_vectorizer,y_train)
 my_test_data = vectorizer.transform(x_test)
 my_pred = nb_clf.predict(my_test_data)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(my_pred, y_test)
# Out:
# 0.7748638289287876

# %%
clf.predict(vectorizer.transform(['I like this']))
# Out:
# array([1])

# %%
df_pred = pd.DataFrame(data =my_pred)
df_pred.value_counts()
# Out:
# 1    4946
# 2      10
# 0       1
# dtype: int64

# %%
dataframe['classes'].value_counts()
# Out:
# 1    15350
# 2     3335
# 0     1141
# Name: classes, dtype: int64
