# %% [markdown]
# # Information Extraction
#
# Information extraction is a task of automatically extracting structured information from unstructured and/or semi-structured documents. In most of the cases, this activity concerns processing human language texts by means of NLP.
# - Input : Unstructered Text, Digital texts, web pages, emails, etc
# - Output : structured data, Knowledge Graph
# <img src="RE_output.JPG">
#
# ## Information Extraction Pipeline
# <img src="NER.JPG">

# %% [markdown]
# ### Step 1.
# **Coreference resolution** is the NLP (Natural Language Processing) equivalent of endophoric awareness used in information retrieval systems, conversational agents, and virtual assistants like Amazon’s Alexa. It is the task of clustering mentions in text that refer to the same underlying entities.
# For example:
# <img src="https://miro.medium.com/max/3534/1*YestCzcJ4zvlioClwmVNsQ.png">
#
# Algorithms which resolve coreferences commonly look for the nearest preceding mention that is compatible with the referring expression. Instead of using rule-based dependency parse trees, neural networks can also be trained which take into account word embeddings and distance between mentions as features.

# %%
#Installing required Packages
# !pip install git+https://github.com/huggingface/neuralcoref.git
# !pip install transformers==3.4.0
# !pip install torch==1.6.0
# !pip install git+https://github.com/thunlp/OpenNRE.git
# Out:
# Collecting git+https://github.com/huggingface/neuralcoref.git
#   Cloning https://github.com/huggingface/neuralcoref.git to /tmp/pip-req-build-x4b49zwj
#   Running command git clone -q https://github.com/huggingface/neuralcoref.git /tmp/pip-req-build-x4b49zwj
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref==4.0) (1.19.5)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from neuralcoref==4.0) (1.18.11)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref==4.0) (2.23.0)
# Requirement already satisfied: spacy<3.0.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from neuralcoref==4.0) (2.2.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (1.25.11)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (57.2.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (3.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (2.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (4.41.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (4.6.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.1.0->neuralcoref==4.0) (3.5.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->neuralcoref==4.0) (0.5.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.11 in /usr/local/lib/python3.7/dist-packages (from boto3->neuralcoref==4.0) (1.21.11)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->neuralcoref==4.0) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.11->boto3->neuralcoref==4.0) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.11->boto3->neuralcoref==4.0) (1.15.0)
# Requirement already satisfied: transformers==3.4.0 in /usr/local/lib/python3.7/dist-packages (3.4.0)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (0.1.96)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (3.17.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (0.0.45)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (2019.12.20)
# Requirement already satisfied: tokenizers==0.9.2 in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (0.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.4.0) (1.19.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.4.0) (2.4.7)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->transformers==3.4.0) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.4.0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.4.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.4.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.4.0) (1.25.11)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.4.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.4.0) (1.0.1)
# Requirement already satisfied: torch==1.6.0 in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.6.0) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.6.0) (0.16.0)
# Collecting git+https://github.com/thunlp/OpenNRE.git
#   Cloning https://github.com/thunlp/OpenNRE.git to /tmp/pip-req-build-fsrv28hv
#   Running command git clone -q https://github.com/thunlp/OpenNRE.git /tmp/pip-req-build-fsrv28hv

# %%
# !pip install git+https://github.com/thunlp/OpenNRE.git
# Out:
# Collecting git+https://github.com/thunlp/OpenNRE.git
#   Cloning https://github.com/thunlp/OpenNRE.git to /tmp/pip-req-build-v44xwrxv
#   Running command git clone -q https://github.com/thunlp/OpenNRE.git /tmp/pip-req-build-v44xwrxv

# %%
import spacy
spacy.__version__
# Out:
# '2.2.4'

# %%
#!pip install neuralcoref --no-binary neuralcoref

# %%
#Load your usual SpaCy model (one of SpaCy English models)
import spacy
nlp = spacy.load('en_core_web_sm')

# Add neural coref to SpaCy's pipe
import neuralcoref
neuralcoref.add_to_pipe(nlp)

# You can now use NeuralCoref as you usually manipulate a SpaCy document annotations.
doc = nlp('My sister has a dog. She loves him.')
# Out:
# /usr/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: spacy.morphology.Morphology size changed, may indicate binary incompatibility. Expected 104 from C header, got 112 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: spacy.vocab.Vocab size changed, may indicate binary incompatibility. Expected 96 from C header, got 104 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# You can retrieve a list of all the clusters of corefering mentions using the `doc._.coref_clusters` attribute

# %%
doc._.coref_clusters
# Out:
# [My sister: [My sister, She], a dog: [a dog, him]]

# %% [markdown]
# Replacing corefering mentions with the main mentions in each cluster by using the `doc._.coref_resolved` attribute

# %%
doc._.coref_resolved
# Out:
# 'My sister has a dog. My sister loves a dog.'

# %%
doc = nlp('David went to the concert. He said it was an amazing experience.')
doc._.coref_clusters,doc._.coref_resolved
# Out:
# ([David: [David, He]],
#  'David went to the concert. David said it was an amazing experience.')

# %%
txt = """Elon Musk is a business magnate, industrial designer, and engineer. He is the founder, CEO, CTO, and chief designer of SpaceX.
          He is also early investor, CEO, and product architect of Tesla, Inc.
          He is also the founder of The Boring Company and the co-founder of Neuralink.
          A centibillionaire, Musk became the richest person in the world in January 2021, 
          with an estimated net worth of $185 billion at the time, surpassing Jeff Bezos. 
          Musk was born to a Canadian mother and South African father and raised in Pretoria, South Africa.
          He briefly attended the University of Pretoria before moving to Canada aged 17 to attend Queen's University. 
          He transferred to the University of Pennsylvania two years later, where he received dual bachelor's degrees in economics
          and physics. He moved to California in 1995 to attend Stanford University,but decided instead to pursue a business career.
          He went on co-founding a web software company Zip2 with his brother Kimbal Musk"""

# %%
doc = nlp(txt)
resolved_text = doc._.coref_resolved
resolved_text
# Out:
# "Elon Musk is a business magnate, industrial designer, and engineer. Elon Musk is the founder, CEO, CTO, and chief designer of SpaceX.\n          Elon Musk is also early investor, CEO, and product architect of Tesla, Inc.\n          Elon Musk is also the founder of The Boring Company and the co-founder of Neuralink.\n          A centibillionaire, Elon Musk became the richest person in the world in January 2021, \n          with an estimated net worth of $185 billion at the time, surpassing Jeff Bezos. \n          Elon Musk was born to a Canadian mother and South African father and raised in Pretoria, South Africa.\n          Elon Musk briefly attended the University of Pretoria before moving to Canada aged 17 to attend Queen's University. \n          Elon Musk transferred to Queen's University two years later, where Elon Musk received dual bachelor's degrees in economics\n          and physics. Elon Musk moved to California in 1995 to attend Queen's University,but decided instead to pursue a business career.\n          Elon Musk went on co-founding a web software company Zip2 with Elon Musk brother Kimbal Musk"

# %% [markdown]
# In this example, there are no advanced coreference resolution techniques required. The Neuralcoref model changed a couple of pronouns “He” to “Elon Musk”. While it might seem very simple, this is an important step that will increase the overall efficiency of our Infomation Extraction pipeline.

# %%
#clusters #list of all the clusters of corefering mentions
#doc._.coref_clusters

# %% [markdown]
# ## Named Entity Recognition
# Named Entity Recognition NER works by locating and identifying the named entities present in unstructured text into the standard categories such as person names, locations, organizations, time expressions, quantities, monetary values, percentage, codes etc.
# <img src="NE.JPG">

# %% [markdown]
# ## Limitations of NER
# - A single real world entity can have many different text records
# - There is no silver bullet NLP model, various domains require custom models
# - No model is 100% accurate.

# %% [markdown]
# ### Step 2.
# **Named Entity Linking** will assign a unique identity to entities mentioned in the text.
# In other words, Named Entity Linking is the task to link entity mentions in text with their corresponding entities in a knowledge base.
#  For example text, “President Ford granted a pardon to President Nixon.”, we would first identify all the words of interests, such as ‘Ford’. This is called Named Entity Recognition (NER). The word ‘Ford’ can refer to **President Gerald Ford**, **Henry Ford**, or the car company “Ford”. As such, the second step in a pipeline is candidate selection, where we narrow down the list of possible candidates for the identified words of interest. Subsequently, we disambiguate entities from the candidate list and link each identified entity to a unique identifier within a knowledge base. In the example above, we should ideally identify the entity ‘Ford’ as ‘Gerald Ford’.
# <img src="https://miro.medium.com/max/700/0*IOOZpjlLaJUWjex9">
#
#
# ### Wikification :
# Entity linking techniques that map named entities to Wikipedia entities.
# wikiID
# <img src="wikiID.JPG">
#
# Wikifier API is used : <a href="http://wikifier.org/info.html" target="_blank">Wikifier</a>

# %%
import urllib
from string import punctuation
import nltk
import json
import itertools

#ENTITY_TYPES = ["human", "person", "company", "enterprise", "business", "geographic region",
#                "human settlement", "geographic entity", "territorial entity type", "organization"]
ENTITY_TYPES = ["People", "time", "event", "person", "business", "company", "neighborhood", "deceasedperson", "film", "region", "ethnicity", "location", "country", "administrative_division", "us_county"]

def wikifier(text, lang="en", threshold=0.8):
    """Function that fetches entity linking results from wikifier.com API"""
    # Prepare the URL.
    data = urllib.parse.urlencode([
        ("text", text), ("lang", lang),
        ("userKey", "tgbdmkpmkluegqfbawcwjywieevmza"),
        ("pageRankSqThreshold", "%g" %
         threshold), ("applyPageRankSqThreshold", "true"),
        ("nTopDfValuesToIgnore", "100"), ("nWordsToIgnoreFromList", "100"),
        ("wikiDataClasses", "true"), ("wikiDataClassIds", "false"),
        ("support", "true"), ("ranges", "false"), ("minLinkFrequency", "2"),
        ("includeCosines", "false"), ("maxMentionEntropy", "3")
    ])
    url = "http://www.wikifier.org/annotate-article"
    # Call the Wikifier and read the response.
    req = urllib.request.Request(url, data=data.encode("utf8"), method="POST")
    with urllib.request.urlopen(req, timeout=60) as f:
        response = f.read()
        response = json.loads(response.decode("utf8"))
    # Output the annotations.
    results = list()
    
    for annotation in response["annotations"]:
        # Filter out desired entity classes
        print(annotation)
        print ("!title : ", annotation['title'])
        print("*****")
        print ("!response.wikiDataItemId : ", annotation['wikiDataItemId'])
        print("################################")
        if ('wikiDataClasses' in annotation) and (any([el['enLabel'] in ENTITY_TYPES for el in annotation['wikiDataClasses']])):

            # Specify entity label
            if any([el['enLabel'] in ["human", "person"] for el in annotation['wikiDataClasses']]):
                label = 'Person'
            elif any([el['enLabel'] in ["company", "enterprise", "business", "organization"] for el in annotation['wikiDataClasses']]):
                label = 'Organization'
            elif any([el['enLabel'] in ["geographic region", "human settlement", "geographic entity", "territorial entity type"] for el in annotation['wikiDataClasses']]):
                label = 'Location'
            else:
                label = None

            results.append({'title': annotation['title'], 'wikiId': annotation['wikiDataItemId'], 'label': label,
                            'characters': [(el['chFrom'], el['chTo']) for el in annotation['support']]})
            print(results)
            break
    return results

# %%
wikifier("Elon Musk is a business magnate, industrial designer, and engineer. Elon Musk is the founder, CEO, CTO, and chief designer of SpaceX")
# Out:
# {'title': 'Elon Musk', 'url': 'http://en.wikipedia.org/wiki/Elon_Musk', 'lang': 'en', 'pageRank': 0.05254839199814167, 'secLang': 'en', 'secTitle': 'Elon Musk', 'secUrl': 'http://en.wikipedia.org/wiki/Elon_Musk', 'wikiDataItemId': 'Q317521', 'wikiDataClasses': [{'itemId': 'Q5', 'enLabel': 'human'}, {'itemId': 'Q215627', 'enLabel': 'person'}, {'itemId': 'Q154954', 'enLabel': 'natural person'}, {'itemId': 'Q164509', 'enLabel': 'omnivore'}, {'itemId': 'Q830077', 'enLabel': 'subject'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q18336849', 'enLabel': 'item with given name property'}, {'itemId': 'Q795052', 'enLabel': 'individual'}, {'itemId': 'Q3778211', 'enLabel': 'legal person'}, {'itemId': 'Q72638', 'enLabel': 'consumer'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q26720107', 'enLabel': 'subject of a right'}, {'itemId': 'Q159344', 'enLabel': 'heterotroph'}, {'itemId': 'Q7239', 'enLabel': 'organism'}, {'itemId': 'Q16686022', 'enLabel': 'natural physical object'}, {'itemId': 'Q1274979', 'enLabel': 'creature'}, {'itemId': 'Q223557', 'enLabel': 'physical object'}, {'itemId': 'Q29651224', 'enLabel': 'natural object'}, {'itemId': 'Q4406616', 'enLabel': 'concrete object'}, {'itemId': 'Q1454986', 'enLabel': 'physical system'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q1322005', 'enLabel': 'natural phenomenon'}, {'itemId': 'Q58778', 'enLabel': 'system'}, {'itemId': 'Q30060700', 'enLabel': 'scientific object'}, {'itemId': 'Q483247', 'enLabel': 'phenomenon'}, {'itemId': 'Q6671777', 'enLabel': 'structure'}, {'itemId': 'Q1190554', 'enLabel': 'occurrence'}, {'itemId': 'Q16722960', 'enLabel': 'phenomenon'}, {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}], 'dbPediaTypes': ['Person', 'Agent'], 'dbPediaIri': 'http://dbpedia.org/resource/Elon_Musk', 'supportLen': 4, 'support': [{'wFrom': 0, 'wTo': 1, 'chFrom': 0, 'chTo': 8, 'pMentionGivenSurface': 0.6319444444444444, 'pageRank': 0.0217276483973197, 'prbConfidence': 1, 'entropy': 0}, {'wFrom': 1, 'wTo': 1, 'chFrom': 5, 'chTo': 8, 'pMentionGivenSurface': 0.02986022871664549, 'pageRank': 0.001026660739440773, 'prbConfidence': 0.7396744309530539, 'entropy': 1.421398888649255}, {'wFrom': 13, 'wTo': 14, 'chFrom': 68, 'chTo': 76, 'pMentionGivenSurface': 0.6319444444444444, 'pageRank': 0.0217276483973197, 'prbConfidence': 1, 'entropy': 0}, {'wFrom': 14, 'wTo': 14, 'chFrom': 73, 'chTo': 76, 'pMentionGivenSurface': 0.02986022871664549, 'pageRank': 0.001026660739440773, 'prbConfidence': 0.7396744309530539, 'entropy': 1.421398888649255}]}
# !title :  Elon Musk
# *****
# !response.wikiDataItemId :  Q317521
# ################################
# [{'title': 'Elon Musk', 'wikiId': 'Q317521', 'label': 'Person', 'characters': [(0, 8), (5, 8), (68, 76), (73, 76)]}]
# [{'characters': [(0, 8), (5, 8), (68, 76), (73, 76)],
#   'label': 'Person',
#   'title': 'Elon Musk',
#   'wikiId': 'Q317521'}]

# %%
wikifier("One of the newest auditoriums in New York , built into the bedrock below Carnegie Hall , has added a dose of richness to the concert scene.")
# Out:
# {'title': 'New York (state)', 'url': 'http://en.wikipedia.org/wiki/New_York_(state)', 'lang': 'en', 'pageRank': 0.03762592137391238, 'secLang': 'en', 'secTitle': 'New York (state)', 'secUrl': 'http://en.wikipedia.org/wiki/New_York_(state)', 'wikiDataItemId': 'Q1384', 'wikiDataClasses': [{'itemId': 'Q35657', 'enLabel': 'state of the United States'}, {'itemId': 'Q852446', 'enLabel': 'administrative territorial entity of the United States'}, {'itemId': 'Q107390', 'enLabel': 'federated state'}, {'itemId': 'Q10864048', 'enLabel': 'first-level administrative country subdivision'}, {'itemId': 'Q192611', 'enLabel': 'constituency'}, {'itemId': 'Q15916867', 'enLabel': 'administrative territorial entity of a single country'}, {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'}, {'itemId': 'Q5164076', 'enLabel': 'constituent state'}, {'itemId': 'Q1799794', 'enLabel': 'administrative territorial entity of a specific level'}, {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'}, {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'}, {'itemId': 'Q7275', 'enLabel': 'state'}, {'itemId': 'Q1496967', 'enLabel': 'territorial entity'}, {'itemId': 'Q16686448', 'enLabel': 'artificial entity'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q177634', 'enLabel': 'community'}, {'itemId': 'Q155076', 'enLabel': 'juridical person'}, {'itemId': 'Q1896989', 'enLabel': 'subject of international law'}, {'itemId': 'Q1063239', 'enLabel': 'polity'}, {'itemId': 'Q96196009', 'enLabel': 'state (former and current)'}, {'itemId': 'Q82794', 'enLabel': 'geographic region'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q874405', 'enLabel': 'social group'}, {'itemId': 'Q3778211', 'enLabel': 'legal person'}, {'itemId': 'Q12047392', 'enLabel': 'legal form'}, {'itemId': 'Q7210356', 'enLabel': 'political organisation'}, {'itemId': 'Q618123', 'enLabel': 'geographical object'}, {'itemId': 'Q27096213', 'enLabel': 'geographic entity'}, {'itemId': 'Q2221906', 'enLabel': 'geographic location'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q58778', 'enLabel': 'system'}, {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'}, {'itemId': 'Q26720107', 'enLabel': 'subject of a right'}, {'itemId': 'Q16889133', 'enLabel': 'class'}, {'itemId': 'Q58416391', 'enLabel': 'spatial entity'}, {'itemId': 'Q17334923', 'enLabel': 'location'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q6671777', 'enLabel': 'structure'}, {'itemId': 'Q4330518', 'enLabel': 'research object'}, {'itemId': 'Q2198779', 'enLabel': 'unit'}, {'itemId': 'Q830077', 'enLabel': 'subject'}, {'itemId': 'Q5127848', 'enLabel': 'class'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q7184903', 'enLabel': 'abstract object'}], 'dbPediaTypes': ['PopulatedPlace', 'Place'], 'dbPediaIri': 'http://dbpedia.org/resource/New_York_(state)', 'supportLen': 1, 'support': [{'wFrom': 6, 'wTo': 7, 'chFrom': 33, 'chTo': 40, 'pMentionGivenSurface': 0.09953058238530943, 'pageRank': 0.009461553498090126, 'prbConfidence': 0.09151626522677835, 'entropy': 1.612752991942401}]}
# !title :  New York (state)
# *****
# !response.wikiDataItemId :  Q1384
# ################################
# [{'title': 'New York (state)', 'wikiId': 'Q1384', 'label': 'Organization', 'characters': [(33, 40)]}]
# [{'characters': [(33, 40)],
#   'label': 'Organization',
#   'title': 'New York (state)',
#   'wikiId': 'Q1384'}]

# %%
txt = ("The Rev. Charles Hewawasam , a Roman Catholic priest who lost a nun and 18 members of his congregation in Matara , Sri Lanka , saw the tsunami as a reaction to ethnic and religious tensions . ")

# %%
wikifier(txt)
# Out:
# {'title': 'Catholic Church', 'url': 'http://en.wikipedia.org/wiki/Catholic_Church', 'lang': 'en', 'pageRank': 0.02169495699554522, 'secLang': 'en', 'secTitle': 'Catholic Church', 'secUrl': 'http://en.wikipedia.org/wiki/Catholic_Church', 'wikiDataItemId': 'Q9592', 'wikiDataClasses': [{'itemId': 'Q879146', 'enLabel': 'Christian denomination'}, {'itemId': 'Q34651', 'enLabel': 'Christian Church'}, {'itemId': 'Q13414953', 'enLabel': 'religious denomination'}, {'itemId': 'Q1530022', 'enLabel': 'religious organization'}, {'itemId': 'Q94670589', 'enLabel': 'Christian organization'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q488383', 'enLabel': 'object'}], 'dbPediaTypes': [], 'dbPediaIri': 'http://dbpedia.org/resource/Catholic_Church', 'supportLen': 5, 'support': [{'wFrom': 7, 'wTo': 7, 'chFrom': 31, 'chTo': 35, 'pMentionGivenSurface': 0.05629036171761591, 'pageRank': 0.001866427470238834, 'prbConfidence': 0.1968350329478147, 'entropy': 2.988135591944383}, {'wFrom': 7, 'wTo': 8, 'chFrom': 31, 'chTo': 44, 'pMentionGivenSurface': 0.3324866625749492, 'pageRank': 0.01102430720966058, 'prbConfidence': 0.2252466896722969, 'entropy': 0.4516571554522854}, {'wFrom': 8, 'wTo': 8, 'chFrom': 37, 'chTo': 44, 'pMentionGivenSurface': 0.09027437177230893, 'pageRank': 0.002993240089300437, 'prbConfidence': 0.2606927050688328, 'entropy': 0.9528770275516423}, {'wFrom': 8, 'wTo': 9, 'chFrom': 37, 'chTo': 51, 'pMentionGivenSurface': 0.09153821956590123, 'pageRank': 0.003035145669015751, 'prbConfidence': 0.4511421540096229, 'entropy': 0.2783164620233618}, {'wFrom': 9, 'wTo': 9, 'chFrom': 46, 'chTo': 51, 'pMentionGivenSurface': 0.1098194979066665, 'pageRank': 0.003641300595812188, 'prbConfidence': 0.2251319073244635, 'entropy': 1.026715735064206}]}
# !title :  Catholic Church
# *****
# !response.wikiDataItemId :  Q9592
# ################################
# {'title': 'Matara, Sri Lanka', 'url': 'http://en.wikipedia.org/wiki/Matara,_Sri_Lanka', 'lang': 'en', 'pageRank': 0.04707678261794928, 'secLang': 'en', 'secTitle': 'Matara, Sri Lanka', 'secUrl': 'http://en.wikipedia.org/wiki/Matara,_Sri_Lanka', 'wikiDataItemId': 'Q13360574', 'wikiDataClasses': [{'itemId': 'Q486972', 'enLabel': 'human settlement'}, {'itemId': 'Q82794', 'enLabel': 'geographic region'}, {'itemId': 'Q27096235', 'enLabel': 'artificial geographic entity'}, {'itemId': 'Q177634', 'enLabel': 'community'}, {'itemId': 'Q2221906', 'enLabel': 'geographic location'}, {'itemId': 'Q618123', 'enLabel': 'geographical object'}, {'itemId': 'Q27096213', 'enLabel': 'geographic entity'}, {'itemId': 'Q8205328', 'enLabel': 'artificial physical object'}, {'itemId': 'Q874405', 'enLabel': 'social group'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q17334923', 'enLabel': 'location'}, {'itemId': 'Q58416391', 'enLabel': 'spatial entity'}, {'itemId': 'Q223557', 'enLabel': 'physical object'}, {'itemId': 'Q16686448', 'enLabel': 'artificial entity'}, {'itemId': 'Q58778', 'enLabel': 'system'}, {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q4406616', 'enLabel': 'concrete object'}, {'itemId': 'Q1454986', 'enLabel': 'physical system'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q6671777', 'enLabel': 'structure'}, {'itemId': 'Q4330518', 'enLabel': 'research object'}, {'itemId': 'Q2198779', 'enLabel': 'unit'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q30060700', 'enLabel': 'scientific object'}, {'itemId': 'Q7184903', 'enLabel': 'abstract object'}, {'itemId': 'Q16887380', 'enLabel': 'group'}], 'dbPediaTypes': ['City', 'Settlement', 'PopulatedPlace', 'Place', 'AdministrativeRegion', 'Region'], 'dbPediaIri': 'http://dbpedia.org/resource/Matara,_Sri_Lanka', 'supportLen': 2, 'support': [{'wFrom': 21, 'wTo': 21, 'chFrom': 106, 'chTo': 111, 'pMentionGivenSurface': 0.4755784061696658, 'pageRank': 0.01576882035294656, 'prbConfidence': 0.4177732450364021, 'entropy': 1.497646625879448}, {'wFrom': 21, 'wTo': 24, 'chFrom': 106, 'chTo': 123, 'pMentionGivenSurface': 0.7313432835820896, 'pageRank': 0.02424925250080795, 'prbConfidence': 1, 'entropy': 0}]}
# !title :  Matara, Sri Lanka
# *****
# !response.wikiDataItemId :  Q13360574
# ################################
# [{'title': 'Matara, Sri Lanka', 'wikiId': 'Q13360574', 'label': 'Organization', 'characters': [(106, 111), (106, 123)]}]
# [{'characters': [(106, 111), (106, 123)],
#   'label': 'Organization',
#   'title': 'Matara, Sri Lanka',
#   'wikiId': 'Q13360574'}]

# %% [markdown]
# ### Step 3.
# **Relationship Extraction** :  It is the task of extracting semantic relationships from text, which usually occur between two or more entities. These relations can be of different types. E.g “Paris is in France” states a “is in” relationship from Paris to France. This can be denoted using triples, (Paris, is in, France).
# Relation extraction is a crucial technique in automatic knowledge graph construction. By using relation extraction, we can accumulatively extract new relation facts and expand the knowledge graph, which, as a way for machines to understand the human world, has many downstream applications like question answering, recommender system and search engine.
#
# We have used <a href="https://opennre-docs.readthedocs.io/en/latest/get_started/introduction.html" target="_blank">OpenNRE</a> here.
# The following models are available currently:
# - wiki80_cnn_softmax: trained on wiki80 dataset with a CNN encoder.
# - wiki80_bert_softmax: trained on wiki80 dataset with a BERT encoder.
# - wiki80_bertentity_softmax: trained on wiki80 dataset with a BERT encoder (using entity representation concatenation).
# - tacred_bert_softmax: trained on TACRED dataset with a BERT encoder.
# - tacred_bertentity_softmax: trained on TACRED dataset with a BERT encoder (using entity representation concatenation).

# %%
import opennre
model = opennre.get_model('wiki80_bert_softmax')
#model = model.cuda()

entities_threshold = 0.8


relations_list = []
# First get all the entities in the sentence
#entities = wikifier(resolved_text, threshold=entities_threshold)
entities = wikifier(txt, threshold=entities_threshold)
#entities
# Out:
# 2021-08-01 06:27:50,107 - root - INFO - Loading BERT pre-trained checkpoint.
# {'title': 'Catholic Church', 'url': 'http://en.wikipedia.org/wiki/Catholic_Church', 'lang': 'en', 'pageRank': 0.02169495699554522, 'secLang': 'en', 'secTitle': 'Catholic Church', 'secUrl': 'http://en.wikipedia.org/wiki/Catholic_Church', 'wikiDataItemId': 'Q9592', 'wikiDataClasses': [{'itemId': 'Q879146', 'enLabel': 'Christian denomination'}, {'itemId': 'Q34651', 'enLabel': 'Christian Church'}, {'itemId': 'Q13414953', 'enLabel': 'religious denomination'}, {'itemId': 'Q1530022', 'enLabel': 'religious organization'}, {'itemId': 'Q94670589', 'enLabel': 'Christian organization'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q488383', 'enLabel': 'object'}], 'dbPediaTypes': [], 'dbPediaIri': 'http://dbpedia.org/resource/Catholic_Church', 'supportLen': 5, 'support': [{'wFrom': 7, 'wTo': 7, 'chFrom': 31, 'chTo': 35, 'pMentionGivenSurface': 0.05629036171761591, 'pageRank': 0.001866427470238834, 'prbConfidence': 0.1968350329478147, 'entropy': 2.988135591944383}, {'wFrom': 7, 'wTo': 8, 'chFrom': 31, 'chTo': 44, 'pMentionGivenSurface': 0.3324866625749492, 'pageRank': 0.01102430720966058, 'prbConfidence': 0.2252466896722969, 'entropy': 0.4516571554522854}, {'wFrom': 8, 'wTo': 8, 'chFrom': 37, 'chTo': 44, 'pMentionGivenSurface': 0.09027437177230893, 'pageRank': 0.002993240089300437, 'prbConfidence': 0.2606927050688328, 'entropy': 0.9528770275516423}, {'wFrom': 8, 'wTo': 9, 'chFrom': 37, 'chTo': 51, 'pMentionGivenSurface': 0.09153821956590123, 'pageRank': 0.003035145669015751, 'prbConfidence': 0.4511421540096229, 'entropy': 0.2783164620233618}, {'wFrom': 9, 'wTo': 9, 'chFrom': 46, 'chTo': 51, 'pMentionGivenSurface': 0.1098194979066665, 'pageRank': 0.003641300595812188, 'prbConfidence': 0.2251319073244635, 'entropy': 1.026715735064206}]}
# !title :  Catholic Church
# *****
# !response.wikiDataItemId :  Q9592
# ################################
# {'title': 'Matara, Sri Lanka', 'url': 'http://en.wikipedia.org/wiki/Matara,_Sri_Lanka', 'lang': 'en', 'pageRank': 0.04707678261794928, 'secLang': 'en', 'secTitle': 'Matara, Sri Lanka', 'secUrl': 'http://en.wikipedia.org/wiki/Matara,_Sri_Lanka', 'wikiDataItemId': 'Q13360574', 'wikiDataClasses': [{'itemId': 'Q486972', 'enLabel': 'human settlement'}, {'itemId': 'Q82794', 'enLabel': 'geographic region'}, {'itemId': 'Q27096235', 'enLabel': 'artificial geographic entity'}, {'itemId': 'Q177634', 'enLabel': 'community'}, {'itemId': 'Q2221906', 'enLabel': 'geographic location'}, {'itemId': 'Q618123', 'enLabel': 'geographical object'}, {'itemId': 'Q27096213', 'enLabel': 'geographic entity'}, {'itemId': 'Q8205328', 'enLabel': 'artificial physical object'}, {'itemId': 'Q874405', 'enLabel': 'social group'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q17334923', 'enLabel': 'location'}, {'itemId': 'Q58416391', 'enLabel': 'spatial entity'}, {'itemId': 'Q223557', 'enLabel': 'physical object'}, {'itemId': 'Q16686448', 'enLabel': 'artificial entity'}, {'itemId': 'Q58778', 'enLabel': 'system'}, {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q4406616', 'enLabel': 'concrete object'}, {'itemId': 'Q1454986', 'enLabel': 'physical system'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q6671777', 'enLabel': 'structure'}, {'itemId': 'Q4330518', 'enLabel': 'research object'}, {'itemId': 'Q2198779', 'enLabel': 'unit'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q30060700', 'enLabel': 'scientific object'}, {'itemId': 'Q7184903', 'enLabel': 'abstract object'}, {'itemId': 'Q16887380', 'enLabel': 'group'}], 'dbPediaTypes': ['City', 'Settlement', 'PopulatedPlace', 'Place', 'AdministrativeRegion', 'Region'], 'dbPediaIri': 'http://dbpedia.org/resource/Matara,_Sri_Lanka', 'supportLen': 2, 'support': [{'wFrom': 21, 'wTo': 21, 'chFrom': 106, 'chTo': 111, 'pMentionGivenSurface': 0.4755784061696658, 'pageRank': 0.01576882035294656, 'prbConfidence': 0.4177732450364021, 'entropy': 1.497646625879448}, {'wFrom': 21, 'wTo': 24, 'chFrom': 106, 'chTo': 123, 'pMentionGivenSurface': 0.7313432835820896, 'pageRank': 0.02424925250080795, 'prbConfidence': 1, 'entropy': 0}]}
# !title :  Matara, Sri Lanka
# *****
# !response.wikiDataItemId :  Q13360574
# ################################
# [{'title': 'Matara, Sri Lanka', 'wikiId': 'Q13360574', 'label': 'Organization', 'characters': [(106, 111), (106, 123)]}]

# %%
model.infer({'text': 'The Rev. Charles Hewawasam , a Roman Catholic priest who lost a nun and 18 members of his congregation in Matara , Sri Lanka , saw the tsunami as a reaction to ethnic and religious tensions . ', 'h': {'pos': (115, 124)}, 't': {'pos': (106, 112)}})
# Out:
# ('contains administrative territorial entity', 0.6635950803756714)

# %%
model.infer({'text': 'One of the newest auditoriums in New York , built into the bedrock below Carnegie Hall , has added a dose of richness to the concert scene .', 'h': {'pos': (32, 40)}, 't': {'pos': (72, 85)}})
# Out:
# ('occupant', 0.9436891674995422)

# %%
model.infer({'text': "A lot of people wo n't go across the river to Hoboken because , ` Oh , my god , that 's New Jersey .", 'h': {'pos': (87, 97)}, 't': {'pos': (45, 52)}})
# Out:
# ('residence', 0.7096606492996216)

# %%
entities[0]
# Out:
# {'characters': [(106, 111), (106, 123)],
#  'label': 'Organization',
#  'title': 'Matara, Sri Lanka',
#  'wikiId': 'Q13360574'}

# %%
#list(itertools.permutations(entities, 2))[0]

# %%
# Iterate over every permutation pair of entities
relation_threshold = 0.96
for permutation in itertools.permutations(entities, 2):
    for source in permutation[0]['characters']:
        for target in permutation[1]['characters']:
            # Relationship extraction with OpenNRE
            data = model.infer(
                {'text': resolved_text, 'h': {'pos': [source[0], source[1] + 1]}, 't': {'pos': [target[0], target[1] + 1]}})
            if data[1] > relation_threshold:
                print (data[1],permutation[0]['title'],permutation[1]['title'], data[0])
            
                relations_list.append(
                    {'source': permutation[0]['title'], 'target': permutation[1]['title'], 'type': data[0]})

# %%
relations = [dict(y) for y in set(tuple(x.items()) for x in relations_list)]
relations
# Out:
# []

# %%
relation_threshold = 0.96
for permutation in itertools.permutations(entities, 2):
  print(permutation)

# %%
# Iterate over every permutation pair of entities
relation_threshold = 0.96
for permutation in itertools.permutations(entities, 2):
  for source in permutation[0]['characters']:
    for target in permutation[1]['characters']:
      data = model.infer(
                {'text': resolved_text, 'h': {'pos': [source[0], source[1] + 1]}, 't': {'pos': [target[0], target[1] + 1]}})
      if data[1] > relation_threshold:
        print(data[1],permutation[0]['title'],permutation[1]['title'], data[0])
        print(data)

# %% [markdown]
#  ### Step 4.
#  **Knowledge Graph** is a variant of semantic network with added constraints whose scope, structure, characteristics and even uses are not fully realized and in the process of development.
#
#  In our example:
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# For implementation of Knowledge Graphs we need Neo4j using Graph databases, For more information refer [this.](https://medium.com/neo4j/making-sense-of-news-the-knowledge-graph-way-d33810ce5005)

# %% [markdown]
# # Code starts

# %%
import opennre
model = opennre.get_model('wiki80_bert_softmax')
# Out:
# 2021-08-01 06:27:55,479 - root - INFO - Loading BERT pre-trained checkpoint.

# %%
import urllib
from string import punctuation
import nltk
import json
import itertools

#ENTITY_TYPES = ["human", "person", "company", "enterprise", "business", "geographic region",
#                "human settlement", "geographic entity", "territorial entity type", "organization"]
ENTITY_TYPES = ["People", "time", "event", "person", "business", "company", "neighborhood", "deceasedperson", "film", "region", "ethnicity", "location", "country", "administrative_division", "us_county"]

def wikifier(text, lang="en", threshold=-1):
    """Function that fetches entity linking results from wikifier.com API"""
    # Prepare the URL.
    data = urllib.parse.urlencode([
        ("text", text), ("lang", lang),
        ("userKey", "tgbdmkpmkluegqfbawcwjywieevmza"),
        ("pageRankSqThreshold", "%g" %
         threshold), ("applyPageRankSqThreshold", "true"),
        ("nTopDfValuesToIgnore", "100"), ("nWordsToIgnoreFromList", "100"),
        ("wikiDataClasses", "true"), ("wikiDataClassIds", "false"),
        ("support", "true"), ("ranges", "false"), ("minLinkFrequency", "2"),
        ("includeCosines", "false"), ("maxMentionEntropy", "3")
    ])
    url = "http://www.wikifier.org/annotate-article"
    # Call the Wikifier and read the response.
    req = urllib.request.Request(url, data=data.encode("utf8"), method="POST")
    with urllib.request.urlopen(req, timeout=60) as f:
        response = f.read()
        response = json.loads(response.decode("utf8"))
    # Output the annotations.
    results = list()
    i =0;
    for annotation in response["annotations"]:
        print(annotation)
        # Filter out desired entity classes
        #print ("!title : ", annotation['title'])
        #print("*****")
        #print ("!response.wikiDataItemId : ", annotation['wikiDataItemId'])
        #print("################################")
        #print(i)
        if ('wikiDataClasses' in annotation) and (any([el['enLabel'] in ENTITY_TYPES for el in annotation['wikiDataClasses']])):
            for el in annotation['wikiDataClasses']:
              if (el['enLabel'] in ENTITY_TYPES):
                      label = el['enLabel']   
                      break
            results.append({'title': annotation['title'], 'wikiId': annotation['wikiDataItemId'], 'label': label,
                            'characters': [(el['chFrom'], el['chTo']) for el in annotation['support']], 'pagerank':annotation['pageRank']})
    if len(results)>2:
       results = sorted(results.items(), key =lambda kv:(kv[1], kv[0]))
       results = results[-2:]
    
    return results

# %%
txt = "When Ms. Rice arrived in Oslo , Norway , on Wednesday for a meeting with NATO ministers , she declined to comment on the subpoena ."

# %%
doc = nlp(txt)
resolved_text = doc._.coref_resolved
resolved_text
# Out:
# 'When Ms. Rice arrived in Oslo , Norway , on Wednesday for a meeting with NATO ministers , Ms. Rice declined to comment on the subpoena .'

# %%
result = wikifier(resolved_text)
# Out:
# {'title': 'When (Shania Twain song)', 'url': 'http://en.wikipedia.org/wiki/When_(Shania_Twain_song)', 'lang': 'en', 'pageRank': 0.004121085684906071, 'secLang': 'en', 'secTitle': 'When (Shania Twain song)', 'secUrl': 'http://en.wikipedia.org/wiki/When_(Shania_Twain_song)', 'wikiDataItemId': 'Q7992410', 'wikiDataClasses': [{'itemId': 'Q134556', 'enLabel': 'single'}, {'itemId': 'Q2031291', 'enLabel': 'release'}, {'itemId': 'Q732577', 'enLabel': 'publication'}, {'itemId': 'Q2188189', 'enLabel': 'musical work'}, {'itemId': 'Q386724', 'enLabel': 'work'}, {'itemId': 'Q838948', 'enLabel': 'work of art'}, {'itemId': 'Q15401930', 'enLabel': 'product'}, {'itemId': 'Q16686448', 'enLabel': 'artificial entity'}, {'itemId': 'Q17537576', 'enLabel': 'creative work'}, {'itemId': 'Q18593264', 'enLabel': 'item of collection or exhibition'}, {'itemId': 'Q28877', 'enLabel': 'goods'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q551997', 'enLabel': 'wire'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q15621286', 'enLabel': 'intellectual work'}, {'itemId': 'Q223557', 'enLabel': 'physical object'}, {'itemId': 'Q337060', 'enLabel': 'perceptible object'}, {'itemId': 'Q11064354', 'enLabel': 'string'}, {'itemId': 'Q214609', 'enLabel': 'base material'}, {'itemId': 'Q124291', 'enLabel': 'electrical conductor'}, {'itemId': 'Q4406616', 'enLabel': 'concrete object'}, {'itemId': 'Q1454986', 'enLabel': 'physical system'}, {'itemId': 'Q2424752', 'enLabel': 'product'}, {'itemId': 'Q517596', 'enLabel': 'mechanism'}, {'itemId': 'Q266328', 'enLabel': 'joining technology'}, {'itemId': 'Q1865992', 'enLabel': 'cord'}, {'itemId': 'Q28555911', 'enLabel': 'ordinary matter'}, {'itemId': 'Q26717101', 'enLabel': 'conductor'}, {'itemId': 'Q58778', 'enLabel': 'system'}, {'itemId': 'Q30060700', 'enLabel': 'scientific object'}, {'itemId': 'Q8205328', 'enLabel': 'artificial physical object'}, {'itemId': 'Q2695280', 'enLabel': 'technique'}, {'itemId': 'Q2844972', 'enLabel': 'braid'}, {'itemId': 'Q6005984', 'enLabel': 'baryonic matter'}, {'itemId': 'Q6671777', 'enLabel': 'structure'}, {'itemId': 'Q1914636', 'enLabel': 'activity'}, {'itemId': 'Q3249551', 'enLabel': 'process'}, {'itemId': 'Q4026292', 'enLabel': 'action'}, {'itemId': 'Q28823', 'enLabel': 'textile'}, {'itemId': 'Q28921572', 'enLabel': 'common matter'}, {'itemId': 'Q20937557', 'enLabel': 'series'}, {'itemId': 'Q1190554', 'enLabel': 'occurrence'}, {'itemId': 'Q1150070', 'enLabel': 'change'}, {'itemId': 'Q35758', 'enLabel': 'matter'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}, {'itemId': 'Q28728771', 'enLabel': 'material substance'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q28732711', 'enLabel': 'physical substance'}], 'dbPediaTypes': ['Work', 'MusicalWork', 'Single'], 'dbPediaIri': 'http://dbpedia.org/resource/When_(Shania_Twain_song)', 'supportLen': 1, 'support': [{'wFrom': 0, 'wTo': 0, 'chFrom': 0, 'chTo': 3, 'pMentionGivenSurface': 0.00014517249603368, 'pageRank': 8.315032642686583e-06, 'prbConfidence': 0.2357137710085675, 'entropy': 2.270609062508543}]}
# {'title': 'Ms.', 'url': 'http://en.wikipedia.org/wiki/Ms%2e', 'lang': 'en', 'pageRank': 0.006211494827700966, 'secLang': 'en', 'secTitle': 'Ms.', 'secUrl': 'http://en.wikipedia.org/wiki/Ms%2e', 'wikiDataItemId': 'Q1951543', 'wikiDataClasses': [{'itemId': 'Q5378582', 'enLabel': 'English honorific'}, {'itemId': 'Q1326966', 'enLabel': 'honorific'}, {'itemId': 'Q207869', 'enLabel': 'epithet'}, {'itemId': 'Q3320743', 'enLabel': 'title of honor'}, {'itemId': 'Q1200750', 'enLabel': 'description'}, {'itemId': 'Q4189293', 'enLabel': 'rank'}, {'itemId': 'Q618779', 'enLabel': 'award'}, {'itemId': 'Q216353', 'enLabel': 'title'}, {'itemId': 'Q2063340', 'enLabel': 'sensemaking'}, {'itemId': 'Q234460', 'enLabel': 'text'}, {'itemId': 'Q4120621', 'enLabel': 'rank'}, {'itemId': 'Q4164871', 'enLabel': 'position'}, {'itemId': 'Q82799', 'enLabel': 'name'}, {'itemId': 'Q21142755', 'enLabel': 'recognition'}, {'itemId': 'Q4372150', 'enLabel': 'bounty'}, {'itemId': 'Q230788', 'enLabel': 'grant'}, {'itemId': 'Q23009538', 'enLabel': 'addition'}, {'itemId': 'Q3249551', 'enLabel': 'process'}, {'itemId': 'Q11028', 'enLabel': 'information'}, {'itemId': 'Q47461344', 'enLabel': 'written work'}, {'itemId': 'Q184754', 'enLabel': 'string'}, {'itemId': 'Q5127848', 'enLabel': 'class'}, {'itemId': 'Q24017414', 'enLabel': 'first-order metaclass'}, {'itemId': 'Q214339', 'enLabel': 'role'}, {'itemId': 'Q3695082', 'enLabel': 'sign'}, {'itemId': 'Q8171', 'enLabel': 'word'}, {'itemId': 'Q3265221', 'enLabel': 'identification'}, {'itemId': 'Q1414816', 'enLabel': 'incentive'}, {'itemId': 'Q859031', 'enLabel': 'stimulus'}, {'itemId': 'Q760120', 'enLabel': 'expenditure'}, {'itemId': 'Q23009459', 'enLabel': 'connection'}, {'itemId': 'Q1190554', 'enLabel': 'occurrence'}, {'itemId': 'Q1150070', 'enLabel': 'change'}, {'itemId': 'Q20937557', 'enLabel': 'series'}, {'itemId': 'Q7184903', 'enLabel': 'abstract object'}, {'itemId': 'Q17537576', 'enLabel': 'creative work'}, {'itemId': 'Q386724', 'enLabel': 'work'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q23959932', 'enLabel': 'fixed-order metaclass'}, {'itemId': 'Q4897819', 'enLabel': 'role'}, {'itemId': 'Q9081', 'enLabel': 'knowledge'}, {'itemId': 'Q2944660', 'enLabel': 'lexical item'}, {'itemId': 'Q187931', 'enLabel': 'phrase'}, {'itemId': 'Q744778', 'enLabel': 'association'}, {'itemId': 'Q1321905', 'enLabel': 'reinforcement'}, {'itemId': 'Q240673', 'enLabel': 'cost'}, {'itemId': 'Q4026292', 'enLabel': 'action'}, {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q15621286', 'enLabel': 'intellectual work'}, {'itemId': 'Q15401930', 'enLabel': 'product'}, {'itemId': 'Q16686448', 'enLabel': 'artificial entity'}, {'itemId': 'Q23960977', 'enLabel': '(meta)class'}, {'itemId': 'Q19361238', 'enLabel': 'Wikidata metaclass'}, {'itemId': 'Q1207505', 'enLabel': 'quality'}, {'itemId': 'Q492', 'enLabel': 'memory'}, {'itemId': 'Q1048607', 'enLabel': 'conviction'}, {'itemId': 'Q20817253', 'enLabel': 'linguistic unit'}, {'itemId': 'Q111352', 'enLabel': 'lexeme'}, {'itemId': 'Q12767945', 'enLabel': 'language device'}, {'itemId': 'Q1786828', 'enLabel': 'constituent'}, {'itemId': 'Q781413', 'enLabel': 'mental process'}, {'itemId': 'Q54989186', 'enLabel': 'mental state'}, {'itemId': 'Q20679883', 'enLabel': 'psychological theory'}, {'itemId': 'Q1499548', 'enLabel': 'monetary value'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q551997', 'enLabel': 'wire'}, {'itemId': 'Q19478619', 'enLabel': 'metaclass'}, {'itemId': 'Q21522864', 'enLabel': 'class or metaclass of Wikidata ontology'}, {'itemId': 'Q937228', 'enLabel': 'property'}, {'itemId': 'Q14819853', 'enLabel': 'learning or memory'}, {'itemId': 'Q34394', 'enLabel': 'belief'}, {'itemId': 'Q29651519', 'enLabel': 'mental object'}, {'itemId': 'Q5371079', 'enLabel': 'emic unit'}, {'itemId': 'Q2996394', 'enLabel': 'biological process'}, {'itemId': 'Q14912053', 'en ...
# {'title': 'Oslo', 'url': 'http://en.wikipedia.org/wiki/Oslo', 'lang': 'en', 'pageRank': 0.06611331737596278, 'secLang': 'en', 'secTitle': 'Oslo', 'secUrl': 'http://en.wikipedia.org/wiki/Oslo', 'wikiDataItemId': 'Q585', 'wikiDataClasses': [{'itemId': 'Q5119', 'enLabel': 'capital'}, {'itemId': 'Q1549591', 'enLabel': 'big city'}, {'itemId': 'Q515', 'enLabel': 'city'}, {'itemId': 'Q1306755', 'enLabel': 'administrative centre'}, {'itemId': 'Q486972', 'enLabel': 'human settlement'}, {'itemId': 'Q7930989', 'enLabel': 'city/town'}, {'itemId': 'Q177634', 'enLabel': 'community'}, {'itemId': 'Q702492', 'enLabel': 'urban area'}, {'itemId': 'Q2221906', 'enLabel': 'geographic location'}, {'itemId': 'Q82794', 'enLabel': 'geographic region'}, {'itemId': 'Q27096235', 'enLabel': 'artificial geographic entity'}, {'itemId': 'Q3257686', 'enLabel': 'locality'}, {'itemId': 'Q874405', 'enLabel': 'social group'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q15042037', 'enLabel': 'statistical territorial entity'}, {'itemId': 'Q17334923', 'enLabel': 'location'}, {'itemId': 'Q618123', 'enLabel': 'geographical object'}, {'itemId': 'Q27096213', 'enLabel': 'geographic entity'}, {'itemId': 'Q8205328', 'enLabel': 'artificial physical object'}, {'itemId': 'Q58778', 'enLabel': 'system'}, {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'}, {'itemId': 'Q58416391', 'enLabel': 'spatial entity'}, {'itemId': 'Q223557', 'enLabel': 'physical object'}, {'itemId': 'Q16686448', 'enLabel': 'artificial entity'}, {'itemId': 'Q6671777', 'enLabel': 'structure'}, {'itemId': 'Q4330518', 'enLabel': 'research object'}, {'itemId': 'Q2198779', 'enLabel': 'unit'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q1496967', 'enLabel': 'territorial entity'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q4406616', 'enLabel': 'concrete object'}, {'itemId': 'Q1454986', 'enLabel': 'physical system'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q7184903', 'enLabel': 'abstract object'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q30060700', 'enLabel': 'scientific object'}], 'dbPediaTypes': ['Settlement', 'PopulatedPlace', 'Place', 'AdministrativeRegion', 'Region'], 'dbPediaIri': 'http://dbpedia.org/resource/Oslo', 'supportLen': 2, 'support': [{'wFrom': 6, 'wTo': 6, 'chFrom': 25, 'chTo': 28, 'pMentionGivenSurface': 0.4115526718933045, 'pageRank': 0.0235724671991848, 'prbConfidence': 0.2411024920119854, 'entropy': 0.3737311092139872}, {'wFrom': 6, 'wTo': 8, 'chFrom': 25, 'chTo': 37, 'pMentionGivenSurface': 0.2106135986733002, 'pageRank': 0.01206329708318778, 'prbConfidence': 1, 'entropy': 0}]}
# {'title': 'Norway', 'url': 'http://en.wikipedia.org/wiki/Norway', 'lang': 'en', 'pageRank': 0.05156403227960502, 'secLang': 'en', 'secTitle': 'Norway', 'secUrl': 'http://en.wikipedia.org/wiki/Norway', 'wikiDataItemId': 'Q20', 'wikiDataClasses': [{'itemId': 'Q3624078', 'enLabel': 'sovereign state'}, {'itemId': 'Q6256', 'enLabel': 'country'}, {'itemId': 'Q41614', 'enLabel': 'constitutional monarchy'}, {'itemId': 'Q7275', 'enLabel': 'state'}, {'itemId': 'Q1048835', 'enLabel': 'political territorial entity'}, {'itemId': 'Q7269', 'enLabel': 'monarchy'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q177634', 'enLabel': 'community'}, {'itemId': 'Q155076', 'enLabel': 'juridical person'}, {'itemId': 'Q56061', 'enLabel': 'administrative territorial entity'}, {'itemId': 'Q1896989', 'enLabel': 'subject of international law'}, {'itemId': 'Q1063239', 'enLabel': 'polity'}, {'itemId': 'Q96196009', 'enLabel': 'state (former and current)'}, {'itemId': 'Q15642541', 'enLabel': 'human-geographic territorial entity'}, {'itemId': 'Q22676587', 'enLabel': 'monarchic system'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q874405', 'enLabel': 'social group'}, {'itemId': 'Q3778211', 'enLabel': 'legal person'}, {'itemId': 'Q12047392', 'enLabel': 'legal form'}, {'itemId': 'Q7210356', 'enLabel': 'political organisation'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q1496967', 'enLabel': 'territorial entity'}, {'itemId': 'Q16686448', 'enLabel': 'artificial entity'}, {'itemId': 'Q1307214', 'enLabel': 'form of government'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q58778', 'enLabel': 'system'}, {'itemId': 'Q7887142', 'enLabel': 'unit of analysis'}, {'itemId': 'Q26720107', 'enLabel': 'subject of a right'}, {'itemId': 'Q16889133', 'enLabel': 'class'}, {'itemId': 'Q82794', 'enLabel': 'geographic region'}, {'itemId': 'Q183039', 'enLabel': 'form of state'}, {'itemId': 'Q2752458', 'enLabel': 'administrative type'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q6671777', 'enLabel': 'structure'}, {'itemId': 'Q4330518', 'enLabel': 'research object'}, {'itemId': 'Q2198779', 'enLabel': 'unit'}, {'itemId': 'Q830077', 'enLabel': 'subject'}, {'itemId': 'Q5127848', 'enLabel': 'class'}, {'itemId': 'Q618123', 'enLabel': 'geographical object'}, {'itemId': 'Q27096213', 'enLabel': 'geographic entity'}, {'itemId': 'Q2221906', 'enLabel': 'geographic location'}, {'itemId': 'Q28108', 'enLabel': 'political system'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q7184903', 'enLabel': 'abstract object'}, {'itemId': 'Q58416391', 'enLabel': 'spatial entity'}, {'itemId': 'Q17334923', 'enLabel': 'location'}, {'itemId': 'Q1639378', 'enLabel': 'social system'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}], 'dbPediaTypes': ['PopulatedPlace', 'Place', 'Country'], 'dbPediaIri': 'http://dbpedia.org/resource/Norway', 'supportLen': 1, 'support': [{'wFrom': 8, 'wTo': 8, 'chFrom': 32, 'chTo': 37, 'pMentionGivenSurface': 0.3577934055798939, 'pageRank': 0.02049330229911182, 'prbConfidence': 0.2784215396111993, 'entropy': 1.15896669804641}]}
# {'title': 'Sheffield Wednesday F.C.', 'url': 'http://en.wikipedia.org/wiki/Sheffield_Wednesday_F%2eC%2e', 'lang': 'en', 'pageRank': 0.00438394520343681, 'secLang': 'en', 'secTitle': 'Sheffield Wednesday F.C.', 'secUrl': 'http://en.wikipedia.org/wiki/Sheffield_Wednesday_F%2eC%2e', 'wikiDataItemId': 'Q19498', 'wikiDataClasses': [{'itemId': 'Q476028', 'enLabel': 'association football club'}, {'itemId': 'Q17270000', 'enLabel': 'football club'}, {'itemId': 'Q847017', 'enLabel': 'sports club'}, {'itemId': 'Q4438121', 'enLabel': 'sports organization'}, {'itemId': 'Q988108', 'enLabel': 'club'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q48204', 'enLabel': 'voluntary association'}, {'itemId': 'Q155076', 'enLabel': 'juridical person'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q79913', 'enLabel': 'non-governmental organization'}, {'itemId': 'Q15911314', 'enLabel': 'association'}, {'itemId': 'Q3778211', 'enLabel': 'legal person'}, {'itemId': 'Q12047392', 'enLabel': 'legal form'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q163740', 'enLabel': 'nonprofit organization'}, {'itemId': 'Q895526', 'enLabel': 'organ'}, {'itemId': 'Q26720107', 'enLabel': 'subject of a right'}, {'itemId': 'Q16889133', 'enLabel': 'class'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q2101636', 'enLabel': 'political power'}, {'itemId': 'Q830077', 'enLabel': 'subject'}, {'itemId': 'Q5127848', 'enLabel': 'class'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q25107', 'enLabel': 'power'}, {'itemId': 'Q7184903', 'enLabel': 'abstract object'}, {'itemId': 'Q488383', 'enLabel': 'object'}, {'itemId': 'Q18340964', 'enLabel': 'power'}], 'dbPediaTypes': ['Agent', 'Organisation', 'SoccerClub', 'SportsTeam'], 'dbPediaIri': 'http://dbpedia.org/resource/Sheffield_Wednesday_F.C.', 'supportLen': 1, 'support': [{'wFrom': 11, 'wTo': 11, 'chFrom': 44, 'chTo': 52, 'pMentionGivenSurface': 0.00394269340974212, 'pageRank': 0.000225825313319027, 'prbConfidence': 0.2434251069320076, 'entropy': 1.9846303469449}]}
# {'title': 'Trump Tower meeting', 'url': 'http://en.wikipedia.org/wiki/Trump_Tower_meeting', 'lang': 'en', 'pageRank': 0.006495706109211948, 'secLang': 'en', 'secTitle': 'Trump Tower meeting', 'secUrl': 'http://en.wikipedia.org/wiki/Trump_Tower_meeting', 'wikiDataItemId': 'Q33015021', 'wikiDataClasses': [{'itemId': 'Q2761147', 'enLabel': 'meeting'}, {'itemId': 'Q1656682', 'enLabel': 'event'}, {'itemId': 'Q61788060', 'enLabel': 'human activity'}, {'itemId': 'Q602884', 'enLabel': 'social phenomenon'}, {'itemId': 'Q1190554', 'enLabel': 'occurrence'}, {'itemId': 'Q1914636', 'enLabel': 'activity'}, {'itemId': 'Q483247', 'enLabel': 'phenomenon'}, {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}, {'itemId': 'Q4026292', 'enLabel': 'action'}, {'itemId': 'Q20937557', 'enLabel': 'series'}, {'itemId': 'Q16722960', 'enLabel': 'phenomenon'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q488383', 'enLabel': 'object'}], 'dbPediaTypes': [], 'dbPediaIri': '', 'supportLen': 1, 'support': [{'wFrom': 13, 'wTo': 14, 'chFrom': 58, 'chTo': 66, 'pMentionGivenSurface': 0.0002486943546381497, 'pageRank': 1.424444528658056e-05, 'prbConfidence': 0.8063829803660527, 'entropy': 0.9182958340544897}]}
# {'title': '2018 Russia–United States summit', 'url': 'http://en.wikipedia.org/wiki/2018_Russia%e2%80%93United_States_summit', 'lang': 'en', 'pageRank': 0.01561481206993901, 'secLang': 'en', 'secTitle': '2018 Russia–United States summit', 'secUrl': 'http://en.wikipedia.org/wiki/2018_Russia%e2%80%93United_States_summit', 'wikiDataItemId': 'Q55230658', 'wikiDataClasses': [{'itemId': 'Q1072326', 'enLabel': 'summit'}, {'itemId': 'Q17195514', 'enLabel': 'political conference'}, {'itemId': 'Q625994', 'enLabel': 'convention'}, {'itemId': 'Q2761147', 'enLabel': 'meeting'}, {'itemId': 'Q1656682', 'enLabel': 'event'}, {'itemId': 'Q61788060', 'enLabel': 'human activity'}, {'itemId': 'Q602884', 'enLabel': 'social phenomenon'}, {'itemId': 'Q1190554', 'enLabel': 'occurrence'}, {'itemId': 'Q1914636', 'enLabel': 'activity'}, {'itemId': 'Q483247', 'enLabel': 'phenomenon'}, {'itemId': 'Q26907166', 'enLabel': 'temporal entity'}, {'itemId': 'Q4026292', 'enLabel': 'action'}, {'itemId': 'Q20937557', 'enLabel': 'series'}, {'itemId': 'Q16722960', 'enLabel': 'phenomenon'}, {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q488383', 'enLabel': 'object'}], 'dbPediaTypes': [], 'dbPediaIri': '', 'supportLen': 1, 'support': [{'wFrom': 14, 'wTo': 14, 'chFrom': 60, 'chTo': 66, 'pMentionGivenSurface': 0.0008727272727272727, 'pageRank': 4.998712537949709e-05, 'prbConfidence': 0.2074431723797511, 'entropy': 2.809162162316192}]}
# {'title': 'NATO', 'url': 'http://en.wikipedia.org/wiki/NATO', 'lang': 'en', 'pageRank': 0.05282371877396369, 'secLang': 'en', 'secTitle': 'NATO', 'secUrl': 'http://en.wikipedia.org/wiki/NATO', 'wikiDataItemId': 'Q7184', 'wikiDataClasses': [{'itemId': 'Q1127126', 'enLabel': 'military alliance'}, {'itemId': 'Q245065', 'enLabel': 'intergovernmental organization'}, {'itemId': 'Q484652', 'enLabel': 'international organization'}, {'itemId': 'Q878249', 'enLabel': 'alliance'}, {'itemId': 'Q17149090', 'enLabel': 'armed organization'}, {'itemId': 'Q7210356', 'enLabel': 'political organisation'}, {'itemId': 'Q1896989', 'enLabel': 'subject of international law'}, {'itemId': 'Q43229', 'enLabel': 'organization'}, {'itemId': 'Q3778211', 'enLabel': 'legal person'}, {'itemId': 'Q24229398', 'enLabel': 'agent'}, {'itemId': 'Q16334295', 'enLabel': 'group of humans'}, {'itemId': 'Q26720107', 'enLabel': 'subject of a right'}, {'itemId': 'Q23958946', 'enLabel': 'individual entity'}, {'itemId': 'Q16334298', 'enLabel': 'group of living things'}, {'itemId': 'Q830077', 'enLabel': 'subject'}, {'itemId': 'Q35120', 'enLabel': 'entity'}, {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'}, {'itemId': 'Q517966', 'enLabel': 'structure'}, {'itemId': 'Q16887380', 'enLabel': 'group'}, {'itemId': 'Q488383', 'enLabel': 'object'}], 'dbPediaTypes': ['Agent', 'Place', 'Organisation'], 'dbPediaIri': 'http://dbpedia.org/resource/NATO', 'supportLen': 1, 'support': [{'wFrom': 16, 'wTo': 16, 'chFrom': 73, 'chTo': 76, 'pMentionGivenSurface': 0.4415964478530703, 'pageRank': 0.02529328198600955, 'prbConfidence': 0.2969403198019516, 'entropy': 0.1212127118478396}]}
# {'title': 'Cabinet (government)', 'url': 'http://en.wikipedia.org/wiki/Cabinet_(government)', 'lang': 'en', 'pageRank': 0.01613129241599919, 'secLang': 'en', 'secTitle': 'Cabinet (government)', 'secUrl': 'http://en.wikipedia.org/wiki/Cabinet_(government)', 'wikiDataItemId': 'Q640506', 'wikiDataClasses': [], 'dbPediaTypes': ['Agent'], 'dbPediaIri': 'http://dbpedia.org/resource/Council_of_Ministers', 'supportLen': 1, 'support': [{'wFrom': 17, 'wTo': 17, 'chFrom': 78, 'chTo': 86, 'pMentionGivenSurface': 0.007918658930697561, 'pageRank': 0.0004535563505071653, 'prbConfidence': 0.1238684713261985, 'entropy': 2.247995245101242}]}
# {'title': 'Declension', 'url': 'http://en.wikipedia.org/wiki/Declension', 'lang': 'en', 'pageRank': 0.003629601655868443, 'secLang': 'en', 'secTitle': 'Declension', 'secUrl': 'http://en.wikipedia.org/wiki/Declension', 'wikiDataItemId': 'Q188078', 'wikiDataClasses': [], 'dbPediaTypes': [], 'dbPediaIri': 'http://dbpedia.org/resource/Declension', 'supportLen': 1, 'support': [{'wFrom': 22, 'wTo': 22, 'chFrom': 99, 'chTo': 106, 'pMentionGivenSurface': 0.0009998806112702962, 'pageRank': 5.727007627927722e-05, 'prbConfidence': 0.834556860313917, 'entropy': 0.2580186686648155}]}
# {'title': 'Political criticism', 'url': 'http://en.wikipedia.org/wiki/Political_criticism', 'lang': 'en', 'pageRank': 0.004184668638091965, 'secLang': 'en', 'secTitle': 'Political criticism', 'secUrl': 'http://en.wikipedia.org/wiki/Political_criticism', 'wikiDataItemId': 'Q7210274', 'wikiDataClasses': [], 'dbPediaTypes': [], 'dbPediaIri': 'http://dbpedia.org/resource/Political_criticism', 'supportLen': 1, 'support': [{'wFrom': 24, 'wTo': 24, 'chFrom': 111, 'chTo': 117, 'pMentionGivenSurface': 0.00220531480868894, 'pageRank': 0.0001263136277369951, 'prbConfidence': 0.5444204481416125, 'entropy': 0.7090255510923709}]}
# {'title': 'Subpoena', 'url': 'http://en.wikipedia.org/wiki/Subpoena', 'lang': 'en', 'pageRank': 0.02661157034952249, 'secLang': 'en', 'secTitle': 'Subpoena', 'secUrl': 'http://en.wikipedia.org/wiki/Subpoena', 'wikiDataItemId': 'Q5608642', 'wikiDataClasses': [], 'dbPediaTypes': [], 'dbPediaIri': 'http://dbpedia.org/resource/Subpoena', 'supportLen': 1, 'support': [{'wFrom': 27, 'wTo': 27, 'chFrom': 126, 'chTo': 133, 'pMentionGivenSurface': 0.2616541353383459, 'pageRank': 0.01498674153764997, 'prbConfidence': 0.677511754275777, 'entropy': 0.1027797290648276}]}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-187-c230ed6d7bc1> in <module>()
# ----> 1 result = wikifier(resolved_text)
#
# <ipython-input-184-c384ade1792c> in wikifier(text, lang, threshold)
#      47                             'characters': [(el['chFrom'], el['chTo']) for el in annotation['support']], 'pagerank':annotation['pageRank']})
#      48     if len(results)>2:
# ---> 49        results = sorted(results.items(), key =lambda kv:(kv[1], kv[0]))
#      50        results = results[-2:]
#      51
#
# AttributeError: 'list' object has no attribute 'items'

# %%
for el in result:
  print(el)

# %%
for el in result:
    print(el)
# Out:
# {'title': 'Oslo', 'wikiId': 'Q585', 'label': 'location', 'characters': [(25, 28), (25, 37)], 'pagerank': 0.06611331737596278}
# {'title': 'Norway', 'wikiId': 'Q20', 'label': 'country', 'characters': [(32, 37)], 'pagerank': 0.05156403227960502}
# {'title': 'Trump Tower meeting', 'wikiId': 'Q33015021', 'label': 'event', 'characters': [(58, 66)], 'pagerank': 0.006495706109211948}
# {'title': '2018 Russia–United States summit', 'wikiId': 'Q55230658', 'label': 'event', 'characters': [(60, 66)], 'pagerank': 0.01561481206993901}

# %%
print(result)
# Out:
# [{'title': 'Oslo', 'wikiId': 'Q585', 'label': 'location', 'characters': [(25, 28), (25, 37)]}]

# %%
loc = '/'+ result[0]['label'] + '/' + result[1]['label'] + '/'

# %%
loc
# Out:
# '/location/location/'

# %%
key_value ={}   

# Initializing the value
key_value[2] = 56      
key_value[1] = 2
key_value[5] = 12
key_value[4] = 24
key_value[6] = 18     
key_value[3] = 323

# %%
/len(key_value)
# Out:
# 6

# %%
key_value =sorted(key_value.items(), key =lambda kv:(kv[1], kv[0]))

# %%
print(key_value)
# Out:
# [(1, 2), (5, 12), (6, 18), (4, 24), (2, 56), (3, 323)]

# %%
result = key_value[-2:]

# %%
print(result)
# Out:
# [(2, 56), (3, 323)]

# %%
from google.colab import drive 

drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("drive/MyDrive/Cogni_AI/Hackathon_3/Predictions")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4867865f8914> in <module>()
#       1 import os
# ----> 2 os.chdir("drive/MyDrive/Cogni_AI/Hackathon_3/Predictions")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/Cogni_AI/Hackathon_3/Predictions'

# %%
import pandas as pd

# %%
test_df = pd.read_excel('Submission_Entity_874384_1.xlsx')

# %%
test_df.head()
# Out:
#                                                 text  ...                                           relation
# 0  The Little Comedy , '' a mannered operetta bas...  ...                   /person/location/after a work by
# 1  A court in Rome acquitted five people accused ...  ...                         /location/location/country
# 2  There were also performers who were born in Lo...  ...                             /person/person/sibling
# 3  When Julian Resuello , the mayor of San Carlos...  ...  /location/country/contains administrative terr...
# 4  When Julian Resuello , the mayor of San Carlos...  ...  /location/country/contains administrative terr...
#
# [5 rows x 4 columns]

# %%
test_df.shape
# Out:
# (11086, 4)

# %%
df = test_df.copy()

# %%
df.text
# Out:
# 0        The Little Comedy , '' a mannered operetta bas...
# 1        A court in Rome acquitted five people accused ...
# 2        There were also performers who were born in Lo...
# 3        When Julian Resuello , the mayor of San Carlos...
# 4        When Julian Resuello , the mayor of San Carlos...
#                                ...
# 11081    Staten Island Steve Whalen , an aspiring filmm...
# 11082    Lukacs , a distinguished historian of 20th-cen...
# 11083    Since accepting an invitation in 1996 from the...
# 11084    LOYOLA , MD. 62 , ST. PETER 'S 55 -- Michael T...
# 11085    It became a Shiite pilgrimage center after the...
# Name: text, Length: 11086, dtype: object

# %%
df.shape
# Out:
# (11086, 4)

# %%
df.drop_duplicates(subset ="text",
                     keep = False, inplace = True)

# %%
df.shape
# Out:
# (5503, 4)

# %%
data = df.text.values

# %%
data = data.to_string
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-c0dcdba1a15c> in <module>()
# ----> 1 data = data.to_string()
#
# AttributeError: 'function' object has no attribute 'to_string'

# %%
# Out:
# "The Little Comedy , '' a mannered operetta based on a short story by Arthur Schnitzler set in fin-de-si Ã¨cle Vienna , opens the evening ."

# %%
import opennre
model = opennre.get_model('wiki80_bert_softmax')
#model = model.cuda()

entities_threshold = 0.8


'''
relations_list = []
# First get all the entities in the sentence
#entities = wikifier(resolved_text, threshold=entities_threshold)
entities = wikifier(txt, threshold=entities_threshold)
#entities
'''
# Out:
# 2021-08-01 06:28:03,870 - root - INFO - Loading BERT pre-trained checkpoint.
# '\nrelations_list = []\n# First get all the entities in the sentence\n#entities = wikifier(resolved_text, threshold=entities_threshold)\nentities = wikifier(txt, threshold=entities_threshold)\n#entities\n'

# %%
def fun_rel(df):
  wikified_test=[]
  threshold_wiki = 0.8
  relation_threshold = 0.8
  relation_lst = ['nationality', 'locations', 'children', 'advisors', 'majorshareholders', 'place_lived', 'place_founded', 'neighborhood_of','place_of_death', 'featured_film_locations', 'capital', 'founders', 
  'geographic_distribution', 'administrative_divisions', 'place_of_burial', 'company', 'contains', 'country', 'county_seat', 'religion', 'place_of_birth', 'ethnicity']
  for index, row in df.iterrows():
    try:    
      print("Itr:", index)
      entities = wikifier(row['text'], threshold=threshold_wiki)
      max=[ 'NA' ,relation_threshold]
      for permutation in itertools.permutations(entities, 2):
        for source in permutation[0]['characters']:
          for target in permutation[1]['characters']:
            data = model.infer({'text': row['text'], 'h': {'pos': [source[0], source[1] + 1]}, 't': {'pos': [target[0], target[1] + 1]}})
            if data[1] > max[1]:   # and data[0] in relation_lst
              max = data
            #print(data[1],permutation[0]['title'],permutation[1]['title'], data[0])
            #print(data)
      if (len(entities) > 1):
        df.loc[index, 'h_name'] = entities[0]['title']
        df.loc[index,'t_name'] = entities[1]['title'] 
        df.loc[index,'relation'] = '/'+ entities[0]['label'] + '/' + entities[1]['label'] + '/' + max[0]
        if (max[0] == 'NA'):
          df.loc[index,'relation'] = 'NA'
      else:
        continue
    except:
      print("Error at index:{}".format(index))
  return df

# %%
def fun_rel(df):
  wikified_test=[]
  threshold_wiki = 0.8
  relation_threshold = 0.8
  relation_lst = ['nationality', 'locations', 'children', 'advisors', 'majorshareholders', 'place_lived', 'place_founded', 'neighborhood_of','place_of_death', 'featured_film_locations', 'capital', 'founders', 
  'geographic_distribution', 'administrative_divisions', 'place_of_burial', 'company', 'contains', 'country', 'county_seat', 'religion', 'place_of_birth', 'ethnicity']
  for index, row in df.iterrows():
    '''
    try:    
      print("Itr:", index)
      entities = wikifier(row['text'], threshold=threshold_wiki)
      max=[ 'NA' ,relation_threshold]
      for permutation in itertools.permutations(entities, 2):
        for source in permutation[0]['characters']:
          for target in permutation[1]['characters']:
            data = model.infer({'text': row['text'], 'h': {'pos': [source[0], source[1] + 1]}, 't': {'pos': [target[0], target[1] + 1]}})
            if data[1] > max[1]:   # and data[0] in relation_lst
              max = data
              #print(data[1],permutation[0]['title'],permutation[1]['title'], data[0])
              #print(data)
      if (len(entities) > 1):
        df.loc[index, 'h_name'] = entities[0]['title']
        df.loc[index,'t_name'] = entities[1]['title'] 
        df.loc[index,'relation'] = '/'+ entities[0]['label'] + '/' + entities[1]['label'] + '/' + max[0]
        if (max[0] == 'NA'):
          df.loc[index,'relation'] = 'NA'
      else:
      continue
    except:
    print("Error at index:{}".format(index))
    '''
  return df

# %%
"""
for i in range(11):
  start = int(i*1000)
  end = int(i*1000)+1000
  df_ = test_df.loc[start:end]
  df_ = fun_rel(df_)
  name = 'pred_'+str(i)+'.xlsx'
  df_.to_excel(name)
  print("completed:", str(i+1))

df_ = test_df.loc[11000:]
df_ = fun_rel(df_)
name = 'pred_12.xlsx'
df_.to_excel(name)
print("finish")
"""
# Out:
# '\nfor i in range(11):\n  start = int(i*1000)\n  end = int(i*1000)+1000\n  df_ = test_df.loc[start:end]\n  df_ = fun_rel(df_)\n  name = \'pred_\'+str(i)+\'.xlsx\'\n  df_.to_excel(name)\n  print("completed:", str(i+1))\n\ndf_ = test_df.loc[11000:]\ndf_ = fun_rel(df_)\nname = \'pred_12.xlsx\'\ndf_.to_excel(name)\nprint("finish")\n'

# %%
test_df['text'].isnull().sum()
# Out:
# 0

# %%
df.to_excel('trial_2.xlsx')

# %%
model.infer({'text': 'The Rev. Charles Hewawasam , a Roman Catholic priest who lost a nun and 18 members of his congregation in Matara , Sri Lanka , saw the tsunami as a reaction to ethnic and religious tensions . ', 'h': {'pos': (115, 124)}, 't': {'pos': (106, 112)}})
# Out:
# ('contains administrative territorial entity', 0.6635950803756714)

# %%
# Iterate over every permutation pair of entities
relation_threshold = 0.96
for permutation in itertools.permutations(entities, 2):
  for source in permutation[0]['characters']:
    for target in permutation[1]['characters']:
      data = model.infer(
                {'text': resolved_text, 'h': {'pos': [source[0], source[1] + 1]}, 't': {'pos': [target[0], target[1] + 1]}})
      if data[1] > relation_threshold:
        print(data[1],permutation[0]['title'],permutation[1]['title'], data[0])
        print(data)

# %% [markdown]
# # Working on predictions

# %%
import pandas as pd

# %%
df = pd.read_excel('pred_0.xlsx')

# %%
df.shape
# Out:
# (1001, 5)

# %%
df.head()
# Out:
#    Unnamed: 0  ...                                 relation
# 0        1000  ...  /country/location/headquarters location
# 1        1001  ...               /person/location/residence
# 2        1002  ...                /location/country/country
# 3        1003  ...                /location/country/country
# 4        1004  ...                                      NaN
#
# [5 rows x 5 columns]

# %%
df.drop

# %%
for i in range(1,12):
  name = 'pred_'+str(i)+'.xlsx'
  df_ = pd.read_excel(name)
  df_.drop(index=df_.index[0],axis=0,inplace=True)
  df = df.append(df_, ignore_index = True)

# %%
df.shape
# Out:
# (11086, 5)

# %%
df.head(1)
# Out:
#    ind  ...                          relation
# 0    0  ...  /person/location/after a work by
#
# [1 rows x 5 columns]

# %%
df.columns = ['ind','text','h_name','t_name','relation']

# %%
i=0
lst=[]
for index, row in df.iterrows():
  if (i != row['ind']):
    lst.append(i)
  i=i+1
print(len(lst))
# Out:
# 0

# %%
lst
# Out:
# []

# %%
#df_final = df.drop(columns=['ind'], axis=1)
df.to_excel('Submission_Entity_874384.xlsx', index=False)

# %%
df = pd.read_excel('final_prediction.xlsx')

# %%
df.shape
# Out:
# (11086, 5)

# %%
df.isnull().sum()
# Out:
# text              10
# h_name             0
# t_name             0
# relation           0
# Final_relation     0
# dtype: int64

# %%
df['t_name'].fillna('NA', inplace = True)

# %%
df.head()
# Out:
#    ind  ...                                           relation
# 0    0  ...                   /person/location/after a work by
# 1    1  ...                         /location/location/country
# 2    2  ...                             /person/person/sibling
# 3    3  ...  /location/country/contains administrative terr...
# 4    4  ...  /location/country/contains administrative terr...
#
# [5 rows x 5 columns]

# %%
df_final.head()
# Out:
#                                                 text  ...                                           relation
# 0  The Little Comedy , '' a mannered operetta bas...  ...                   /person/location/after a work by
# 1  A court in Rome acquitted five people accused ...  ...                         /location/location/country
# 2  There were also performers who were born in Lo...  ...                             /person/person/sibling
# 3  When Julian Resuello , the mayor of San Carlos...  ...  /location/country/contains administrative terr...
# 4  When Julian Resuello , the mayor of San Carlos...  ...  /location/country/contains administrative terr...
#
# [5 rows x 4 columns]

# %%
df_final.shape
# Out:
# (11086, 4)

# %% [markdown]
# ## New Changed format

# %%
df = test_df.copy()

# %%
df.head()
# Out:
#                                                 text  ...                                           relation
# 0  The Little Comedy , '' a mannered operetta bas...  ...                   /person/location/after a work by
# 1  A court in Rome acquitted five people accused ...  ...                         /location/location/country
# 2  There were also performers who were born in Lo...  ...                             /person/person/sibling
# 3  When Julian Resuello , the mayor of San Carlos...  ...  /location/country/contains administrative terr...
# 4  When Julian Resuello , the mayor of San Carlos...  ...  /location/country/contains administrative terr...
#
# [5 rows x 4 columns]

# %%
df['Final_relation'] = df['relation']

# %%
df_1 = pd.read_excel('trial_1.xlsx')

# %%
for index, row in df.iterrows():
  try:
    row['Final_relation'] = row['relation'].split('/')[-1]
  except:
    row['relation'] = None 
df.head(20)
# Out:
#                                                  text  ...                              Final_relation
# 0   The Little Comedy , '' a mannered operetta bas...  ...                             after a work by
# 1   A court in Rome acquitted five people accused ...  ...                                     country
# 2   There were also performers who were born in Lo...  ...                                     sibling
# 3   When Julian Resuello , the mayor of San Carlos...  ...  contains administrative territorial entity
# 4   When Julian Resuello , the mayor of San Carlos...  ...  contains administrative territorial entity
# 5   A3 Concern Raised by Libya Deal Alex Salmond ,...  ...                                   residence
# 6   A3 Concern Raised by Libya Deal Alex Salmond ,...  ...                                   residence
# 7   Alex Salmond , the newly elected first ministe...  ...                                   residence
# 8   Alex Salmond , the newly elected first ministe...  ...                                   residence
# 9   Indeed , Mr. ChÃ¡vez said Sunday that he wishe...  ...                      country of citizenship
# 10  Indeed , Mr. ChÃ¡vez said Sunday that he wishe...  ...                      country of citizenship
# 11  They suggest that if elected , he would immedi...  ...                      country of citizenship
# 12  They suggest that if elected , he would immedi...  ...                      country of citizenship
# 13  Another outstanding selection is Alejandro Lan...  ...                      country of citizenship
# 14  Another outstanding selection is Alejandro Lan...  ...                      country of citizenship
# 15  A8 More Criticism for Evo Morales Political op...  ...                      country of citizenship
# 16  A8 More Criticism for Evo Morales Political op...  ...                      country of citizenship
# 17  For example , President Evo Morales of Bolivia...  ...                          head of government
# 18  For example , President Evo Morales of Bolivia...  ...                          head of government
# 19  Evo Morales has put Bolivia on the map , '' sh...  ...                                         NaN
#
# [20 rows x 5 columns]

# %%
df.head(20)
# Out:
#                                                  text  ...                              Final_relation
# 0   The Little Comedy , '' a mannered operetta bas...  ...                             after a work by
# 1   A court in Rome acquitted five people accused ...  ...                                     country
# 2   There were also performers who were born in Lo...  ...                                     sibling
# 3   When Julian Resuello , the mayor of San Carlos...  ...  contains administrative territorial entity
# 4   When Julian Resuello , the mayor of San Carlos...  ...  contains administrative territorial entity
# 5   A3 Concern Raised by Libya Deal Alex Salmond ,...  ...                                   residence
# 6   A3 Concern Raised by Libya Deal Alex Salmond ,...  ...                                   residence
# 7   Alex Salmond , the newly elected first ministe...  ...                                   residence
# 8   Alex Salmond , the newly elected first ministe...  ...                                   residence
# 9   Indeed , Mr. ChÃ¡vez said Sunday that he wishe...  ...                      country of citizenship
# 10  Indeed , Mr. ChÃ¡vez said Sunday that he wishe...  ...                      country of citizenship
# 11  They suggest that if elected , he would immedi...  ...                      country of citizenship
# 12  They suggest that if elected , he would immedi...  ...                      country of citizenship
# 13  Another outstanding selection is Alejandro Lan...  ...                      country of citizenship
# 14  Another outstanding selection is Alejandro Lan...  ...                      country of citizenship
# 15  A8 More Criticism for Evo Morales Political op...  ...                      country of citizenship
# 16  A8 More Criticism for Evo Morales Political op...  ...                      country of citizenship
# 17  For example , President Evo Morales of Bolivia...  ...                          head of government
# 18  For example , President Evo Morales of Bolivia...  ...                          head of government
# 19  Evo Morales has put Bolivia on the map , '' sh...  ...                                         NaN
#
# [20 rows x 5 columns]

# %%
tmp = df.iloc[:1,:]
tmp
# Out:
#                                                 text  ...                          relation
# 0  The Little Comedy , '' a mannered operetta bas...  ...  /person/location/after a work by
#
# [1 rows x 4 columns]

# %%
tmp[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-17e703353a5f> in <module>()
# ----> 1 tmp[3]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 3
